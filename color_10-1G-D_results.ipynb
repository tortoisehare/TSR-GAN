# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_10-1G-D_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.03, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1130.945801
#
# Train accuracy so far: 49.231044
#
# loss in epoch 1: 351.420074
#
# Train accuracy so far: 83.376266
#
# loss in epoch 2: 216.973434
#
# Train accuracy so far: 89.971690
#
# loss in epoch 3: 150.079224
#
# Train accuracy so far: 93.118927
#
# loss in epoch 4: 110.570129
#
# Train accuracy so far: 95.052156
#
# loss in epoch 5: 83.844406
#
# Train accuracy so far: 96.284016
#
# loss in epoch 6: 66.961159
#
# Train accuracy so far: 97.005789
#
# loss in epoch 7: 55.298065
#
# Train accuracy so far: 97.480170
#
# loss in epoch 8: 46.474003
#
# Train accuracy so far: 97.870387
#
# loss in epoch 9: 40.211346
#
# Train accuracy so far: 98.245301
#
# loss in epoch 10: 30.582113
#
# Train accuracy so far: 98.594710
#
# loss in epoch 11: 30.492558
#
# Train accuracy so far: 98.564105
#
# loss in epoch 12: 26.486862
#
# Train accuracy so far: 98.686526
#
# loss in epoch 13: 21.067282
#
# Train accuracy so far: 98.939019
#
# loss in epoch 14: 22.991495
#
# Train accuracy so far: 98.900763
#
# loss in epoch 15: 17.665693
#
# Train accuracy so far: 99.112449
#
# loss in epoch 16: 20.148735
#
# Train accuracy so far: 99.007881
#
# loss in epoch 17: 15.143624
#
# Train accuracy so far: 99.262924
#
# loss in epoch 18: 14.905992
#
# Train accuracy so far: 99.209365
#
# loss in epoch 19: 12.837030
#
# Train accuracy so far: 99.367492
#
# accuracy in testing set: 90.395883

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.03
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(10):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.03
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.03
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.395883
#
# epoch 1:
# loss_D: 0.391, loss_G_fake: 0.326,
# loss_perturb: 39.304, loss_adv: 101.430,
#
# accuracy in training set after perturbation: 82.200515
#
# 47.40698862075806 seconds
# epoch 2:
# loss_D: 0.145, loss_G_fake: 0.610,
# loss_perturb: 41.667, loss_adv: 95.936,
#
# accuracy in training set after perturbation: 78.415670
#
# 94.40825366973877 seconds
# epoch 3:
# loss_D: 0.123, loss_G_fake: 0.686,
# loss_perturb: 43.629, loss_adv: 95.930,
#
# accuracy in training set after perturbation: 78.476880
#
# 141.42275667190552 seconds
# epoch 4:
# loss_D: 0.098, loss_G_fake: 0.754,
# loss_perturb: 43.059, loss_adv: 94.304,
#
# accuracy in training set after perturbation: 76.916014
#
# 188.42552375793457 seconds
# epoch 5:
# loss_D: 0.107, loss_G_fake: 0.756,
# loss_perturb: 42.596, loss_adv: 94.554,
#
# accuracy in training set after perturbation: 77.290928
#
# 235.5216076374054 seconds
# epoch 6:
# loss_D: 0.100, loss_G_fake: 0.779,
# loss_perturb: 42.405, loss_adv: 93.303,
#
# accuracy in training set after perturbation: 76.258002
#
# 282.4619128704071 seconds
# epoch 7:
# loss_D: 0.094, loss_G_fake: 0.793,
# loss_perturb: 40.839, loss_adv: 91.471,
#
# accuracy in training set after perturbation: 74.819557
#
# 329.43359375 seconds
# epoch 8:
# loss_D: 0.085, loss_G_fake: 0.820,
# loss_perturb: 41.908, loss_adv: 90.602,
#
# accuracy in training set after perturbation: 74.263562
#
# 376.3654844760895 seconds
# epoch 9:
# loss_D: 0.098, loss_G_fake: 0.803,
# loss_perturb: 40.356, loss_adv: 89.553,
#
# accuracy in training set after perturbation: 73.243388
#
# 423.2827227115631 seconds
# epoch 10:
# loss_D: 0.073, loss_G_fake: 0.860,
# loss_perturb: 41.001, loss_adv: 91.354,
#
# accuracy in training set after perturbation: 74.623173
#
# 470.2791464328766 seconds
# epoch 11:
# loss_D: 0.089, loss_G_fake: 0.821,
# loss_perturb: 39.716, loss_adv: 90.378,
#
# accuracy in training set after perturbation: 73.812135
#
# 517.3387897014618 seconds
# epoch 12:
# loss_D: 0.087, loss_G_fake: 0.803,
# loss_perturb: 39.567, loss_adv: 88.220,
#
# accuracy in training set after perturbation: 71.947767
#
# 564.3756415843964 seconds
# epoch 13:
# loss_D: 0.093, loss_G_fake: 0.811,
# loss_perturb: 38.973, loss_adv: 87.204,
#
# accuracy in training set after perturbation: 71.154582
#
# 611.3132407665253 seconds
# epoch 14:
# loss_D: 0.075, loss_G_fake: 0.840,
# loss_perturb: 38.987, loss_adv: 86.832,
#
# accuracy in training set after perturbation: 70.761815
#
# 658.2678561210632 seconds
# epoch 15:
# loss_D: 0.066, loss_G_fake: 0.863,
# loss_perturb: 38.707, loss_adv: 88.266,
#
# accuracy in training set after perturbation: 72.021730
#
# 705.3200101852417 seconds
# epoch 16:
# loss_D: 0.072, loss_G_fake: 0.864,
# loss_perturb: 38.878, loss_adv: 85.742,
#
# accuracy in training set after perturbation: 70.009437
#
# 752.2802262306213 seconds
# epoch 17:
# loss_D: 0.069, loss_G_fake: 0.858,
# loss_perturb: 39.340, loss_adv: 86.408,
#
# accuracy in training set after perturbation: 70.216022
#
# 799.2335360050201 seconds
# epoch 18:
# loss_D: 0.096, loss_G_fake: 0.836,
# loss_perturb: 39.186, loss_adv: 85.369,
#
# accuracy in training set after perturbation: 69.519753
#
# 846.2230422496796 seconds
# epoch 19:
# loss_D: 0.071, loss_G_fake: 0.868,
# loss_perturb: 37.846, loss_adv: 84.641,
#
# accuracy in training set after perturbation: 69.004565
#
# 893.1832604408264 seconds
# epoch 20:
# loss_D: 0.058, loss_G_fake: 0.892,
# loss_perturb: 37.634, loss_adv: 85.949,
#
# accuracy in training set after perturbation: 70.116555
#
# 940.1770026683807 seconds
# epoch 21:
# loss_D: 0.059, loss_G_fake: 0.895,
# loss_perturb: 38.372, loss_adv: 84.850,
#
# accuracy in training set after perturbation: 69.213701
#
# 987.267373085022 seconds
# epoch 22:
# loss_D: 0.045, loss_G_fake: 0.913,
# loss_perturb: 39.178, loss_adv: 85.293,
#
# accuracy in training set after perturbation: 69.667678
#
# 1034.413985967636 seconds
# epoch 23:
# loss_D: 0.049, loss_G_fake: 0.907,
# loss_perturb: 38.368, loss_adv: 84.875,
#
# accuracy in training set after perturbation: 69.132087
#
# 1081.4223775863647 seconds
# epoch 24:
# loss_D: 0.065, loss_G_fake: 0.888,
# loss_perturb: 38.784, loss_adv: 84.173,
#
# accuracy in training set after perturbation: 68.632202
#
# 1128.4506282806396 seconds
# epoch 25:
# loss_D: 0.050, loss_G_fake: 0.907,
# loss_perturb: 39.420, loss_adv: 84.390,
#
# accuracy in training set after perturbation: 68.953557
#
# 1175.4070801734924 seconds
# epoch 26:
# loss_D: 0.063, loss_G_fake: 0.883,
# loss_perturb: 39.660, loss_adv: 83.928,
#
# accuracy in training set after perturbation: 68.499579
#
# 1222.353835105896 seconds
# epoch 27:
# loss_D: 0.053, loss_G_fake: 0.900,
# loss_perturb: 39.495, loss_adv: 84.488,
#
# accuracy in training set after perturbation: 68.782677
#
# 1269.3323819637299 seconds
# epoch 28:
# loss_D: 0.072, loss_G_fake: 0.877,
# loss_perturb: 38.318, loss_adv: 86.320,
#
# accuracy in training set after perturbation: 70.162463
#
# 1316.4243333339691 seconds
# epoch 29:
# loss_D: 0.043, loss_G_fake: 0.922,
# loss_perturb: 38.344, loss_adv: 85.743,
#
# accuracy in training set after perturbation: 69.920171
#
# 1363.5018100738525 seconds
# epoch 30:
# loss_D: 0.061, loss_G_fake: 0.894,
# loss_perturb: 38.872, loss_adv: 84.182,
#
# accuracy in training set after perturbation: 68.678110
#
# 1410.4663743972778 seconds
# epoch 31:
# loss_D: 0.038, loss_G_fake: 0.940,
# loss_perturb: 38.838, loss_adv: 83.037,
#
# accuracy in training set after perturbation: 67.785457
#
# 1457.4539864063263 seconds
# epoch 32:
# loss_D: 0.034, loss_G_fake: 0.945,
# loss_perturb: 38.989, loss_adv: 83.558,
#
# accuracy in training set after perturbation: 68.346553
#
# 1504.4111080169678 seconds
# epoch 33:
# loss_D: 0.041, loss_G_fake: 0.934,
# loss_perturb: 39.151, loss_adv: 82.938,
#
# accuracy in training set after perturbation: 67.691091
#
# 1551.471628189087 seconds
# epoch 34:
# loss_D: 0.034, loss_G_fake: 0.943,
# loss_perturb: 38.467, loss_adv: 82.605,
#
# accuracy in training set after perturbation: 67.441149
#
# 1598.4565770626068 seconds
# epoch 35:
# loss_D: 0.046, loss_G_fake: 0.921,
# loss_perturb: 38.751, loss_adv: 82.600,
#
# accuracy in training set after perturbation: 67.321278
#
# 1645.5258059501648 seconds
# epoch 36:
# loss_D: 0.036, loss_G_fake: 0.940,
# loss_perturb: 38.787, loss_adv: 82.289,
#
# accuracy in training set after perturbation: 67.226912
#
# 1692.4360105991364 seconds
# epoch 37:
# loss_D: 0.029, loss_G_fake: 0.950,
# loss_perturb: 38.561, loss_adv: 81.694,
#
# accuracy in training set after perturbation: 66.637762
#
# 1739.3622970581055 seconds
# epoch 38:
# loss_D: 0.042, loss_G_fake: 0.931,
# loss_perturb: 38.318, loss_adv: 81.441,
#
# accuracy in training set after perturbation: 66.515341
#
# 1786.3106789588928 seconds
# epoch 39:
# loss_D: 0.039, loss_G_fake: 0.933,
# loss_perturb: 38.424, loss_adv: 80.664,
#
# accuracy in training set after perturbation: 65.816522
#
# 1833.3244173526764 seconds
# epoch 40:
# loss_D: 0.041, loss_G_fake: 0.930,
# loss_perturb: 38.404, loss_adv: 80.670,
#
# accuracy in training set after perturbation: 65.765513
#
# 1880.3720231056213 seconds
# epoch 41:
# loss_D: 0.030, loss_G_fake: 0.946,
# loss_perturb: 38.418, loss_adv: 82.111,
#
# accuracy in training set after perturbation: 67.048382
#
# 1927.386566400528 seconds
# epoch 42:
# loss_D: 0.037, loss_G_fake: 0.937,
# loss_perturb: 38.289, loss_adv: 80.342,
#
# accuracy in training set after perturbation: 65.637991
#
# 1974.3212459087372 seconds
# epoch 43:
# loss_D: 0.055, loss_G_fake: 0.900,
# loss_perturb: 38.010, loss_adv: 81.759,
#
# accuracy in training set after perturbation: 66.599505
#
# 2021.2830567359924 seconds
# epoch 44:
# loss_D: 0.039, loss_G_fake: 0.933,
# loss_perturb: 38.206, loss_adv: 79.953,
#
# accuracy in training set after perturbation: 65.166161
#
# 2068.2193660736084 seconds
# epoch 45:
# loss_D: 0.041, loss_G_fake: 0.931,
# loss_perturb: 37.496, loss_adv: 80.088,
#
# accuracy in training set after perturbation: 65.288582
#
# 2115.2459275722504 seconds
# epoch 46:
# loss_D: 0.038, loss_G_fake: 0.937,
# loss_perturb: 37.754, loss_adv: 80.828,
#
# accuracy in training set after perturbation: 65.890484
#
# 2162.1687319278717 seconds
# epoch 47:
# loss_D: 0.033, loss_G_fake: 0.943,
# loss_perturb: 37.756, loss_adv: 80.724,
#
# accuracy in training set after perturbation: 65.757862
#
# 2209.1245577335358 seconds
# epoch 48:
# loss_D: 0.034, loss_G_fake: 0.941,
# loss_perturb: 37.681, loss_adv: 79.360,
#
# accuracy in training set after perturbation: 64.803999
#
# 2256.2189497947693 seconds
# epoch 49:
# loss_D: 0.036, loss_G_fake: 0.936,
# loss_perturb: 37.521, loss_adv: 79.288,
#
# accuracy in training set after perturbation: 64.650973
#
# 2303.2334809303284 seconds
# epoch 50:
# loss_D: 0.024, loss_G_fake: 0.953,
# loss_perturb: 37.530, loss_adv: 78.589,
#
# accuracy in training set after perturbation: 64.189344
#
# 2350.285121202469 seconds
# epoch 51:
# loss_D: 0.022, loss_G_fake: 0.959,
# loss_perturb: 37.426, loss_adv: 78.354,
#
# accuracy in training set after perturbation: 64.015915
#
# 2397.2729749679565 seconds
# epoch 52:
# loss_D: 0.021, loss_G_fake: 0.961,
# loss_perturb: 37.406, loss_adv: 78.130,
#
# accuracy in training set after perturbation: 63.857788
#
# 2444.2576670646667 seconds
# epoch 53:
# loss_D: 0.022, loss_G_fake: 0.964,
# loss_perturb: 37.263, loss_adv: 77.978,
#
# accuracy in training set after perturbation: 63.720064
#
# 2491.206218957901 seconds
# epoch 54:
# loss_D: 0.021, loss_G_fake: 0.964,
# loss_perturb: 37.173, loss_adv: 77.809,
#
# accuracy in training set after perturbation: 63.587442
#
# 2538.226137161255 seconds
# epoch 55:
# loss_D: 0.021, loss_G_fake: 0.964,
# loss_perturb: 37.087, loss_adv: 77.730,
#
# accuracy in training set after perturbation: 63.477773
#
# 2585.3109567165375 seconds
# epoch 56:
# loss_D: 0.020, loss_G_fake: 0.965,
# loss_perturb: 37.024, loss_adv: 77.572,
#
# accuracy in training set after perturbation: 63.317096
#
# 2632.302607536316 seconds
# epoch 57:
# loss_D: 0.020, loss_G_fake: 0.965,
# loss_perturb: 36.967, loss_adv: 77.323,
#
# accuracy in training set after perturbation: 63.169170
#
# 2679.2929561138153 seconds
# epoch 58:
# loss_D: 0.020, loss_G_fake: 0.967,
# loss_perturb: 36.906, loss_adv: 77.212,
#
# accuracy in training set after perturbation: 63.082456
#
# 2726.2783126831055 seconds
# epoch 59:
# loss_D: 0.020, loss_G_fake: 0.965,
# loss_perturb: 36.846, loss_adv: 77.148,
#
# accuracy in training set after perturbation: 62.998291
#
# 2773.2732548713684 seconds
# epoch 60:
# loss_D: 0.019, loss_G_fake: 0.968,
# loss_perturb: 36.754, loss_adv: 77.035,
#
# accuracy in training set after perturbation: 62.868219
#
# 2820.2929797172546 seconds
# epoch 61:
# loss_D: 0.023, loss_G_fake: 0.958,
# loss_perturb: 36.678, loss_adv: 76.852,
#
# accuracy in training set after perturbation: 62.689689
#
# 2867.329192638397 seconds
# epoch 62:
# loss_D: 0.020, loss_G_fake: 0.968,
# loss_perturb: 36.599, loss_adv: 76.877,
#
# accuracy in training set after perturbation: 62.773853
#
# 2914.3251190185547 seconds
# epoch 63:
# loss_D: 0.019, loss_G_fake: 0.968,
# loss_perturb: 36.568, loss_adv: 76.889,
#
# accuracy in training set after perturbation: 62.730496
#
# 2961.2597398757935 seconds
# epoch 64:
# loss_D: 0.020, loss_G_fake: 0.965,
# loss_perturb: 36.555, loss_adv: 76.718,
#
# accuracy in training set after perturbation: 62.702441
#
# 3008.20600438118 seconds
# epoch 65:
# loss_D: 0.021, loss_G_fake: 0.965,
# loss_perturb: 36.531, loss_adv: 76.416,
#
# accuracy in training set after perturbation: 62.330077
#
# 3055.1377744674683 seconds
# epoch 66:
# loss_D: 0.018, loss_G_fake: 0.968,
# loss_perturb: 36.567, loss_adv: 76.455,
#
# accuracy in training set after perturbation: 62.416792
#
# 3102.098793745041 seconds
# epoch 67:
# loss_D: 0.020, loss_G_fake: 0.964,
# loss_perturb: 36.491, loss_adv: 76.261,
#
# accuracy in training set after perturbation: 62.289270
#
# 3149.132018327713 seconds
# epoch 68:
# loss_D: 0.019, loss_G_fake: 0.968,
# loss_perturb: 36.357, loss_adv: 76.186,
#
# accuracy in training set after perturbation: 62.228060
#
# 3196.20494556427 seconds
# epoch 69:
# loss_D: 0.019, loss_G_fake: 0.968,
# loss_perturb: 36.332, loss_adv: 76.204,
#
# accuracy in training set after perturbation: 62.263766
#
# 3243.253337621689 seconds
# epoch 70:
# loss_D: 0.019, loss_G_fake: 0.965,
# loss_perturb: 36.255, loss_adv: 76.169,
#
# accuracy in training set after perturbation: 62.159198
#
# 3290.2498104572296 seconds
# epoch 71:
# loss_D: 0.019, loss_G_fake: 0.966,
# loss_perturb: 36.291, loss_adv: 75.965,
#
# accuracy in training set after perturbation: 61.967916
#
# 3337.208288669586 seconds
# epoch 72:
# loss_D: 0.019, loss_G_fake: 0.967,
# loss_perturb: 36.250, loss_adv: 75.892,
#
# accuracy in training set after perturbation: 61.978117
#
# 3384.2024269104004 seconds
# epoch 73:
# loss_D: 0.019, loss_G_fake: 0.966,
# loss_perturb: 36.189, loss_adv: 76.084,
#
# accuracy in training set after perturbation: 62.141345
#
# 3431.1287109851837 seconds
# epoch 74:
# loss_D: 0.019, loss_G_fake: 0.966,
# loss_perturb: 36.160, loss_adv: 76.179,
#
# accuracy in training set after perturbation: 62.184702
#
# 3478.1258721351624 seconds
# epoch 75:
# loss_D: 0.019, loss_G_fake: 0.965,
# loss_perturb: 36.140, loss_adv: 75.615,
#
# accuracy in training set after perturbation: 61.774082
#
# 3525.103304386139 seconds
# epoch 76:
# loss_D: 0.019, loss_G_fake: 0.964,
# loss_perturb: 36.149, loss_adv: 75.641,
#
# accuracy in training set after perturbation: 61.748578
#
# 3572.225420475006 seconds
# epoch 77:
# loss_D: 0.019, loss_G_fake: 0.965,
# loss_perturb: 36.132, loss_adv: 75.657,
#
# accuracy in training set after perturbation: 61.794486
#
# 3619.1918456554413 seconds
# epoch 78:
# loss_D: 0.021, loss_G_fake: 0.957,
# loss_perturb: 36.064, loss_adv: 75.369,
#
# accuracy in training set after perturbation: 61.554745
#
# 3666.1767172813416 seconds
# epoch 79:
# loss_D: 0.019, loss_G_fake: 0.966,
# loss_perturb: 36.027, loss_adv: 75.476,
#
# accuracy in training set after perturbation: 61.615956
#
# 3713.2264907360077 seconds
# epoch 80:
# loss_D: 0.018, loss_G_fake: 0.966,
# loss_perturb: 35.953, loss_adv: 75.296,
#
# accuracy in training set after perturbation: 61.462929
#
# 3760.2289984226227 seconds
# epoch 81:
# loss_D: 0.018, loss_G_fake: 0.966,
# loss_perturb: 35.947, loss_adv: 75.270,
#
# accuracy in training set after perturbation: 61.422122
#
# 3807.2954115867615 seconds
# epoch 82:
# loss_D: 0.018, loss_G_fake: 0.966,
# loss_perturb: 35.945, loss_adv: 75.242,
#
# accuracy in training set after perturbation: 61.404269
#
# 3854.250282764435 seconds
# epoch 83:
# loss_D: 0.018, loss_G_fake: 0.965,
# loss_perturb: 35.945, loss_adv: 75.228,
#
# accuracy in training set after perturbation: 61.388967
#
# 3901.2013897895813 seconds
# epoch 84:
# loss_D: 0.018, loss_G_fake: 0.966,
# loss_perturb: 35.940, loss_adv: 75.203,
#
# accuracy in training set after perturbation: 61.378765
#
# 3948.166750431061 seconds
# epoch 85:
# loss_D: 0.018, loss_G_fake: 0.966,
# loss_perturb: 35.932, loss_adv: 75.202,
#
# accuracy in training set after perturbation: 61.391517
#
# 3995.1317279338837 seconds
# epoch 86:
# loss_D: 0.018, loss_G_fake: 0.966,
# loss_perturb: 35.929, loss_adv: 75.191,
#
# accuracy in training set after perturbation: 61.360912
#
# 4042.089431285858 seconds
# epoch 87:
# loss_D: 0.017, loss_G_fake: 0.966,
# loss_perturb: 35.925, loss_adv: 75.159,
#
# accuracy in training set after perturbation: 61.358362
#
# 4089.048510313034 seconds
# epoch 88:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.922, loss_adv: 75.156,
#
# accuracy in training set after perturbation: 61.345609
#
# 4136.08575129509 seconds
# epoch 89:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.922, loss_adv: 75.146,
#
# accuracy in training set after perturbation: 61.325206
#
# 4183.077817201614 seconds
# epoch 90:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.920, loss_adv: 75.132,
#
# accuracy in training set after perturbation: 61.332857
#
# 4229.995956659317 seconds
# epoch 91:
# loss_D: 0.017, loss_G_fake: 0.968,
# loss_perturb: 35.922, loss_adv: 75.116,
#
# accuracy in training set after perturbation: 61.330307
#
# 4276.945595264435 seconds
# epoch 92:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.922, loss_adv: 75.091,
#
# accuracy in training set after perturbation: 61.294601
#
# 4323.856773614883 seconds
# epoch 93:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.920, loss_adv: 75.069,
#
# accuracy in training set after perturbation: 61.294601
#
# 4370.828127145767 seconds
# epoch 94:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.912, loss_adv: 75.074,
#
# accuracy in training set after perturbation: 61.271647
#
# 4417.841547489166 seconds
# epoch 95:
# loss_D: 0.017, loss_G_fake: 0.966,
# loss_perturb: 35.906, loss_adv: 75.062,
#
# accuracy in training set after perturbation: 61.274197
#
# 4464.781485080719 seconds
# epoch 96:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.900, loss_adv: 75.052,
#
# accuracy in training set after perturbation: 61.274197
#
# 4511.867295026779 seconds
# epoch 97:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.895, loss_adv: 75.043,
#
# accuracy in training set after perturbation: 61.225739
#
# 4558.820738792419 seconds
# epoch 98:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.887, loss_adv: 75.045,
#
# accuracy in training set after perturbation: 61.230840
#
# 4605.742449045181 seconds
# epoch 99:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.883, loss_adv: 75.029,
#
# accuracy in training set after perturbation: 61.251243
#
# 4652.631986379623 seconds
# epoch 100:
# loss_D: 0.017, loss_G_fake: 0.967,
# loss_perturb: 35.884, loss_adv: 75.019,
#
# accuracy in training set after perturbation: 61.251243
#
# 4699.53009057045 seconds
# accuracy in test set on all perturbed images: 58.345210
#
# misclassifications on previously correctly classified images: 42.866192
