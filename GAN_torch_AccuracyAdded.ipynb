# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/GAN_torch_AccuracyAdded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 1x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.2)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.2)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.4)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.4)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 1*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:1*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

X_test = np.dot(X_test, grayscale)
X_train = np.dot(X_train, grayscale)
X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

#expand dimensions to fit 4D input array
X_train = np.expand_dims(X_train,-1)
X_test = np.expand_dims(X_test,-1)
X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
print(X_valid.shape)
print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (34799, 1, 32, 32)
# (34799, 43)
# (12630, 1, 32, 32)
# (12630, 43)
# (4410, 1, 32, 32)
# (4410, 43)

# %%
import torch
import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 1 #number of channels
    batch_size = 128

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 40
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 812.757385
#
# Train accuracy so far: 19.362625
#
# loss in epoch 1: 300.768646
#
# Train accuracy so far: 67.389868
#
# loss in epoch 2: 161.283890
#
# Train accuracy so far: 83.370212
#
# loss in epoch 3: 108.389114
#
# Train accuracy so far: 89.321532
#
# loss in epoch 4: 80.196808
#
# Train accuracy so far: 92.226788
#
# loss in epoch 5: 62.165539
#
# Train accuracy so far: 94.249835
#
# loss in epoch 6: 50.661808
#
# Train accuracy so far: 95.261358
#
# loss in epoch 7: 42.030334
#
# Train accuracy so far: 96.129199
#
# loss in epoch 8: 34.948498
#
# Train accuracy so far: 96.764275
#
# loss in epoch 9: 30.169285
#
# Train accuracy so far: 97.212564
#
# loss in epoch 10: 26.282164
#
# Train accuracy so far: 97.591885
#
# loss in epoch 11: 22.862436
#
# Train accuracy so far: 97.919480
#
# loss in epoch 12: 20.460236
#
# Train accuracy so far: 98.040174
#
# loss in epoch 13: 17.566502
#
# Train accuracy so far: 98.396506
#
# loss in epoch 14: 16.852858
#
# Train accuracy so far: 98.396506
#
# loss in epoch 15: 14.476595
#
# Train accuracy so far: 98.614903
#
# loss in epoch 16: 13.219235
#
# Train accuracy so far: 98.732722
#
# loss in epoch 17: 10.949250
#
# Train accuracy so far: 98.979856
#
# loss in epoch 18: 12.204515
#
# Train accuracy so far: 98.749964
#
# loss in epoch 19: 9.196489
#
# Train accuracy so far: 99.155148
#
# loss in epoch 20: 4.820587
#
# Train accuracy so far: 99.632173
#
# loss in epoch 21: 4.007004
#
# Train accuracy so far: 99.738498
#
# loss in epoch 22: 3.609691
#
# Train accuracy so far: 99.764361
#
# loss in epoch 23: 3.330565
#
# Train accuracy so far: 99.790224
#
# loss in epoch 24: 3.107772
#
# Train accuracy so far: 99.804592
#
# loss in epoch 25: 2.907722
#
# Train accuracy so far: 99.816087
#
# loss in epoch 26: 2.729116
#
# Train accuracy so far: 99.844823
#
# loss in epoch 27: 2.555627
#
# Train accuracy so far: 99.856318
#
# loss in epoch 28: 2.394205
#
# Train accuracy so far: 99.864939
#
# loss in epoch 29: 2.243038
#
# Train accuracy so far: 99.873560
#
# loss in epoch 30: 2.100187
#
# Train accuracy so far: 99.890801
#
# loss in epoch 31: 1.960912
#
# Train accuracy so far: 99.899422
#
# loss in epoch 32: 1.836930
#
# Train accuracy so far: 99.913791
#
# loss in epoch 33: 1.711344
#
# Train accuracy so far: 99.919538
#
# loss in epoch 34: 1.598159
#
# Train accuracy so far: 99.925285
#
# loss in epoch 35: 1.488649
#
# Train accuracy so far: 99.933906
#
# loss in epoch 36: 1.389590
#
# Train accuracy so far: 99.942527
#
# loss in epoch 37: 1.294564
#
# Train accuracy so far: 99.954022
#
# loss in epoch 38: 1.211704
#
# Train accuracy so far: 99.968390
#
# loss in epoch 39: 1.131124
#
# Train accuracy so far: 99.968390
#
# accuracy in testing set: 89.263658

# %%
import torch.nn as nn
import torch
import numpy as np

import torch.nn.functional as F
import torchvision
import os

#models_path = './models/'


# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)

            # add a clipping trick
            adv_images = torch.clamp(perturbation, -0.3, 0.3) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 10
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward()
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -0.3, 0.3) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                print('accuracy in testing set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
                
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)

# %%
import torch
import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader


use_cuda=True
image_nc=1
epochs = 60
batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct = 0
for i, data in enumerate(test_dataloader, 0):
    test_img, test_label = data
    test_img, test_label = test_img.to(device), test_label.to(device)
    test_label = torch.argmax(test_label,1)
    pred_lab = torch.argmax(targeted_model(test_img), 1)
    num_correct += torch.sum(pred_lab==test_label,0)

print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)
# Out:
# CUDA Available:  True
# accuracy in testing set: 89.263658
#
# accuracy in testing set aftern perturbation: 0.181040
#
# accuracy in testing set aftern perturbation: 0.376448
#
# accuracy in testing set aftern perturbation: 0.531624
#
# accuracy in testing set aftern perturbation: 0.643697
#
# accuracy in testing set aftern perturbation: 0.735653
#
# accuracy in testing set aftern perturbation: 0.816115
#
# accuracy in testing set aftern perturbation: 0.864967
#
# accuracy in testing set aftern perturbation: 0.905198
#
# accuracy in testing set aftern perturbation: 0.933935
#
# accuracy in testing set aftern perturbation: 0.959798
#
# accuracy in testing set aftern perturbation: 0.979913
#
# accuracy in testing set aftern perturbation: 0.985661
#
# accuracy in testing set aftern perturbation: 0.994281
#
# accuracy in testing set aftern perturbation: 1.008650
#
# accuracy in testing set aftern perturbation: 1.017271
#
# accuracy in testing set aftern perturbation: 1.028765
#
# accuracy in testing set aftern perturbation: 1.048881
#
# accuracy in testing set aftern perturbation: 1.057502
#
# accuracy in testing set aftern perturbation: 1.066123
#
# accuracy in testing set aftern perturbation: 1.074744
#
# accuracy in testing set aftern perturbation: 1.077617
#
# accuracy in testing set aftern perturbation: 1.083364
#
# accuracy in testing set aftern perturbation: 1.086238
#
# accuracy in testing set aftern perturbation: 1.091985
#
# accuracy in testing set aftern perturbation: 1.094859
#
# accuracy in testing set aftern perturbation: 1.100606
#
# accuracy in testing set aftern perturbation: 1.112101
#
# accuracy in testing set aftern perturbation: 1.123596
#
# accuracy in testing set aftern perturbation: 1.126469
#
# accuracy in testing set aftern perturbation: 1.137964
#
# accuracy in testing set aftern perturbation: 1.146585
#
# accuracy in testing set aftern perturbation: 1.152332
#
# accuracy in testing set aftern perturbation: 1.166700
#
# accuracy in testing set aftern perturbation: 1.183942
#
# accuracy in testing set aftern perturbation: 1.201184
#
# accuracy in testing set aftern perturbation: 1.206931
#
# accuracy in testing set aftern perturbation: 1.221299
#
# accuracy in testing set aftern perturbation: 1.250036
#
# accuracy in testing set aftern perturbation: 1.258657
#
# accuracy in testing set aftern perturbation: 1.275899
#
# accuracy in testing set aftern perturbation: 1.287393
#
# accuracy in testing set aftern perturbation: 1.313256
#
# accuracy in testing set aftern perturbation: 1.336245
#
# accuracy in testing set aftern perturbation: 1.344866
#
# accuracy in testing set aftern perturbation: 1.362108
#
# accuracy in testing set aftern perturbation: 1.379350
#
# accuracy in testing set aftern perturbation: 1.385097
#
# accuracy in testing set aftern perturbation: 1.387971
#
# accuracy in testing set aftern perturbation: 1.402339
#
# accuracy in testing set aftern perturbation: 1.410960
#
# accuracy in testing set aftern perturbation: 1.431076
#
# accuracy in testing set aftern perturbation: 1.445444
#
# accuracy in testing set aftern perturbation: 1.451191
#
# accuracy in testing set aftern perturbation: 1.468433
#
# accuracy in testing set aftern perturbation: 1.477054
#
# accuracy in testing set aftern perturbation: 1.491422
#
# accuracy in testing set aftern perturbation: 1.505790
#
# accuracy in testing set aftern perturbation: 1.508664
#
# accuracy in testing set aftern perturbation: 1.508664
#
# accuracy in testing set aftern perturbation: 1.528780
#
# accuracy in testing set aftern perturbation: 1.531653
#
# accuracy in testing set aftern perturbation: 1.548895
#
# accuracy in testing set aftern perturbation: 1.560390
#
# accuracy in testing set aftern perturbation: 1.583379
#
# accuracy in testing set aftern perturbation: 1.594873
#
# accuracy in testing set aftern perturbation: 1.609242
#
# accuracy in testing set aftern perturbation: 1.612115
#
# accuracy in testing set aftern perturbation: 1.629357
#
# accuracy in testing set aftern perturbation: 1.643725
#
# accuracy in testing set aftern perturbation: 1.658094
#
# accuracy in testing set aftern perturbation: 1.666715
#
# accuracy in testing set aftern perturbation: 1.683956
#
# accuracy in testing set aftern perturbation: 1.695451
#
# accuracy in testing set aftern perturbation: 1.698325
#
# accuracy in testing set aftern perturbation: 1.701198
#
# accuracy in testing set aftern perturbation: 1.706946
#
# accuracy in testing set aftern perturbation: 1.712693
#
# accuracy in testing set aftern perturbation: 1.715567
#
# accuracy in testing set aftern perturbation: 1.718440
#
# accuracy in testing set aftern perturbation: 1.721314
#
# accuracy in testing set aftern perturbation: 1.721314
#
# accuracy in testing set aftern perturbation: 1.724187
#
# accuracy in testing set aftern perturbation: 1.727061
#
# accuracy in testing set aftern perturbation: 1.735682
#
# accuracy in testing set aftern perturbation: 1.741429
#
# accuracy in testing set aftern perturbation: 1.741429
#
# accuracy in testing set aftern perturbation: 1.750050
#
# accuracy in testing set aftern perturbation: 1.752924
#
# accuracy in testing set aftern perturbation: 1.752924
#
# accuracy in testing set aftern perturbation: 1.758671
#
# accuracy in testing set aftern perturbation: 1.773039
#
# accuracy in testing set aftern perturbation: 1.773039
#
# accuracy in testing set aftern perturbation: 1.790281
#
# accuracy in testing set aftern perturbation: 1.801776
#
# accuracy in testing set aftern perturbation: 1.810397
#
# accuracy in testing set aftern perturbation: 1.821891
#
# accuracy in testing set aftern perturbation: 1.836260
#
# accuracy in testing set aftern perturbation: 1.842007
#
# accuracy in testing set aftern perturbation: 1.844881
#
# accuracy in testing set aftern perturbation: 1.853502
#
# accuracy in testing set aftern perturbation: 1.859249
#
# accuracy in testing set aftern perturbation: 1.859249
#
# accuracy in testing set aftern perturbation: 1.864996
#
# accuracy in testing set aftern perturbation: 1.879364
#
# accuracy in testing set aftern perturbation: 1.882238
#
# accuracy in testing set aftern perturbation: 1.890859
#
# accuracy in testing set aftern perturbation: 1.902354
#
# accuracy in testing set aftern perturbation: 1.916722
#
# accuracy in testing set aftern perturbation: 1.916722
#
# accuracy in testing set aftern perturbation: 1.922469
#
# accuracy in testing set aftern perturbation: 1.931090
#
# accuracy in testing set aftern perturbation: 1.942585
#
# accuracy in testing set aftern perturbation: 1.956953
#
# accuracy in testing set aftern perturbation: 1.968447
#
# accuracy in testing set aftern perturbation: 1.977068
#
# accuracy in testing set aftern perturbation: 1.982816
#
# accuracy in testing set aftern perturbation: 1.994310
#
# accuracy in testing set aftern perturbation: 1.997184
#
# accuracy in testing set aftern perturbation: 2.002931
#
# accuracy in testing set aftern perturbation: 2.008678
#
# accuracy in testing set aftern perturbation: 2.017299
#
# accuracy in testing set aftern perturbation: 2.023047
#
# accuracy in testing set aftern perturbation: 2.028794
#
# accuracy in testing set aftern perturbation: 2.034541
#
# accuracy in testing set aftern perturbation: 2.051783
#
# accuracy in testing set aftern perturbation: 2.060404
#
# accuracy in testing set aftern perturbation: 2.069025
#
# accuracy in testing set aftern perturbation: 2.080520
#
# accuracy in testing set aftern perturbation: 2.083393
#
# accuracy in testing set aftern perturbation: 2.092014
#
# accuracy in testing set aftern perturbation: 2.103509
#
# accuracy in testing set aftern perturbation: 2.115003
#
# accuracy in testing set aftern perturbation: 2.117877
#
# accuracy in testing set aftern perturbation: 2.129372
#
# accuracy in testing set aftern perturbation: 2.137992
#
# accuracy in testing set aftern perturbation: 2.152361
#
# accuracy in testing set aftern perturbation: 2.152361
#
# accuracy in testing set aftern perturbation: 2.163855
#
# accuracy in testing set aftern perturbation: 2.172476
#
# accuracy in testing set aftern perturbation: 2.172476
#
# accuracy in testing set aftern perturbation: 2.183971
#
# accuracy in testing set aftern perturbation: 2.183971
#
# accuracy in testing set aftern perturbation: 2.189718
#
# accuracy in testing set aftern perturbation: 2.201213
#
# accuracy in testing set aftern perturbation: 2.206960
#
# accuracy in testing set aftern perturbation: 2.212707
#
# accuracy in testing set aftern perturbation: 2.227075
#
# accuracy in testing set aftern perturbation: 2.244317
#
# accuracy in testing set aftern perturbation: 2.247191
#
# accuracy in testing set aftern perturbation: 2.261559
#
# accuracy in testing set aftern perturbation: 2.273054
#
# accuracy in testing set aftern perturbation: 2.275927
#
# accuracy in testing set aftern perturbation: 2.281675
#
# accuracy in testing set aftern perturbation: 2.290296
#
# accuracy in testing set aftern perturbation: 2.293169
#
# accuracy in testing set aftern perturbation: 2.296043
#
# accuracy in testing set aftern perturbation: 2.301790
#
# accuracy in testing set aftern perturbation: 2.301790
#
# accuracy in testing set aftern perturbation: 2.304664
#
# accuracy in testing set aftern perturbation: 2.313285
#
# accuracy in testing set aftern perturbation: 2.313285
#
# accuracy in testing set aftern perturbation: 2.319032
#
# accuracy in testing set aftern perturbation: 2.319032
#
# accuracy in testing set aftern perturbation: 2.321906
#
# accuracy in testing set aftern perturbation: 2.330527
#
# accuracy in testing set aftern perturbation: 2.330527
#
# accuracy in testing set aftern perturbation: 2.339148
#
# accuracy in testing set aftern perturbation: 2.344895
#
# accuracy in testing set aftern perturbation: 2.353516
#
# accuracy in testing set aftern perturbation: 2.353516
#
# accuracy in testing set aftern perturbation: 2.359263
#
# accuracy in testing set aftern perturbation: 2.365010
#
# accuracy in testing set aftern perturbation: 2.365010
#
# accuracy in testing set aftern perturbation: 2.367884
#
# accuracy in testing set aftern perturbation: 2.367884
#
# accuracy in testing set aftern perturbation: 2.370758
#
# accuracy in testing set aftern perturbation: 2.379379
#
# accuracy in testing set aftern perturbation: 2.382252
#
# accuracy in testing set aftern perturbation: 2.388000
#
# accuracy in testing set aftern perturbation: 2.390873
#
# accuracy in testing set aftern perturbation: 2.393747
#
# accuracy in testing set aftern perturbation: 2.399494
#
# accuracy in testing set aftern perturbation: 2.410989
#
# accuracy in testing set aftern perturbation: 2.416736
#
# accuracy in testing set aftern perturbation: 2.416736
#
# accuracy in testing set aftern perturbation: 2.425357
#
# accuracy in testing set aftern perturbation: 2.428231
#
# accuracy in testing set aftern perturbation: 2.433978
#
# accuracy in testing set aftern perturbation: 2.436852
#
# accuracy in testing set aftern perturbation: 2.436852
#
# accuracy in testing set aftern perturbation: 2.439725
#
# accuracy in testing set aftern perturbation: 2.439725
#
# accuracy in testing set aftern perturbation: 2.451220
#
# accuracy in testing set aftern perturbation: 2.454094
#
# accuracy in testing set aftern perturbation: 2.459841
#
# accuracy in testing set aftern perturbation: 2.474209
#
# accuracy in testing set aftern perturbation: 2.482830
#
# accuracy in testing set aftern perturbation: 2.488577
#
# accuracy in testing set aftern perturbation: 2.500072
#
# accuracy in testing set aftern perturbation: 2.508693
#
# accuracy in testing set aftern perturbation: 2.508693
#
# accuracy in testing set aftern perturbation: 2.511566
#
# accuracy in testing set aftern perturbation: 2.514440
#
# accuracy in testing set aftern perturbation: 2.520187
#
# accuracy in testing set aftern perturbation: 2.531682
#
# accuracy in testing set aftern perturbation: 2.537429
#
# accuracy in testing set aftern perturbation: 2.546050
#
# accuracy in testing set aftern perturbation: 2.551797
#
# accuracy in testing set aftern perturbation: 2.554671
#
# accuracy in testing set aftern perturbation: 2.557545
#
# accuracy in testing set aftern perturbation: 2.563292
#
# accuracy in testing set aftern perturbation: 2.574787
#
# accuracy in testing set aftern perturbation: 2.597776
#
# accuracy in testing set aftern perturbation: 2.612144
#
# accuracy in testing set aftern perturbation: 2.640880
#
# accuracy in testing set aftern perturbation: 2.666743
#
# accuracy in testing set aftern perturbation: 2.689732
#
# accuracy in testing set aftern perturbation: 2.712722
#
# accuracy in testing set aftern perturbation: 2.747205
#
# accuracy in testing set aftern perturbation: 2.767321
#
# accuracy in testing set aftern perturbation: 2.798931
#
# accuracy in testing set aftern perturbation: 2.830541
#
# accuracy in testing set aftern perturbation: 2.847783
#
# accuracy in testing set aftern perturbation: 2.870772
#
# accuracy in testing set aftern perturbation: 2.885140
#
# accuracy in testing set aftern perturbation: 2.911003
#
# accuracy in testing set aftern perturbation: 2.951234
#
# accuracy in testing set aftern perturbation: 2.985718
#
# accuracy in testing set aftern perturbation: 3.025949
#
# accuracy in testing set aftern perturbation: 3.069054
#
# accuracy in testing set aftern perturbation: 3.094917
#
# accuracy in testing set aftern perturbation: 3.106411
#
# accuracy in testing set aftern perturbation: 3.117906
#
# accuracy in testing set aftern perturbation: 3.126527
#
# accuracy in testing set aftern perturbation: 3.138021
#
# accuracy in testing set aftern perturbation: 3.143768
#
# accuracy in testing set aftern perturbation: 3.146642
#
# accuracy in testing set aftern perturbation: 3.155263
#
# accuracy in testing set aftern perturbation: 3.169631
#
# accuracy in testing set aftern perturbation: 3.172505
#
# accuracy in testing set aftern perturbation: 3.178252
#
# accuracy in testing set aftern perturbation: 3.186873
#
# accuracy in testing set aftern perturbation: 3.195494
#
# accuracy in testing set aftern perturbation: 3.195494
#
# accuracy in testing set aftern perturbation: 3.201241
#
# accuracy in testing set aftern perturbation: 3.206989
#
# accuracy in testing set aftern perturbation: 3.209862
#
# accuracy in testing set aftern perturbation: 3.218483
#
# accuracy in testing set aftern perturbation: 3.227104
#
# accuracy in testing set aftern perturbation: 3.235725
#
# accuracy in testing set aftern perturbation: 3.244346
#
# accuracy in testing set aftern perturbation: 3.247220
#
# accuracy in testing set aftern perturbation: 3.250093
#
# accuracy in testing set aftern perturbation: 3.252967
#
# accuracy in testing set aftern perturbation: 3.258714
#
# accuracy in testing set aftern perturbation: 3.261588
#
# accuracy in testing set aftern perturbation: 3.261588
#
# accuracy in testing set aftern perturbation: 3.261588
#
# accuracy in testing set aftern perturbation: 3.264462
#
# accuracy in testing set aftern perturbation: 3.270209
#
# accuracy in testing set aftern perturbation: 3.273083
#
# accuracy in testing set aftern perturbation: 3.281703
#
# accuracy in testing set aftern perturbation: 3.281703
#
# accuracy in testing set aftern perturbation: 3.284577
#
# accuracy in testing set aftern perturbation: 3.287451
#
# accuracy in testing set aftern perturbation: 3.293198
#
# accuracy in testing set aftern perturbation: 3.296072
#
# accuracy in testing set aftern perturbation: 3.301819
#
# accuracy in testing set aftern perturbation: 3.310440
#
# accuracy in testing set aftern perturbation: 3.310440
#
# accuracy in testing set aftern perturbation: 3.319061
#
# accuracy in testing set aftern perturbation: 3.321935
#
# epoch 1:
# loss_D: 0.318, loss_G_fake: 0.402,
# loss_perturb: 14.414, loss_adv: 3.952,
#
# accuracy in testing set aftern perturbation: 0.005747
#
# accuracy in testing set aftern perturbation: 0.008621
#
# accuracy in testing set aftern perturbation: 0.014368
#
# accuracy in testing set aftern perturbation: 0.022989
#
# accuracy in testing set aftern perturbation: 0.028736
#
# accuracy in testing set aftern perturbation: 0.034484
#
# accuracy in testing set aftern perturbation: 0.043105
#
# accuracy in testing set aftern perturbation: 0.051726
#
# accuracy in testing set aftern perturbation: 0.057473
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.071841
#
# accuracy in testing set aftern perturbation: 0.086209
#
# accuracy in testing set aftern perturbation: 0.097704
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.112072
#
# accuracy in testing set aftern perturbation: 0.114946
#
# accuracy in testing set aftern perturbation: 0.126440
#
# accuracy in testing set aftern perturbation: 0.143682
#
# accuracy in testing set aftern perturbation: 0.155177
#
# accuracy in testing set aftern perturbation: 0.172419
#
# accuracy in testing set aftern perturbation: 0.181040
#
# accuracy in testing set aftern perturbation: 0.183913
#
# accuracy in testing set aftern perturbation: 0.195408
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.206902
#
# accuracy in testing set aftern perturbation: 0.212650
#
# accuracy in testing set aftern perturbation: 0.221271
#
# accuracy in testing set aftern perturbation: 0.235639
#
# accuracy in testing set aftern perturbation: 0.238513
#
# accuracy in testing set aftern perturbation: 0.244260
#
# accuracy in testing set aftern perturbation: 0.247134
#
# accuracy in testing set aftern perturbation: 0.252881
#
# accuracy in testing set aftern perturbation: 0.255754
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.267249
#
# accuracy in testing set aftern perturbation: 0.275870
#
# accuracy in testing set aftern perturbation: 0.275870
#
# accuracy in testing set aftern perturbation: 0.293112
#
# accuracy in testing set aftern perturbation: 0.295986
#
# accuracy in testing set aftern perturbation: 0.304606
#
# accuracy in testing set aftern perturbation: 0.318975
#
# accuracy in testing set aftern perturbation: 0.318975
#
# accuracy in testing set aftern perturbation: 0.327596
#
# accuracy in testing set aftern perturbation: 0.339090
#
# accuracy in testing set aftern perturbation: 0.344837
#
# accuracy in testing set aftern perturbation: 0.353458
#
# accuracy in testing set aftern perturbation: 0.362079
#
# accuracy in testing set aftern perturbation: 0.376448
#
# accuracy in testing set aftern perturbation: 0.379321
#
# accuracy in testing set aftern perturbation: 0.379321
#
# accuracy in testing set aftern perturbation: 0.382195
#
# accuracy in testing set aftern perturbation: 0.390816
#
# accuracy in testing set aftern perturbation: 0.390816
#
# accuracy in testing set aftern perturbation: 0.399437
#
# accuracy in testing set aftern perturbation: 0.399437
#
# accuracy in testing set aftern perturbation: 0.399437
#
# accuracy in testing set aftern perturbation: 0.408058
#
# accuracy in testing set aftern perturbation: 0.408058
#
# accuracy in testing set aftern perturbation: 0.410931
#
# accuracy in testing set aftern perturbation: 0.416679
#
# accuracy in testing set aftern perturbation: 0.416679
#
# accuracy in testing set aftern perturbation: 0.416679
#
# accuracy in testing set aftern perturbation: 0.419552
#
# accuracy in testing set aftern perturbation: 0.425300
#
# accuracy in testing set aftern perturbation: 0.433921
#
# accuracy in testing set aftern perturbation: 0.436794
#
# accuracy in testing set aftern perturbation: 0.436794
#
# accuracy in testing set aftern perturbation: 0.439668
#
# accuracy in testing set aftern perturbation: 0.448289
#
# accuracy in testing set aftern perturbation: 0.451162
#
# accuracy in testing set aftern perturbation: 0.454036
#
# accuracy in testing set aftern perturbation: 0.454036
#
# accuracy in testing set aftern perturbation: 0.456910
#
# accuracy in testing set aftern perturbation: 0.459783
#
# accuracy in testing set aftern perturbation: 0.462657
#
# accuracy in testing set aftern perturbation: 0.465531
#
# accuracy in testing set aftern perturbation: 0.471278
#
# accuracy in testing set aftern perturbation: 0.474152
#
# accuracy in testing set aftern perturbation: 0.474152
#
# accuracy in testing set aftern perturbation: 0.482772
#
# accuracy in testing set aftern perturbation: 0.485646
#
# accuracy in testing set aftern perturbation: 0.491393
#
# accuracy in testing set aftern perturbation: 0.491393
#
# accuracy in testing set aftern perturbation: 0.497141
#
# accuracy in testing set aftern perturbation: 0.500014
#
# accuracy in testing set aftern perturbation: 0.500014
#
# accuracy in testing set aftern perturbation: 0.502888
#
# accuracy in testing set aftern perturbation: 0.508635
#
# accuracy in testing set aftern perturbation: 0.520130
#
# accuracy in testing set aftern perturbation: 0.520130
#
# accuracy in testing set aftern perturbation: 0.528751
#
# accuracy in testing set aftern perturbation: 0.534498
#
# accuracy in testing set aftern perturbation: 0.540245
#
# accuracy in testing set aftern perturbation: 0.551740
#
# accuracy in testing set aftern perturbation: 0.554614
#
# accuracy in testing set aftern perturbation: 0.560361
#
# accuracy in testing set aftern perturbation: 0.568982
#
# accuracy in testing set aftern perturbation: 0.583350
#
# accuracy in testing set aftern perturbation: 0.600592
#
# accuracy in testing set aftern perturbation: 0.617834
#
# accuracy in testing set aftern perturbation: 0.623581
#
# accuracy in testing set aftern perturbation: 0.640823
#
# accuracy in testing set aftern perturbation: 0.649444
#
# accuracy in testing set aftern perturbation: 0.666686
#
# accuracy in testing set aftern perturbation: 0.678180
#
# accuracy in testing set aftern perturbation: 0.686801
#
# accuracy in testing set aftern perturbation: 0.701170
#
# accuracy in testing set aftern perturbation: 0.704043
#
# accuracy in testing set aftern perturbation: 0.715538
#
# accuracy in testing set aftern perturbation: 0.724159
#
# accuracy in testing set aftern perturbation: 0.744274
#
# accuracy in testing set aftern perturbation: 0.758642
#
# accuracy in testing set aftern perturbation: 0.770137
#
# accuracy in testing set aftern perturbation: 0.775884
#
# accuracy in testing set aftern perturbation: 0.787379
#
# accuracy in testing set aftern perturbation: 0.804621
#
# accuracy in testing set aftern perturbation: 0.813242
#
# accuracy in testing set aftern perturbation: 0.824736
#
# accuracy in testing set aftern perturbation: 0.833357
#
# accuracy in testing set aftern perturbation: 0.853473
#
# accuracy in testing set aftern perturbation: 0.870715
#
# accuracy in testing set aftern perturbation: 0.899451
#
# accuracy in testing set aftern perturbation: 0.925314
#
# accuracy in testing set aftern perturbation: 0.933935
#
# accuracy in testing set aftern perturbation: 0.962671
#
# accuracy in testing set aftern perturbation: 0.977040
#
# accuracy in testing set aftern perturbation: 0.997155
#
# accuracy in testing set aftern perturbation: 1.014397
#
# accuracy in testing set aftern perturbation: 1.031639
#
# accuracy in testing set aftern perturbation: 1.048881
#
# accuracy in testing set aftern perturbation: 1.057502
#
# accuracy in testing set aftern perturbation: 1.057502
#
# accuracy in testing set aftern perturbation: 1.066123
#
# accuracy in testing set aftern perturbation: 1.077617
#
# accuracy in testing set aftern perturbation: 1.091985
#
# accuracy in testing set aftern perturbation: 1.109227
#
# accuracy in testing set aftern perturbation: 1.117848
#
# accuracy in testing set aftern perturbation: 1.126469
#
# accuracy in testing set aftern perturbation: 1.135090
#
# accuracy in testing set aftern perturbation: 1.146585
#
# accuracy in testing set aftern perturbation: 1.158079
#
# accuracy in testing set aftern perturbation: 1.169574
#
# accuracy in testing set aftern perturbation: 1.181068
#
# accuracy in testing set aftern perturbation: 1.189689
#
# accuracy in testing set aftern perturbation: 1.206931
#
# accuracy in testing set aftern perturbation: 1.221299
#
# accuracy in testing set aftern perturbation: 1.241415
#
# accuracy in testing set aftern perturbation: 1.258657
#
# accuracy in testing set aftern perturbation: 1.267278
#
# accuracy in testing set aftern perturbation: 1.281646
#
# accuracy in testing set aftern perturbation: 1.290267
#
# accuracy in testing set aftern perturbation: 1.313256
#
# accuracy in testing set aftern perturbation: 1.324751
#
# accuracy in testing set aftern perturbation: 1.336245
#
# accuracy in testing set aftern perturbation: 1.347740
#
# accuracy in testing set aftern perturbation: 1.353487
#
# accuracy in testing set aftern perturbation: 1.362108
#
# accuracy in testing set aftern perturbation: 1.364982
#
# accuracy in testing set aftern perturbation: 1.373603
#
# accuracy in testing set aftern perturbation: 1.385097
#
# accuracy in testing set aftern perturbation: 1.396592
#
# accuracy in testing set aftern perturbation: 1.405213
#
# accuracy in testing set aftern perturbation: 1.408086
#
# accuracy in testing set aftern perturbation: 1.419581
#
# accuracy in testing set aftern perturbation: 1.428202
#
# accuracy in testing set aftern perturbation: 1.428202
#
# accuracy in testing set aftern perturbation: 1.436823
#
# accuracy in testing set aftern perturbation: 1.439697
#
# accuracy in testing set aftern perturbation: 1.442570
#
# accuracy in testing set aftern perturbation: 1.448317
#
# accuracy in testing set aftern perturbation: 1.454065
#
# accuracy in testing set aftern perturbation: 1.459812
#
# accuracy in testing set aftern perturbation: 1.462686
#
# accuracy in testing set aftern perturbation: 1.465559
#
# accuracy in testing set aftern perturbation: 1.474180
#
# accuracy in testing set aftern perturbation: 1.488549
#
# accuracy in testing set aftern perturbation: 1.491422
#
# accuracy in testing set aftern perturbation: 1.497169
#
# accuracy in testing set aftern perturbation: 1.500043
#
# accuracy in testing set aftern perturbation: 1.517285
#
# accuracy in testing set aftern perturbation: 1.520159
#
# accuracy in testing set aftern perturbation: 1.534527
#
# accuracy in testing set aftern perturbation: 1.540274
#
# accuracy in testing set aftern perturbation: 1.543148
#
# accuracy in testing set aftern perturbation: 1.546021
#
# accuracy in testing set aftern perturbation: 1.557516
#
# accuracy in testing set aftern perturbation: 1.569011
#
# accuracy in testing set aftern perturbation: 1.569011
#
# accuracy in testing set aftern perturbation: 1.577632
#
# accuracy in testing set aftern perturbation: 1.589126
#
# accuracy in testing set aftern perturbation: 1.600621
#
# accuracy in testing set aftern perturbation: 1.617863
#
# accuracy in testing set aftern perturbation: 1.632231
#
# accuracy in testing set aftern perturbation: 1.640852
#
# accuracy in testing set aftern perturbation: 1.640852
#
# accuracy in testing set aftern perturbation: 1.643725
#
# accuracy in testing set aftern perturbation: 1.652346
#
# accuracy in testing set aftern perturbation: 1.658094
#
# accuracy in testing set aftern perturbation: 1.660967
#
# accuracy in testing set aftern perturbation: 1.669588
#
# accuracy in testing set aftern perturbation: 1.669588
#
# accuracy in testing set aftern perturbation: 1.672462
#
# accuracy in testing set aftern perturbation: 1.678209
#
# accuracy in testing set aftern perturbation: 1.689704
#
# accuracy in testing set aftern perturbation: 1.698325
#
# accuracy in testing set aftern perturbation: 1.701198
#
# accuracy in testing set aftern perturbation: 1.701198
#
# accuracy in testing set aftern perturbation: 1.712693
#
# accuracy in testing set aftern perturbation: 1.724187
#
# accuracy in testing set aftern perturbation: 1.735682
#
# accuracy in testing set aftern perturbation: 1.744303
#
# accuracy in testing set aftern perturbation: 1.764419
#
# accuracy in testing set aftern perturbation: 1.778787
#
# accuracy in testing set aftern perturbation: 1.790281
#
# accuracy in testing set aftern perturbation: 1.798902
#
# accuracy in testing set aftern perturbation: 1.810397
#
# accuracy in testing set aftern perturbation: 1.821891
#
# accuracy in testing set aftern perturbation: 1.833386
#
# accuracy in testing set aftern perturbation: 1.847754
#
# accuracy in testing set aftern perturbation: 1.867870
#
# accuracy in testing set aftern perturbation: 1.876491
#
# accuracy in testing set aftern perturbation: 1.902354
#
# accuracy in testing set aftern perturbation: 1.913848
#
# accuracy in testing set aftern perturbation: 1.925343
#
# accuracy in testing set aftern perturbation: 1.942585
#
# accuracy in testing set aftern perturbation: 1.959826
#
# accuracy in testing set aftern perturbation: 1.968447
#
# accuracy in testing set aftern perturbation: 1.991437
#
# accuracy in testing set aftern perturbation: 2.011552
#
# accuracy in testing set aftern perturbation: 2.031668
#
# accuracy in testing set aftern perturbation: 2.043162
#
# accuracy in testing set aftern perturbation: 2.048909
#
# accuracy in testing set aftern perturbation: 2.066151
#
# accuracy in testing set aftern perturbation: 2.080520
#
# accuracy in testing set aftern perturbation: 2.089140
#
# accuracy in testing set aftern perturbation: 2.094888
#
# accuracy in testing set aftern perturbation: 2.097761
#
# accuracy in testing set aftern perturbation: 2.103509
#
# accuracy in testing set aftern perturbation: 2.106382
#
# accuracy in testing set aftern perturbation: 2.112130
#
# accuracy in testing set aftern perturbation: 2.120751
#
# accuracy in testing set aftern perturbation: 2.132245
#
# accuracy in testing set aftern perturbation: 2.135119
#
# accuracy in testing set aftern perturbation: 2.146613
#
# accuracy in testing set aftern perturbation: 2.160982
#
# accuracy in testing set aftern perturbation: 2.172476
#
# accuracy in testing set aftern perturbation: 2.175350
#
# accuracy in testing set aftern perturbation: 2.192592
#
# accuracy in testing set aftern perturbation: 2.204086
#
# accuracy in testing set aftern perturbation: 2.209834
#
# accuracy in testing set aftern perturbation: 2.229949
#
# accuracy in testing set aftern perturbation: 2.244317
#
# accuracy in testing set aftern perturbation: 2.250065
#
# accuracy in testing set aftern perturbation: 2.273054
#
# accuracy in testing set aftern perturbation: 2.275927
#
# accuracy in testing set aftern perturbation: 2.290296
#
# accuracy in testing set aftern perturbation: 2.293169
#
# accuracy in testing set aftern perturbation: 2.296043
#
# accuracy in testing set aftern perturbation: 2.301790
#
# accuracy in testing set aftern perturbation: 2.313285
#
# accuracy in testing set aftern perturbation: 2.321906
#
# accuracy in testing set aftern perturbation: 2.324779
#
# accuracy in testing set aftern perturbation: 2.327653
#
# accuracy in testing set aftern perturbation: 2.327653
#
# accuracy in testing set aftern perturbation: 2.333400
#
# accuracy in testing set aftern perturbation: 2.339148
#
# accuracy in testing set aftern perturbation: 2.344895
#
# accuracy in testing set aftern perturbation: 2.350642
#
# accuracy in testing set aftern perturbation: 2.359263
#
# accuracy in testing set aftern perturbation: 2.362137
#
# accuracy in testing set aftern perturbation: 2.370758
#
# accuracy in testing set aftern perturbation: 2.376505
#
# epoch 2:
# loss_D: 0.089, loss_G_fake: 0.669,
# loss_perturb: 15.488, loss_adv: 2.746,
#
# accuracy in testing set aftern perturbation: 0.000000
#
# accuracy in testing set aftern perturbation: 0.008621
#
# accuracy in testing set aftern perturbation: 0.008621
#
# accuracy in testing set aftern perturbation: 0.017242
#
# accuracy in testing set aftern perturbation: 0.020116
#
# accuracy in testing set aftern perturbation: 0.020116
#
# accuracy in testing set aftern perturbation: 0.025863
#
# accuracy in testing set aftern perturbation: 0.028736
#
# accuracy in testing set aftern perturbation: 0.031610
#
# accuracy in testing set aftern perturbation: 0.037357
#
# accuracy in testing set aftern perturbation: 0.040231
#
# accuracy in testing set aftern perturbation: 0.045978
#
# accuracy in testing set aftern perturbation: 0.057473
#
# accuracy in testing set aftern perturbation: 0.060347
#
# accuracy in testing set aftern perturbation: 0.060347
#
# accuracy in testing set aftern perturbation: 0.063220
#
# accuracy in testing set aftern perturbation: 0.066094
#
# accuracy in testing set aftern perturbation: 0.077588
#
# accuracy in testing set aftern perturbation: 0.089083
#
# accuracy in testing set aftern perturbation: 0.100578
#
# accuracy in testing set aftern perturbation: 0.100578
#
# accuracy in testing set aftern perturbation: 0.100578
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.123567
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.146556
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.152303
#
# accuracy in testing set aftern perturbation: 0.160924
#
# accuracy in testing set aftern perturbation: 0.163798
#
# accuracy in testing set aftern perturbation: 0.169545
#
# accuracy in testing set aftern perturbation: 0.175292
#
# accuracy in testing set aftern perturbation: 0.178166
#
# accuracy in testing set aftern perturbation: 0.186787
#
# accuracy in testing set aftern perturbation: 0.198282
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.212650
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.235639
#
# accuracy in testing set aftern perturbation: 0.247134
#
# accuracy in testing set aftern perturbation: 0.255754
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.275870
#
# accuracy in testing set aftern perturbation: 0.284491
#
# accuracy in testing set aftern perturbation: 0.287365
#
# accuracy in testing set aftern perturbation: 0.293112
#
# accuracy in testing set aftern perturbation: 0.301733
#
# accuracy in testing set aftern perturbation: 0.307480
#
# accuracy in testing set aftern perturbation: 0.316101
#
# accuracy in testing set aftern perturbation: 0.324722
#
# accuracy in testing set aftern perturbation: 0.327596
#
# accuracy in testing set aftern perturbation: 0.330469
#
# accuracy in testing set aftern perturbation: 0.333343
#
# accuracy in testing set aftern perturbation: 0.336217
#
# accuracy in testing set aftern perturbation: 0.336217
#
# accuracy in testing set aftern perturbation: 0.341964
#
# accuracy in testing set aftern perturbation: 0.347711
#
# accuracy in testing set aftern perturbation: 0.362079
#
# accuracy in testing set aftern perturbation: 0.367827
#
# accuracy in testing set aftern perturbation: 0.370700
#
# accuracy in testing set aftern perturbation: 0.373574
#
# accuracy in testing set aftern perturbation: 0.376448
#
# accuracy in testing set aftern perturbation: 0.379321
#
# accuracy in testing set aftern perturbation: 0.382195
#
# accuracy in testing set aftern perturbation: 0.385069
#
# accuracy in testing set aftern perturbation: 0.387942
#
# accuracy in testing set aftern perturbation: 0.387942
#
# accuracy in testing set aftern perturbation: 0.390816
#
# accuracy in testing set aftern perturbation: 0.393689
#
# accuracy in testing set aftern perturbation: 0.396563
#
# accuracy in testing set aftern perturbation: 0.402310
#
# accuracy in testing set aftern perturbation: 0.402310
#
# accuracy in testing set aftern perturbation: 0.405184
#
# accuracy in testing set aftern perturbation: 0.408058
#
# accuracy in testing set aftern perturbation: 0.410931
#
# accuracy in testing set aftern perturbation: 0.416679
#
# accuracy in testing set aftern perturbation: 0.419552
#
# accuracy in testing set aftern perturbation: 0.431047
#
# accuracy in testing set aftern perturbation: 0.431047
#
# accuracy in testing set aftern perturbation: 0.439668
#
# accuracy in testing set aftern perturbation: 0.442541
#
# accuracy in testing set aftern perturbation: 0.445415
#
# accuracy in testing set aftern perturbation: 0.448289
#
# accuracy in testing set aftern perturbation: 0.456910
#
# accuracy in testing set aftern perturbation: 0.456910
#
# accuracy in testing set aftern perturbation: 0.459783
#
# accuracy in testing set aftern perturbation: 0.462657
#
# accuracy in testing set aftern perturbation: 0.462657
#
# accuracy in testing set aftern perturbation: 0.465531
#
# accuracy in testing set aftern perturbation: 0.479899
#
# accuracy in testing set aftern perturbation: 0.479899
#
# accuracy in testing set aftern perturbation: 0.488520
#
# accuracy in testing set aftern perturbation: 0.500014
#
# accuracy in testing set aftern perturbation: 0.500014
#
# accuracy in testing set aftern perturbation: 0.502888
#
# accuracy in testing set aftern perturbation: 0.511509
#
# accuracy in testing set aftern perturbation: 0.511509
#
# accuracy in testing set aftern perturbation: 0.511509
#
# accuracy in testing set aftern perturbation: 0.511509
#
# accuracy in testing set aftern perturbation: 0.517256
#
# accuracy in testing set aftern perturbation: 0.520130
#
# accuracy in testing set aftern perturbation: 0.523004
#
# accuracy in testing set aftern perturbation: 0.528751
#
# accuracy in testing set aftern perturbation: 0.528751
#
# accuracy in testing set aftern perturbation: 0.534498
#
# accuracy in testing set aftern perturbation: 0.534498
#
# accuracy in testing set aftern perturbation: 0.540245
#
# accuracy in testing set aftern perturbation: 0.543119
#
# accuracy in testing set aftern perturbation: 0.543119
#
# accuracy in testing set aftern perturbation: 0.543119
#
# accuracy in testing set aftern perturbation: 0.545993
#
# accuracy in testing set aftern perturbation: 0.545993
#
# accuracy in testing set aftern perturbation: 0.551740
#
# accuracy in testing set aftern perturbation: 0.557487
#
# accuracy in testing set aftern perturbation: 0.560361
#
# accuracy in testing set aftern perturbation: 0.566108
#
# accuracy in testing set aftern perturbation: 0.568982
#
# accuracy in testing set aftern perturbation: 0.571856
#
# accuracy in testing set aftern perturbation: 0.574729
#
# accuracy in testing set aftern perturbation: 0.574729
#
# accuracy in testing set aftern perturbation: 0.577603
#
# accuracy in testing set aftern perturbation: 0.580476
#
# accuracy in testing set aftern perturbation: 0.580476
#
# accuracy in testing set aftern perturbation: 0.589097
#
# accuracy in testing set aftern perturbation: 0.597718
#
# accuracy in testing set aftern perturbation: 0.600592
#
# accuracy in testing set aftern perturbation: 0.600592
#
# accuracy in testing set aftern perturbation: 0.606339
#
# accuracy in testing set aftern perturbation: 0.606339
#
# accuracy in testing set aftern perturbation: 0.609213
#
# accuracy in testing set aftern perturbation: 0.617834
#
# accuracy in testing set aftern perturbation: 0.620707
#
# accuracy in testing set aftern perturbation: 0.623581
#
# accuracy in testing set aftern perturbation: 0.632202
#
# accuracy in testing set aftern perturbation: 0.637949
#
# accuracy in testing set aftern perturbation: 0.643697
#
# accuracy in testing set aftern perturbation: 0.646570
#
# accuracy in testing set aftern perturbation: 0.658065
#
# accuracy in testing set aftern perturbation: 0.663812
#
# accuracy in testing set aftern perturbation: 0.663812
#
# accuracy in testing set aftern perturbation: 0.666686
#
# accuracy in testing set aftern perturbation: 0.669559
#
# accuracy in testing set aftern perturbation: 0.678180
#
# accuracy in testing set aftern perturbation: 0.695422
#
# accuracy in testing set aftern perturbation: 0.704043
#
# accuracy in testing set aftern perturbation: 0.706917
#
# accuracy in testing set aftern perturbation: 0.709791
#
# accuracy in testing set aftern perturbation: 0.715538
#
# accuracy in testing set aftern perturbation: 0.721285
#
# accuracy in testing set aftern perturbation: 0.732780
#
# accuracy in testing set aftern perturbation: 0.744274
#
# accuracy in testing set aftern perturbation: 0.750022
#
# accuracy in testing set aftern perturbation: 0.752895
#
# accuracy in testing set aftern perturbation: 0.755769
#
# accuracy in testing set aftern perturbation: 0.761516
#
# accuracy in testing set aftern perturbation: 0.761516
#
# accuracy in testing set aftern perturbation: 0.767263
#
# accuracy in testing set aftern perturbation: 0.773011
#
# accuracy in testing set aftern perturbation: 0.781632
#
# accuracy in testing set aftern perturbation: 0.784505
#
# accuracy in testing set aftern perturbation: 0.787379
#
# accuracy in testing set aftern perturbation: 0.787379
#
# accuracy in testing set aftern perturbation: 0.801747
#
# accuracy in testing set aftern perturbation: 0.804621
#
# accuracy in testing set aftern perturbation: 0.818989
#
# accuracy in testing set aftern perturbation: 0.821863
#
# accuracy in testing set aftern perturbation: 0.824736
#
# accuracy in testing set aftern perturbation: 0.830484
#
# accuracy in testing set aftern perturbation: 0.830484
#
# accuracy in testing set aftern perturbation: 0.836231
#
# accuracy in testing set aftern perturbation: 0.841978
#
# accuracy in testing set aftern perturbation: 0.850599
#
# accuracy in testing set aftern perturbation: 0.859220
#
# accuracy in testing set aftern perturbation: 0.862094
#
# accuracy in testing set aftern perturbation: 0.867841
#
# accuracy in testing set aftern perturbation: 0.870715
#
# accuracy in testing set aftern perturbation: 0.870715
#
# accuracy in testing set aftern perturbation: 0.876462
#
# accuracy in testing set aftern perturbation: 0.876462
#
# accuracy in testing set aftern perturbation: 0.879336
#
# accuracy in testing set aftern perturbation: 0.879336
#
# accuracy in testing set aftern perturbation: 0.882209
#
# accuracy in testing set aftern perturbation: 0.890830
#
# accuracy in testing set aftern perturbation: 0.896577
#
# accuracy in testing set aftern perturbation: 0.899451
#
# accuracy in testing set aftern perturbation: 0.899451
#
# accuracy in testing set aftern perturbation: 0.905198
#
# accuracy in testing set aftern perturbation: 0.905198
#
# accuracy in testing set aftern perturbation: 0.908072
#
# accuracy in testing set aftern perturbation: 0.916693
#
# accuracy in testing set aftern perturbation: 0.925314
#
# accuracy in testing set aftern perturbation: 0.928188
#
# accuracy in testing set aftern perturbation: 0.942556
#
# accuracy in testing set aftern perturbation: 0.954050
#
# accuracy in testing set aftern perturbation: 0.956924
#
# accuracy in testing set aftern perturbation: 0.962671
#
# accuracy in testing set aftern perturbation: 0.962671
#
# accuracy in testing set aftern perturbation: 0.965545
#
# accuracy in testing set aftern perturbation: 0.977040
#
# accuracy in testing set aftern perturbation: 0.985661
#
# accuracy in testing set aftern perturbation: 0.997155
#
# accuracy in testing set aftern perturbation: 1.005776
#
# accuracy in testing set aftern perturbation: 1.011523
#
# accuracy in testing set aftern perturbation: 1.020144
#
# accuracy in testing set aftern perturbation: 1.031639
#
# accuracy in testing set aftern perturbation: 1.046007
#
# accuracy in testing set aftern perturbation: 1.060375
#
# accuracy in testing set aftern perturbation: 1.066123
#
# accuracy in testing set aftern perturbation: 1.086238
#
# accuracy in testing set aftern perturbation: 1.103480
#
# accuracy in testing set aftern perturbation: 1.120722
#
# accuracy in testing set aftern perturbation: 1.140837
#
# accuracy in testing set aftern perturbation: 1.155206
#
# accuracy in testing set aftern perturbation: 1.166700
#
# accuracy in testing set aftern perturbation: 1.178195
#
# accuracy in testing set aftern perturbation: 1.195437
#
# accuracy in testing set aftern perturbation: 1.206931
#
# accuracy in testing set aftern perturbation: 1.221299
#
# accuracy in testing set aftern perturbation: 1.238541
#
# accuracy in testing set aftern perturbation: 1.244289
#
# accuracy in testing set aftern perturbation: 1.247162
#
# accuracy in testing set aftern perturbation: 1.252910
#
# accuracy in testing set aftern perturbation: 1.258657
#
# accuracy in testing set aftern perturbation: 1.275899
#
# accuracy in testing set aftern perturbation: 1.296014
#
# accuracy in testing set aftern perturbation: 1.313256
#
# accuracy in testing set aftern perturbation: 1.339119
#
# accuracy in testing set aftern perturbation: 1.347740
#
# accuracy in testing set aftern perturbation: 1.350614
#
# accuracy in testing set aftern perturbation: 1.359234
#
# accuracy in testing set aftern perturbation: 1.364982
#
# accuracy in testing set aftern perturbation: 1.390845
#
# accuracy in testing set aftern perturbation: 1.408086
#
# accuracy in testing set aftern perturbation: 1.419581
#
# accuracy in testing set aftern perturbation: 1.448317
#
# accuracy in testing set aftern perturbation: 1.456938
#
# accuracy in testing set aftern perturbation: 1.465559
#
# accuracy in testing set aftern perturbation: 1.477054
#
# accuracy in testing set aftern perturbation: 1.494296
#
# accuracy in testing set aftern perturbation: 1.500043
#
# accuracy in testing set aftern perturbation: 1.514411
#
# accuracy in testing set aftern perturbation: 1.525906
#
# accuracy in testing set aftern perturbation: 1.537401
#
# accuracy in testing set aftern perturbation: 1.543148
#
# accuracy in testing set aftern perturbation: 1.551769
#
# accuracy in testing set aftern perturbation: 1.563263
#
# accuracy in testing set aftern perturbation: 1.574758
#
# accuracy in testing set aftern perturbation: 1.583379
#
# accuracy in testing set aftern perturbation: 1.600621
#
# accuracy in testing set aftern perturbation: 1.606368
#
# accuracy in testing set aftern perturbation: 1.609242
#
# accuracy in testing set aftern perturbation: 1.609242
#
# accuracy in testing set aftern perturbation: 1.614989
#
# accuracy in testing set aftern perturbation: 1.620736
#
# accuracy in testing set aftern perturbation: 1.632231
#
# accuracy in testing set aftern perturbation: 1.635104
#
# accuracy in testing set aftern perturbation: 1.640852
#
# accuracy in testing set aftern perturbation: 1.646599
#
# accuracy in testing set aftern perturbation: 1.652346
#
# accuracy in testing set aftern perturbation: 1.669588
#
# accuracy in testing set aftern perturbation: 1.672462
#
# accuracy in testing set aftern perturbation: 1.678209
#
# accuracy in testing set aftern perturbation: 1.683956
#
# accuracy in testing set aftern perturbation: 1.686830
#
# accuracy in testing set aftern perturbation: 1.695451
#
# accuracy in testing set aftern perturbation: 1.704072
#
# accuracy in testing set aftern perturbation: 1.712693
#
# accuracy in testing set aftern perturbation: 1.718440
#
# epoch 3:
# loss_D: 0.034, loss_G_fake: 0.788,
# loss_perturb: 16.020, loss_adv: 1.976,
#
# accuracy in testing set aftern perturbation: 0.005747
#
# accuracy in testing set aftern perturbation: 0.011495
#
# accuracy in testing set aftern perturbation: 0.014368
#
# accuracy in testing set aftern perturbation: 0.020116
#
# accuracy in testing set aftern perturbation: 0.022989
#
# accuracy in testing set aftern perturbation: 0.028736
#
# accuracy in testing set aftern perturbation: 0.031610
#
# accuracy in testing set aftern perturbation: 0.034484
#
# accuracy in testing set aftern perturbation: 0.034484
#
# accuracy in testing set aftern perturbation: 0.034484
#
# accuracy in testing set aftern perturbation: 0.043105
#
# accuracy in testing set aftern perturbation: 0.045978
#
# accuracy in testing set aftern perturbation: 0.051726
#
# accuracy in testing set aftern perturbation: 0.051726
#
# accuracy in testing set aftern perturbation: 0.051726
#
# accuracy in testing set aftern perturbation: 0.054599
#
# accuracy in testing set aftern perturbation: 0.057473
#
# accuracy in testing set aftern perturbation: 0.060347
#
# accuracy in testing set aftern perturbation: 0.066094
#
# accuracy in testing set aftern perturbation: 0.080462
#
# accuracy in testing set aftern perturbation: 0.086209
#
# accuracy in testing set aftern perturbation: 0.091957
#
# accuracy in testing set aftern perturbation: 0.097704
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.112072
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.140809
#
# accuracy in testing set aftern perturbation: 0.155177
#
# accuracy in testing set aftern perturbation: 0.160924
#
# accuracy in testing set aftern perturbation: 0.160924
#
# accuracy in testing set aftern perturbation: 0.169545
#
# accuracy in testing set aftern perturbation: 0.172419
#
# accuracy in testing set aftern perturbation: 0.172419
#
# accuracy in testing set aftern perturbation: 0.175292
#
# accuracy in testing set aftern perturbation: 0.178166
#
# accuracy in testing set aftern perturbation: 0.178166
#
# accuracy in testing set aftern perturbation: 0.186787
#
# accuracy in testing set aftern perturbation: 0.192534
#
# accuracy in testing set aftern perturbation: 0.192534
#
# accuracy in testing set aftern perturbation: 0.195408
#
# accuracy in testing set aftern perturbation: 0.195408
#
# accuracy in testing set aftern perturbation: 0.195408
#
# accuracy in testing set aftern perturbation: 0.206902
#
# accuracy in testing set aftern perturbation: 0.215523
#
# accuracy in testing set aftern perturbation: 0.218397
#
# accuracy in testing set aftern perturbation: 0.218397
#
# accuracy in testing set aftern perturbation: 0.221271
#
# accuracy in testing set aftern perturbation: 0.224144
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.241386
#
# ...
#
# accuracy in testing set aftern perturbation: 0.198282
#
# accuracy in testing set aftern perturbation: 0.198282
#
# accuracy in testing set aftern perturbation: 0.198282
#
# accuracy in testing set aftern perturbation: 0.198282
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.201155
#
# accuracy in testing set aftern perturbation: 0.204029
#
# accuracy in testing set aftern perturbation: 0.204029
#
# accuracy in testing set aftern perturbation: 0.204029
#
# accuracy in testing set aftern perturbation: 0.206902
#
# accuracy in testing set aftern perturbation: 0.206902
#
# accuracy in testing set aftern perturbation: 0.209776
#
# accuracy in testing set aftern perturbation: 0.209776
#
# accuracy in testing set aftern perturbation: 0.212650
#
# accuracy in testing set aftern perturbation: 0.215523
#
# accuracy in testing set aftern perturbation: 0.218397
#
# accuracy in testing set aftern perturbation: 0.218397
#
# accuracy in testing set aftern perturbation: 0.221271
#
# accuracy in testing set aftern perturbation: 0.224144
#
# accuracy in testing set aftern perturbation: 0.224144
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.232765
#
# accuracy in testing set aftern perturbation: 0.235639
#
# accuracy in testing set aftern perturbation: 0.238513
#
# accuracy in testing set aftern perturbation: 0.238513
#
# accuracy in testing set aftern perturbation: 0.238513
#
# accuracy in testing set aftern perturbation: 0.241386
#
# accuracy in testing set aftern perturbation: 0.241386
#
# accuracy in testing set aftern perturbation: 0.241386
#
# accuracy in testing set aftern perturbation: 0.244260
#
# accuracy in testing set aftern perturbation: 0.244260
#
# accuracy in testing set aftern perturbation: 0.247134
#
# accuracy in testing set aftern perturbation: 0.252881
#
# accuracy in testing set aftern perturbation: 0.252881
#
# accuracy in testing set aftern perturbation: 0.252881
#
# accuracy in testing set aftern perturbation: 0.258628
#
# accuracy in testing set aftern perturbation: 0.258628
#
# accuracy in testing set aftern perturbation: 0.258628
#
# accuracy in testing set aftern perturbation: 0.258628
#
# accuracy in testing set aftern perturbation: 0.258628
#
# accuracy in testing set aftern perturbation: 0.261502
#
# accuracy in testing set aftern perturbation: 0.261502
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.264375
#
# accuracy in testing set aftern perturbation: 0.267249
#
# accuracy in testing set aftern perturbation: 0.267249
#
# accuracy in testing set aftern perturbation: 0.267249
#
# accuracy in testing set aftern perturbation: 0.267249
#
# accuracy in testing set aftern perturbation: 0.270123
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.272996
#
# accuracy in testing set aftern perturbation: 0.275870
#
# accuracy in testing set aftern perturbation: 0.275870
#
# accuracy in testing set aftern perturbation: 0.275870
#
# accuracy in testing set aftern perturbation: 0.278744
#
# accuracy in testing set aftern perturbation: 0.278744
#
# epoch 18:
# loss_D: 0.001, loss_G_fake: 0.965,
# loss_perturb: 9.840, loss_adv: 0.322,
#
# accuracy in testing set aftern perturbation: 0.002874
#
# accuracy in testing set aftern perturbation: 0.008621
#
# accuracy in testing set aftern perturbation: 0.011495
#
# accuracy in testing set aftern perturbation: 0.011495
#
# accuracy in testing set aftern perturbation: 0.014368
#
# accuracy in testing set aftern perturbation: 0.017242
#
# accuracy in testing set aftern perturbation: 0.022989
#
# accuracy in testing set aftern perturbation: 0.025863
#
# accuracy in testing set aftern perturbation: 0.025863
#
# accuracy in testing set aftern perturbation: 0.025863
#
# accuracy in testing set aftern perturbation: 0.031610
#
# accuracy in testing set aftern perturbation: 0.031610
#
# accuracy in testing set aftern perturbation: 0.031610
#
# accuracy in testing set aftern perturbation: 0.037357
#
# accuracy in testing set aftern perturbation: 0.037357
#
# accuracy in testing set aftern perturbation: 0.037357
#
# accuracy in testing set aftern perturbation: 0.037357
#
# accuracy in testing set aftern perturbation: 0.037357
#
# accuracy in testing set aftern perturbation: 0.043105
#
# accuracy in testing set aftern perturbation: 0.043105
#
# accuracy in testing set aftern perturbation: 0.048852
#
# accuracy in testing set aftern perturbation: 0.054599
#
# accuracy in testing set aftern perturbation: 0.054599
#
# accuracy in testing set aftern perturbation: 0.054599
#
# accuracy in testing set aftern perturbation: 0.054599
#
# accuracy in testing set aftern perturbation: 0.060347
#
# accuracy in testing set aftern perturbation: 0.060347
#
# accuracy in testing set aftern perturbation: 0.060347
#
# accuracy in testing set aftern perturbation: 0.063220
#
# accuracy in testing set aftern perturbation: 0.063220
#
# accuracy in testing set aftern perturbation: 0.063220
#
# accuracy in testing set aftern perturbation: 0.063220
#
# accuracy in testing set aftern perturbation: 0.066094
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.068967
#
# accuracy in testing set aftern perturbation: 0.071841
#
# accuracy in testing set aftern perturbation: 0.074715
#
# accuracy in testing set aftern perturbation: 0.077588
#
# accuracy in testing set aftern perturbation: 0.077588
#
# accuracy in testing set aftern perturbation: 0.077588
#
# accuracy in testing set aftern perturbation: 0.083336
#
# accuracy in testing set aftern perturbation: 0.083336
#
# accuracy in testing set aftern perturbation: 0.083336
#
# accuracy in testing set aftern perturbation: 0.083336
#
# accuracy in testing set aftern perturbation: 0.086209
#
# accuracy in testing set aftern perturbation: 0.089083
#
# accuracy in testing set aftern perturbation: 0.091957
#
# accuracy in testing set aftern perturbation: 0.091957
#
# accuracy in testing set aftern perturbation: 0.091957
#
# accuracy in testing set aftern perturbation: 0.094830
#
# accuracy in testing set aftern perturbation: 0.097704
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.103451
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.109199
#
# accuracy in testing set aftern perturbation: 0.112072
#
# accuracy in testing set aftern perturbation: 0.114946
#
# accuracy in testing set aftern perturbation: 0.114946
#
# accuracy in testing set aftern perturbation: 0.114946
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.117819
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.120693
#
# accuracy in testing set aftern perturbation: 0.123567
#
# accuracy in testing set aftern perturbation: 0.129314
#
# accuracy in testing set aftern perturbation: 0.129314
#
# accuracy in testing set aftern perturbation: 0.129314
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.132188
#
# accuracy in testing set aftern perturbation: 0.135061
#
# accuracy in testing set aftern perturbation: 0.135061
#
# accuracy in testing set aftern perturbation: 0.135061
#
# accuracy in testing set aftern perturbation: 0.137935
#
# accuracy in testing set aftern perturbation: 0.137935
#
# accuracy in testing set aftern perturbation: 0.137935
#
# accuracy in testing set aftern perturbation: 0.143682
#
# accuracy in testing set aftern perturbation: 0.143682
#
# accuracy in testing set aftern perturbation: 0.143682
#
# accuracy in testing set aftern perturbation: 0.146556
#
# accuracy in testing set aftern perturbation: 0.146556
#
# accuracy in testing set aftern perturbation: 0.146556
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.149430
#
# accuracy in testing set aftern perturbation: 0.155177
#
# accuracy in testing set aftern perturbation: 0.158051
#
# accuracy in testing set aftern perturbation: 0.160924
#
# accuracy in testing set aftern perturbation: 0.169545
#
# accuracy in testing set aftern perturbation: 0.172419
#
# accuracy in testing set aftern perturbation: 0.175292
#
# accuracy in testing set aftern perturbation: 0.183913
#
# accuracy in testing set aftern perturbation: 0.192534
#
# accuracy in testing set aftern perturbation: 0.206902
#
# accuracy in testing set aftern perturbation: 0.227018
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.229892
#
# accuracy in testing set aftern perturbation: 0.232765
#
# accuracy in testing set aftern perturbation: 0.232765
#
# accuracy in testing set aftern perturbation: 0.232765
#
# accuracy in testing set aftern perturbation: 0.235639
#
# accuracy in testing set aftern perturbation: 0.241386
#
# accuracy in testing set aftern perturbation: 0.241386
#
# accuracy in testing set aftern perturbation: 0.244260
#
# accuracy in testing set aftern perturbation: 0.247134
#
# accuracy in testing set aftern perturbation: 0.250007
#
# accuracy in testing set aftern perturbation: 0.252881
#
# accuracy in testing set aftern perturbation: 0.255754
#
# accuracy in testing set aftern perturbation: 0.261502
#
# accuracy in testing set aftern perturbation: 0.267249
#
# accuracy in testing set aftern perturbation: 0.278744
#
# accuracy in testing set aftern perturbation: 0.284491
#
# accuracy in testing set aftern perturbation: 0.287365
#
# accuracy in testing set aftern perturbation: 0.290238
#
# accuracy in testing set aftern perturbation: 0.298859
#
# accuracy in testing set aftern perturbation: 0.301733
#
# accuracy in testing set aftern perturbation: 0.301733
#
# accuracy in testing set aftern perturbation: 0.301733
#
# accuracy in testing set aftern perturbation: 0.301733
#
# accuracy in testing set aftern perturbation: 0.304606
#
# accuracy in testing set aftern perturbation: 0.304606
#
# accuracy in testing set aftern perturbation: 0.304606
#
# accuracy in testing set aftern perturbation: 0.304606
#
# accuracy in testing set aftern perturbation: 0.304606
#
# accuracy in testing set aftern perturbation: 0.307480
#
# accuracy in testing set aftern perturbation: 0.310354
#
# accuracy in testing set aftern perturbation: 0.310354
#
# accuracy in testing set aftern perturbation: 0.310354
#
# accuracy in testing set aftern perturbation: 0.313227
#
# accuracy in testing set aftern perturbation: 0.313227
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c90b381c6ee3> in <module>()
#      48                           BOX_MAX)
#      49
# ---> 50 advGAN.train(dataloader, epochs)
#
# <ipython-input-5-d0c11b3374d3> in train(self, train_dataloader, epochs)
#     157                 #print(images.shape)
#     158
# --> 159                 loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch =                     self.train_batch(images, labels)
#     160                 loss_D_sum += loss_D_batch
#     161                 loss_G_fake_sum += loss_G_fake_batch
#
# <ipython-input-5-d0c11b3374d3> in train_batch(self, x, labels)
#     114             pert_lambda = 1
#     115             loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
# --> 116             loss_G.backward()
#     117             self.optimizer_G.step()
#     118
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:
