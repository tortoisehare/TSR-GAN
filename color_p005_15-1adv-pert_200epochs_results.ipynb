# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p005_15-1adv-pert_200epochs_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.005, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 15:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.005
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 15
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.005
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.005
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<20:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 200

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.500, loss_G_fake: 0.250,
# loss_perturb: 12.497, loss_adv: 125.845,
#
# accuracy in training set after perturbation: 99.517968
#
# 8.73798131942749 seconds
# epoch 2:
# loss_D: 0.495, loss_G_fake: 0.255,
# loss_perturb: 14.403, loss_adv: 124.023,
#
# accuracy in training set after perturbation: 98.589610
#
# 17.45930314064026 seconds
# epoch 3:
# loss_D: 0.450, loss_G_fake: 0.290,
# loss_perturb: 12.253, loss_adv: 123.253,
#
# accuracy in training set after perturbation: 98.143283
#
# 26.19276213645935 seconds
# epoch 4:
# loss_D: 0.404, loss_G_fake: 0.327,
# loss_perturb: 11.521, loss_adv: 121.982,
#
# accuracy in training set after perturbation: 97.482721
#
# 34.95135807991028 seconds
# epoch 5:
# loss_D: 0.291, loss_G_fake: 0.426,
# loss_perturb: 9.124, loss_adv: 120.268,
#
# accuracy in training set after perturbation: 96.439593
#
# 43.61999750137329 seconds
# epoch 6:
# loss_D: 0.235, loss_G_fake: 0.490,
# loss_perturb: 8.986, loss_adv: 119.356,
#
# accuracy in training set after perturbation: 95.817287
#
# 52.35505986213684 seconds
# epoch 7:
# loss_D: 0.192, loss_G_fake: 0.549,
# loss_perturb: 8.793, loss_adv: 118.340,
#
# accuracy in training set after perturbation: 95.179678
#
# 61.11497116088867 seconds
# epoch 8:
# loss_D: 0.308, loss_G_fake: 0.474,
# loss_perturb: 8.432, loss_adv: 117.394,
#
# accuracy in training set after perturbation: 94.524216
#
# 69.78445529937744 seconds
# epoch 9:
# loss_D: 0.293, loss_G_fake: 0.463,
# loss_perturb: 8.373, loss_adv: 116.470,
#
# accuracy in training set after perturbation: 93.863654
#
# 78.42981600761414 seconds
# epoch 10:
# loss_D: 0.299, loss_G_fake: 0.476,
# loss_perturb: 8.248, loss_adv: 115.676,
#
# accuracy in training set after perturbation: 93.333163
#
# 87.0854263305664 seconds
# epoch 11:
# loss_D: 0.306, loss_G_fake: 0.488,
# loss_perturb: 8.362, loss_adv: 115.427,
#
# accuracy in training set after perturbation: 93.141881
#
# 95.72542357444763 seconds
# epoch 12:
# loss_D: 0.291, loss_G_fake: 0.479,
# loss_perturb: 8.171, loss_adv: 114.669,
#
# accuracy in training set after perturbation: 92.575684
#
# 104.37628483772278 seconds
# epoch 13:
# loss_D: 0.319, loss_G_fake: 0.470,
# loss_perturb: 7.407, loss_adv: 114.110,
#
# accuracy in training set after perturbation: 92.119156
#
# 113.03666162490845 seconds
# epoch 14:
# loss_D: 0.288, loss_G_fake: 0.517,
# loss_perturb: 7.616, loss_adv: 113.570,
#
# accuracy in training set after perturbation: 91.703435
#
# 121.71539282798767 seconds
# epoch 15:
# loss_D: 0.274, loss_G_fake: 0.502,
# loss_perturb: 6.960, loss_adv: 113.121,
#
# accuracy in training set after perturbation: 91.415236
#
# 130.3535692691803 seconds
# epoch 16:
# loss_D: 0.274, loss_G_fake: 0.512,
# loss_perturb: 6.701, loss_adv: 112.695,
#
# accuracy in training set after perturbation: 91.132138
#
# 139.0919783115387 seconds
# epoch 17:
# loss_D: 0.272, loss_G_fake: 0.525,
# loss_perturb: 6.915, loss_adv: 112.441,
#
# accuracy in training set after perturbation: 90.968910
#
# 147.79104900360107 seconds
# epoch 18:
# loss_D: 0.281, loss_G_fake: 0.522,
# loss_perturb: 6.912, loss_adv: 112.244,
#
# accuracy in training set after perturbation: 90.764875
#
# 156.44933009147644 seconds
# epoch 19:
# loss_D: 0.273, loss_G_fake: 0.526,
# loss_perturb: 6.703, loss_adv: 111.852,
#
# accuracy in training set after perturbation: 90.489428
#
# 165.11857199668884 seconds
# epoch 20:
# loss_D: 0.308, loss_G_fake: 0.518,
# loss_perturb: 6.812, loss_adv: 111.626,
#
# accuracy in training set after perturbation: 90.397613
#
# 173.91820359230042 seconds
# epoch 21:
# loss_D: 0.271, loss_G_fake: 0.547,
# loss_perturb: 6.765, loss_adv: 111.284,
#
# accuracy in training set after perturbation: 90.122166
#
# 182.67770266532898 seconds
# epoch 22:
# loss_D: 0.283, loss_G_fake: 0.515,
# loss_perturb: 6.478, loss_adv: 110.689,
#
# accuracy in training set after perturbation: 89.632482
#
# 191.5944836139679 seconds
# epoch 23:
# loss_D: 0.262, loss_G_fake: 0.556,
# loss_perturb: 6.339, loss_adv: 110.540,
#
# accuracy in training set after perturbation: 89.502410
#
# 200.27004981040955 seconds
# epoch 24:
# loss_D: 0.266, loss_G_fake: 0.552,
# loss_perturb: 6.043, loss_adv: 110.315,
#
# accuracy in training set after perturbation: 89.316228
#
# 208.92438507080078 seconds
# epoch 25:
# loss_D: 0.269, loss_G_fake: 0.542,
# loss_perturb: 5.889, loss_adv: 110.010,
#
# accuracy in training set after perturbation: 89.219312
#
# 217.60732650756836 seconds
# epoch 26:
# loss_D: 0.260, loss_G_fake: 0.554,
# loss_perturb: 6.274, loss_adv: 109.900,
#
# accuracy in training set after perturbation: 89.130047
#
# 226.35702991485596 seconds
# epoch 27:
# loss_D: 0.278, loss_G_fake: 0.536,
# loss_perturb: 6.433, loss_adv: 109.590,
#
# accuracy in training set after perturbation: 88.852049
#
# 234.97701501846313 seconds
# epoch 28:
# loss_D: 0.289, loss_G_fake: 0.522,
# loss_perturb: 5.978, loss_adv: 109.307,
#
# accuracy in training set after perturbation: 88.630161
#
# 243.65176105499268 seconds
# epoch 29:
# loss_D: 0.264, loss_G_fake: 0.545,
# loss_perturb: 6.159, loss_adv: 109.312,
#
# accuracy in training set after perturbation: 88.673519
#
# 252.2667043209076 seconds
# epoch 30:
# loss_D: 0.315, loss_G_fake: 0.509,
# loss_perturb: 6.001, loss_adv: 108.843,
#
# accuracy in training set after perturbation: 88.199138
#
# 260.945255279541 seconds
# epoch 31:
# loss_D: 0.303, loss_G_fake: 0.521,
# loss_perturb: 5.596, loss_adv: 108.645,
#
# accuracy in training set after perturbation: 88.018057
#
# 269.58709621429443 seconds
# epoch 32:
# loss_D: 0.286, loss_G_fake: 0.535,
# loss_perturb: 5.626, loss_adv: 108.497,
#
# accuracy in training set after perturbation: 87.941544
#
# 278.21736192703247 seconds
# epoch 33:
# loss_D: 0.282, loss_G_fake: 0.530,
# loss_perturb: 5.613, loss_adv: 108.304,
#
# accuracy in training set after perturbation: 87.816573
#
# 286.7982325553894 seconds
# epoch 34:
# loss_D: 0.287, loss_G_fake: 0.528,
# loss_perturb: 5.747, loss_adv: 108.656,
#
# accuracy in training set after perturbation: 88.204239
#
# 295.4605095386505 seconds
# epoch 35:
# loss_D: 0.286, loss_G_fake: 0.537,
# loss_perturb: 5.780, loss_adv: 108.208,
#
# accuracy in training set after perturbation: 87.844628
#
# 304.16831374168396 seconds
# epoch 36:
# loss_D: 0.295, loss_G_fake: 0.529,
# loss_perturb: 5.850, loss_adv: 108.041,
#
# accuracy in training set after perturbation: 87.678849
#
# 312.807834148407 seconds
# epoch 37:
# loss_D: 0.299, loss_G_fake: 0.525,
# loss_perturb: 5.646, loss_adv: 107.792,
#
# accuracy in training set after perturbation: 87.464613
#
# 321.3720245361328 seconds
# epoch 38:
# loss_D: 0.287, loss_G_fake: 0.533,
# loss_perturb: 5.294, loss_adv: 107.614,
#
# accuracy in training set after perturbation: 87.296284
#
# 330.0052375793457 seconds
# epoch 39:
# loss_D: 0.277, loss_G_fake: 0.541,
# loss_perturb: 5.313, loss_adv: 107.435,
#
# accuracy in training set after perturbation: 87.186615
#
# 338.5864100456238 seconds
# epoch 40:
# loss_D: 0.290, loss_G_fake: 0.530,
# loss_perturb: 5.186, loss_adv: 107.403,
#
# accuracy in training set after perturbation: 87.173863
#
# 347.2292277812958 seconds
# epoch 41:
# loss_D: 0.284, loss_G_fake: 0.536,
# loss_perturb: 5.309, loss_adv: 107.409,
#
# accuracy in training set after perturbation: 87.240174
#
# 355.838392496109 seconds
# epoch 42:
# loss_D: 0.282, loss_G_fake: 0.531,
# loss_perturb: 5.522, loss_adv: 107.284,
#
# accuracy in training set after perturbation: 87.163661
#
# 364.4651310443878 seconds
# epoch 43:
# loss_D: 0.288, loss_G_fake: 0.528,
# loss_perturb: 5.180, loss_adv: 107.107,
#
# accuracy in training set after perturbation: 86.995333
#
# 373.08764123916626 seconds
# epoch 44:
# loss_D: 0.269, loss_G_fake: 0.544,
# loss_perturb: 5.212, loss_adv: 107.025,
#
# accuracy in training set after perturbation: 86.890765
#
# 381.76419043540955 seconds
# epoch 45:
# loss_D: 0.264, loss_G_fake: 0.560,
# loss_perturb: 5.295, loss_adv: 106.874,
#
# accuracy in training set after perturbation: 86.775995
#
# 390.4196774959564 seconds
# epoch 46:
# loss_D: 0.280, loss_G_fake: 0.547,
# loss_perturb: 5.242, loss_adv: 106.882,
#
# accuracy in training set after perturbation: 86.906067
#
# 399.0439786911011 seconds
# epoch 47:
# loss_D: 0.284, loss_G_fake: 0.535,
# loss_perturb: 5.082, loss_adv: 106.718,
#
# accuracy in training set after perturbation: 86.691831
#
# 407.64219403266907 seconds
# epoch 48:
# loss_D: 0.297, loss_G_fake: 0.527,
# loss_perturb: 5.040, loss_adv: 106.660,
#
# accuracy in training set after perturbation: 86.668877
#
# 416.28995275497437 seconds
# epoch 49:
# loss_D: 0.252, loss_G_fake: 0.566,
# loss_perturb: 5.067, loss_adv: 106.562,
#
# accuracy in training set after perturbation: 86.625520
#
# 424.8869683742523 seconds
# epoch 50:
# loss_D: 0.211, loss_G_fake: 0.607,
# loss_perturb: 4.840, loss_adv: 106.021,
#
# accuracy in training set after perturbation: 85.939453
#
# 433.50845432281494 seconds
# epoch 51:
# loss_D: 0.199, loss_G_fake: 0.615,
# loss_perturb: 4.562, loss_adv: 105.747,
#
# accuracy in training set after perturbation: 85.531383
#
# 442.09206891059875 seconds
# epoch 52:
# loss_D: 0.205, loss_G_fake: 0.606,
# loss_perturb: 4.347, loss_adv: 105.602,
#
# accuracy in training set after perturbation: 85.342651
#
# 450.7683503627777 seconds
# epoch 53:
# loss_D: 0.213, loss_G_fake: 0.597,
# loss_perturb: 4.172, loss_adv: 105.496,
#
# accuracy in training set after perturbation: 85.227881
#
# 459.3858149051666 seconds
# epoch 54:
# loss_D: 0.209, loss_G_fake: 0.600,
# loss_perturb: 4.023, loss_adv: 105.414,
#
# accuracy in training set after perturbation: 85.176873
#
# 468.1043426990509 seconds
# epoch 55:
# loss_D: 0.211, loss_G_fake: 0.598,
# loss_perturb: 3.882, loss_adv: 105.342,
#
# accuracy in training set after perturbation: 85.062103
#
# 476.81844687461853 seconds
# epoch 56:
# loss_D: 0.211, loss_G_fake: 0.597,
# loss_perturb: 3.757, loss_adv: 105.277,
#
# accuracy in training set after perturbation: 85.011094
#
# 485.4232783317566 seconds
# epoch 57:
# loss_D: 0.213, loss_G_fake: 0.596,
# loss_perturb: 3.643, loss_adv: 105.221,
#
# accuracy in training set after perturbation: 84.952434
#
# 494.12561106681824 seconds
# epoch 58:
# loss_D: 0.212, loss_G_fake: 0.596,
# loss_perturb: 3.553, loss_adv: 105.173,
#
# accuracy in training set after perturbation: 84.962636
#
# 502.95945501327515 seconds
# epoch 59:
# loss_D: 0.211, loss_G_fake: 0.597,
# loss_perturb: 3.460, loss_adv: 105.114,
#
# accuracy in training set after perturbation: 84.919279
#
# 511.5852589607239 seconds
# epoch 60:
# loss_D: 0.214, loss_G_fake: 0.593,
# loss_perturb: 3.378, loss_adv: 105.062,
#
# accuracy in training set after perturbation: 84.837665
#
# 520.1942555904388 seconds
# epoch 61:
# loss_D: 0.213, loss_G_fake: 0.595,
# loss_perturb: 3.316, loss_adv: 105.027,
#
# accuracy in training set after perturbation: 84.822362
#
# 528.8164141178131 seconds
# epoch 62:
# loss_D: 0.214, loss_G_fake: 0.593,
# loss_perturb: 3.248, loss_adv: 104.982,
#
# accuracy in training set after perturbation: 84.824913
#
# 537.515159368515 seconds
# epoch 63:
# loss_D: 0.213, loss_G_fake: 0.595,
# loss_perturb: 3.197, loss_adv: 104.943,
#
# accuracy in training set after perturbation: 84.771354
#
# 546.2127282619476 seconds
# epoch 64:
# loss_D: 0.213, loss_G_fake: 0.595,
# loss_perturb: 3.154, loss_adv: 104.909,
#
# accuracy in training set after perturbation: 84.837665
#
# 554.860776424408 seconds
# epoch 65:
# loss_D: 0.214, loss_G_fake: 0.594,
# loss_perturb: 3.116, loss_adv: 104.867,
#
# accuracy in training set after perturbation: 84.753500
#
# 563.4473032951355 seconds
# epoch 66:
# loss_D: 0.215, loss_G_fake: 0.593,
# loss_perturb: 3.070, loss_adv: 104.833,
#
# accuracy in training set after perturbation: 84.699941
#
# 572.0628542900085 seconds
# epoch 67:
# loss_D: 0.214, loss_G_fake: 0.594,
# loss_perturb: 3.040, loss_adv: 104.806,
#
# accuracy in training set after perturbation: 84.761152
#
# 580.6690533161163 seconds
# epoch 68:
# loss_D: 0.216, loss_G_fake: 0.591,
# loss_perturb: 3.013, loss_adv: 104.763,
#
# accuracy in training set after perturbation: 84.684639
#
# 589.2764778137207 seconds
# epoch 69:
# loss_D: 0.217, loss_G_fake: 0.591,
# loss_perturb: 2.988, loss_adv: 104.732,
#
# accuracy in training set after perturbation: 84.699941
#
# 597.8854608535767 seconds
# epoch 70:
# loss_D: 0.217, loss_G_fake: 0.592,
# loss_perturb: 2.952, loss_adv: 104.703,
#
# accuracy in training set after perturbation: 84.605575
#
# 606.5180628299713 seconds
# epoch 71:
# loss_D: 0.218, loss_G_fake: 0.590,
# loss_perturb: 2.932, loss_adv: 104.676,
#
# accuracy in training set after perturbation: 84.648933
#
# 615.1038055419922 seconds
# epoch 72:
# loss_D: 0.217, loss_G_fake: 0.590,
# loss_perturb: 2.920, loss_adv: 104.652,
#
# accuracy in training set after perturbation: 84.633630
#
# 623.7928867340088 seconds
# epoch 73:
# loss_D: 0.216, loss_G_fake: 0.593,
# loss_perturb: 2.914, loss_adv: 104.629,
#
# accuracy in training set after perturbation: 84.648933
#
# 632.4768826961517 seconds
# epoch 74:
# loss_D: 0.216, loss_G_fake: 0.592,
# loss_perturb: 2.893, loss_adv: 104.596,
#
# accuracy in training set after perturbation: 84.580071
#
# 641.1034514904022 seconds
# epoch 75:
# loss_D: 0.215, loss_G_fake: 0.592,
# loss_perturb: 2.879, loss_adv: 104.561,
#
# accuracy in training set after perturbation: 84.569869
#
# 649.6837639808655 seconds
# epoch 76:
# loss_D: 0.218, loss_G_fake: 0.589,
# loss_perturb: 2.868, loss_adv: 104.536,
#
# accuracy in training set after perturbation: 84.557117
#
# 658.3466019630432 seconds
# epoch 77:
# loss_D: 0.217, loss_G_fake: 0.590,
# loss_perturb: 2.840, loss_adv: 104.498,
#
# accuracy in training set after perturbation: 84.467852
#
# 666.9776127338409 seconds
# epoch 78:
# loss_D: 0.217, loss_G_fake: 0.590,
# loss_perturb: 2.821, loss_adv: 104.470,
#
# accuracy in training set after perturbation: 84.495907
#
# 675.5852453708649 seconds
# epoch 79:
# loss_D: 0.219, loss_G_fake: 0.588,
# loss_perturb: 2.802, loss_adv: 104.446,
#
# accuracy in training set after perturbation: 84.480604
#
# 684.1891779899597 seconds
# epoch 80:
# loss_D: 0.230, loss_G_fake: 0.556,
# loss_perturb: 2.781, loss_adv: 104.394,
#
# accuracy in training set after perturbation: 84.409192
#
# 692.827586889267 seconds
# epoch 81:
# loss_D: 0.213, loss_G_fake: 0.589,
# loss_perturb: 2.776, loss_adv: 104.368,
#
# accuracy in training set after perturbation: 84.294422
#
# 701.4221081733704 seconds
# epoch 82:
# loss_D: 0.212, loss_G_fake: 0.593,
# loss_perturb: 2.771, loss_adv: 104.356,
#
# accuracy in training set after perturbation: 84.268918
#
# 710.1088750362396 seconds
# epoch 83:
# loss_D: 0.212, loss_G_fake: 0.593,
# loss_perturb: 2.764, loss_adv: 104.346,
#
# accuracy in training set after perturbation: 84.212808
#
# 718.7341244220734 seconds
# epoch 84:
# loss_D: 0.212, loss_G_fake: 0.593,
# loss_perturb: 2.757, loss_adv: 104.337,
#
# accuracy in training set after perturbation: 84.210258
#
# 727.3674495220184 seconds
# epoch 85:
# loss_D: 0.212, loss_G_fake: 0.592,
# loss_perturb: 2.751, loss_adv: 104.329,
#
# accuracy in training set after perturbation: 84.189854
#
# 735.9886600971222 seconds
# epoch 86:
# loss_D: 0.212, loss_G_fake: 0.593,
# loss_perturb: 2.745, loss_adv: 104.322,
#
# accuracy in training set after perturbation: 84.197506
#
# 744.5879559516907 seconds
# epoch 87:
# loss_D: 0.213, loss_G_fake: 0.592,
# loss_perturb: 2.740, loss_adv: 104.316,
#
# accuracy in training set after perturbation: 84.200056
#
# 753.1557552814484 seconds
# epoch 88:
# loss_D: 0.213, loss_G_fake: 0.591,
# loss_perturb: 2.735, loss_adv: 104.310,
#
# accuracy in training set after perturbation: 84.146497
#
# 761.7666957378387 seconds
# epoch 89:
# loss_D: 0.214, loss_G_fake: 0.591,
# loss_perturb: 2.730, loss_adv: 104.304,
#
# accuracy in training set after perturbation: 84.154148
#
# 770.3578794002533 seconds
# epoch 90:
# loss_D: 0.214, loss_G_fake: 0.591,
# loss_perturb: 2.725, loss_adv: 104.299,
#
# accuracy in training set after perturbation: 84.172001
#
# 779.0682537555695 seconds
# epoch 91:
# loss_D: 0.214, loss_G_fake: 0.590,
# loss_perturb: 2.721, loss_adv: 104.293,
#
# accuracy in training set after perturbation: 84.179653
#
# 787.8242959976196 seconds
# epoch 92:
# loss_D: 0.214, loss_G_fake: 0.590,
# loss_perturb: 2.717, loss_adv: 104.288,
#
# accuracy in training set after perturbation: 84.154148
#
# 796.4759836196899 seconds
# epoch 93:
# loss_D: 0.214, loss_G_fake: 0.589,
# loss_perturb: 2.712, loss_adv: 104.284,
#
# accuracy in training set after perturbation: 84.161800
#
# 805.1691718101501 seconds
# epoch 94:
# loss_D: 0.214, loss_G_fake: 0.589,
# loss_perturb: 2.708, loss_adv: 104.279,
#
# accuracy in training set after perturbation: 84.202607
#
# 813.9788439273834 seconds
# epoch 95:
# loss_D: 0.214, loss_G_fake: 0.590,
# loss_perturb: 2.704, loss_adv: 104.274,
#
# accuracy in training set after perturbation: 84.164350
#
# 822.5672438144684 seconds
# epoch 96:
# loss_D: 0.215, loss_G_fake: 0.589,
# loss_perturb: 2.700, loss_adv: 104.270,
#
# accuracy in training set after perturbation: 84.182203
#
# 831.1616005897522 seconds
# epoch 97:
# loss_D: 0.214, loss_G_fake: 0.589,
# loss_perturb: 2.697, loss_adv: 104.265,
#
# accuracy in training set after perturbation: 84.177102
#
# 839.7626504898071 seconds
# epoch 98:
# loss_D: 0.215, loss_G_fake: 0.589,
# loss_perturb: 2.693, loss_adv: 104.261,
#
# accuracy in training set after perturbation: 84.161800
#
# 848.3615679740906 seconds
# epoch 99:
# loss_D: 0.215, loss_G_fake: 0.589,
# loss_perturb: 2.690, loss_adv: 104.257,
#
# accuracy in training set after perturbation: 84.210258
#
# 856.9770910739899 seconds
# epoch 100:
# loss_D: 0.215, loss_G_fake: 0.588,
# loss_perturb: 2.686, loss_adv: 104.253,
#
# accuracy in training set after perturbation: 84.159249
#
# 865.6376190185547 seconds
# epoch 101:
# loss_D: 0.215, loss_G_fake: 0.588,
# loss_perturb: 2.683, loss_adv: 104.248,
#
# accuracy in training set after perturbation: 84.151598
#
# 874.2796430587769 seconds
# epoch 102:
# loss_D: 0.215, loss_G_fake: 0.588,
# loss_perturb: 2.680, loss_adv: 104.245,
#
# accuracy in training set after perturbation: 84.174552
#
# 882.9193234443665 seconds
# epoch 103:
# loss_D: 0.216, loss_G_fake: 0.587,
# loss_perturb: 2.677, loss_adv: 104.241,
#
# accuracy in training set after perturbation: 84.166900
#
# 891.5087265968323 seconds
# epoch 104:
# loss_D: 0.215, loss_G_fake: 0.588,
# loss_perturb: 2.674, loss_adv: 104.237,
#
# accuracy in training set after perturbation: 84.194955
#
# 900.1310493946075 seconds
# epoch 105:
# loss_D: 0.215, loss_G_fake: 0.587,
# loss_perturb: 2.671, loss_adv: 104.234,
#
# accuracy in training set after perturbation: 84.189854
#
# 908.7638022899628 seconds
# epoch 106:
# loss_D: 0.216, loss_G_fake: 0.587,
# loss_perturb: 2.669, loss_adv: 104.230,
#
# accuracy in training set after perturbation: 84.151598
#
# 917.3329751491547 seconds
# epoch 107:
# loss_D: 0.216, loss_G_fake: 0.587,
# loss_perturb: 2.666, loss_adv: 104.226,
#
# accuracy in training set after perturbation: 84.179653
#
# 925.887336730957 seconds
# epoch 108:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.663, loss_adv: 104.223,
#
# accuracy in training set after perturbation: 84.164350
#
# 934.5397822856903 seconds
# epoch 109:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.660, loss_adv: 104.219,
#
# accuracy in training set after perturbation: 84.166900
#
# 943.149688243866 seconds
# epoch 110:
# loss_D: 0.216, loss_G_fake: 0.587,
# loss_perturb: 2.658, loss_adv: 104.215,
#
# accuracy in training set after perturbation: 84.197506
#
# 951.797792673111 seconds
# epoch 111:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.655, loss_adv: 104.212,
#
# accuracy in training set after perturbation: 84.136295
#
# 960.3927803039551 seconds
# epoch 112:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.652, loss_adv: 104.208,
#
# accuracy in training set after perturbation: 84.210258
#
# 968.9767167568207 seconds
# epoch 113:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.651, loss_adv: 104.205,
#
# accuracy in training set after perturbation: 84.154148
#
# 977.5521509647369 seconds
# epoch 114:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.647, loss_adv: 104.202,
#
# accuracy in training set after perturbation: 84.146497
#
# 986.1507921218872 seconds
# epoch 115:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.645, loss_adv: 104.199,
#
# accuracy in training set after perturbation: 84.138846
#
# 994.7744364738464 seconds
# epoch 116:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.642, loss_adv: 104.196,
#
# accuracy in training set after perturbation: 84.177102
#
# 1003.3599240779877 seconds
# epoch 117:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.641, loss_adv: 104.193,
#
# accuracy in training set after perturbation: 84.172001
#
# 1011.9970536231995 seconds
# epoch 118:
# loss_D: 0.216, loss_G_fake: 0.586,
# loss_perturb: 2.639, loss_adv: 104.190,
#
# accuracy in training set after perturbation: 84.164350
#
# 1020.609457731247 seconds
# epoch 119:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.636, loss_adv: 104.186,
#
# accuracy in training set after perturbation: 84.172001
#
# 1029.2831313610077 seconds
# epoch 120:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.633, loss_adv: 104.183,
#
# accuracy in training set after perturbation: 84.115892
#
# 1037.8979709148407 seconds
# epoch 121:
# loss_D: 0.217, loss_G_fake: 0.585,
# loss_perturb: 2.631, loss_adv: 104.180,
#
# accuracy in training set after perturbation: 84.141396
#
# 1046.455069065094 seconds
# epoch 122:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.629, loss_adv: 104.177,
#
# accuracy in training set after perturbation: 84.164350
#
# 1055.0652170181274 seconds
# epoch 123:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.627, loss_adv: 104.174,
#
# accuracy in training set after perturbation: 84.177102
#
# 1063.5972633361816 seconds
# epoch 124:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.625, loss_adv: 104.171,
#
# accuracy in training set after perturbation: 84.174552
#
# 1072.181923866272 seconds
# epoch 125:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.623, loss_adv: 104.168,
#
# accuracy in training set after perturbation: 84.131194
#
# 1080.757381439209 seconds
# epoch 126:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.621, loss_adv: 104.166,
#
# accuracy in training set after perturbation: 84.184754
#
# 1089.4765729904175 seconds
# epoch 127:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.619, loss_adv: 104.163,
#
# accuracy in training set after perturbation: 84.131194
#
# 1098.057130098343 seconds
# epoch 128:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.617, loss_adv: 104.160,
#
# accuracy in training set after perturbation: 84.177102
#
# 1106.6956934928894 seconds
# epoch 129:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.614, loss_adv: 104.157,
#
# accuracy in training set after perturbation: 84.159249
#
# 1115.42418217659 seconds
# epoch 130:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.612, loss_adv: 104.155,
#
# accuracy in training set after perturbation: 84.146497
#
# 1124.181002855301 seconds
# epoch 131:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.610, loss_adv: 104.152,
#
# accuracy in training set after perturbation: 84.136295
#
# 1132.7458219528198 seconds
# epoch 132:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.608, loss_adv: 104.148,
#
# accuracy in training set after perturbation: 84.133745
#
# 1141.341532945633 seconds
# epoch 133:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.606, loss_adv: 104.146,
#
# accuracy in training set after perturbation: 84.131194
#
# 1149.8842387199402 seconds
# epoch 134:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.604, loss_adv: 104.143,
#
# accuracy in training set after perturbation: 84.120993
#
# 1158.4434521198273 seconds
# epoch 135:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.602, loss_adv: 104.140,
#
# accuracy in training set after perturbation: 84.151598
#
# 1166.9911756515503 seconds
# epoch 136:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.601, loss_adv: 104.138,
#
# accuracy in training set after perturbation: 84.151598
#
# 1175.582664489746 seconds
# epoch 137:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.599, loss_adv: 104.135,
#
# accuracy in training set after perturbation: 84.138846
#
# 1184.163649559021 seconds
# epoch 138:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.596, loss_adv: 104.133,
#
# accuracy in training set after perturbation: 84.166900
#
# 1192.813348531723 seconds
# epoch 139:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.596, loss_adv: 104.130,
#
# accuracy in training set after perturbation: 84.143947
#
# 1201.4137399196625 seconds
# epoch 140:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.594, loss_adv: 104.127,
#
# accuracy in training set after perturbation: 84.110791
#
# 1210.0370349884033 seconds
# epoch 141:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.592, loss_adv: 104.124,
#
# accuracy in training set after perturbation: 84.133745
#
# 1218.6141340732574 seconds
# epoch 142:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.590, loss_adv: 104.122,
#
# accuracy in training set after perturbation: 84.136295
#
# 1227.2119657993317 seconds
# epoch 143:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.589, loss_adv: 104.119,
#
# accuracy in training set after perturbation: 84.154148
#
# 1235.7911486625671 seconds
# epoch 144:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.587, loss_adv: 104.116,
#
# accuracy in training set after perturbation: 84.103140
#
# 1244.3697109222412 seconds
# epoch 145:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.586, loss_adv: 104.114,
#
# accuracy in training set after perturbation: 84.136295
#
# 1252.9462313652039 seconds
# epoch 146:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.584, loss_adv: 104.112,
#
# accuracy in training set after perturbation: 84.146497
#
# 1261.5703520774841 seconds
# epoch 147:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.583, loss_adv: 104.109,
#
# accuracy in training set after perturbation: 84.166900
#
# 1270.2080128192902 seconds
# epoch 148:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.582, loss_adv: 104.107,
#
# accuracy in training set after perturbation: 84.149047
#
# 1278.7934007644653 seconds
# epoch 149:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.580, loss_adv: 104.104,
#
# accuracy in training set after perturbation: 84.090387
#
# 1287.3686192035675 seconds
# epoch 150:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.579, loss_adv: 104.102,
#
# accuracy in training set after perturbation: 84.128644
#
# 1296.0107083320618 seconds
# epoch 151:
# loss_D: 0.217, loss_G_fake: 0.584,
# loss_perturb: 2.578, loss_adv: 104.100,
#
# accuracy in training set after perturbation: 84.161800
#
# 1304.5677304267883 seconds
# epoch 152:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.576, loss_adv: 104.097,
#
# accuracy in training set after perturbation: 84.105690
#
# 1313.1729481220245 seconds
# epoch 153:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.575, loss_adv: 104.095,
#
# accuracy in training set after perturbation: 84.136295
#
# 1321.7017135620117 seconds
# epoch 154:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.575, loss_adv: 104.093,
#
# accuracy in training set after perturbation: 84.154148
#
# 1330.3051006793976 seconds
# epoch 155:
# loss_D: 0.216, loss_G_fake: 0.585,
# loss_perturb: 2.573, loss_adv: 104.090,
#
# accuracy in training set after perturbation: 84.131194
#
# 1338.8795795440674 seconds
# epoch 156:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.571, loss_adv: 104.087,
#
# accuracy in training set after perturbation: 84.098039
#
# 1347.4993197917938 seconds
# epoch 157:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.570, loss_adv: 104.085,
#
# accuracy in training set after perturbation: 84.128644
#
# 1356.121579170227 seconds
# epoch 158:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.569, loss_adv: 104.083,
#
# accuracy in training set after perturbation: 84.110791
#
# 1364.712134361267 seconds
# epoch 159:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.567, loss_adv: 104.080,
#
# accuracy in training set after perturbation: 84.123543
#
# 1373.271237373352 seconds
# epoch 160:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.567, loss_adv: 104.078,
#
# accuracy in training set after perturbation: 84.136295
#
# 1381.8675847053528 seconds
# epoch 161:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.565, loss_adv: 104.075,
#
# accuracy in training set after perturbation: 84.146497
#
# 1390.4756772518158 seconds
# epoch 162:
# loss_D: 0.216, loss_G_fake: 0.584,
# loss_perturb: 2.564, loss_adv: 104.073,
#
# accuracy in training set after perturbation: 84.113341
#
# 1399.0909521579742 seconds
# epoch 163:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.563, loss_adv: 104.071,
#
# accuracy in training set after perturbation: 84.123543
#
# 1407.6329863071442 seconds
# epoch 164:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.562, loss_adv: 104.069,
#
# accuracy in training set after perturbation: 84.156699
#
# 1416.196984052658 seconds
# epoch 165:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.560, loss_adv: 104.066,
#
# accuracy in training set after perturbation: 84.126093
#
# 1424.8871130943298 seconds
# epoch 166:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.560, loss_adv: 104.064,
#
# accuracy in training set after perturbation: 84.156699
#
# 1433.6828067302704 seconds
# epoch 167:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.559, loss_adv: 104.062,
#
# accuracy in training set after perturbation: 84.166900
#
# 1442.2515585422516 seconds
# epoch 168:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.558, loss_adv: 104.059,
#
# accuracy in training set after perturbation: 84.077635
#
# 1450.8332388401031 seconds
# epoch 169:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.556, loss_adv: 104.056,
#
# accuracy in training set after perturbation: 84.169451
#
# 1459.3817923069 seconds
# epoch 170:
# loss_D: 0.217, loss_G_fake: 0.582,
# loss_perturb: 2.556, loss_adv: 104.054,
#
# accuracy in training set after perturbation: 84.113341
#
# 1467.9187002182007 seconds
# epoch 171:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.554, loss_adv: 104.051,
#
# accuracy in training set after perturbation: 84.126093
#
# 1476.488513469696 seconds
# epoch 172:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.554, loss_adv: 104.049,
#
# accuracy in training set after perturbation: 84.120993
#
# 1485.067212343216 seconds
# epoch 173:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.553, loss_adv: 104.047,
#
# accuracy in training set after perturbation: 84.146497
#
# 1493.6456999778748 seconds
# epoch 174:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.553, loss_adv: 104.044,
#
# accuracy in training set after perturbation: 84.103140
#
# 1502.2773506641388 seconds
# epoch 175:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.551, loss_adv: 104.042,
#
# accuracy in training set after perturbation: 84.118442
#
# 1510.9512016773224 seconds
# epoch 176:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.551, loss_adv: 104.039,
#
# accuracy in training set after perturbation: 84.110791
#
# 1519.548299074173 seconds
# epoch 177:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.550, loss_adv: 104.037,
#
# accuracy in training set after perturbation: 84.108240
#
# 1528.069417476654 seconds
# epoch 178:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.549, loss_adv: 104.035,
#
# accuracy in training set after perturbation: 84.092938
#
# 1536.6450884342194 seconds
# epoch 179:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.548, loss_adv: 104.033,
#
# accuracy in training set after perturbation: 84.143947
#
# 1545.21160197258 seconds
# epoch 180:
# loss_D: 0.217, loss_G_fake: 0.582,
# loss_perturb: 2.547, loss_adv: 104.031,
#
# accuracy in training set after perturbation: 84.123543
#
# 1553.7716717720032 seconds
# epoch 181:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.546, loss_adv: 104.028,
#
# accuracy in training set after perturbation: 84.069984
#
# 1562.3424298763275 seconds
# epoch 182:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.545, loss_adv: 104.026,
#
# accuracy in training set after perturbation: 84.133745
#
# 1570.8854956626892 seconds
# epoch 183:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.545, loss_adv: 104.024,
#
# accuracy in training set after perturbation: 84.141396
#
# 1579.460286140442 seconds
# epoch 184:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.544, loss_adv: 104.022,
#
# accuracy in training set after perturbation: 84.069984
#
# 1588.0865302085876 seconds
# epoch 185:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.543, loss_adv: 104.019,
#
# accuracy in training set after perturbation: 84.120993
#
# 1596.7034375667572 seconds
# epoch 186:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.543, loss_adv: 104.017,
#
# accuracy in training set after perturbation: 84.136295
#
# 1605.276343345642 seconds
# epoch 187:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.542, loss_adv: 104.015,
#
# accuracy in training set after perturbation: 84.080186
#
# 1613.8233106136322 seconds
# epoch 188:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.541, loss_adv: 104.013,
#
# accuracy in training set after perturbation: 84.098039
#
# 1622.428794145584 seconds
# epoch 189:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.540, loss_adv: 104.010,
#
# accuracy in training set after perturbation: 84.062333
#
# 1631.0151376724243 seconds
# epoch 190:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.539, loss_adv: 104.008,
#
# accuracy in training set after perturbation: 84.154148
#
# 1639.6079845428467 seconds
# epoch 191:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.538, loss_adv: 104.007,
#
# accuracy in training set after perturbation: 84.105690
#
# 1648.1725301742554 seconds
# epoch 192:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.538, loss_adv: 104.005,
#
# accuracy in training set after perturbation: 84.080186
#
# 1656.7488918304443 seconds
# epoch 193:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.537, loss_adv: 104.002,
#
# accuracy in training set after perturbation: 84.087837
#
# 1665.3079962730408 seconds
# epoch 194:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.536, loss_adv: 104.001,
#
# accuracy in training set after perturbation: 84.128644
#
# 1673.9503121376038 seconds
# epoch 195:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.535, loss_adv: 103.999,
#
# accuracy in training set after perturbation: 84.082736
#
# 1682.5141396522522 seconds
# epoch 196:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.535, loss_adv: 103.997,
#
# accuracy in training set after perturbation: 84.105690
#
# 1691.0840094089508 seconds
# epoch 197:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.534, loss_adv: 103.995,
#
# accuracy in training set after perturbation: 84.069984
#
# 1699.774376153946 seconds
# epoch 198:
# loss_D: 0.216, loss_G_fake: 0.582,
# loss_perturb: 2.533, loss_adv: 103.992,
#
# accuracy in training set after perturbation: 84.072534
#
# 1708.3226470947266 seconds
# epoch 199:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.533, loss_adv: 103.990,
#
# accuracy in training set after perturbation: 84.108240
#
# 1716.8697481155396 seconds
# epoch 200:
# loss_D: 0.216, loss_G_fake: 0.583,
# loss_perturb: 2.533, loss_adv: 103.989,
#
# accuracy in training set after perturbation: 84.100589
#
# 1725.4736757278442 seconds
# accuracy in test set on all perturbed images: 82.232779
#
# misclassifications on previously correctly classified images: 18.289786
