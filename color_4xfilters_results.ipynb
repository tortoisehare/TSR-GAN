# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_4xfilters_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.03, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 32, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(128),
                       ResnetBlock(128),
                       ResnetBlock(128),
                       ResnetBlock(128),]

        decoder_lis = [
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(32, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1225.206055
#
# Train accuracy so far: 41.482823
#
# loss in epoch 1: 334.397461
#
# Train accuracy so far: 84.013874
#
# loss in epoch 2: 162.469284
#
# Train accuracy so far: 92.764416
#
# loss in epoch 3: 103.400063
#
# Train accuracy so far: 95.546941
#
# loss in epoch 4: 74.065338
#
# Train accuracy so far: 96.944579
#
# loss in epoch 5: 55.048695
#
# Train accuracy so far: 97.719911
#
# loss in epoch 6: 48.800976
#
# Train accuracy so far: 97.880589
#
# loss in epoch 7: 37.256519
#
# Train accuracy so far: 98.390676
#
# loss in epoch 8: 32.316429
#
# Train accuracy so far: 98.620215
#
# loss in epoch 9: 26.370127
#
# Train accuracy so far: 98.829350
#
# loss in epoch 10: 25.195860
#
# Train accuracy so far: 98.895662
#
# loss in epoch 11: 23.576263
#
# Train accuracy so far: 98.933918
#
# loss in epoch 12: 18.174234
#
# Train accuracy so far: 99.150705
#
# loss in epoch 13: 16.483107
#
# Train accuracy so far: 99.234870
#
# loss in epoch 14: 17.204882
#
# Train accuracy so far: 99.178760
#
# loss in epoch 15: 12.248221
#
# Train accuracy so far: 99.390446
#
# loss in epoch 16: 10.045057
#
# Train accuracy so far: 99.520518
#
# loss in epoch 17: 16.489794
#
# Train accuracy so far: 99.247622
#
# loss in epoch 18: 11.815685
#
# Train accuracy so far: 99.446556
#
# loss in epoch 19: 11.962004
#
# Train accuracy so far: 99.428703
#
# accuracy in testing set: 90.950119

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.03
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.03
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.03
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.950119
#
# epoch 1:
# loss_D: 0.407, loss_G_fake: 0.328,
# loss_perturb: 33.666, loss_adv: 99.210,
#
# accuracy in training set after perturbation: 80.519779
#
# 20.74008059501648 seconds
# epoch 2:
# loss_D: 0.212, loss_G_fake: 0.557,
# loss_perturb: 35.844, loss_adv: 81.169,
#
# accuracy in training set after perturbation: 66.614808
#
# 40.87204456329346 seconds
# epoch 3:
# loss_D: 0.148, loss_G_fake: 0.661,
# loss_perturb: 36.302, loss_adv: 72.411,
#
# accuracy in training set after perturbation: 59.639369
#
# 60.62106800079346 seconds
# epoch 4:
# loss_D: 0.154, loss_G_fake: 0.676,
# loss_perturb: 35.761, loss_adv: 67.991,
#
# accuracy in training set after perturbation: 56.063659
#
# 80.30175447463989 seconds
# epoch 5:
# loss_D: 0.142, loss_G_fake: 0.704,
# loss_perturb: 34.937, loss_adv: 63.291,
#
# accuracy in training set after perturbation: 52.243107
#
# 100.24960446357727 seconds
# epoch 6:
# loss_D: 0.118, loss_G_fake: 0.752,
# loss_perturb: 35.150, loss_adv: 62.381,
#
# accuracy in training set after perturbation: 51.539187
#
# 120.20802092552185 seconds
# epoch 7:
# loss_D: 0.096, loss_G_fake: 0.789,
# loss_perturb: 34.798, loss_adv: 58.871,
#
# accuracy in training set after perturbation: 48.649545
#
# 140.10306215286255 seconds
# epoch 8:
# loss_D: 0.086, loss_G_fake: 0.814,
# loss_perturb: 33.846, loss_adv: 56.803,
#
# accuracy in training set after perturbation: 46.930552
#
# 159.94472193717957 seconds
# epoch 9:
# loss_D: 0.064, loss_G_fake: 0.854,
# loss_perturb: 33.713, loss_adv: 55.863,
#
# accuracy in training set after perturbation: 46.216430
#
# 179.77085304260254 seconds
# epoch 10:
# loss_D: 0.055, loss_G_fake: 0.873,
# loss_perturb: 32.874, loss_adv: 53.547,
#
# accuracy in training set after perturbation: 44.201586
#
# 199.58110451698303 seconds
# epoch 11:
# loss_D: 0.059, loss_G_fake: 0.872,
# loss_perturb: 32.745, loss_adv: 52.866,
#
# accuracy in training set after perturbation: 43.586932
#
# 219.3950936794281 seconds
# epoch 12:
# loss_D: 0.047, loss_G_fake: 0.889,
# loss_perturb: 32.053, loss_adv: 50.890,
#
# accuracy in training set after perturbation: 42.038818
#
# 239.20021796226501 seconds
# epoch 13:
# loss_D: 0.050, loss_G_fake: 0.886,
# loss_perturb: 32.400, loss_adv: 50.416,
#
# accuracy in training set after perturbation: 41.697059
#
# 259.0525281429291 seconds
# epoch 14:
# loss_D: 0.044, loss_G_fake: 0.892,
# loss_perturb: 31.651, loss_adv: 49.999,
#
# accuracy in training set after perturbation: 41.411411
#
# 278.8666045665741 seconds
# epoch 15:
# loss_D: 0.042, loss_G_fake: 0.904,
# loss_perturb: 30.876, loss_adv: 47.677,
#
# accuracy in training set after perturbation: 39.450126
#
# 298.6821277141571 seconds
# epoch 16:
# loss_D: 0.038, loss_G_fake: 0.914,
# loss_perturb: 30.767, loss_adv: 47.528,
#
# accuracy in training set after perturbation: 39.263945
#
# 318.5346395969391 seconds
# epoch 17:
# loss_D: 0.029, loss_G_fake: 0.928,
# loss_perturb: 29.301, loss_adv: 46.008,
#
# accuracy in training set after perturbation: 38.021883
#
# 338.4128108024597 seconds
# epoch 18:
# loss_D: 0.031, loss_G_fake: 0.929,
# loss_perturb: 28.845, loss_adv: 45.339,
#
# accuracy in training set after perturbation: 37.516897
#
# 358.2134087085724 seconds
# epoch 19:
# loss_D: 0.025, loss_G_fake: 0.937,
# loss_perturb: 28.586, loss_adv: 43.992,
#
# accuracy in training set after perturbation: 36.389604
#
# 377.99664330482483 seconds
# epoch 20:
# loss_D: 0.029, loss_G_fake: 0.936,
# loss_perturb: 27.281, loss_adv: 42.752,
#
# accuracy in training set after perturbation: 35.249560
#
# 397.82002210617065 seconds
# epoch 21:
# loss_D: 0.023, loss_G_fake: 0.942,
# loss_perturb: 26.432, loss_adv: 41.766,
#
# accuracy in training set after perturbation: 34.430870
#
# 417.6120135784149 seconds
# epoch 22:
# loss_D: 0.027, loss_G_fake: 0.939,
# loss_perturb: 25.740, loss_adv: 41.757,
#
# accuracy in training set after perturbation: 34.418118
#
# 437.3924343585968 seconds
# epoch 23:
# loss_D: 0.023, loss_G_fake: 0.946,
# loss_perturb: 24.815, loss_adv: 40.447,
#
# accuracy in training set after perturbation: 33.359688
#
# 457.18940329551697 seconds
# epoch 24:
# loss_D: 0.030, loss_G_fake: 0.936,
# loss_perturb: 24.733, loss_adv: 39.575,
#
# accuracy in training set after perturbation: 32.727180
#
# 476.9012897014618 seconds
# epoch 25:
# loss_D: 0.021, loss_G_fake: 0.951,
# loss_perturb: 24.398, loss_adv: 39.194,
#
# accuracy in training set after perturbation: 32.354816
#
# 496.656943321228 seconds
# epoch 26:
# loss_D: 0.016, loss_G_fake: 0.957,
# loss_perturb: 23.919, loss_adv: 38.477,
#
# accuracy in training set after perturbation: 31.770767
#
# 516.4028458595276 seconds
# epoch 27:
# loss_D: 0.018, loss_G_fake: 0.955,
# loss_perturb: 23.500, loss_adv: 37.694,
#
# accuracy in training set after perturbation: 31.176516
#
# 536.1835532188416 seconds
# epoch 28:
# loss_D: 0.018, loss_G_fake: 0.956,
# loss_perturb: 22.987, loss_adv: 36.985,
#
# accuracy in training set after perturbation: 30.510852
#
# 555.9728724956512 seconds
# epoch 29:
# loss_D: 0.020, loss_G_fake: 0.951,
# loss_perturb: 22.318, loss_adv: 36.356,
#
# accuracy in training set after perturbation: 29.937004
#
# 575.7407779693604 seconds
# epoch 30:
# loss_D: 0.019, loss_G_fake: 0.953,
# loss_perturb: 22.366, loss_adv: 35.900,
#
# accuracy in training set after perturbation: 29.615649
#
# 595.467193365097 seconds
# epoch 31:
# loss_D: 0.021, loss_G_fake: 0.951,
# loss_perturb: 21.889, loss_adv: 35.475,
#
# accuracy in training set after perturbation: 29.271341
#
# 615.2567255496979 seconds
# epoch 32:
# loss_D: 0.014, loss_G_fake: 0.960,
# loss_perturb: 21.436, loss_adv: 34.862,
#
# accuracy in training set after perturbation: 28.791859
#
# 635.0285456180573 seconds
# epoch 33:
# loss_D: 0.029, loss_G_fake: 0.940,
# loss_perturb: 20.855, loss_adv: 34.206,
#
# accuracy in training set after perturbation: 28.309827
#
# 654.9078695774078 seconds
# epoch 34:
# loss_D: 0.010, loss_G_fake: 0.963,
# loss_perturb: 20.971, loss_adv: 33.736,
#
# accuracy in training set after perturbation: 27.883904
#
# 674.6954135894775 seconds
# epoch 35:
# loss_D: 0.008, loss_G_fake: 0.965,
# loss_perturb: 20.333, loss_adv: 33.235,
#
# accuracy in training set after perturbation: 27.389120
#
# 694.430826663971 seconds
# epoch 36:
# loss_D: 0.009, loss_G_fake: 0.968,
# loss_perturb: 19.995, loss_adv: 32.626,
#
# accuracy in training set after perturbation: 26.924941
#
# 714.0610730648041 seconds
# epoch 37:
# loss_D: 0.005, loss_G_fake: 0.975,
# loss_perturb: 19.798, loss_adv: 32.164,
#
# accuracy in training set after perturbation: 26.486266
#
# 733.777268409729 seconds
# epoch 38:
# loss_D: 0.002, loss_G_fake: 0.982,
# loss_perturb: 19.859, loss_adv: 31.970,
#
# accuracy in training set after perturbation: 26.419955
#
# 753.5237834453583 seconds
# epoch 39:
# loss_D: 0.010, loss_G_fake: 0.972,
# loss_perturb: 19.467, loss_adv: 31.763,
#
# accuracy in training set after perturbation: 26.241424
#
# 773.3520503044128 seconds
# epoch 40:
# loss_D: 0.010, loss_G_fake: 0.969,
# loss_perturb: 18.842, loss_adv: 31.152,
#
# accuracy in training set after perturbation: 25.642072
#
# 793.1785140037537 seconds
# epoch 41:
# loss_D: 0.014, loss_G_fake: 0.959,
# loss_perturb: 18.285, loss_adv: 30.507,
#
# accuracy in training set after perturbation: 25.063123
#
# 812.9802582263947 seconds
# epoch 42:
# loss_D: 0.007, loss_G_fake: 0.972,
# loss_perturb: 18.109, loss_adv: 30.297,
#
# accuracy in training set after perturbation: 24.864189
#
# 832.81920170784 seconds
# epoch 43:
# loss_D: 0.003, loss_G_fake: 0.981,
# loss_perturb: 18.085, loss_adv: 30.189,
#
# accuracy in training set after perturbation: 24.894795
#
# 852.7543036937714 seconds
# epoch 44:
# loss_D: 0.015, loss_G_fake: 0.959,
# loss_perturb: 18.163, loss_adv: 29.998,
#
# accuracy in training set after perturbation: 24.744319
#
# 872.5176937580109 seconds
# epoch 45:
# loss_D: 0.005, loss_G_fake: 0.977,
# loss_perturb: 17.586, loss_adv: 29.398,
#
# accuracy in training set after perturbation: 24.195975
#
# 892.2313044071198 seconds
# epoch 46:
# loss_D: 0.001, loss_G_fake: 0.987,
# loss_perturb: 17.382, loss_adv: 29.044,
#
# accuracy in training set after perturbation: 23.889923
#
# 912.0246803760529 seconds
# epoch 47:
# loss_D: 0.005, loss_G_fake: 0.979,
# loss_perturb: 17.536, loss_adv: 28.960,
#
# accuracy in training set after perturbation: 23.930730
#
# 931.7545347213745 seconds
# epoch 48:
# loss_D: 0.005, loss_G_fake: 0.976,
# loss_perturb: 17.290, loss_adv: 28.565,
#
# accuracy in training set after perturbation: 23.581321
#
# 951.5124638080597 seconds
# epoch 49:
# loss_D: 0.004, loss_G_fake: 0.978,
# loss_perturb: 17.562, loss_adv: 28.451,
#
# accuracy in training set after perturbation: 23.430845
#
# 971.3074386119843 seconds
# epoch 50:
# loss_D: 0.001, loss_G_fake: 0.990,
# loss_perturb: 16.718, loss_adv: 27.300,
#
# accuracy in training set after perturbation: 22.244893
#
# 991.0145938396454 seconds
# epoch 51:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 15.681, loss_adv: 26.758,
#
# accuracy in training set after perturbation: 21.704201
#
# 1010.8297193050385 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 14.911, loss_adv: 26.492,
#
# accuracy in training set after perturbation: 21.449157
#
# 1030.657785654068 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 14.351, loss_adv: 26.289,
#
# accuracy in training set after perturbation: 21.301232
#
# 1050.455959558487 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 13.781, loss_adv: 26.129,
#
# accuracy in training set after perturbation: 21.130353
#
# 1070.2195825576782 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 13.191, loss_adv: 25.987,
#
# accuracy in training set after perturbation: 21.023234
#
# 1090.0009667873383 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 12.772, loss_adv: 25.874,
#
# accuracy in training set after perturbation: 20.921217
#
# 1109.8045029640198 seconds
# epoch 57:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 12.042, loss_adv: 25.795,
#
# accuracy in training set after perturbation: 20.885511
#
# 1129.5590515136719 seconds
# epoch 58:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 11.445, loss_adv: 25.659,
#
# accuracy in training set after perturbation: 20.729934
#
# 1149.2916510105133 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 10.951, loss_adv: 25.582,
#
# accuracy in training set after perturbation: 20.737586
#
# 1169.0898931026459 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 10.309, loss_adv: 25.477,
#
# accuracy in training set after perturbation: 20.592211
#
# 1188.9391124248505 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 9.836, loss_adv: 25.400,
#
# accuracy in training set after perturbation: 20.587110
#
# 1208.7430939674377 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 9.279, loss_adv: 25.314,
#
# accuracy in training set after perturbation: 20.477441
#
# 1228.5025382041931 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 8.705, loss_adv: 25.218,
#
# accuracy in training set after perturbation: 20.362672
#
# 1248.33957529068 seconds
# epoch 64:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 8.323, loss_adv: 25.175,
#
# accuracy in training set after perturbation: 20.380525
#
# 1268.225911140442 seconds
# epoch 65:
# loss_D: 0.001, loss_G_fake: 0.992,
# loss_perturb: 8.127, loss_adv: 25.101,
#
# accuracy in training set after perturbation: 20.344819
#
# 1288.0210444927216 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 7.691, loss_adv: 25.027,
#
# accuracy in training set after perturbation: 20.265755
#
# 1307.787590265274 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 7.541, loss_adv: 24.941,
#
# accuracy in training set after perturbation: 20.145885
#
# 1327.5371928215027 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 7.029, loss_adv: 24.871,
#
# accuracy in training set after perturbation: 20.056620
#
# 1347.2817075252533 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 6.827, loss_adv: 24.808,
#
# accuracy in training set after perturbation: 20.020914
#
# 1367.0256876945496 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 6.603, loss_adv: 24.765,
#
# accuracy in training set after perturbation: 20.008161
#
# 1386.8774156570435 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 6.511, loss_adv: 24.726,
#
# accuracy in training set after perturbation: 20.005611
#
# 1406.656903743744 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 6.216, loss_adv: 24.616,
#
# accuracy in training set after perturbation: 19.850034
#
# 1426.455563545227 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 6.137, loss_adv: 24.559,
#
# accuracy in training set after perturbation: 19.827081
#
# 1446.199892282486 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 6.104, loss_adv: 24.539,
#
# accuracy in training set after perturbation: 19.814328
#
# 1466.0446598529816 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 5.991, loss_adv: 24.476,
#
# accuracy in training set after perturbation: 19.760769
#
# 1485.8540136814117 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 5.842, loss_adv: 24.405,
#
# accuracy in training set after perturbation: 19.671504
#
# 1505.6789088249207 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 5.696, loss_adv: 24.358,
#
# accuracy in training set after perturbation: 19.635798
#
# 1525.4677939414978 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 5.546, loss_adv: 24.299,
#
# accuracy in training set after perturbation: 19.574587
#
# 1545.2453413009644 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 5.601, loss_adv: 24.261,
#
# accuracy in training set after perturbation: 19.594991
#
# 1565.051787853241 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 5.127, loss_adv: 24.122,
#
# accuracy in training set after perturbation: 19.253233
#
# 1584.958251953125 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.952, loss_adv: 24.092,
#
# accuracy in training set after perturbation: 19.194573
#
# 1604.7787940502167 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.847, loss_adv: 24.080,
#
# accuracy in training set after perturbation: 19.217527
#
# 1624.5322370529175 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.766, loss_adv: 24.065,
#
# accuracy in training set after perturbation: 19.163967
#
# 1644.2449333667755 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.676, loss_adv: 24.059,
#
# accuracy in training set after perturbation: 19.176720
#
# 1664.037290096283 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.626, loss_adv: 24.051,
#
# accuracy in training set after perturbation: 19.189472
#
# 1683.7929475307465 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.573, loss_adv: 24.041,
#
# accuracy in training set after perturbation: 19.207325
#
# 1703.5330700874329 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.516, loss_adv: 24.031,
#
# accuracy in training set after perturbation: 19.153766
#
# 1723.266226053238 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.476, loss_adv: 24.023,
#
# accuracy in training set after perturbation: 19.163967
#
# 1743.0138676166534 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.432, loss_adv: 24.016,
#
# accuracy in training set after perturbation: 19.181821
#
# 1762.8232493400574 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.406, loss_adv: 24.008,
#
# accuracy in training set after perturbation: 19.169068
#
# 1782.6113901138306 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.373, loss_adv: 23.999,
#
# accuracy in training set after perturbation: 19.197123
#
# 1802.4082903862 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.338, loss_adv: 23.991,
#
# accuracy in training set after perturbation: 19.163967
#
# 1822.25501537323 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.314, loss_adv: 23.985,
#
# accuracy in training set after perturbation: 19.161417
#
# 1842.015721321106 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.281, loss_adv: 23.977,
#
# accuracy in training set after perturbation: 19.174169
#
# 1861.872806072235 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.254, loss_adv: 23.968,
#
# accuracy in training set after perturbation: 19.163967
#
# 1881.7805848121643 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.241, loss_adv: 23.960,
#
# accuracy in training set after perturbation: 19.179270
#
# 1901.662965297699 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.211, loss_adv: 23.952,
#
# accuracy in training set after perturbation: 19.143564
#
# 1921.503922700882 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.203, loss_adv: 23.947,
#
# accuracy in training set after perturbation: 19.166518
#
# 1941.3365106582642 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.167, loss_adv: 23.939,
#
# accuracy in training set after perturbation: 19.123160
#
# 1961.145554304123 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.154, loss_adv: 23.934,
#
# accuracy in training set after perturbation: 19.153766
#
# 1980.9143288135529 seconds
# accuracy in test set on all perturbed images: 28.115598
#
# misclassifications on previously correctly classified images: 72.137767
