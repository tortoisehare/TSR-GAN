# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p005_10-1adv-pert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.005, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 10:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.005
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 10
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.005
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.005
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<20:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.500, loss_G_fake: 0.250,
# loss_perturb: 10.119, loss_adv: 125.724,
#
# accuracy in training set after perturbation: 99.495014
#
# 8.663479328155518 seconds
# epoch 2:
# loss_D: 0.496, loss_G_fake: 0.252,
# loss_perturb: 6.473, loss_adv: 124.635,
#
# accuracy in training set after perturbation: 98.951771
#
# 17.29750919342041 seconds
# epoch 3:
# loss_D: 0.493, loss_G_fake: 0.256,
# loss_perturb: 7.336, loss_adv: 121.422,
#
# accuracy in training set after perturbation: 97.110357
#
# 25.945534706115723 seconds
# epoch 4:
# loss_D: 0.467, loss_G_fake: 0.275,
# loss_perturb: 5.926, loss_adv: 119.269,
#
# accuracy in training set after perturbation: 95.771379
#
# 34.64818334579468 seconds
# epoch 5:
# loss_D: 0.444, loss_G_fake: 0.295,
# loss_perturb: 6.022, loss_adv: 117.942,
#
# accuracy in training set after perturbation: 94.901681
#
# 43.32969546318054 seconds
# epoch 6:
# loss_D: 0.440, loss_G_fake: 0.299,
# loss_perturb: 5.902, loss_adv: 116.855,
#
# accuracy in training set after perturbation: 94.075340
#
# 52.088462114334106 seconds
# epoch 7:
# loss_D: 0.451, loss_G_fake: 0.295,
# loss_perturb: 6.197, loss_adv: 115.880,
#
# accuracy in training set after perturbation: 93.417328
#
# 60.783159255981445 seconds
# epoch 8:
# loss_D: 0.443, loss_G_fake: 0.302,
# loss_perturb: 5.570, loss_adv: 115.086,
#
# accuracy in training set after perturbation: 92.861333
#
# 69.44150805473328 seconds
# epoch 9:
# loss_D: 0.443, loss_G_fake: 0.302,
# loss_perturb: 5.186, loss_adv: 114.396,
#
# accuracy in training set after perturbation: 92.295136
#
# 78.06361675262451 seconds
# epoch 10:
# loss_D: 0.432, loss_G_fake: 0.312,
# loss_perturb: 5.172, loss_adv: 113.953,
#
# accuracy in training set after perturbation: 91.996735
#
# 86.68150115013123 seconds
# epoch 11:
# loss_D: 0.422, loss_G_fake: 0.319,
# loss_perturb: 5.021, loss_adv: 113.413,
#
# accuracy in training set after perturbation: 91.642225
#
# 95.54045462608337 seconds
# epoch 12:
# loss_D: 0.423, loss_G_fake: 0.323,
# loss_perturb: 5.271, loss_adv: 113.059,
#
# accuracy in training set after perturbation: 91.366778
#
# 104.24992084503174 seconds
# epoch 13:
# loss_D: 0.424, loss_G_fake: 0.329,
# loss_perturb: 4.631, loss_adv: 112.501,
#
# accuracy in training set after perturbation: 90.894948
#
# 112.87554621696472 seconds
# epoch 14:
# loss_D: 0.419, loss_G_fake: 0.340,
# loss_perturb: 5.159, loss_adv: 112.468,
#
# accuracy in training set after perturbation: 90.961259
#
# 121.49101781845093 seconds
# epoch 15:
# loss_D: 0.406, loss_G_fake: 0.357,
# loss_perturb: 4.906, loss_adv: 111.774,
#
# accuracy in training set after perturbation: 90.461374
#
# 130.13448357582092 seconds
# epoch 16:
# loss_D: 0.405, loss_G_fake: 0.368,
# loss_perturb: 4.916, loss_adv: 111.578,
#
# accuracy in training set after perturbation: 90.351705
#
# 138.81213474273682 seconds
# epoch 17:
# loss_D: 0.404, loss_G_fake: 0.375,
# loss_perturb: 4.619, loss_adv: 111.341,
#
# accuracy in training set after perturbation: 90.122166
#
# 147.41829824447632 seconds
# epoch 18:
# loss_D: 0.396, loss_G_fake: 0.386,
# loss_perturb: 4.548, loss_adv: 110.938,
#
# accuracy in training set after perturbation: 89.867122
#
# 156.06548619270325 seconds
# epoch 19:
# loss_D: 0.391, loss_G_fake: 0.392,
# loss_perturb: 4.714, loss_adv: 110.588,
#
# accuracy in training set after perturbation: 89.535566
#
# 164.6427206993103 seconds
# epoch 20:
# loss_D: 0.384, loss_G_fake: 0.404,
# loss_perturb: 4.184, loss_adv: 110.024,
#
# accuracy in training set after perturbation: 89.165753
#
# 173.26844549179077 seconds
# epoch 21:
# loss_D: 0.382, loss_G_fake: 0.410,
# loss_perturb: 4.403, loss_adv: 109.933,
#
# accuracy in training set after perturbation: 89.170854
#
# 181.84119319915771 seconds
# epoch 22:
# loss_D: 0.372, loss_G_fake: 0.418,
# loss_perturb: 4.266, loss_adv: 109.682,
#
# accuracy in training set after perturbation: 88.928562
#
# 190.39369559288025 seconds
# epoch 23:
# loss_D: 0.380, loss_G_fake: 0.421,
# loss_perturb: 4.349, loss_adv: 109.338,
#
# accuracy in training set after perturbation: 88.594455
#
# 199.0069899559021 seconds
# epoch 24:
# loss_D: 0.368, loss_G_fake: 0.426,
# loss_perturb: 4.089, loss_adv: 109.024,
#
# accuracy in training set after perturbation: 88.443980
#
# 207.64995574951172 seconds
# epoch 25:
# loss_D: 0.384, loss_G_fake: 0.418,
# loss_perturb: 4.029, loss_adv: 108.913,
#
# accuracy in training set after perturbation: 88.339412
#
# 216.29405045509338 seconds
# epoch 26:
# loss_D: 0.387, loss_G_fake: 0.415,
# loss_perturb: 4.028, loss_adv: 108.606,
#
# accuracy in training set after perturbation: 88.063965
#
# 224.8941171169281 seconds
# epoch 27:
# loss_D: 0.361, loss_G_fake: 0.432,
# loss_perturb: 3.880, loss_adv: 108.435,
#
# accuracy in training set after perturbation: 87.893086
#
# 233.50438690185547 seconds
# epoch 28:
# loss_D: 0.355, loss_G_fake: 0.441,
# loss_perturb: 4.016, loss_adv: 108.985,
#
# accuracy in training set after perturbation: 88.545997
#
# 242.08361649513245 seconds
# epoch 29:
# loss_D: 0.346, loss_G_fake: 0.449,
# loss_perturb: 3.994, loss_adv: 108.350,
#
# accuracy in training set after perturbation: 87.933893
#
# 250.64825534820557 seconds
# epoch 30:
# loss_D: 0.338, loss_G_fake: 0.459,
# loss_perturb: 3.977, loss_adv: 108.127,
#
# accuracy in training set after perturbation: 87.747711
#
# 259.24434208869934 seconds
# epoch 31:
# loss_D: 0.334, loss_G_fake: 0.463,
# loss_perturb: 3.835, loss_adv: 107.857,
#
# accuracy in training set after perturbation: 87.576832
#
# 267.81459879875183 seconds
# epoch 32:
# loss_D: 0.346, loss_G_fake: 0.460,
# loss_perturb: 3.809, loss_adv: 107.868,
#
# accuracy in training set after perturbation: 87.587034
#
# 276.40623807907104 seconds
# epoch 33:
# loss_D: 0.354, loss_G_fake: 0.457,
# loss_perturb: 3.877, loss_adv: 107.654,
#
# accuracy in training set after perturbation: 87.380448
#
# 284.9748547077179 seconds
# epoch 34:
# loss_D: 0.356, loss_G_fake: 0.454,
# loss_perturb: 4.000, loss_adv: 107.450,
#
# accuracy in training set after perturbation: 87.316687
#
# 293.6566159725189 seconds
# epoch 35:
# loss_D: 0.331, loss_G_fake: 0.471,
# loss_perturb: 3.913, loss_adv: 107.252,
#
# accuracy in training set after perturbation: 87.031039
#
# 302.2570745944977 seconds
# epoch 36:
# loss_D: 0.336, loss_G_fake: 0.471,
# loss_perturb: 3.818, loss_adv: 107.246,
#
# accuracy in training set after perturbation: 87.173863
#
# 310.8389587402344 seconds
# epoch 37:
# loss_D: 0.316, loss_G_fake: 0.481,
# loss_perturb: 3.768, loss_adv: 107.058,
#
# accuracy in training set after perturbation: 86.990232
#
# 319.4139859676361 seconds
# epoch 38:
# loss_D: 0.331, loss_G_fake: 0.482,
# loss_perturb: 3.554, loss_adv: 106.788,
#
# accuracy in training set after perturbation: 86.645923
#
# 328.02133560180664 seconds
# epoch 39:
# loss_D: 0.320, loss_G_fake: 0.491,
# loss_perturb: 3.711, loss_adv: 107.009,
#
# accuracy in training set after perturbation: 87.036140
#
# 336.60055661201477 seconds
# epoch 40:
# loss_D: 0.305, loss_G_fake: 0.498,
# loss_perturb: 3.773, loss_adv: 106.786,
#
# accuracy in training set after perturbation: 86.842307
#
# 345.18703532218933 seconds
# epoch 41:
# loss_D: 0.311, loss_G_fake: 0.500,
# loss_perturb: 3.689, loss_adv: 106.627,
#
# accuracy in training set after perturbation: 86.686730
#
# 353.79987597465515 seconds
# epoch 42:
# loss_D: 0.300, loss_G_fake: 0.512,
# loss_perturb: 3.724, loss_adv: 106.467,
#
# accuracy in training set after perturbation: 86.482695
#
# 362.4438154697418 seconds
# epoch 43:
# loss_D: 0.295, loss_G_fake: 0.517,
# loss_perturb: 4.009, loss_adv: 106.914,
#
# accuracy in training set after perturbation: 87.082047
#
# 371.0506820678711 seconds
# epoch 44:
# loss_D: 0.293, loss_G_fake: 0.519,
# loss_perturb: 3.833, loss_adv: 106.444,
#
# accuracy in training set after perturbation: 86.582162
#
# 379.7100522518158 seconds
# epoch 45:
# loss_D: 0.299, loss_G_fake: 0.512,
# loss_perturb: 3.761, loss_adv: 106.288,
#
# accuracy in training set after perturbation: 86.421485
#
# 388.2518413066864 seconds
# epoch 46:
# loss_D: 0.303, loss_G_fake: 0.514,
# loss_perturb: 3.975, loss_adv: 106.289,
#
# accuracy in training set after perturbation: 86.469943
#
# 396.81812024116516 seconds
# epoch 47:
# loss_D: 0.286, loss_G_fake: 0.527,
# loss_perturb: 3.948, loss_adv: 106.282,
#
# accuracy in training set after perturbation: 86.508200
#
# 405.63956451416016 seconds
# epoch 48:
# loss_D: 0.295, loss_G_fake: 0.522,
# loss_perturb: 3.711, loss_adv: 106.138,
#
# accuracy in training set after perturbation: 86.296514
#
# 414.3261249065399 seconds
# epoch 49:
# loss_D: 0.286, loss_G_fake: 0.534,
# loss_perturb: 3.813, loss_adv: 106.180,
#
# accuracy in training set after perturbation: 86.464842
#
# 422.8865559101105 seconds
# epoch 50:
# loss_D: 0.230, loss_G_fake: 0.557,
# loss_perturb: 3.778, loss_adv: 105.692,
#
# accuracy in training set after perturbation: 85.852738
#
# 431.4967420101166 seconds
# epoch 51:
# loss_D: 0.231, loss_G_fake: 0.557,
# loss_perturb: 3.462, loss_adv: 105.359,
#
# accuracy in training set after perturbation: 85.258487
#
# 440.0893757343292 seconds
# epoch 52:
# loss_D: 0.234, loss_G_fake: 0.553,
# loss_perturb: 3.237, loss_adv: 105.198,
#
# accuracy in training set after perturbation: 85.041700
#
# 448.71124744415283 seconds
# epoch 53:
# loss_D: 0.237, loss_G_fake: 0.550,
# loss_perturb: 3.054, loss_adv: 105.086,
#
# accuracy in training set after perturbation: 84.914178
#
# 457.4535071849823 seconds
# epoch 54:
# loss_D: 0.240, loss_G_fake: 0.547,
# loss_perturb: 2.912, loss_adv: 105.008,
#
# accuracy in training set after perturbation: 84.847867
#
# 466.07767152786255 seconds
# epoch 55:
# loss_D: 0.242, loss_G_fake: 0.546,
# loss_perturb: 2.793, loss_adv: 104.939,
#
# accuracy in training set after perturbation: 84.779005
#
# 474.64242148399353 seconds
# epoch 56:
# loss_D: 0.243, loss_G_fake: 0.545,
# loss_perturb: 2.694, loss_adv: 104.872,
#
# accuracy in training set after perturbation: 84.758601
#
# 483.2679624557495 seconds
# epoch 57:
# loss_D: 0.246, loss_G_fake: 0.542,
# loss_perturb: 2.606, loss_adv: 104.814,
#
# accuracy in training set after perturbation: 84.705042
#
# 491.8159513473511 seconds
# epoch 58:
# loss_D: 0.249, loss_G_fake: 0.540,
# loss_perturb: 2.539, loss_adv: 104.762,
#
# accuracy in training set after perturbation: 84.705042
#
# 500.35756039619446 seconds
# epoch 59:
# loss_D: 0.251, loss_G_fake: 0.538,
# loss_perturb: 2.468, loss_adv: 104.717,
#
# accuracy in training set after perturbation: 84.661685
#
# 508.9425172805786 seconds
# epoch 60:
# loss_D: 0.251, loss_G_fake: 0.538,
# loss_perturb: 2.410, loss_adv: 104.682,
#
# accuracy in training set after perturbation: 84.669336
#
# 517.5046365261078 seconds
# epoch 61:
# loss_D: 0.252, loss_G_fake: 0.538,
# loss_perturb: 2.361, loss_adv: 104.646,
#
# accuracy in training set after perturbation: 84.659134
#
# 526.0286195278168 seconds
# epoch 62:
# loss_D: 0.252, loss_G_fake: 0.538,
# loss_perturb: 2.315, loss_adv: 104.589,
#
# accuracy in training set after perturbation: 84.572420
#
# 534.685378074646 seconds
# epoch 63:
# loss_D: 0.252, loss_G_fake: 0.538,
# loss_perturb: 2.278, loss_adv: 104.545,
#
# accuracy in training set after perturbation: 84.518860
#
# 543.3422708511353 seconds
# epoch 64:
# loss_D: 0.250, loss_G_fake: 0.541,
# loss_perturb: 2.250, loss_adv: 104.515,
#
# accuracy in training set after perturbation: 84.567319
#
# 552.0550396442413 seconds
# epoch 65:
# loss_D: 0.250, loss_G_fake: 0.542,
# loss_perturb: 2.225, loss_adv: 104.523,
#
# accuracy in training set after perturbation: 84.654034
#
# 560.8624746799469 seconds
# epoch 66:
# loss_D: 0.249, loss_G_fake: 0.543,
# loss_perturb: 2.196, loss_adv: 104.437,
#
# accuracy in training set after perturbation: 84.449999
#
# 569.7519886493683 seconds
# epoch 67:
# loss_D: 0.251, loss_G_fake: 0.540,
# loss_perturb: 2.171, loss_adv: 104.394,
#
# accuracy in training set after perturbation: 84.404091
#
# 578.5803954601288 seconds
# epoch 68:
# loss_D: 0.250, loss_G_fake: 0.542,
# loss_perturb: 2.153, loss_adv: 104.360,
#
# accuracy in training set after perturbation: 84.424494
#
# 587.6034944057465 seconds
# epoch 69:
# loss_D: 0.250, loss_G_fake: 0.542,
# loss_perturb: 2.137, loss_adv: 104.326,
#
# accuracy in training set after perturbation: 84.347981
#
# 596.4714095592499 seconds
# epoch 70:
# loss_D: 0.251, loss_G_fake: 0.542,
# loss_perturb: 2.124, loss_adv: 104.295,
#
# accuracy in training set after perturbation: 84.368385
#
# 605.3380780220032 seconds
# epoch 71:
# loss_D: 0.252, loss_G_fake: 0.542,
# loss_perturb: 2.123, loss_adv: 104.295,
#
# accuracy in training set after perturbation: 84.437247
#
# 614.0614688396454 seconds
# epoch 72:
# loss_D: 0.252, loss_G_fake: 0.541,
# loss_perturb: 2.110, loss_adv: 104.250,
#
# accuracy in training set after perturbation: 84.368385
#
# 622.783851146698 seconds
# epoch 73:
# loss_D: 0.251, loss_G_fake: 0.543,
# loss_perturb: 2.101, loss_adv: 104.216,
#
# accuracy in training set after perturbation: 84.307174
#
# 631.4472050666809 seconds
# epoch 74:
# loss_D: 0.251, loss_G_fake: 0.542,
# loss_perturb: 2.100, loss_adv: 104.193,
#
# accuracy in training set after perturbation: 84.314826
#
# 640.1414339542389 seconds
# epoch 75:
# loss_D: 0.250, loss_G_fake: 0.544,
# loss_perturb: 2.106, loss_adv: 104.175,
#
# accuracy in training set after perturbation: 84.347981
#
# 648.8233108520508 seconds
# epoch 76:
# loss_D: 0.249, loss_G_fake: 0.545,
# loss_perturb: 2.117, loss_adv: 104.157,
#
# accuracy in training set after perturbation: 84.322477
#
# 657.4869863986969 seconds
# epoch 77:
# loss_D: 0.249, loss_G_fake: 0.546,
# loss_perturb: 2.124, loss_adv: 104.131,
#
# accuracy in training set after perturbation: 84.307174
#
# 666.1283557415009 seconds
# epoch 78:
# loss_D: 0.247, loss_G_fake: 0.547,
# loss_perturb: 2.123, loss_adv: 104.106,
#
# accuracy in training set after perturbation: 84.289321
#
# 674.8112201690674 seconds
# epoch 79:
# loss_D: 0.248, loss_G_fake: 0.547,
# loss_perturb: 2.114, loss_adv: 104.076,
#
# accuracy in training set after perturbation: 84.197506
#
# 683.4552340507507 seconds
# epoch 80:
# loss_D: 0.241, loss_G_fake: 0.546,
# loss_perturb: 2.097, loss_adv: 104.000,
#
# accuracy in training set after perturbation: 84.062333
#
# 692.2420363426208 seconds
# epoch 81:
# loss_D: 0.240, loss_G_fake: 0.548,
# loss_perturb: 2.086, loss_adv: 103.978,
#
# accuracy in training set after perturbation: 83.899105
#
# 700.9511497020721 seconds
# epoch 82:
# loss_D: 0.241, loss_G_fake: 0.548,
# loss_perturb: 2.077, loss_adv: 103.968,
#
# accuracy in training set after perturbation: 83.863399
#
# 709.6848487854004 seconds
# epoch 83:
# loss_D: 0.241, loss_G_fake: 0.547,
# loss_perturb: 2.070, loss_adv: 103.960,
#
# accuracy in training set after perturbation: 83.886353
#
# 718.5735342502594 seconds
# epoch 84:
# loss_D: 0.242, loss_G_fake: 0.547,
# loss_perturb: 2.063, loss_adv: 103.953,
#
# accuracy in training set after perturbation: 83.894004
#
# 727.2404308319092 seconds
# epoch 85:
# loss_D: 0.242, loss_G_fake: 0.546,
# loss_perturb: 2.058, loss_adv: 103.946,
#
# accuracy in training set after perturbation: 83.871050
#
# 735.8586032390594 seconds
# epoch 86:
# loss_D: 0.242, loss_G_fake: 0.546,
# loss_perturb: 2.052, loss_adv: 103.940,
#
# accuracy in training set after perturbation: 83.868500
#
# 744.4937219619751 seconds
# epoch 87:
# loss_D: 0.242, loss_G_fake: 0.546,
# loss_perturb: 2.047, loss_adv: 103.935,
#
# accuracy in training set after perturbation: 83.863399
#
# 753.1193082332611 seconds
# epoch 88:
# loss_D: 0.243, loss_G_fake: 0.546,
# loss_perturb: 2.042, loss_adv: 103.929,
#
# accuracy in training set after perturbation: 83.868500
#
# 761.8794474601746 seconds
# epoch 89:
# loss_D: 0.243, loss_G_fake: 0.546,
# loss_perturb: 2.038, loss_adv: 103.924,
#
# accuracy in training set after perturbation: 83.871050
#
# 770.5096809864044 seconds
# epoch 90:
# loss_D: 0.243, loss_G_fake: 0.545,
# loss_perturb: 2.035, loss_adv: 103.919,
#
# accuracy in training set after perturbation: 83.876151
#
# 779.2320072650909 seconds
# epoch 91:
# loss_D: 0.243, loss_G_fake: 0.545,
# loss_perturb: 2.030, loss_adv: 103.915,
#
# accuracy in training set after perturbation: 83.891453
#
# 787.8247654438019 seconds
# epoch 92:
# loss_D: 0.243, loss_G_fake: 0.545,
# loss_perturb: 2.027, loss_adv: 103.910,
#
# accuracy in training set after perturbation: 83.878701
#
# 796.4674730300903 seconds
# epoch 93:
# loss_D: 0.244, loss_G_fake: 0.545,
# loss_perturb: 2.023, loss_adv: 103.906,
#
# accuracy in training set after perturbation: 83.899105
#
# 805.075793504715 seconds
# epoch 94:
# loss_D: 0.244, loss_G_fake: 0.545,
# loss_perturb: 2.020, loss_adv: 103.901,
#
# accuracy in training set after perturbation: 83.894004
#
# 813.7183353900909 seconds
# epoch 95:
# loss_D: 0.244, loss_G_fake: 0.545,
# loss_perturb: 2.017, loss_adv: 103.897,
#
# accuracy in training set after perturbation: 83.901655
#
# 822.3177256584167 seconds
# epoch 96:
# loss_D: 0.244, loss_G_fake: 0.545,
# loss_perturb: 2.015, loss_adv: 103.894,
#
# accuracy in training set after perturbation: 83.888903
#
# 830.9962441921234 seconds
# epoch 97:
# loss_D: 0.244, loss_G_fake: 0.544,
# loss_perturb: 2.011, loss_adv: 103.889,
#
# accuracy in training set after perturbation: 83.881252
#
# 839.6513063907623 seconds
# epoch 98:
# loss_D: 0.244, loss_G_fake: 0.544,
# loss_perturb: 2.008, loss_adv: 103.885,
#
# accuracy in training set after perturbation: 83.863399
#
# 848.3167173862457 seconds
# epoch 99:
# loss_D: 0.244, loss_G_fake: 0.545,
# loss_perturb: 2.006, loss_adv: 103.882,
#
# accuracy in training set after perturbation: 83.914407
#
# 857.0120191574097 seconds
# epoch 100:
# loss_D: 0.244, loss_G_fake: 0.544,
# loss_perturb: 2.003, loss_adv: 103.878,
#
# accuracy in training set after perturbation: 83.894004
#
# 865.6918332576752 seconds
# accuracy in test set on all perturbed images: 81.900238
#
# misclassifications on previously correctly classified images: 18.598575
