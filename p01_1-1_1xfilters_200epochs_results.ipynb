# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/p01_1-1_1xfilters_200epochs_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pert 0.01, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 1x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.5)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.5)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.6)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.6)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 1*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:1*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

X_test = np.dot(X_test, grayscale)
X_train = np.dot(X_train, grayscale)
X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
X_train = np.expand_dims(X_train,-1)
X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 1, 32, 32)
# (39209, 43)
# (12630, 1, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 1 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1193.792236
#
# Train accuracy so far: 45.915479
#
# loss in epoch 1: 354.900970
#
# Train accuracy so far: 84.194955
#
# loss in epoch 2: 203.248566
#
# Train accuracy so far: 91.259660
#
# loss in epoch 3: 139.179703
#
# Train accuracy so far: 94.144202
#
# loss in epoch 4: 102.459068
#
# Train accuracy so far: 95.679563
#
# loss in epoch 5: 78.902824
#
# Train accuracy so far: 96.768599
#
# loss in epoch 6: 60.991600
#
# Train accuracy so far: 97.452116
#
# loss in epoch 7: 50.032291
#
# Train accuracy so far: 97.849983
#
# loss in epoch 8: 40.417599
#
# Train accuracy so far: 98.227448
#
# loss in epoch 9: 36.542507
#
# Train accuracy so far: 98.411079
#
# loss in epoch 10: 30.485725
#
# Train accuracy so far: 98.561555
#
# loss in epoch 11: 25.528242
#
# Train accuracy so far: 98.834451
#
# loss in epoch 12: 21.495441
#
# Train accuracy so far: 99.058890
#
# loss in epoch 13: 24.302420
#
# Train accuracy so far: 98.801296
#
# loss in epoch 14: 18.620249
#
# Train accuracy so far: 99.163457
#
# loss in epoch 15: 16.566515
#
# Train accuracy so far: 99.242521
#
# loss in epoch 16: 13.266971
#
# Train accuracy so far: 99.319034
#
# loss in epoch 17: 13.485975
#
# Train accuracy so far: 99.377694
#
# loss in epoch 18: 13.617745
#
# Train accuracy so far: 99.341988
#
# loss in epoch 19: 10.281184
#
# Train accuracy so far: 99.535821
#
# accuracy in testing set: 90.973872

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.01
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.01
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.01
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image, cmap='gray')
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image, cmap='gray')
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=1
epochs = 200

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.973872
#
# epoch 1:
# loss_D: 0.499, loss_G_fake: 0.252,
# loss_perturb: 8.729, loss_adv: 118.999,
#
# accuracy in training set after perturbation: 95.643857
#
# 8.32655119895935 seconds
# epoch 2:
# loss_D: 0.497, loss_G_fake: 0.253,
# loss_perturb: 7.102, loss_adv: 116.420,
#
# accuracy in training set after perturbation: 94.090642
#
# 16.646257877349854 seconds
# epoch 3:
# loss_D: 0.493, loss_G_fake: 0.256,
# loss_perturb: 5.995, loss_adv: 114.969,
#
# accuracy in training set after perturbation: 93.039863
#
# 24.72438931465149 seconds
# epoch 4:
# loss_D: 0.494, loss_G_fake: 0.257,
# loss_perturb: 5.555, loss_adv: 114.712,
#
# accuracy in training set after perturbation: 92.815425
#
# 32.79046082496643 seconds
# epoch 5:
# loss_D: 0.497, loss_G_fake: 0.252,
# loss_perturb: 4.624, loss_adv: 114.157,
#
# accuracy in training set after perturbation: 92.463465
#
# 40.945066690444946 seconds
# epoch 6:
# loss_D: 0.480, loss_G_fake: 0.266,
# loss_perturb: 4.498, loss_adv: 113.505,
#
# accuracy in training set after perturbation: 92.098753
#
# 49.05136775970459 seconds
# epoch 7:
# loss_D: 0.405, loss_G_fake: 0.326,
# loss_perturb: 5.775, loss_adv: 113.147,
#
# accuracy in training set after perturbation: 91.736591
#
# 57.081937074661255 seconds
# epoch 8:
# loss_D: 0.324, loss_G_fake: 0.398,
# loss_perturb: 5.223, loss_adv: 111.743,
#
# accuracy in training set after perturbation: 90.935755
#
# 65.07755041122437 seconds
# epoch 9:
# loss_D: 0.295, loss_G_fake: 0.432,
# loss_perturb: 5.291, loss_adv: 110.844,
#
# accuracy in training set after perturbation: 90.168074
#
# 73.07474851608276 seconds
# epoch 10:
# loss_D: 0.277, loss_G_fake: 0.453,
# loss_perturb: 4.742, loss_adv: 109.028,
#
# accuracy in training set after perturbation: 88.890306
#
# 81.04459857940674 seconds
# epoch 11:
# loss_D: 0.293, loss_G_fake: 0.445,
# loss_perturb: 4.679, loss_adv: 107.768,
#
# accuracy in training set after perturbation: 87.905838
#
# 89.07143878936768 seconds
# epoch 12:
# loss_D: 0.295, loss_G_fake: 0.451,
# loss_perturb: 4.566, loss_adv: 106.179,
#
# accuracy in training set after perturbation: 86.804050
#
# 97.0690016746521 seconds
# epoch 13:
# loss_D: 0.299, loss_G_fake: 0.450,
# loss_perturb: 4.341, loss_adv: 105.205,
#
# accuracy in training set after perturbation: 85.916499
#
# 105.0738365650177 seconds
# epoch 14:
# loss_D: 0.307, loss_G_fake: 0.447,
# loss_perturb: 4.177, loss_adv: 103.926,
#
# accuracy in training set after perturbation: 84.977939
#
# 113.0960328578949 seconds
# epoch 15:
# loss_D: 0.306, loss_G_fake: 0.451,
# loss_perturb: 4.442, loss_adv: 102.987,
#
# accuracy in training set after perturbation: 84.281670
#
# 121.32425260543823 seconds
# epoch 16:
# loss_D: 0.331, loss_G_fake: 0.432,
# loss_perturb: 4.181, loss_adv: 101.773,
#
# accuracy in training set after perturbation: 83.381367
#
# 129.5288426876068 seconds
# epoch 17:
# loss_D: 0.341, loss_G_fake: 0.425,
# loss_perturb: 4.250, loss_adv: 100.870,
#
# accuracy in training set after perturbation: 82.787115
#
# 137.72560596466064 seconds
# epoch 18:
# loss_D: 0.330, loss_G_fake: 0.435,
# loss_perturb: 3.864, loss_adv: 99.459,
#
# accuracy in training set after perturbation: 81.672575
#
# 145.74009108543396 seconds
# epoch 19:
# loss_D: 0.324, loss_G_fake: 0.441,
# loss_perturb: 4.228, loss_adv: 98.840,
#
# accuracy in training set after perturbation: 81.221148
#
# 153.6949064731598 seconds
# epoch 20:
# loss_D: 0.335, loss_G_fake: 0.434,
# loss_perturb: 3.799, loss_adv: 97.883,
#
# accuracy in training set after perturbation: 80.420312
#
# 161.66506218910217 seconds
# epoch 21:
# loss_D: 0.327, loss_G_fake: 0.443,
# loss_perturb: 4.035, loss_adv: 97.285,
#
# accuracy in training set after perturbation: 79.999490
#
# 169.63943910598755 seconds
# epoch 22:
# loss_D: 0.323, loss_G_fake: 0.447,
# loss_perturb: 3.796, loss_adv: 96.305,
#
# accuracy in training set after perturbation: 79.117039
#
# 177.60768008232117 seconds
# epoch 23:
# loss_D: 0.312, loss_G_fake: 0.457,
# loss_perturb: 3.577, loss_adv: 95.620,
#
# accuracy in training set after perturbation: 78.688566
#
# 185.57516980171204 seconds
# epoch 24:
# loss_D: 0.339, loss_G_fake: 0.444,
# loss_perturb: 3.674, loss_adv: 94.961,
#
# accuracy in training set after perturbation: 78.188681
#
# 193.5438370704651 seconds
# epoch 25:
# loss_D: 0.327, loss_G_fake: 0.442,
# loss_perturb: 3.684, loss_adv: 94.717,
#
# accuracy in training set after perturbation: 78.058609
#
# 201.66369581222534 seconds
# epoch 26:
# loss_D: 0.320, loss_G_fake: 0.449,
# loss_perturb: 3.718, loss_adv: 94.095,
#
# accuracy in training set after perturbation: 77.449055
#
# 209.7020800113678 seconds
# epoch 27:
# loss_D: 0.335, loss_G_fake: 0.442,
# loss_perturb: 3.420, loss_adv: 93.699,
#
# accuracy in training set after perturbation: 77.247571
#
# 217.6726005077362 seconds
# epoch 28:
# loss_D: 0.326, loss_G_fake: 0.452,
# loss_perturb: 4.007, loss_adv: 93.283,
#
# accuracy in training set after perturbation: 77.028233
#
# 225.63163948059082 seconds
# epoch 29:
# loss_D: 0.340, loss_G_fake: 0.451,
# loss_perturb: 3.499, loss_adv: 92.489,
#
# accuracy in training set after perturbation: 76.291158
#
# 233.59294438362122 seconds
# epoch 30:
# loss_D: 0.319, loss_G_fake: 0.458,
# loss_perturb: 3.438, loss_adv: 92.066,
#
# accuracy in training set after perturbation: 75.931546
#
# 241.59081935882568 seconds
# epoch 31:
# loss_D: 0.323, loss_G_fake: 0.453,
# loss_perturb: 3.142, loss_adv: 91.176,
#
# accuracy in training set after perturbation: 75.202122
#
# 249.55264115333557 seconds
# epoch 32:
# loss_D: 0.340, loss_G_fake: 0.449,
# loss_perturb: 3.185, loss_adv: 90.883,
#
# accuracy in training set after perturbation: 75.008289
#
# 257.7206304073334 seconds
# epoch 33:
# loss_D: 0.327, loss_G_fake: 0.456,
# loss_perturb: 3.280, loss_adv: 90.810,
#
# accuracy in training set after perturbation: 74.903721
#
# 265.7948410511017 seconds
# epoch 34:
# loss_D: 0.324, loss_G_fake: 0.462,
# loss_perturb: 3.129, loss_adv: 90.145,
#
# accuracy in training set after perturbation: 74.429340
#
# 273.78013849258423 seconds
# epoch 35:
# loss_D: 0.321, loss_G_fake: 0.464,
# loss_perturb: 3.220, loss_adv: 90.350,
#
# accuracy in training set after perturbation: 74.638476
#
# 281.78773045539856 seconds
# epoch 36:
# loss_D: 0.310, loss_G_fake: 0.466,
# loss_perturb: 3.206, loss_adv: 89.735,
#
# accuracy in training set after perturbation: 74.125838
#
# 289.82973647117615 seconds
# epoch 37:
# loss_D: 0.307, loss_G_fake: 0.489,
# loss_perturb: 3.122, loss_adv: 89.263,
#
# accuracy in training set after perturbation: 73.666760
#
# 297.8117802143097 seconds
# epoch 38:
# loss_D: 0.274, loss_G_fake: 0.512,
# loss_perturb: 3.135, loss_adv: 88.788,
#
# accuracy in training set after perturbation: 73.406616
#
# 305.77569365501404 seconds
# epoch 39:
# loss_D: 0.277, loss_G_fake: 0.534,
# loss_perturb: 3.222, loss_adv: 88.528,
#
# accuracy in training set after perturbation: 73.120967
#
# 313.7514171600342 seconds
# epoch 40:
# loss_D: 0.241, loss_G_fake: 0.591,
# loss_perturb: 3.189, loss_adv: 88.045,
#
# accuracy in training set after perturbation: 72.707797
#
# 321.7262394428253 seconds
# epoch 41:
# loss_D: 0.222, loss_G_fake: 0.637,
# loss_perturb: 3.104, loss_adv: 87.714,
#
# accuracy in training set after perturbation: 72.394093
#
# 329.70933747291565 seconds
# epoch 42:
# loss_D: 0.216, loss_G_fake: 0.658,
# loss_perturb: 3.111, loss_adv: 87.410,
#
# accuracy in training set after perturbation: 72.241067
#
# 337.6549105644226 seconds
# epoch 43:
# loss_D: 0.153, loss_G_fake: 0.744,
# loss_perturb: 3.086, loss_adv: 87.276,
#
# accuracy in training set after perturbation: 72.136499
#
# 345.6301760673523 seconds
# epoch 44:
# loss_D: 0.159, loss_G_fake: 0.738,
# loss_perturb: 3.083, loss_adv: 87.051,
#
# accuracy in training set after perturbation: 71.845750
#
# 353.58999037742615 seconds
# epoch 45:
# loss_D: 0.328, loss_G_fake: 0.666,
# loss_perturb: 2.918, loss_adv: 86.870,
#
# accuracy in training set after perturbation: 71.799842
#
# 361.6140172481537 seconds
# epoch 46:
# loss_D: 0.407, loss_G_fake: 0.557,
# loss_perturb: 2.992, loss_adv: 86.265,
#
# accuracy in training set after perturbation: 71.185187
#
# 369.6409251689911 seconds
# epoch 47:
# loss_D: 0.268, loss_G_fake: 0.652,
# loss_perturb: 3.269, loss_adv: 86.526,
#
# accuracy in training set after perturbation: 71.646816
#
# 377.60127329826355 seconds
# epoch 48:
# loss_D: 0.236, loss_G_fake: 0.680,
# loss_perturb: 3.271, loss_adv: 86.536,
#
# accuracy in training set after perturbation: 71.733531
#
# 385.5818169116974 seconds
# epoch 49:
# loss_D: 0.196, loss_G_fake: 0.719,
# loss_perturb: 2.989, loss_adv: 86.031,
#
# accuracy in training set after perturbation: 71.129078
#
# 393.56286549568176 seconds
# epoch 50:
# loss_D: 0.112, loss_G_fake: 0.814,
# loss_perturb: 2.813, loss_adv: 84.875,
#
# accuracy in training set after perturbation: 69.813053
#
# 401.522598028183 seconds
# epoch 51:
# loss_D: 0.097, loss_G_fake: 0.837,
# loss_perturb: 2.655, loss_adv: 84.297,
#
# accuracy in training set after perturbation: 69.030070
#
# 409.4855134487152 seconds
# epoch 52:
# loss_D: 0.091, loss_G_fake: 0.848,
# loss_perturb: 2.521, loss_adv: 84.004,
#
# accuracy in training set after perturbation: 68.711265
#
# 417.4527406692505 seconds
# epoch 53:
# loss_D: 0.084, loss_G_fake: 0.862,
# loss_perturb: 2.407, loss_adv: 83.796,
#
# accuracy in training set after perturbation: 68.497029
#
# 425.41453528404236 seconds
# epoch 54:
# loss_D: 0.079, loss_G_fake: 0.872,
# loss_perturb: 2.312, loss_adv: 83.597,
#
# accuracy in training set after perturbation: 68.267490
#
# 433.36025500297546 seconds
# epoch 55:
# loss_D: 0.075, loss_G_fake: 0.879,
# loss_perturb: 2.237, loss_adv: 83.437,
#
# accuracy in training set after perturbation: 68.101711
#
# 441.3737268447876 seconds
# epoch 56:
# loss_D: 0.072, loss_G_fake: 0.885,
# loss_perturb: 2.183, loss_adv: 83.311,
#
# accuracy in training set after perturbation: 68.014997
#
# 449.41919589042664 seconds
# epoch 57:
# loss_D: 0.067, loss_G_fake: 0.896,
# loss_perturb: 2.137, loss_adv: 83.184,
#
# accuracy in training set after perturbation: 67.943584
#
# 457.4107389450073 seconds
# epoch 58:
# loss_D: 0.065, loss_G_fake: 0.900,
# loss_perturb: 2.099, loss_adv: 83.064,
#
# accuracy in training set after perturbation: 67.826264
#
# 465.34693789482117 seconds
# epoch 59:
# loss_D: 0.064, loss_G_fake: 0.903,
# loss_perturb: 2.072, loss_adv: 82.966,
#
# accuracy in training set after perturbation: 67.780357
#
# 473.31672835350037 seconds
# epoch 60:
# loss_D: 0.062, loss_G_fake: 0.906,
# loss_perturb: 2.048, loss_adv: 82.883,
#
# accuracy in training set after perturbation: 67.739550
#
# 481.2728307247162 seconds
# epoch 61:
# loss_D: 0.059, loss_G_fake: 0.912,
# loss_perturb: 2.024, loss_adv: 82.753,
#
# accuracy in training set after perturbation: 67.532964
#
# 489.2454333305359 seconds
# epoch 62:
# loss_D: 0.057, loss_G_fake: 0.916,
# loss_perturb: 2.009, loss_adv: 82.656,
#
# accuracy in training set after perturbation: 67.507460
#
# 497.20152473449707 seconds
# epoch 63:
# loss_D: 0.058, loss_G_fake: 0.915,
# loss_perturb: 1.987, loss_adv: 82.560,
#
# accuracy in training set after perturbation: 67.397791
#
# 505.24139738082886 seconds
# epoch 64:
# loss_D: 0.054, loss_G_fake: 0.921,
# loss_perturb: 1.975, loss_adv: 82.475,
#
# accuracy in training set after perturbation: 67.354434
#
# 513.2006793022156 seconds
# epoch 65:
# loss_D: 0.053, loss_G_fake: 0.924,
# loss_perturb: 1.964, loss_adv: 82.383,
#
# accuracy in training set after perturbation: 67.283022
#
# 521.2002065181732 seconds
# epoch 66:
# loss_D: 0.053, loss_G_fake: 0.925,
# loss_perturb: 1.966, loss_adv: 82.326,
#
# accuracy in training set after perturbation: 67.387590
#
# 529.2191400527954 seconds
# epoch 67:
# loss_D: 0.051, loss_G_fake: 0.928,
# loss_perturb: 1.977, loss_adv: 82.272,
#
# accuracy in training set after perturbation: 67.288123
#
# 537.1437573432922 seconds
# epoch 68:
# loss_D: 0.052, loss_G_fake: 0.927,
# loss_perturb: 2.000, loss_adv: 82.229,
#
# accuracy in training set after perturbation: 67.316177
#
# 545.0779719352722 seconds
# epoch 69:
# loss_D: 0.050, loss_G_fake: 0.931,
# loss_perturb: 2.011, loss_adv: 82.157,
#
# accuracy in training set after perturbation: 67.242215
#
# 553.0085771083832 seconds
# epoch 70:
# loss_D: 0.049, loss_G_fake: 0.933,
# loss_perturb: 2.009, loss_adv: 82.071,
#
# accuracy in training set after perturbation: 67.104491
#
# 560.9612901210785 seconds
# epoch 71:
# loss_D: 0.050, loss_G_fake: 0.931,
# loss_perturb: 2.002, loss_adv: 82.071,
#
# accuracy in training set after perturbation: 67.211610
#
# 569.1362478733063 seconds
# epoch 72:
# loss_D: 0.047, loss_G_fake: 0.935,
# loss_perturb: 1.991, loss_adv: 81.941,
#
# accuracy in training set after perturbation: 66.969318
#
# 577.2059075832367 seconds
# epoch 73:
# loss_D: 0.047, loss_G_fake: 0.936,
# loss_perturb: 1.979, loss_adv: 81.841,
#
# accuracy in training set after perturbation: 66.816292
#
# 585.1478404998779 seconds
# epoch 74:
# loss_D: 0.047, loss_G_fake: 0.935,
# loss_perturb: 1.966, loss_adv: 81.768,
#
# accuracy in training set after perturbation: 66.744880
#
# 593.1050572395325 seconds
# epoch 75:
# loss_D: 0.047, loss_G_fake: 0.937,
# loss_perturb: 1.963, loss_adv: 81.744,
#
# accuracy in training set after perturbation: 66.918310
#
# 601.0903639793396 seconds
# epoch 76:
# loss_D: 0.047, loss_G_fake: 0.937,
# loss_perturb: 1.957, loss_adv: 81.660,
#
# accuracy in training set after perturbation: 66.724477
#
# 609.1451139450073 seconds
# epoch 77:
# loss_D: 0.045, loss_G_fake: 0.939,
# loss_perturb: 1.956, loss_adv: 81.575,
#
# accuracy in training set after perturbation: 66.681119
#
# 617.1181449890137 seconds
# epoch 78:
# loss_D: 0.044, loss_G_fake: 0.942,
# loss_perturb: 1.948, loss_adv: 81.509,
#
# accuracy in training set after perturbation: 66.622459
#
# 625.0807716846466 seconds
# epoch 79:
# loss_D: 0.044, loss_G_fake: 0.941,
# loss_perturb: 1.952, loss_adv: 81.439,
#
# accuracy in training set after perturbation: 66.528093
#
# 633.0351619720459 seconds
# epoch 80:
# loss_D: 0.041, loss_G_fake: 0.952,
# loss_perturb: 1.937, loss_adv: 81.356,
#
# accuracy in training set after perturbation: 66.464332
#
# 640.990415096283 seconds
# epoch 81:
# loss_D: 0.041, loss_G_fake: 0.952,
# loss_perturb: 1.932, loss_adv: 81.304,
#
# accuracy in training set after perturbation: 66.257747
#
# 648.9188027381897 seconds
# epoch 82:
# loss_D: 0.041, loss_G_fake: 0.952,
# loss_perturb: 1.926, loss_adv: 81.279,
#
# accuracy in training set after perturbation: 66.140427
#
# 656.8669993877411 seconds
# epoch 83:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.920, loss_adv: 81.259,
#
# accuracy in training set after perturbation: 66.122574
#
# 664.8352901935577 seconds
# epoch 84:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.914, loss_adv: 81.243,
#
# accuracy in training set after perturbation: 66.084317
#
# 672.7960813045502 seconds
# epoch 85:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.910, loss_adv: 81.229,
#
# accuracy in training set after perturbation: 66.099620
#
# 680.7895057201385 seconds
# epoch 86:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.905, loss_adv: 81.214,
#
# accuracy in training set after perturbation: 66.051162
#
# 688.787145614624 seconds
# epoch 87:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.901, loss_adv: 81.201,
#
# accuracy in training set after perturbation: 66.079217
#
# 696.7397940158844 seconds
# epoch 88:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.898, loss_adv: 81.189,
#
# accuracy in training set after perturbation: 66.097070
#
# 704.6732113361359 seconds
# epoch 89:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.894, loss_adv: 81.177,
#
# accuracy in training set after perturbation: 66.040960
#
# 712.621871471405 seconds
# epoch 90:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.890, loss_adv: 81.165,
#
# accuracy in training set after perturbation: 66.043510
#
# 720.5536189079285 seconds
# epoch 91:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.887, loss_adv: 81.153,
#
# accuracy in training set after perturbation: 66.038410
#
# 728.5171642303467 seconds
# epoch 92:
# loss_D: 0.040, loss_G_fake: 0.951,
# loss_perturb: 1.885, loss_adv: 81.143,
#
# accuracy in training set after perturbation: 66.066464
#
# 736.4657697677612 seconds
# epoch 93:
# loss_D: 0.039, loss_G_fake: 0.951,
# loss_perturb: 1.881, loss_adv: 81.131,
#
# accuracy in training set after perturbation: 66.020557
#
# 744.4060356616974 seconds
# epoch 94:
# loss_D: 0.039, loss_G_fake: 0.951,
# loss_perturb: 1.879, loss_adv: 81.121,
#
# accuracy in training set after perturbation: 66.040960
#
# 752.3559322357178 seconds
# epoch 95:
# loss_D: 0.039, loss_G_fake: 0.951,
# loss_perturb: 1.876, loss_adv: 81.110,
#
# accuracy in training set after perturbation: 66.033309
#
# 760.3161337375641 seconds
# epoch 96:
# loss_D: 0.039, loss_G_fake: 0.951,
# loss_perturb: 1.874, loss_adv: 81.100,
#
# accuracy in training set after perturbation: 66.012905
#
# 768.3363008499146 seconds
# epoch 97:
# loss_D: 0.039, loss_G_fake: 0.951,
# loss_perturb: 1.871, loss_adv: 81.090,
#
# accuracy in training set after perturbation: 66.020557
#
# 776.3000435829163 seconds
# epoch 98:
# loss_D: 0.039, loss_G_fake: 0.951,
# loss_perturb: 1.870, loss_adv: 81.080,
#
# accuracy in training set after perturbation: 66.025657
#
# 784.233615398407 seconds
# epoch 99:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.868, loss_adv: 81.071,
#
# accuracy in training set after perturbation: 66.033309
#
# 792.191751241684 seconds
# epoch 100:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.867, loss_adv: 81.060,
#
# accuracy in training set after perturbation: 66.010355
#
# 800.1375515460968 seconds
# epoch 101:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.864, loss_adv: 81.051,
#
# accuracy in training set after perturbation: 65.977199
#
# 808.1414194107056 seconds
# epoch 102:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.862, loss_adv: 81.040,
#
# accuracy in training set after perturbation: 65.946594
#
# 816.1630322933197 seconds
# epoch 103:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.860, loss_adv: 81.031,
#
# accuracy in training set after perturbation: 66.000153
#
# 824.0976135730743 seconds
# epoch 104:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.859, loss_adv: 81.023,
#
# accuracy in training set after perturbation: 65.995052
#
# 832.05779337883 seconds
# epoch 105:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.858, loss_adv: 81.013,
#
# accuracy in training set after perturbation: 65.987401
#
# 840.029326915741 seconds
# epoch 106:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.857, loss_adv: 81.004,
#
# accuracy in training set after perturbation: 65.972098
#
# 848.0613307952881 seconds
# epoch 107:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.856, loss_adv: 80.996,
#
# accuracy in training set after perturbation: 65.979750
#
# 855.9857478141785 seconds
# epoch 108:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.855, loss_adv: 80.987,
#
# accuracy in training set after perturbation: 66.020557
#
# 863.9400632381439 seconds
# epoch 109:
# loss_D: 0.039, loss_G_fake: 0.952,
# loss_perturb: 1.853, loss_adv: 80.979,
#
# accuracy in training set after perturbation: 65.961897
#
# 871.8844990730286 seconds
# epoch 110:
# loss_D: 0.038, loss_G_fake: 0.952,
# loss_perturb: 1.852, loss_adv: 80.970,
#
# accuracy in training set after perturbation: 65.961897
#
# 880.0728588104248 seconds
# epoch 111:
# loss_D: 0.038, loss_G_fake: 0.952,
# loss_perturb: 1.851, loss_adv: 80.963,
#
# accuracy in training set after perturbation: 65.949144
#
# 888.0917003154755 seconds
# epoch 112:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.850, loss_adv: 80.954,
#
# accuracy in training set after perturbation: 65.959346
#
# 896.02321434021 seconds
# epoch 113:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.849, loss_adv: 80.947,
#
# accuracy in training set after perturbation: 65.928741
#
# 903.9757831096649 seconds
# epoch 114:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.848, loss_adv: 80.939,
#
# accuracy in training set after perturbation: 65.972098
#
# 911.9462018013 seconds
# epoch 115:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.847, loss_adv: 80.930,
#
# accuracy in training set after perturbation: 65.913438
#
# 919.8855359554291 seconds
# epoch 116:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.846, loss_adv: 80.923,
#
# accuracy in training set after perturbation: 65.951695
#
# 927.8997859954834 seconds
# epoch 117:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.845, loss_adv: 80.914,
#
# accuracy in training set after perturbation: 65.900686
#
# 935.8635439872742 seconds
# epoch 118:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.844, loss_adv: 80.908,
#
# accuracy in training set after perturbation: 65.928741
#
# 943.8167178630829 seconds
# epoch 119:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.844, loss_adv: 80.899,
#
# accuracy in training set after perturbation: 65.928741
#
# 951.7770702838898 seconds
# epoch 120:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.843, loss_adv: 80.893,
#
# accuracy in training set after perturbation: 65.944043
#
# 959.7283136844635 seconds
# epoch 121:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.843, loss_adv: 80.886,
#
# accuracy in training set after perturbation: 65.923640
#
# 967.6889908313751 seconds
# epoch 122:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.842, loss_adv: 80.878,
#
# accuracy in training set after perturbation: 65.951695
#
# 975.6417729854584 seconds
# epoch 123:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.842, loss_adv: 80.871,
#
# accuracy in training set after perturbation: 65.908337
#
# 983.6093280315399 seconds
# epoch 124:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.842, loss_adv: 80.862,
#
# accuracy in training set after perturbation: 65.908337
#
# 991.5589807033539 seconds
# epoch 125:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.841, loss_adv: 80.854,
#
# accuracy in training set after perturbation: 65.862430
#
# 999.517153263092 seconds
# epoch 126:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.840, loss_adv: 80.847,
#
# accuracy in training set after perturbation: 65.949144
#
# 1007.5566499233246 seconds
# epoch 127:
# loss_D: 0.038, loss_G_fake: 0.953,
# loss_perturb: 1.840, loss_adv: 80.842,
#
# accuracy in training set after perturbation: 65.908337
#
# 1015.5782203674316 seconds
# epoch 128:
# loss_D: 0.038, loss_G_fake: 0.954,
# loss_perturb: 1.840, loss_adv: 80.834,
#
# accuracy in training set after perturbation: 65.908337
#
# 1023.559579372406 seconds
# epoch 129:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.840, loss_adv: 80.828,
#
# accuracy in training set after perturbation: 65.875182
#
# 1031.5383701324463 seconds
# epoch 130:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.820,
#
# accuracy in training set after perturbation: 65.877732
#
# 1039.4991717338562 seconds
# epoch 131:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.813,
#
# accuracy in training set after perturbation: 65.880283
#
# 1047.4560940265656 seconds
# epoch 132:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.838, loss_adv: 80.806,
#
# accuracy in training set after perturbation: 65.895585
#
# 1055.4197735786438 seconds
# epoch 133:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.799,
#
# accuracy in training set after perturbation: 65.900686
#
# 1063.438256263733 seconds
# epoch 134:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.791,
#
# accuracy in training set after perturbation: 65.826723
#
# 1071.4144880771637 seconds
# epoch 135:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.784,
#
# accuracy in training set after perturbation: 65.862430
#
# 1079.3951437473297 seconds
# epoch 136:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.778,
#
# accuracy in training set after perturbation: 65.923640
#
# 1087.47980093956 seconds
# epoch 137:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.772,
#
# accuracy in training set after perturbation: 65.890484
#
# 1095.5118081569672 seconds
# epoch 138:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.764,
#
# accuracy in training set after perturbation: 65.862430
#
# 1103.4780433177948 seconds
# epoch 139:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.838, loss_adv: 80.757,
#
# accuracy in training set after perturbation: 65.798669
#
# 1111.4657850265503 seconds
# epoch 140:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.751,
#
# accuracy in training set after perturbation: 65.854778
#
# 1119.5487730503082 seconds
# epoch 141:
# loss_D: 0.037, loss_G_fake: 0.954,
# loss_perturb: 1.839, loss_adv: 80.745,
#
# accuracy in training set after perturbation: 65.875182
#
# 1127.5480864048004 seconds
# epoch 142:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.839, loss_adv: 80.738,
#
# accuracy in training set after perturbation: 65.834375
#
# 1135.500197172165 seconds
# epoch 143:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.839, loss_adv: 80.731,
#
# accuracy in training set after perturbation: 65.824173
#
# 1143.4804935455322 seconds
# epoch 144:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.723,
#
# accuracy in training set after perturbation: 65.773164
#
# 1151.4634261131287 seconds
# epoch 145:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.837, loss_adv: 80.717,
#
# accuracy in training set after perturbation: 65.780816
#
# 1159.4457449913025 seconds
# epoch 146:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.712,
#
# accuracy in training set after perturbation: 65.872631
#
# 1167.4475343227386 seconds
# epoch 147:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.705,
#
# accuracy in training set after perturbation: 65.806320
#
# 1175.4643714427948 seconds
# epoch 148:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.698,
#
# accuracy in training set after perturbation: 65.819072
#
# 1183.4614071846008 seconds
# epoch 149:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.693,
#
# accuracy in training set after perturbation: 65.826723
#
# 1191.646642923355 seconds
# epoch 150:
# loss_D: 0.037, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.687,
#
# accuracy in training set after perturbation: 65.742559
#
# 1199.6749331951141 seconds
# epoch 151:
# loss_D: 0.036, loss_G_fake: 0.955,
# loss_perturb: 1.838, loss_adv: 80.681,
#
# accuracy in training set after perturbation: 65.762963
#
# 1207.656659603119 seconds
# epoch 152:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.675,
#
# accuracy in training set after perturbation: 65.803770
#
# 1215.6653113365173 seconds
# epoch 153:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.670,
#
# accuracy in training set after perturbation: 65.808870
#
# 1223.6686024665833 seconds
# epoch 154:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.663,
#
# accuracy in training set after perturbation: 65.788467
#
# 1231.6829950809479 seconds
# epoch 155:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.659,
#
# accuracy in training set after perturbation: 65.793568
#
# 1239.698617219925 seconds
# epoch 156:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.653,
#
# accuracy in training set after perturbation: 65.824173
#
# 1247.7640924453735 seconds
# epoch 157:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.647,
#
# accuracy in training set after perturbation: 65.780816
#
# 1255.812861919403 seconds
# epoch 158:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.642,
#
# accuracy in training set after perturbation: 65.811421
#
# 1263.7949559688568 seconds
# epoch 159:
# loss_D: 0.036, loss_G_fake: 0.956,
# loss_perturb: 1.838, loss_adv: 80.636,
#
# accuracy in training set after perturbation: 65.768063
#
# 1271.7702548503876 seconds
# epoch 160:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.838, loss_adv: 80.631,
#
# accuracy in training set after perturbation: 65.709403
#
# 1279.7626702785492 seconds
# epoch 161:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.838, loss_adv: 80.625,
#
# accuracy in training set after perturbation: 65.671147
#
# 1287.7607867717743 seconds
# epoch 162:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.838, loss_adv: 80.621,
#
# accuracy in training set after perturbation: 65.768063
#
# 1295.7458827495575 seconds
# epoch 163:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.838, loss_adv: 80.614,
#
# accuracy in training set after perturbation: 65.740009
#
# 1303.7194249629974 seconds
# epoch 164:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.837, loss_adv: 80.607,
#
# accuracy in training set after perturbation: 65.686450
#
# 1311.6796278953552 seconds
# epoch 165:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.837, loss_adv: 80.601,
#
# accuracy in training set after perturbation: 65.696651
#
# 1319.670692205429 seconds
# epoch 166:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.837, loss_adv: 80.596,
#
# accuracy in training set after perturbation: 65.719605
#
# 1327.6891751289368 seconds
# epoch 167:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.837, loss_adv: 80.589,
#
# accuracy in training set after perturbation: 65.717055
#
# 1335.7073674201965 seconds
# epoch 168:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.836, loss_adv: 80.584,
#
# accuracy in training set after perturbation: 65.678798
#
# 1343.663256406784 seconds
# epoch 169:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.836, loss_adv: 80.578,
#
# accuracy in training set after perturbation: 65.666046
#
# 1351.6170284748077 seconds
# epoch 170:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.835, loss_adv: 80.572,
#
# accuracy in training set after perturbation: 65.663496
#
# 1359.575205564499 seconds
# epoch 171:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.835, loss_adv: 80.567,
#
# accuracy in training set after perturbation: 65.673697
#
# 1367.5211551189423 seconds
# epoch 172:
# loss_D: 0.036, loss_G_fake: 0.957,
# loss_perturb: 1.834, loss_adv: 80.561,
#
# accuracy in training set after perturbation: 65.622689
#
# 1375.4646553993225 seconds
# epoch 173:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.834, loss_adv: 80.557,
#
# accuracy in training set after perturbation: 65.706853
#
# 1383.4170677661896 seconds
# epoch 174:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.834, loss_adv: 80.551,
#
# accuracy in training set after perturbation: 65.653294
#
# 1391.3791086673737 seconds
# epoch 175:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.834, loss_adv: 80.546,
#
# accuracy in training set after perturbation: 65.676248
#
# 1399.3443908691406 seconds
# epoch 176:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.834, loss_adv: 80.541,
#
# accuracy in training set after perturbation: 65.655844
#
# 1407.3185033798218 seconds
# epoch 177:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.833, loss_adv: 80.536,
#
# accuracy in training set after perturbation: 65.678798
#
# 1415.3202123641968 seconds
# epoch 178:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.833, loss_adv: 80.531,
#
# accuracy in training set after perturbation: 65.653294
#
# 1423.380865573883 seconds
# epoch 179:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.833, loss_adv: 80.526,
#
# accuracy in training set after perturbation: 65.650743
#
# 1431.3350186347961 seconds
# epoch 180:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.834, loss_adv: 80.521,
#
# accuracy in training set after perturbation: 65.612487
#
# 1439.2924263477325 seconds
# epoch 181:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.833, loss_adv: 80.515,
#
# accuracy in training set after perturbation: 65.556377
#
# 1447.2717986106873 seconds
# epoch 182:
# loss_D: 0.036, loss_G_fake: 0.958,
# loss_perturb: 1.833, loss_adv: 80.510,
#
# accuracy in training set after perturbation: 65.632890
#
# 1455.2833387851715 seconds
# epoch 183:
# loss_D: 0.035, loss_G_fake: 0.958,
# loss_perturb: 1.832, loss_adv: 80.506,
#
# accuracy in training set after perturbation: 65.655844
#
# 1463.2246797084808 seconds
# epoch 184:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.501,
#
# accuracy in training set after perturbation: 65.671147
#
# 1471.169294834137 seconds
# epoch 185:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.496,
#
# accuracy in training set after perturbation: 65.632890
#
# 1479.1324639320374 seconds
# epoch 186:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.491,
#
# accuracy in training set after perturbation: 65.620138
#
# 1487.1305770874023 seconds
# epoch 187:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.486,
#
# accuracy in training set after perturbation: 65.650743
#
# 1495.1925263404846 seconds
# epoch 188:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.481,
#
# accuracy in training set after perturbation: 65.625239
#
# 1503.3423464298248 seconds
# epoch 189:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.474,
#
# accuracy in training set after perturbation: 65.553827
#
# 1511.3127851486206 seconds
# epoch 190:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.469,
#
# accuracy in training set after perturbation: 65.564029
#
# 1519.2584199905396 seconds
# epoch 191:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.464,
#
# accuracy in training set after perturbation: 65.645643
#
# 1527.2202463150024 seconds
# epoch 192:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.834, loss_adv: 80.460,
#
# accuracy in training set after perturbation: 65.615037
#
# 1535.1904518604279 seconds
# epoch 193:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.455,
#
# accuracy in training set after perturbation: 65.602285
#
# 1543.1461703777313 seconds
# epoch 194:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.834, loss_adv: 80.450,
#
# accuracy in training set after perturbation: 65.597184
#
# 1551.0985465049744 seconds
# epoch 195:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.445,
#
# accuracy in training set after perturbation: 65.584432
#
# 1559.0588138103485 seconds
# epoch 196:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.833, loss_adv: 80.440,
#
# accuracy in training set after perturbation: 65.645643
#
# 1567.0322358608246 seconds
# epoch 197:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.834, loss_adv: 80.436,
#
# accuracy in training set after perturbation: 65.574230
#
# 1575.0347509384155 seconds
# epoch 198:
# loss_D: 0.035, loss_G_fake: 0.959,
# loss_perturb: 1.834, loss_adv: 80.431,
#
# accuracy in training set after perturbation: 65.637991
#
# 1582.9705426692963 seconds
# epoch 199:
# loss_D: 0.035, loss_G_fake: 0.960,
# loss_perturb: 1.834, loss_adv: 80.427,
#
# accuracy in training set after perturbation: 65.602285
#
# 1590.9095232486725 seconds
# epoch 200:
# loss_D: 0.035, loss_G_fake: 0.960,
# loss_perturb: 1.834, loss_adv: 80.423,
#
# accuracy in training set after perturbation: 65.581882
#
# 1598.8462121486664 seconds
# accuracy in test set on all perturbed images: 67.783056
#
# misclassifications on previously correctly classified images: 32.747427
