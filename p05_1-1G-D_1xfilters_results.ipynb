# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/p05_1-1G-D_1xfilters_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pert 0.05, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 1x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.5)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.5)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.6)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.6)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 1*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:1*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

X_test = np.dot(X_test, grayscale)
X_train = np.dot(X_train, grayscale)
X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
X_train = np.expand_dims(X_train,-1)
X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 1, 32, 32)
# (39209, 43)
# (12630, 1, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 1 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1193.792236
#
# Train accuracy so far: 45.915479
#
# loss in epoch 1: 354.900970
#
# Train accuracy so far: 84.194955
#
# loss in epoch 2: 203.248566
#
# Train accuracy so far: 91.259660
#
# loss in epoch 3: 139.179703
#
# Train accuracy so far: 94.144202
#
# loss in epoch 4: 102.459068
#
# Train accuracy so far: 95.679563
#
# loss in epoch 5: 78.902824
#
# Train accuracy so far: 96.768599
#
# loss in epoch 6: 60.991600
#
# Train accuracy so far: 97.452116
#
# loss in epoch 7: 50.032291
#
# Train accuracy so far: 97.849983
#
# loss in epoch 8: 40.417599
#
# Train accuracy so far: 98.227448
#
# loss in epoch 9: 36.542507
#
# Train accuracy so far: 98.411079
#
# loss in epoch 10: 30.485725
#
# Train accuracy so far: 98.561555
#
# loss in epoch 11: 25.528242
#
# Train accuracy so far: 98.834451
#
# loss in epoch 12: 21.495441
#
# Train accuracy so far: 99.058890
#
# loss in epoch 13: 24.302420
#
# Train accuracy so far: 98.801296
#
# loss in epoch 14: 18.620249
#
# Train accuracy so far: 99.163457
#
# loss in epoch 15: 16.566515
#
# Train accuracy so far: 99.242521
#
# loss in epoch 16: 13.266971
#
# Train accuracy so far: 99.319034
#
# loss in epoch 17: 13.485975
#
# Train accuracy so far: 99.377694
#
# loss in epoch 18: 13.617745
#
# Train accuracy so far: 99.341988
#
# loss in epoch 19: 10.281184
#
# Train accuracy so far: 99.535821
#
# accuracy in testing set: 90.973872

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.05
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.05
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.05
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image, cmap='gray')
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image, cmap='gray')
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=1
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.973872
#
# epoch 1:
# loss_D: 0.370, loss_G_fake: 0.356,
# loss_perturb: 12.281, loss_adv: 61.713,
#
# accuracy in training set after perturbation: 51.883496
#
# 8.104716777801514 seconds
# epoch 2:
# loss_D: 0.132, loss_G_fake: 0.642,
# loss_perturb: 12.050, loss_adv: 49.852,
#
# accuracy in training set after perturbation: 42.232651
#
# 16.15167260169983 seconds
# epoch 3:
# loss_D: 0.082, loss_G_fake: 0.756,
# loss_perturb: 11.757, loss_adv: 45.950,
#
# accuracy in training set after perturbation: 38.968094
#
# 24.26401996612549 seconds
# epoch 4:
# loss_D: 0.057, loss_G_fake: 0.819,
# loss_perturb: 11.431, loss_adv: 42.112,
#
# accuracy in training set after perturbation: 35.973884
#
# 32.42539191246033 seconds
# epoch 5:
# loss_D: 0.054, loss_G_fake: 0.839,
# loss_perturb: 10.192, loss_adv: 38.777,
#
# accuracy in training set after perturbation: 33.224515
#
# 40.495293378829956 seconds
# epoch 6:
# loss_D: 0.041, loss_G_fake: 0.875,
# loss_perturb: 8.892, loss_adv: 35.606,
#
# accuracy in training set after perturbation: 30.436889
#
# 48.51929330825806 seconds
# epoch 7:
# loss_D: 0.040, loss_G_fake: 0.884,
# loss_perturb: 8.500, loss_adv: 34.313,
#
# accuracy in training set after perturbation: 29.347854
#
# 56.53039216995239 seconds
# epoch 8:
# loss_D: 0.034, loss_G_fake: 0.902,
# loss_perturb: 8.761, loss_adv: 34.306,
#
# accuracy in training set after perturbation: 29.485577
#
# 64.55293488502502 seconds
# epoch 9:
# loss_D: 0.032, loss_G_fake: 0.908,
# loss_perturb: 8.312, loss_adv: 31.071,
#
# accuracy in training set after perturbation: 26.733658
#
# 72.53407979011536 seconds
# epoch 10:
# loss_D: 0.042, loss_G_fake: 0.892,
# loss_perturb: 8.003, loss_adv: 29.798,
#
# accuracy in training set after perturbation: 25.596164
#
# 80.51753449440002 seconds
# epoch 11:
# loss_D: 0.032, loss_G_fake: 0.915,
# loss_perturb: 7.142, loss_adv: 28.014,
#
# accuracy in training set after perturbation: 24.091408
#
# 88.46339988708496 seconds
# epoch 12:
# loss_D: 0.032, loss_G_fake: 0.917,
# loss_perturb: 7.842, loss_adv: 27.569,
#
# accuracy in training set after perturbation: 23.861868
#
# 96.49979853630066 seconds
# epoch 13:
# loss_D: 0.030, loss_G_fake: 0.927,
# loss_perturb: 6.900, loss_adv: 26.104,
#
# accuracy in training set after perturbation: 22.556046
#
# 104.61300373077393 seconds
# epoch 14:
# loss_D: 0.034, loss_G_fake: 0.922,
# loss_perturb: 6.746, loss_adv: 24.392,
#
# accuracy in training set after perturbation: 21.148206
#
# 112.76620435714722 seconds
# epoch 15:
# loss_D: 0.032, loss_G_fake: 0.925,
# loss_perturb: 6.675, loss_adv: 24.104,
#
# accuracy in training set after perturbation: 20.885511
#
# 120.79758214950562 seconds
# epoch 16:
# loss_D: 0.031, loss_G_fake: 0.928,
# loss_perturb: 6.347, loss_adv: 23.159,
#
# accuracy in training set after perturbation: 19.992859
#
# 128.8413429260254 seconds
# epoch 17:
# loss_D: 0.029, loss_G_fake: 0.930,
# loss_perturb: 6.778, loss_adv: 22.523,
#
# accuracy in training set after perturbation: 19.541432
#
# 136.8597116470337 seconds
# epoch 18:
# loss_D: 0.023, loss_G_fake: 0.942,
# loss_perturb: 6.667, loss_adv: 22.358,
#
# accuracy in training set after perturbation: 19.434314
#
# 144.96264147758484 seconds
# epoch 19:
# loss_D: 0.033, loss_G_fake: 0.924,
# loss_perturb: 6.577, loss_adv: 21.118,
#
# accuracy in training set after perturbation: 18.424341
#
# 153.17943239212036 seconds
# epoch 20:
# loss_D: 0.034, loss_G_fake: 0.925,
# loss_perturb: 6.273, loss_adv: 20.335,
#
# accuracy in training set after perturbation: 17.814787
#
# 161.28399634361267 seconds
# epoch 21:
# loss_D: 0.035, loss_G_fake: 0.927,
# loss_perturb: 6.392, loss_adv: 19.282,
#
# accuracy in training set after perturbation: 16.843072
#
# 169.25179982185364 seconds
# epoch 22:
# loss_D: 0.030, loss_G_fake: 0.935,
# loss_perturb: 6.398, loss_adv: 18.537,
#
# accuracy in training set after perturbation: 16.304930
#
# 177.22805190086365 seconds
# epoch 23:
# loss_D: 0.045, loss_G_fake: 0.909,
# loss_perturb: 6.093, loss_adv: 18.208,
#
# accuracy in training set after perturbation: 15.973373
#
# 185.22080087661743 seconds
# epoch 24:
# loss_D: 0.030, loss_G_fake: 0.932,
# loss_perturb: 6.111, loss_adv: 18.050,
#
# accuracy in training set after perturbation: 15.782091
#
# 193.32013607025146 seconds
# epoch 25:
# loss_D: 0.029, loss_G_fake: 0.931,
# loss_perturb: 6.091, loss_adv: 17.401,
#
# accuracy in training set after perturbation: 15.243949
#
# 201.29114198684692 seconds
# epoch 26:
# loss_D: 0.035, loss_G_fake: 0.926,
# loss_perturb: 6.003, loss_adv: 16.958,
#
# accuracy in training set after perturbation: 14.981254
#
# 209.23552799224854 seconds
# epoch 27:
# loss_D: 0.034, loss_G_fake: 0.933,
# loss_perturb: 6.128, loss_adv: 16.438,
#
# accuracy in training set after perturbation: 14.425260
#
# 217.2005364894867 seconds
# epoch 28:
# loss_D: 0.026, loss_G_fake: 0.947,
# loss_perturb: 5.620, loss_adv: 16.297,
#
# accuracy in training set after perturbation: 14.297738
#
# 225.16903853416443 seconds
# epoch 29:
# loss_D: 0.028, loss_G_fake: 0.946,
# loss_perturb: 6.047, loss_adv: 16.071,
#
# accuracy in training set after perturbation: 14.162565
#
# 233.14183497428894 seconds
# epoch 30:
# loss_D: 0.021, loss_G_fake: 0.952,
# loss_perturb: 5.617, loss_adv: 15.648,
#
# accuracy in training set after perturbation: 13.777449
#
# 241.0954077243805 seconds
# epoch 31:
# loss_D: 0.028, loss_G_fake: 0.943,
# loss_perturb: 5.790, loss_adv: 15.317,
#
# accuracy in training set after perturbation: 13.527506
#
# 249.05445551872253 seconds
# epoch 32:
# loss_D: 0.022, loss_G_fake: 0.956,
# loss_perturb: 5.430, loss_adv: 14.687,
#
# accuracy in training set after perturbation: 12.808284
#
# 257.04796600341797 seconds
# epoch 33:
# loss_D: 0.021, loss_G_fake: 0.952,
# loss_perturb: 5.524, loss_adv: 14.553,
#
# accuracy in training set after perturbation: 12.792981
#
# 265.0665833950043 seconds
# epoch 34:
# loss_D: 0.019, loss_G_fake: 0.956,
# loss_perturb: 5.227, loss_adv: 14.046,
#
# accuracy in training set after perturbation: 12.287995
#
# 273.13683104515076 seconds
# epoch 35:
# loss_D: 0.020, loss_G_fake: 0.948,
# loss_perturb: 5.641, loss_adv: 14.178,
#
# accuracy in training set after perturbation: 12.522635
#
# 281.1394214630127 seconds
# epoch 36:
# loss_D: 0.030, loss_G_fake: 0.940,
# loss_perturb: 6.023, loss_adv: 14.007,
#
# accuracy in training set after perturbation: 12.356857
#
# 289.0739600658417 seconds
# epoch 37:
# loss_D: 0.021, loss_G_fake: 0.950,
# loss_perturb: 5.393, loss_adv: 13.617,
#
# accuracy in training set after perturbation: 11.915632
#
# 297.0401072502136 seconds
# epoch 38:
# loss_D: 0.021, loss_G_fake: 0.946,
# loss_perturb: 5.297, loss_adv: 13.887,
#
# accuracy in training set after perturbation: 12.303298
#
# 305.0178632736206 seconds
# epoch 39:
# loss_D: 0.020, loss_G_fake: 0.950,
# loss_perturb: 5.535, loss_adv: 13.814,
#
# accuracy in training set after perturbation: 12.257390
#
# 313.01324105262756 seconds
# epoch 40:
# loss_D: 0.016, loss_G_fake: 0.955,
# loss_perturb: 5.505, loss_adv: 13.382,
#
# accuracy in training set after perturbation: 11.798312
#
# 320.96121430397034 seconds
# epoch 41:
# loss_D: 0.017, loss_G_fake: 0.951,
# loss_perturb: 5.344, loss_adv: 13.330,
#
# accuracy in training set after perturbation: 11.754954
#
# 328.92820382118225 seconds
# epoch 42:
# loss_D: 0.024, loss_G_fake: 0.934,
# loss_perturb: 5.463, loss_adv: 13.180,
#
# accuracy in training set after perturbation: 11.609579
#
# 336.9292848110199 seconds
# epoch 43:
# loss_D: 0.014, loss_G_fake: 0.943,
# loss_perturb: 5.380, loss_adv: 12.588,
#
# accuracy in training set after perturbation: 11.155602
#
# 344.92921805381775 seconds
# epoch 44:
# loss_D: 0.009, loss_G_fake: 0.944,
# loss_perturb: 5.343, loss_adv: 12.515,
#
# accuracy in training set after perturbation: 11.127547
#
# 353.02266359329224 seconds
# epoch 45:
# loss_D: 0.003, loss_G_fake: 0.961,
# loss_perturb: 5.109, loss_adv: 12.590,
#
# accuracy in training set after perturbation: 11.155602
#
# 360.9789400100708 seconds
# epoch 46:
# loss_D: 0.007, loss_G_fake: 0.954,
# loss_perturb: 5.155, loss_adv: 11.947,
#
# accuracy in training set after perturbation: 10.551149
#
# 368.9346921443939 seconds
# epoch 47:
# loss_D: 0.004, loss_G_fake: 0.961,
# loss_perturb: 5.168, loss_adv: 11.985,
#
# accuracy in training set after perturbation: 10.658267
#
# 376.9401295185089 seconds
# epoch 48:
# loss_D: 0.002, loss_G_fake: 0.969,
# loss_perturb: 5.247, loss_adv: 11.656,
#
# accuracy in training set after perturbation: 10.316509
#
# 384.8904495239258 seconds
# epoch 49:
# loss_D: 0.001, loss_G_fake: 0.974,
# loss_perturb: 5.186, loss_adv: 11.797,
#
# accuracy in training set after perturbation: 10.525645
#
# 392.81592059135437 seconds
# epoch 50:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 5.442, loss_adv: 11.193,
#
# accuracy in training set after perturbation: 9.803872
#
# 400.7477970123291 seconds
# epoch 51:
# loss_D: 0.000, loss_G_fake: 0.982,
# loss_perturb: 5.049, loss_adv: 10.458,
#
# accuracy in training set after perturbation: 8.972430
#
# 408.66916704177856 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.982,
# loss_perturb: 4.733, loss_adv: 10.186,
#
# accuracy in training set after perturbation: 8.668928
#
# 416.61064171791077 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.983,
# loss_perturb: 4.451, loss_adv: 10.026,
#
# accuracy in training set after perturbation: 8.457242
#
# 424.54791808128357 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.983,
# loss_perturb: 4.227, loss_adv: 9.946,
#
# accuracy in training set after perturbation: 8.385830
#
# 432.60046339035034 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.984,
# loss_perturb: 4.035, loss_adv: 9.803,
#
# accuracy in training set after perturbation: 8.258308
#
# 440.59290981292725 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.985,
# loss_perturb: 3.866, loss_adv: 9.713,
#
# accuracy in training set after perturbation: 8.191997
#
# 448.5831868648529 seconds
# epoch 57:
# loss_D: 0.000, loss_G_fake: 0.985,
# loss_perturb: 3.710, loss_adv: 9.645,
#
# accuracy in training set after perturbation: 8.084878
#
# 456.7098972797394 seconds
# epoch 58:
# loss_D: 0.001, loss_G_fake: 0.983,
# loss_perturb: 3.571, loss_adv: 9.573,
#
# accuracy in training set after perturbation: 7.970109
#
# 464.9128167629242 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.985,
# loss_perturb: 3.465, loss_adv: 9.541,
#
# accuracy in training set after perturbation: 8.016017
#
# 472.89404249191284 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 3.379, loss_adv: 9.457,
#
# accuracy in training set after perturbation: 7.865541
#
# 480.8313419818878 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 3.326, loss_adv: 9.416,
#
# accuracy in training set after perturbation: 7.906348
#
# 488.75144624710083 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.985,
# loss_perturb: 3.271, loss_adv: 9.364,
#
# accuracy in training set after perturbation: 7.875743
#
# 496.68329524993896 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.242, loss_adv: 9.332,
#
# accuracy in training set after perturbation: 7.814532
#
# 504.65439534187317 seconds
# epoch 64:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.197, loss_adv: 9.272,
#
# accuracy in training set after perturbation: 7.794129
#
# 512.6976399421692 seconds
# epoch 65:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.148, loss_adv: 9.200,
#
# accuracy in training set after perturbation: 7.651305
#
# 520.6350374221802 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.059, loss_adv: 9.162,
#
# accuracy in training set after perturbation: 7.669158
#
# 528.5743374824524 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.056, loss_adv: 9.129,
#
# accuracy in training set after perturbation: 7.602846
#
# 536.498202085495 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.023, loss_adv: 9.085,
#
# accuracy in training set after perturbation: 7.602846
#
# 544.4781856536865 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.004, loss_adv: 9.046,
#
# accuracy in training set after perturbation: 7.590094
#
# 552.4368488788605 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 2.980, loss_adv: 9.005,
#
# accuracy in training set after perturbation: 7.526333
#
# 560.4005811214447 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 2.931, loss_adv: 8.974,
#
# accuracy in training set after perturbation: 7.493178
#
# 568.3534820079803 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 2.951, loss_adv: 8.938,
#
# accuracy in training set after perturbation: 7.462572
#
# 576.3188645839691 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 2.946, loss_adv: 8.903,
#
# accuracy in training set after perturbation: 7.485526
#
# 584.3028945922852 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 2.909, loss_adv: 8.851,
#
# accuracy in training set after perturbation: 7.388610
#
# 592.3828086853027 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 2.874, loss_adv: 8.836,
#
# accuracy in training set after perturbation: 7.345252
#
# 600.3493537902832 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 2.874, loss_adv: 8.798,
#
# accuracy in training set after perturbation: 7.322298
#
# 608.2984068393707 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 2.820, loss_adv: 8.764,
#
# accuracy in training set after perturbation: 7.294244
#
# 616.2411425113678 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 2.779, loss_adv: 8.731,
#
# accuracy in training set after perturbation: 7.273840
#
# 624.1716465950012 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 2.786, loss_adv: 8.714,
#
# accuracy in training set after perturbation: 7.248336
#
# 632.0968396663666 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.777, loss_adv: 8.661,
#
# accuracy in training set after perturbation: 7.115713
#
# 640.0046107769012 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.752, loss_adv: 8.639,
#
# accuracy in training set after perturbation: 7.036650
#
# 647.9446663856506 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.718, loss_adv: 8.631,
#
# accuracy in training set after perturbation: 7.016246
#
# 655.8965213298798 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.687, loss_adv: 8.626,
#
# accuracy in training set after perturbation: 7.000944
#
# 663.8342542648315 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.660, loss_adv: 8.623,
#
# accuracy in training set after perturbation: 7.013696
#
# 671.8532609939575 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.636, loss_adv: 8.618,
#
# accuracy in training set after perturbation: 7.011145
#
# 679.8537864685059 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.613, loss_adv: 8.614,
#
# accuracy in training set after perturbation: 6.998393
#
# 687.7893805503845 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.590, loss_adv: 8.610,
#
# accuracy in training set after perturbation: 7.013696
#
# 695.7196717262268 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.575, loss_adv: 8.606,
#
# accuracy in training set after perturbation: 7.013696
#
# 703.6326620578766 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.560, loss_adv: 8.602,
#
# accuracy in training set after perturbation: 7.000944
#
# 711.5775487422943 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.545, loss_adv: 8.597,
#
# accuracy in training set after perturbation: 7.021347
#
# 719.5116753578186 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.537, loss_adv: 8.592,
#
# accuracy in training set after perturbation: 6.993292
#
# 727.4349653720856 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.522, loss_adv: 8.588,
#
# accuracy in training set after perturbation: 6.995843
#
# 735.3612878322601 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.510, loss_adv: 8.585,
#
# accuracy in training set after perturbation: 6.998393
#
# 743.2853593826294 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.498, loss_adv: 8.581,
#
# accuracy in training set after perturbation: 7.006045
#
# 751.2859961986542 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.489, loss_adv: 8.578,
#
# accuracy in training set after perturbation: 7.011145
#
# 759.2718799114227 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.481, loss_adv: 8.575,
#
# accuracy in training set after perturbation: 6.975439
#
# 767.3697602748871 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.474, loss_adv: 8.573,
#
# accuracy in training set after perturbation: 7.031549
#
# 775.5282125473022 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.469, loss_adv: 8.569,
#
# accuracy in training set after perturbation: 6.975439
#
# 783.4632456302643 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.458, loss_adv: 8.569,
#
# accuracy in training set after perturbation: 6.972889
#
# 791.3905103206635 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.449, loss_adv: 8.563,
#
# accuracy in training set after perturbation: 7.023898
#
# 799.3226609230042 seconds
# accuracy in test set on all perturbed images: 16.975455
#
# misclassifications on previously correctly classified images: 83.499604
