# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p005_3-1adv-pert_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.005, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 3:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.005
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 3
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.005
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.005
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<20:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.500, loss_G_fake: 0.250,
# loss_perturb: 5.883, loss_adv: 124.585,
#
# accuracy in training set after perturbation: 98.862506
#
# 8.946637153625488 seconds
# epoch 2:
# loss_D: 0.493, loss_G_fake: 0.257,
# loss_perturb: 3.765, loss_adv: 120.784,
#
# accuracy in training set after perturbation: 96.658930
#
# 17.830931425094604 seconds
# epoch 3:
# loss_D: 0.459, loss_G_fake: 0.294,
# loss_perturb: 2.863, loss_adv: 118.268,
#
# accuracy in training set after perturbation: 95.075110
#
# 26.60819101333618 seconds
# epoch 4:
# loss_D: 0.443, loss_G_fake: 0.316,
# loss_perturb: 2.783, loss_adv: 116.906,
#
# accuracy in training set after perturbation: 94.146752
#
# 35.464842081069946 seconds
# epoch 5:
# loss_D: 0.402, loss_G_fake: 0.364,
# loss_perturb: 2.573, loss_adv: 115.732,
#
# accuracy in training set after perturbation: 93.305109
#
# 44.37163281440735 seconds
# epoch 6:
# loss_D: 0.338, loss_G_fake: 0.422,
# loss_perturb: 2.531, loss_adv: 114.781,
#
# accuracy in training set after perturbation: 92.664949
#
# 53.3513617515564 seconds
# epoch 7:
# loss_D: 0.284, loss_G_fake: 0.481,
# loss_perturb: 2.328, loss_adv: 113.782,
#
# accuracy in training set after perturbation: 92.001836
#
# 62.45551514625549 seconds
# epoch 8:
# loss_D: 0.254, loss_G_fake: 0.515,
# loss_perturb: 2.291, loss_adv: 113.019,
#
# accuracy in training set after perturbation: 91.325971
#
# 71.35935258865356 seconds
# epoch 9:
# loss_D: 0.247, loss_G_fake: 0.526,
# loss_perturb: 2.376, loss_adv: 112.957,
#
# accuracy in training set after perturbation: 91.376980
#
# 80.23070478439331 seconds
# epoch 10:
# loss_D: 0.231, loss_G_fake: 0.548,
# loss_perturb: 2.237, loss_adv: 112.655,
#
# accuracy in training set after perturbation: 91.109184
#
# 89.2089262008667 seconds
# epoch 11:
# loss_D: 0.229, loss_G_fake: 0.556,
# loss_perturb: 2.289, loss_adv: 112.257,
#
# accuracy in training set after perturbation: 90.864342
#
# 97.90888857841492 seconds
# epoch 12:
# loss_D: 0.252, loss_G_fake: 0.538,
# loss_perturb: 2.144, loss_adv: 111.492,
#
# accuracy in training set after perturbation: 90.193578
#
# 106.73669743537903 seconds
# epoch 13:
# loss_D: 0.258, loss_G_fake: 0.536,
# loss_perturb: 1.966, loss_adv: 110.820,
#
# accuracy in training set after perturbation: 89.716647
#
# 115.48333072662354 seconds
# epoch 14:
# loss_D: 0.232, loss_G_fake: 0.565,
# loss_perturb: 2.168, loss_adv: 111.079,
#
# accuracy in training set after perturbation: 90.030350
#
# 124.1936891078949 seconds
# epoch 15:
# loss_D: 0.224, loss_G_fake: 0.572,
# loss_perturb: 2.035, loss_adv: 110.284,
#
# accuracy in training set after perturbation: 89.395292
#
# 132.8553216457367 seconds
# epoch 16:
# loss_D: 0.225, loss_G_fake: 0.574,
# loss_perturb: 2.005, loss_adv: 109.841,
#
# accuracy in training set after perturbation: 89.081588
#
# 141.48202514648438 seconds
# epoch 17:
# loss_D: 0.233, loss_G_fake: 0.574,
# loss_perturb: 1.964, loss_adv: 109.739,
#
# accuracy in training set after perturbation: 89.079038
#
# 150.13329195976257 seconds
# epoch 18:
# loss_D: 0.227, loss_G_fake: 0.575,
# loss_perturb: 2.002, loss_adv: 109.750,
#
# accuracy in training set after perturbation: 89.137698
#
# 158.7728796005249 seconds
# epoch 19:
# loss_D: 0.222, loss_G_fake: 0.579,
# loss_perturb: 1.798, loss_adv: 109.190,
#
# accuracy in training set after perturbation: 88.642914
#
# 167.3551013469696 seconds
# epoch 20:
# loss_D: 0.228, loss_G_fake: 0.577,
# loss_perturb: 1.801, loss_adv: 108.630,
#
# accuracy in training set after perturbation: 88.023158
#
# 175.99112176895142 seconds
# epoch 21:
# loss_D: 0.222, loss_G_fake: 0.582,
# loss_perturb: 1.876, loss_adv: 108.736,
#
# accuracy in training set after perturbation: 88.298605
#
# 184.6951243877411 seconds
# epoch 22:
# loss_D: 0.214, loss_G_fake: 0.593,
# loss_perturb: 1.839, loss_adv: 108.474,
#
# accuracy in training set after perturbation: 88.041011
#
# 193.51061916351318 seconds
# epoch 23:
# loss_D: 0.212, loss_G_fake: 0.597,
# loss_perturb: 1.882, loss_adv: 108.344,
#
# accuracy in training set after perturbation: 87.979801
#
# 202.1976397037506 seconds
# epoch 24:
# loss_D: 0.208, loss_G_fake: 0.601,
# loss_perturb: 1.913, loss_adv: 108.167,
#
# accuracy in training set after perturbation: 87.824224
#
# 210.86806559562683 seconds
# epoch 25:
# loss_D: 0.200, loss_G_fake: 0.612,
# loss_perturb: 1.962, loss_adv: 108.027,
#
# accuracy in training set after perturbation: 87.763014
#
# 219.56064200401306 seconds
# epoch 26:
# loss_D: 0.217, loss_G_fake: 0.601,
# loss_perturb: 1.843, loss_adv: 107.506,
#
# accuracy in training set after perturbation: 87.184065
#
# 228.32722806930542 seconds
# epoch 27:
# loss_D: 0.218, loss_G_fake: 0.605,
# loss_perturb: 1.679, loss_adv: 107.315,
#
# accuracy in training set after perturbation: 87.117754
#
# 237.34580278396606 seconds
# epoch 28:
# loss_D: 0.208, loss_G_fake: 0.614,
# loss_perturb: 1.703, loss_adv: 107.246,
#
# accuracy in training set after perturbation: 87.107552
#
# 246.0779366493225 seconds
# epoch 29:
# loss_D: 0.212, loss_G_fake: 0.627,
# loss_perturb: 1.753, loss_adv: 107.265,
#
# accuracy in training set after perturbation: 87.145808
#
# 254.93668961524963 seconds
# epoch 30:
# loss_D: 0.178, loss_G_fake: 0.665,
# loss_perturb: 2.006, loss_adv: 107.508,
#
# accuracy in training set after perturbation: 87.434007
#
# 263.62839555740356 seconds
# epoch 31:
# loss_D: 0.175, loss_G_fake: 0.667,
# loss_perturb: 1.710, loss_adv: 107.163,
#
# accuracy in training set after perturbation: 87.140707
#
# 272.4067325592041 seconds
# epoch 32:
# loss_D: 0.184, loss_G_fake: 0.665,
# loss_perturb: 1.822, loss_adv: 106.928,
#
# accuracy in training set after perturbation: 86.934122
#
# 281.12254333496094 seconds
# epoch 33:
# loss_D: 0.197, loss_G_fake: 0.655,
# loss_perturb: 1.671, loss_adv: 106.502,
#
# accuracy in training set after perturbation: 86.426586
#
# 289.7749283313751 seconds
# epoch 34:
# loss_D: 0.196, loss_G_fake: 0.653,
# loss_perturb: 1.688, loss_adv: 106.650,
#
# accuracy in training set after perturbation: 86.727537
#
# 298.476589679718 seconds
# epoch 35:
# loss_D: 0.182, loss_G_fake: 0.663,
# loss_perturb: 1.796, loss_adv: 106.736,
#
# accuracy in training set after perturbation: 86.883114
#
# 307.18391275405884 seconds
# epoch 36:
# loss_D: 0.184, loss_G_fake: 0.668,
# loss_perturb: 1.722, loss_adv: 106.390,
#
# accuracy in training set after perturbation: 86.444439
#
# 315.87638783454895 seconds
# epoch 37:
# loss_D: 0.195, loss_G_fake: 0.663,
# loss_perturb: 1.593, loss_adv: 106.009,
#
# accuracy in training set after perturbation: 85.977709
#
# 324.55074095726013 seconds
# epoch 38:
# loss_D: 0.172, loss_G_fake: 0.688,
# loss_perturb: 1.867, loss_adv: 106.154,
#
# accuracy in training set after perturbation: 86.316917
#
# 333.3039662837982 seconds
# epoch 39:
# loss_D: 0.158, loss_G_fake: 0.709,
# loss_perturb: 1.941, loss_adv: 106.405,
#
# accuracy in training set after perturbation: 86.732638
#
# 342.0012857913971 seconds
# epoch 40:
# loss_D: 0.165, loss_G_fake: 0.689,
# loss_perturb: 1.691, loss_adv: 105.920,
#
# accuracy in training set after perturbation: 86.077176
#
# 350.8175399303436 seconds
# epoch 41:
# loss_D: 0.187, loss_G_fake: 0.675,
# loss_perturb: 1.501, loss_adv: 105.587,
#
# accuracy in training set after perturbation: 85.699712
#
# 359.57574701309204 seconds
# epoch 42:
# loss_D: 0.182, loss_G_fake: 0.676,
# loss_perturb: 1.637, loss_adv: 105.628,
#
# accuracy in training set after perturbation: 85.936902
#
# 368.3118553161621 seconds
# epoch 43:
# loss_D: 0.179, loss_G_fake: 0.685,
# loss_perturb: 1.632, loss_adv: 105.530,
#
# accuracy in training set after perturbation: 85.842536
#
# 377.0216233730316 seconds
# epoch 44:
# loss_D: 0.177, loss_G_fake: 0.693,
# loss_perturb: 1.798, loss_adv: 105.555,
#
# accuracy in training set after perturbation: 85.980260
#
# 385.6612160205841 seconds
# epoch 45:
# loss_D: 0.177, loss_G_fake: 0.693,
# loss_perturb: 1.759, loss_adv: 105.460,
#
# accuracy in training set after perturbation: 85.834885
#
# 394.39829087257385 seconds
# epoch 46:
# loss_D: 0.151, loss_G_fake: 0.721,
# loss_perturb: 1.813, loss_adv: 105.576,
#
# accuracy in training set after perturbation: 86.161341
#
# 403.11154651641846 seconds
# epoch 47:
# loss_D: 0.147, loss_G_fake: 0.726,
# loss_perturb: 1.723, loss_adv: 105.341,
#
# accuracy in training set after perturbation: 85.801729
#
# 411.7741186618805 seconds
# epoch 48:
# loss_D: 0.161, loss_G_fake: 0.708,
# loss_perturb: 1.533, loss_adv: 105.073,
#
# accuracy in training set after perturbation: 85.485475
#
# 420.5032124519348 seconds
# epoch 49:
# loss_D: 0.159, loss_G_fake: 0.716,
# loss_perturb: 1.655, loss_adv: 105.198,
#
# accuracy in training set after perturbation: 85.717565
#
# 429.2175853252411 seconds
# epoch 50:
# loss_D: 0.127, loss_G_fake: 0.741,
# loss_perturb: 1.530, loss_adv: 104.408,
#
# accuracy in training set after perturbation: 84.597924
#
# 437.98943996429443 seconds
# epoch 51:
# loss_D: 0.127, loss_G_fake: 0.737,
# loss_perturb: 1.351, loss_adv: 104.138,
#
# accuracy in training set after perturbation: 84.230661
#
# 446.59845876693726 seconds
# epoch 52:
# loss_D: 0.131, loss_G_fake: 0.728,
# loss_perturb: 1.234, loss_adv: 104.000,
#
# accuracy in training set after perturbation: 84.021526
#
# 455.21862411499023 seconds
# epoch 53:
# loss_D: 0.136, loss_G_fake: 0.722,
# loss_perturb: 1.165, loss_adv: 103.923,
#
# accuracy in training set after perturbation: 83.988370
#
# 463.8379032611847 seconds
# epoch 54:
# loss_D: 0.137, loss_G_fake: 0.720,
# loss_perturb: 1.120, loss_adv: 103.851,
#
# accuracy in training set after perturbation: 83.922059
#
# 472.4558696746826 seconds
# epoch 55:
# loss_D: 0.139, loss_G_fake: 0.716,
# loss_perturb: 1.090, loss_adv: 103.770,
#
# accuracy in training set after perturbation: 83.860848
#
# 481.01644587516785 seconds
# epoch 56:
# loss_D: 0.141, loss_G_fake: 0.713,
# loss_perturb: 1.068, loss_adv: 103.708,
#
# accuracy in training set after perturbation: 83.822592
#
# 489.61057138442993 seconds
# epoch 57:
# loss_D: 0.143, loss_G_fake: 0.710,
# loss_perturb: 1.061, loss_adv: 103.653,
#
# accuracy in training set after perturbation: 83.827693
#
# 498.23924231529236 seconds
# epoch 58:
# loss_D: 0.145, loss_G_fake: 0.709,
# loss_perturb: 1.054, loss_adv: 103.594,
#
# accuracy in training set after perturbation: 83.799638
#
# 506.82720160484314 seconds
# epoch 59:
# loss_D: 0.145, loss_G_fake: 0.708,
# loss_perturb: 1.051, loss_adv: 103.557,
#
# accuracy in training set after perturbation: 83.784335
#
# 515.5346050262451 seconds
# epoch 60:
# loss_D: 0.147, loss_G_fake: 0.707,
# loss_perturb: 1.050, loss_adv: 103.507,
#
# accuracy in training set after perturbation: 83.802188
#
# 524.137754201889 seconds
# epoch 61:
# loss_D: 0.148, loss_G_fake: 0.704,
# loss_perturb: 1.055, loss_adv: 103.485,
#
# accuracy in training set after perturbation: 83.881252
#
# 532.6806359291077 seconds
# epoch 62:
# loss_D: 0.149, loss_G_fake: 0.703,
# loss_perturb: 1.054, loss_adv: 103.409,
#
# accuracy in training set after perturbation: 83.712923
#
# 541.3845269680023 seconds
# epoch 63:
# loss_D: 0.150, loss_G_fake: 0.701,
# loss_perturb: 1.054, loss_adv: 103.360,
#
# accuracy in training set after perturbation: 83.669566
#
# 550.1656403541565 seconds
# epoch 64:
# loss_D: 0.151, loss_G_fake: 0.701,
# loss_perturb: 1.053, loss_adv: 103.303,
#
# accuracy in training set after perturbation: 83.649162
#
# 558.8498151302338 seconds
# epoch 65:
# loss_D: 0.152, loss_G_fake: 0.699,
# loss_perturb: 1.055, loss_adv: 103.271,
#
# accuracy in training set after perturbation: 83.603254
#
# 567.4500420093536 seconds
# epoch 66:
# loss_D: 0.153, loss_G_fake: 0.698,
# loss_perturb: 1.059, loss_adv: 103.225,
#
# accuracy in training set after perturbation: 83.564998
#
# 576.0517685413361 seconds
# epoch 67:
# loss_D: 0.154, loss_G_fake: 0.697,
# loss_perturb: 1.061, loss_adv: 103.188,
#
# accuracy in training set after perturbation: 83.557347
#
# 584.6221082210541 seconds
# epoch 68:
# loss_D: 0.157, loss_G_fake: 0.695,
# loss_perturb: 1.062, loss_adv: 103.154,
#
# accuracy in training set after perturbation: 83.610906
#
# 593.2858829498291 seconds
# epoch 69:
# loss_D: 0.157, loss_G_fake: 0.695,
# loss_perturb: 1.063, loss_adv: 103.122,
#
# accuracy in training set after perturbation: 83.508888
#
# 601.9079060554504 seconds
# epoch 70:
# loss_D: 0.158, loss_G_fake: 0.693,
# loss_perturb: 1.061, loss_adv: 103.080,
#
# accuracy in training set after perturbation: 83.460430
#
# 610.5119185447693 seconds
# epoch 71:
# loss_D: 0.158, loss_G_fake: 0.693,
# loss_perturb: 1.069, loss_adv: 103.078,
#
# accuracy in training set after perturbation: 83.646612
#
# 619.1159331798553 seconds
# epoch 72:
# loss_D: 0.158, loss_G_fake: 0.694,
# loss_perturb: 1.073, loss_adv: 103.027,
#
# accuracy in training set after perturbation: 83.468081
#
# 627.692610502243 seconds
# epoch 73:
# loss_D: 0.159, loss_G_fake: 0.692,
# loss_perturb: 1.074, loss_adv: 102.994,
#
# accuracy in training set after perturbation: 83.432375
#
# 636.2521028518677 seconds
# epoch 74:
# loss_D: 0.160, loss_G_fake: 0.691,
# loss_perturb: 1.078, loss_adv: 102.975,
#
# accuracy in training set after perturbation: 83.445127
#
# 644.8683350086212 seconds
# epoch 75:
# loss_D: 0.160, loss_G_fake: 0.691,
# loss_perturb: 1.083, loss_adv: 102.939,
#
# accuracy in training set after perturbation: 83.417073
#
# 653.4385998249054 seconds
# epoch 76:
# loss_D: 0.160, loss_G_fake: 0.691,
# loss_perturb: 1.085, loss_adv: 102.915,
#
# accuracy in training set after perturbation: 83.460430
#
# 662.0235412120819 seconds
# epoch 77:
# loss_D: 0.160, loss_G_fake: 0.692,
# loss_perturb: 1.092, loss_adv: 102.904,
#
# accuracy in training set after perturbation: 83.427274
#
# 670.6493604183197 seconds
# epoch 78:
# loss_D: 0.160, loss_G_fake: 0.692,
# loss_perturb: 1.099, loss_adv: 102.876,
#
# accuracy in training set after perturbation: 83.432375
#
# 679.3007156848907 seconds
# epoch 79:
# loss_D: 0.160, loss_G_fake: 0.691,
# loss_perturb: 1.100, loss_adv: 102.842,
#
# accuracy in training set after perturbation: 83.371165
#
# 687.8334412574768 seconds
# epoch 80:
# loss_D: 0.158, loss_G_fake: 0.694,
# loss_perturb: 1.091, loss_adv: 102.755,
#
# accuracy in training set after perturbation: 83.146727
#
# 696.5796818733215 seconds
# epoch 81:
# loss_D: 0.158, loss_G_fake: 0.690,
# loss_perturb: 1.083, loss_adv: 102.736,
#
# accuracy in training set after perturbation: 83.011553
#
# 705.4368963241577 seconds
# epoch 82:
# loss_D: 0.159, loss_G_fake: 0.688,
# loss_perturb: 1.076, loss_adv: 102.727,
#
# accuracy in training set after perturbation: 82.988600
#
# 714.3196766376495 seconds
# epoch 83:
# loss_D: 0.160, loss_G_fake: 0.687,
# loss_perturb: 1.071, loss_adv: 102.719,
#
# accuracy in training set after perturbation: 82.980948
#
# 722.9223756790161 seconds
# epoch 84:
# loss_D: 0.160, loss_G_fake: 0.686,
# loss_perturb: 1.066, loss_adv: 102.714,
#
# accuracy in training set after perturbation: 82.975847
#
# 731.5114800930023 seconds
# epoch 85:
# loss_D: 0.161, loss_G_fake: 0.685,
# loss_perturb: 1.062, loss_adv: 102.708,
#
# accuracy in training set after perturbation: 82.947793
#
# 740.0909657478333 seconds
# epoch 86:
# loss_D: 0.161, loss_G_fake: 0.685,
# loss_perturb: 1.059, loss_adv: 102.703,
#
# accuracy in training set after perturbation: 83.003902
#
# 748.6923706531525 seconds
# epoch 87:
# loss_D: 0.162, loss_G_fake: 0.684,
# loss_perturb: 1.055, loss_adv: 102.698,
#
# accuracy in training set after perturbation: 82.980948
#
# 757.3274986743927 seconds
# epoch 88:
# loss_D: 0.162, loss_G_fake: 0.684,
# loss_perturb: 1.053, loss_adv: 102.693,
#
# accuracy in training set after perturbation: 82.991150
#
# 765.9069230556488 seconds
# epoch 89:
# loss_D: 0.162, loss_G_fake: 0.684,
# loss_perturb: 1.050, loss_adv: 102.688,
#
# accuracy in training set after perturbation: 82.978398
#
# 774.4753494262695 seconds
# epoch 90:
# loss_D: 0.162, loss_G_fake: 0.684,
# loss_perturb: 1.049, loss_adv: 102.684,
#
# accuracy in training set after perturbation: 82.998801
#
# 783.0405306816101 seconds
# epoch 91:
# loss_D: 0.162, loss_G_fake: 0.684,
# loss_perturb: 1.047, loss_adv: 102.680,
#
# accuracy in training set after perturbation: 83.019205
#
# 791.5956671237946 seconds
# epoch 92:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.045, loss_adv: 102.676,
#
# accuracy in training set after perturbation: 83.011553
#
# 800.1993274688721 seconds
# epoch 93:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.043, loss_adv: 102.671,
#
# accuracy in training set after perturbation: 82.993700
#
# 808.7219130992889 seconds
# epoch 94:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.042, loss_adv: 102.666,
#
# accuracy in training set after perturbation: 83.039608
#
# 817.3088750839233 seconds
# epoch 95:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.041, loss_adv: 102.662,
#
# accuracy in training set after perturbation: 83.014104
#
# 825.8871886730194 seconds
# epoch 96:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.040, loss_adv: 102.658,
#
# accuracy in training set after perturbation: 83.011553
#
# 834.5454177856445 seconds
# epoch 97:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.039, loss_adv: 102.653,
#
# accuracy in training set after perturbation: 83.034507
#
# 843.154643535614 seconds
# epoch 98:
# loss_D: 0.163, loss_G_fake: 0.682,
# loss_perturb: 1.038, loss_adv: 102.649,
#
# accuracy in training set after perturbation: 83.034507
#
# 851.8739171028137 seconds
# epoch 99:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.038, loss_adv: 102.645,
#
# accuracy in training set after perturbation: 82.996251
#
# 860.6835732460022 seconds
# epoch 100:
# loss_D: 0.163, loss_G_fake: 0.683,
# loss_perturb: 1.037, loss_adv: 102.641,
#
# accuracy in training set after perturbation: 83.039608
#
# 869.3433947563171 seconds
# accuracy in test set on all perturbed images: 82.129850
#
# misclassifications on previously correctly classified images: 18.424386
