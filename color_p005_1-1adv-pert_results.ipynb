# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p005_1-1adv-pert_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.005, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 1:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.005
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 1
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.005
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.005
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<20:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.500, loss_G_fake: 0.250,
# loss_perturb: 2.622, loss_adv: 125.202,
#
# accuracy in training set after perturbation: 99.250172
#
# 8.835986614227295 seconds
# epoch 2:
# loss_D: 0.500, loss_G_fake: 0.250,
# loss_perturb: 1.578, loss_adv: 121.963,
#
# accuracy in training set after perturbation: 97.332245
#
# 17.74646234512329 seconds
# epoch 3:
# loss_D: 0.497, loss_G_fake: 0.253,
# loss_perturb: 1.324, loss_adv: 119.571,
#
# accuracy in training set after perturbation: 95.830039
#
# 26.62074375152588 seconds
# epoch 4:
# loss_D: 0.467, loss_G_fake: 0.278,
# loss_perturb: 1.072, loss_adv: 118.308,
#
# accuracy in training set after perturbation: 95.062358
#
# 35.494460105895996 seconds
# epoch 5:
# loss_D: 0.432, loss_G_fake: 0.307,
# loss_perturb: 1.100, loss_adv: 116.970,
#
# accuracy in training set after perturbation: 94.060037
#
# 44.28413534164429 seconds
# epoch 6:
# loss_D: 0.413, loss_G_fake: 0.327,
# loss_perturb: 0.964, loss_adv: 115.629,
#
# accuracy in training set after perturbation: 93.116376
#
# 53.14665651321411 seconds
# epoch 7:
# loss_D: 0.391, loss_G_fake: 0.347,
# loss_perturb: 0.927, loss_adv: 114.600,
#
# accuracy in training set after perturbation: 92.409906
#
# 61.95197868347168 seconds
# epoch 8:
# loss_D: 0.376, loss_G_fake: 0.366,
# loss_perturb: 0.937, loss_adv: 113.386,
#
# accuracy in training set after perturbation: 91.578464
#
# 70.704749584198 seconds
# epoch 9:
# loss_D: 0.365, loss_G_fake: 0.381,
# loss_perturb: 0.956, loss_adv: 112.885,
#
# accuracy in training set after perturbation: 91.262210
#
# 79.45710158348083 seconds
# epoch 10:
# loss_D: 0.355, loss_G_fake: 0.397,
# loss_perturb: 0.917, loss_adv: 112.049,
#
# accuracy in training set after perturbation: 90.601648
#
# 88.23106741905212 seconds
# epoch 11:
# loss_D: 0.358, loss_G_fake: 0.400,
# loss_perturb: 0.889, loss_adv: 111.702,
#
# accuracy in training set after perturbation: 90.354255
#
# 96.96120500564575 seconds
# epoch 12:
# loss_D: 0.361, loss_G_fake: 0.404,
# loss_perturb: 0.919, loss_adv: 111.160,
#
# accuracy in training set after perturbation: 89.928333
#
# 105.73490786552429 seconds
# epoch 13:
# loss_D: 0.354, loss_G_fake: 0.420,
# loss_perturb: 0.892, loss_adv: 110.513,
#
# accuracy in training set after perturbation: 89.533015
#
# 114.50138258934021 seconds
# epoch 14:
# loss_D: 0.346, loss_G_fake: 0.437,
# loss_perturb: 0.838, loss_adv: 110.336,
#
# accuracy in training set after perturbation: 89.461603
#
# 123.31977415084839 seconds
# epoch 15:
# loss_D: 0.346, loss_G_fake: 0.441,
# loss_perturb: 0.903, loss_adv: 109.557,
#
# accuracy in training set after perturbation: 88.788288
#
# 132.23777079582214 seconds
# epoch 16:
# loss_D: 0.331, loss_G_fake: 0.467,
# loss_perturb: 0.936, loss_adv: 109.913,
#
# accuracy in training set after perturbation: 89.209110
#
# 141.0063292980194 seconds
# epoch 17:
# loss_D: 0.333, loss_G_fake: 0.466,
# loss_perturb: 0.848, loss_adv: 108.655,
#
# accuracy in training set after perturbation: 88.206789
#
# 149.7735800743103 seconds
# epoch 18:
# loss_D: 0.344, loss_G_fake: 0.461,
# loss_perturb: 0.865, loss_adv: 108.210,
#
# accuracy in training set after perturbation: 87.844628
#
# 158.54273343086243 seconds
# epoch 19:
# loss_D: 0.354, loss_G_fake: 0.454,
# loss_perturb: 0.921, loss_adv: 107.912,
#
# accuracy in training set after perturbation: 87.689051
#
# 167.2567207813263 seconds
# epoch 20:
# loss_D: 0.341, loss_G_fake: 0.470,
# loss_perturb: 0.871, loss_adv: 107.599,
#
# accuracy in training set after perturbation: 87.449310
#
# 176.02076506614685 seconds
# epoch 21:
# loss_D: 0.339, loss_G_fake: 0.468,
# loss_perturb: 0.883, loss_adv: 107.608,
#
# accuracy in training set after perturbation: 87.449310
#
# 184.77022552490234 seconds
# epoch 22:
# loss_D: 0.344, loss_G_fake: 0.467,
# loss_perturb: 0.916, loss_adv: 107.293,
#
# accuracy in training set after perturbation: 87.275881
#
# 193.54977560043335 seconds
# epoch 23:
# loss_D: 0.341, loss_G_fake: 0.470,
# loss_perturb: 0.824, loss_adv: 107.203,
#
# accuracy in training set after perturbation: 87.189166
#
# 202.27131366729736 seconds
# epoch 24:
# loss_D: 0.373, loss_G_fake: 0.443,
# loss_perturb: 0.871, loss_adv: 106.787,
#
# accuracy in training set after perturbation: 86.783647
#
# 211.1541097164154 seconds
# epoch 25:
# loss_D: 0.351, loss_G_fake: 0.463,
# loss_perturb: 0.819, loss_adv: 106.491,
#
# accuracy in training set after perturbation: 86.587263
#
# 219.86535143852234 seconds
# epoch 26:
# loss_D: 0.350, loss_G_fake: 0.470,
# loss_perturb: 0.852, loss_adv: 106.292,
#
# accuracy in training set after perturbation: 86.446989
#
# 228.6313455104828 seconds
# epoch 27:
# loss_D: 0.365, loss_G_fake: 0.452,
# loss_perturb: 0.864, loss_adv: 106.221,
#
# accuracy in training set after perturbation: 86.411283
#
# 237.38381624221802 seconds
# epoch 28:
# loss_D: 0.385, loss_G_fake: 0.433,
# loss_perturb: 0.864, loss_adv: 105.920,
#
# accuracy in training set after perturbation: 86.194496
#
# 246.1012282371521 seconds
# epoch 29:
# loss_D: 0.380, loss_G_fake: 0.444,
# loss_perturb: 0.799, loss_adv: 105.811,
#
# accuracy in training set after perturbation: 86.102681
#
# 254.80526781082153 seconds
# epoch 30:
# loss_D: 0.363, loss_G_fake: 0.452,
# loss_perturb: 0.811, loss_adv: 105.660,
#
# accuracy in training set after perturbation: 86.013415
#
# 263.51647686958313 seconds
# epoch 31:
# loss_D: 0.334, loss_G_fake: 0.481,
# loss_perturb: 0.918, loss_adv: 105.748,
#
# accuracy in training set after perturbation: 86.204698
#
# 272.21175265312195 seconds
# epoch 32:
# loss_D: 0.345, loss_G_fake: 0.462,
# loss_perturb: 0.829, loss_adv: 105.336,
#
# accuracy in training set after perturbation: 85.758372
#
# 280.8948016166687 seconds
# epoch 33:
# loss_D: 0.353, loss_G_fake: 0.468,
# loss_perturb: 0.871, loss_adv: 105.216,
#
# accuracy in training set after perturbation: 85.745620
#
# 289.90449023246765 seconds
# epoch 34:
# loss_D: 0.354, loss_G_fake: 0.466,
# loss_perturb: 0.872, loss_adv: 104.976,
#
# accuracy in training set after perturbation: 85.490576
#
# 298.72464895248413 seconds
# epoch 35:
# loss_D: 0.357, loss_G_fake: 0.453,
# loss_perturb: 0.859, loss_adv: 104.991,
#
# accuracy in training set after perturbation: 85.554337
#
# 307.3921604156494 seconds
# epoch 36:
# loss_D: 0.382, loss_G_fake: 0.439,
# loss_perturb: 0.847, loss_adv: 104.810,
#
# accuracy in training set after perturbation: 85.434467
#
# 316.05749440193176 seconds
# epoch 37:
# loss_D: 0.357, loss_G_fake: 0.463,
# loss_perturb: 0.845, loss_adv: 104.990,
#
# accuracy in training set after perturbation: 85.715014
#
# 324.82243609428406 seconds
# epoch 38:
# loss_D: 0.345, loss_G_fake: 0.475,
# loss_perturb: 0.806, loss_adv: 104.670,
#
# accuracy in training set after perturbation: 85.276340
#
# 333.5157973766327 seconds
# epoch 39:
# loss_D: 0.389, loss_G_fake: 0.429,
# loss_perturb: 0.896, loss_adv: 104.445,
#
# accuracy in training set after perturbation: 85.008544
#
# 342.17448568344116 seconds
# epoch 40:
# loss_D: 0.355, loss_G_fake: 0.456,
# loss_perturb: 0.804, loss_adv: 104.258,
#
# accuracy in training set after perturbation: 84.896325
#
# 350.87534403800964 seconds
# epoch 41:
# loss_D: 0.343, loss_G_fake: 0.473,
# loss_perturb: 0.947, loss_adv: 104.488,
#
# accuracy in training set after perturbation: 85.363054
#
# 359.5836248397827 seconds
# epoch 42:
# loss_D: 0.375, loss_G_fake: 0.447,
# loss_perturb: 0.844, loss_adv: 104.231,
#
# accuracy in training set after perturbation: 85.067204
#
# 368.32174038887024 seconds
# epoch 43:
# loss_D: 0.380, loss_G_fake: 0.433,
# loss_perturb: 0.804, loss_adv: 104.069,
#
# accuracy in training set after perturbation: 84.807060
#
# 377.01110649108887 seconds
# epoch 44:
# loss_D: 0.356, loss_G_fake: 0.455,
# loss_perturb: 0.806, loss_adv: 104.219,
#
# accuracy in training set after perturbation: 85.133515
#
# 385.6708583831787 seconds
# epoch 45:
# loss_D: 0.380, loss_G_fake: 0.446,
# loss_perturb: 0.801, loss_adv: 103.960,
#
# accuracy in training set after perturbation: 84.840215
#
# 394.33987402915955 seconds
# epoch 46:
# loss_D: 0.345, loss_G_fake: 0.469,
# loss_perturb: 0.840, loss_adv: 103.921,
#
# accuracy in training set after perturbation: 84.796858
#
# 402.98563289642334 seconds
# epoch 47:
# loss_D: 0.353, loss_G_fake: 0.462,
# loss_perturb: 0.875, loss_adv: 104.270,
#
# accuracy in training set after perturbation: 85.352853
#
# 411.6382803916931 seconds
# epoch 48:
# loss_D: 0.369, loss_G_fake: 0.454,
# loss_perturb: 0.849, loss_adv: 104.091,
#
# accuracy in training set after perturbation: 84.998342
#
# 420.29872822761536 seconds
# epoch 49:
# loss_D: 0.355, loss_G_fake: 0.461,
# loss_perturb: 0.824, loss_adv: 103.797,
#
# accuracy in training set after perturbation: 84.697391
#
# 428.90923953056335 seconds
# epoch 50:
# loss_D: 0.324, loss_G_fake: 0.468,
# loss_perturb: 0.715, loss_adv: 103.143,
#
# accuracy in training set after perturbation: 83.715473
#
# 437.54302883148193 seconds
# epoch 51:
# loss_D: 0.296, loss_G_fake: 0.496,
# loss_perturb: 0.658, loss_adv: 102.947,
#
# accuracy in training set after perturbation: 83.427274
#
# 446.21737146377563 seconds
# epoch 52:
# loss_D: 0.310, loss_G_fake: 0.481,
# loss_perturb: 0.635, loss_adv: 102.858,
#
# accuracy in training set after perturbation: 83.309954
#
# 454.95794129371643 seconds
# epoch 53:
# loss_D: 0.323, loss_G_fake: 0.468,
# loss_perturb: 0.625, loss_adv: 102.779,
#
# accuracy in training set after perturbation: 83.238542
#
# 463.56831407546997 seconds
# epoch 54:
# loss_D: 0.334, loss_G_fake: 0.458,
# loss_perturb: 0.621, loss_adv: 102.719,
#
# accuracy in training set after perturbation: 83.210487
#
# 472.1858263015747 seconds
# epoch 55:
# loss_D: 0.342, loss_G_fake: 0.451,
# loss_perturb: 0.618, loss_adv: 102.661,
#
# accuracy in training set after perturbation: 83.190084
#
# 480.78517866134644 seconds
# epoch 56:
# loss_D: 0.353, loss_G_fake: 0.442,
# loss_perturb: 0.615, loss_adv: 102.603,
#
# accuracy in training set after perturbation: 83.123773
#
# 489.4062087535858 seconds
# epoch 57:
# loss_D: 0.362, loss_G_fake: 0.435,
# loss_perturb: 0.615, loss_adv: 102.557,
#
# accuracy in training set after perturbation: 83.121222
#
# 497.9862439632416 seconds
# epoch 58:
# loss_D: 0.365, loss_G_fake: 0.432,
# loss_perturb: 0.618, loss_adv: 102.511,
#
# accuracy in training set after perturbation: 83.093167
#
# 506.59349608421326 seconds
# epoch 59:
# loss_D: 0.371, loss_G_fake: 0.427,
# loss_perturb: 0.619, loss_adv: 102.466,
#
# accuracy in training set after perturbation: 83.100819
#
# 515.2192211151123 seconds
# epoch 60:
# loss_D: 0.373, loss_G_fake: 0.423,
# loss_perturb: 0.621, loss_adv: 102.421,
#
# accuracy in training set after perturbation: 83.057461
#
# 523.8446457386017 seconds
# epoch 61:
# loss_D: 0.378, loss_G_fake: 0.420,
# loss_perturb: 0.622, loss_adv: 102.378,
#
# accuracy in training set after perturbation: 83.044709
#
# 532.5404410362244 seconds
# epoch 62:
# loss_D: 0.382, loss_G_fake: 0.417,
# loss_perturb: 0.621, loss_adv: 102.344,
#
# accuracy in training set after perturbation: 83.031957
#
# 541.2151200771332 seconds
# epoch 63:
# loss_D: 0.381, loss_G_fake: 0.418,
# loss_perturb: 0.625, loss_adv: 102.322,
#
# accuracy in training set after perturbation: 83.139075
#
# 549.8296530246735 seconds
# epoch 64:
# loss_D: 0.384, loss_G_fake: 0.416,
# loss_perturb: 0.625, loss_adv: 102.280,
#
# accuracy in training set after perturbation: 82.973297
#
# 558.5571258068085 seconds
# epoch 65:
# loss_D: 0.385, loss_G_fake: 0.415,
# loss_perturb: 0.626, loss_adv: 102.243,
#
# accuracy in training set after perturbation: 82.998801
#
# 567.2188868522644 seconds
# epoch 66:
# loss_D: 0.389, loss_G_fake: 0.411,
# loss_perturb: 0.626, loss_adv: 102.211,
#
# accuracy in training set after perturbation: 82.991150
#
# 575.8529169559479 seconds
# epoch 67:
# loss_D: 0.389, loss_G_fake: 0.410,
# loss_perturb: 0.627, loss_adv: 102.184,
#
# accuracy in training set after perturbation: 82.998801
#
# 584.4774160385132 seconds
# epoch 68:
# loss_D: 0.392, loss_G_fake: 0.407,
# loss_perturb: 0.628, loss_adv: 102.147,
#
# accuracy in training set after perturbation: 82.952893
#
# 593.1547493934631 seconds
# epoch 69:
# loss_D: 0.392, loss_G_fake: 0.406,
# loss_perturb: 0.629, loss_adv: 102.119,
#
# accuracy in training set after perturbation: 82.960545
#
# 602.0314908027649 seconds
# epoch 70:
# loss_D: 0.394, loss_G_fake: 0.403,
# loss_perturb: 0.632, loss_adv: 102.093,
#
# accuracy in training set after perturbation: 82.894233
#
# 610.7576520442963 seconds
# epoch 71:
# loss_D: 0.394, loss_G_fake: 0.404,
# loss_perturb: 0.635, loss_adv: 102.072,
#
# accuracy in training set after perturbation: 82.937591
#
# 619.4693701267242 seconds
# epoch 72:
# loss_D: 0.395, loss_G_fake: 0.402,
# loss_perturb: 0.637, loss_adv: 102.052,
#
# accuracy in training set after perturbation: 82.919738
#
# 628.1813588142395 seconds
# epoch 73:
# loss_D: 0.395, loss_G_fake: 0.400,
# loss_perturb: 0.637, loss_adv: 102.017,
#
# accuracy in training set after perturbation: 82.876380
#
# 636.8530447483063 seconds
# epoch 74:
# loss_D: 0.397, loss_G_fake: 0.399,
# loss_perturb: 0.636, loss_adv: 101.988,
#
# accuracy in training set after perturbation: 82.855977
#
# 645.4623243808746 seconds
# epoch 75:
# loss_D: 0.398, loss_G_fake: 0.397,
# loss_perturb: 0.636, loss_adv: 101.968,
#
# accuracy in training set after perturbation: 82.889133
#
# 654.0717105865479 seconds
# epoch 76:
# loss_D: 0.397, loss_G_fake: 0.398,
# loss_perturb: 0.637, loss_adv: 101.941,
#
# accuracy in training set after perturbation: 82.840674
#
# 662.6864731311798 seconds
# epoch 77:
# loss_D: 0.398, loss_G_fake: 0.396,
# loss_perturb: 0.639, loss_adv: 101.922,
#
# accuracy in training set after perturbation: 82.817720
#
# 671.2787218093872 seconds
# epoch 78:
# loss_D: 0.400, loss_G_fake: 0.395,
# loss_perturb: 0.637, loss_adv: 101.892,
#
# accuracy in training set after perturbation: 82.789666
#
# 679.9442479610443 seconds
# epoch 79:
# loss_D: 0.400, loss_G_fake: 0.394,
# loss_perturb: 0.638, loss_adv: 101.869,
#
# accuracy in training set after perturbation: 82.817720
#
# 688.6307654380798 seconds
# epoch 80:
# loss_D: 0.401, loss_G_fake: 0.384,
# loss_perturb: 0.635, loss_adv: 101.806,
#
# accuracy in training set after perturbation: 82.720804
#
# 697.369264125824 seconds
# epoch 81:
# loss_D: 0.401, loss_G_fake: 0.389,
# loss_perturb: 0.632, loss_adv: 101.788,
#
# accuracy in training set after perturbation: 82.532072
#
# 705.9342978000641 seconds
# epoch 82:
# loss_D: 0.402, loss_G_fake: 0.388,
# loss_perturb: 0.630, loss_adv: 101.781,
#
# accuracy in training set after perturbation: 82.539723
#
# 714.5802533626556 seconds
# epoch 83:
# loss_D: 0.403, loss_G_fake: 0.386,
# loss_perturb: 0.628, loss_adv: 101.776,
#
# accuracy in training set after perturbation: 82.529521
#
# 723.1911590099335 seconds
# epoch 84:
# loss_D: 0.404, loss_G_fake: 0.385,
# loss_perturb: 0.626, loss_adv: 101.772,
#
# accuracy in training set after perturbation: 82.501467
#
# 731.8209712505341 seconds
# epoch 85:
# loss_D: 0.405, loss_G_fake: 0.385,
# loss_perturb: 0.625, loss_adv: 101.767,
#
# accuracy in training set after perturbation: 82.537173
#
# 740.4215559959412 seconds
# epoch 86:
# loss_D: 0.405, loss_G_fake: 0.384,
# loss_perturb: 0.624, loss_adv: 101.764,
#
# accuracy in training set after perturbation: 82.483613
#
# 749.033629655838 seconds
# epoch 87:
# loss_D: 0.406, loss_G_fake: 0.384,
# loss_perturb: 0.623, loss_adv: 101.759,
#
# accuracy in training set after perturbation: 82.567778
#
# 757.6510319709778 seconds
# epoch 88:
# loss_D: 0.406, loss_G_fake: 0.383,
# loss_perturb: 0.623, loss_adv: 101.754,
#
# accuracy in training set after perturbation: 82.516769
#
# 766.2809307575226 seconds
# epoch 89:
# loss_D: 0.406, loss_G_fake: 0.383,
# loss_perturb: 0.622, loss_adv: 101.751,
#
# accuracy in training set after perturbation: 82.521870
#
# 774.987655878067 seconds
# epoch 90:
# loss_D: 0.406, loss_G_fake: 0.383,
# loss_perturb: 0.622, loss_adv: 101.747,
#
# accuracy in training set after perturbation: 82.506567
#
# 783.6184432506561 seconds
# epoch 91:
# loss_D: 0.407, loss_G_fake: 0.382,
# loss_perturb: 0.622, loss_adv: 101.744,
#
# accuracy in training set after perturbation: 82.529521
#
# 792.1985652446747 seconds
# epoch 92:
# loss_D: 0.407, loss_G_fake: 0.382,
# loss_perturb: 0.621, loss_adv: 101.741,
#
# accuracy in training set after perturbation: 82.519320
#
# 800.777622461319 seconds
# epoch 93:
# loss_D: 0.407, loss_G_fake: 0.382,
# loss_perturb: 0.621, loss_adv: 101.737,
#
# accuracy in training set after perturbation: 82.565227
#
# 809.3411478996277 seconds
# epoch 94:
# loss_D: 0.407, loss_G_fake: 0.382,
# loss_perturb: 0.621, loss_adv: 101.733,
#
# accuracy in training set after perturbation: 82.488714
#
# 817.9400928020477 seconds
# epoch 95:
# loss_D: 0.407, loss_G_fake: 0.382,
# loss_perturb: 0.621, loss_adv: 101.731,
#
# accuracy in training set after perturbation: 82.580530
#
# 826.6192979812622 seconds
# epoch 96:
# loss_D: 0.407, loss_G_fake: 0.382,
# loss_perturb: 0.621, loss_adv: 101.726,
#
# accuracy in training set after perturbation: 82.529521
#
# 835.3644866943359 seconds
# epoch 97:
# loss_D: 0.407, loss_G_fake: 0.381,
# loss_perturb: 0.621, loss_adv: 101.723,
#
# accuracy in training set after perturbation: 82.542273
#
# 844.1388154029846 seconds
# epoch 98:
# loss_D: 0.408, loss_G_fake: 0.381,
# loss_perturb: 0.620, loss_adv: 101.719,
#
# accuracy in training set after perturbation: 82.542273
#
# 852.8172028064728 seconds
# epoch 99:
# loss_D: 0.408, loss_G_fake: 0.381,
# loss_perturb: 0.620, loss_adv: 101.717,
#
# accuracy in training set after perturbation: 82.521870
#
# 861.4887385368347 seconds
# epoch 100:
# loss_D: 0.408, loss_G_fake: 0.381,
# loss_perturb: 0.620, loss_adv: 101.714,
#
# accuracy in training set after perturbation: 82.542273
#
# 870.0971848964691 seconds
# accuracy in test set on all perturbed images: 80.847189
#
# misclassifications on previously correctly classified images: 19.556611
