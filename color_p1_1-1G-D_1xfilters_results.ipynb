# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p1_1-1G-D_1xfilters_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.1, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.1
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.1
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.1
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.302, loss_G_fake: 0.443,
# loss_perturb: 18.525, loss_adv: 30.529,
#
# accuracy in training set after perturbation: 25.328368
#
# 8.955965518951416 seconds
# epoch 2:
# loss_D: 0.078, loss_G_fake: 0.764,
# loss_perturb: 15.327, loss_adv: 19.654,
#
# accuracy in training set after perturbation: 16.307480
#
# 17.96472430229187 seconds
# epoch 3:
# loss_D: 0.055, loss_G_fake: 0.829,
# loss_perturb: 15.014, loss_adv: 15.018,
#
# accuracy in training set after perturbation: 12.673111
#
# 26.899813652038574 seconds
# epoch 4:
# loss_D: 0.044, loss_G_fake: 0.873,
# loss_perturb: 14.128, loss_adv: 11.775,
#
# accuracy in training set after perturbation: 9.928843
#
# 35.789055585861206 seconds
# epoch 5:
# loss_D: 0.039, loss_G_fake: 0.890,
# loss_perturb: 13.345, loss_adv: 8.910,
#
# accuracy in training set after perturbation: 7.618149
#
# 44.6476628780365 seconds
# epoch 6:
# loss_D: 0.038, loss_G_fake: 0.896,
# loss_perturb: 11.409, loss_adv: 8.213,
#
# accuracy in training set after perturbation: 6.995843
#
# 53.51399326324463 seconds
# epoch 7:
# loss_D: 0.029, loss_G_fake: 0.922,
# loss_perturb: 10.570, loss_adv: 6.442,
#
# accuracy in training set after perturbation: 5.485985
#
# 62.465864419937134 seconds
# epoch 8:
# loss_D: 0.039, loss_G_fake: 0.906,
# loss_perturb: 9.766, loss_adv: 5.669,
#
# accuracy in training set after perturbation: 4.833074
#
# 71.51431465148926 seconds
# epoch 9:
# loss_D: 0.031, loss_G_fake: 0.926,
# loss_perturb: 9.662, loss_adv: 5.001,
#
# accuracy in training set after perturbation: 4.269428
#
# 80.31363439559937 seconds
# epoch 10:
# loss_D: 0.020, loss_G_fake: 0.947,
# loss_perturb: 10.152, loss_adv: 4.786,
#
# accuracy in training set after perturbation: 4.152108
#
# 89.14331817626953 seconds
# epoch 11:
# loss_D: 0.026, loss_G_fake: 0.937,
# loss_perturb: 9.926, loss_adv: 4.073,
#
# accuracy in training set after perturbation: 3.585911
#
# 98.03956484794617 seconds
# epoch 12:
# loss_D: 0.029, loss_G_fake: 0.932,
# loss_perturb: 8.828, loss_adv: 3.279,
#
# accuracy in training set after perturbation: 2.907496
#
# 106.77684998512268 seconds
# epoch 13:
# loss_D: 0.020, loss_G_fake: 0.954,
# loss_perturb: 9.098, loss_adv: 2.819,
#
# accuracy in training set after perturbation: 2.535132
#
# 115.57254147529602 seconds
# epoch 14:
# loss_D: 0.022, loss_G_fake: 0.950,
# loss_perturb: 8.123, loss_adv: 2.244,
#
# accuracy in training set after perturbation: 1.984238
#
# 124.34602808952332 seconds
# epoch 15:
# loss_D: 0.021, loss_G_fake: 0.951,
# loss_perturb: 7.004, loss_adv: 1.950,
#
# accuracy in training set after perturbation: 1.759800
#
# 133.10507082939148 seconds
# epoch 16:
# loss_D: 0.015, loss_G_fake: 0.962,
# loss_perturb: 9.361, loss_adv: 2.871,
#
# accuracy in training set after perturbation: 2.578490
#
# 141.8749701976776 seconds
# epoch 17:
# loss_D: 0.017, loss_G_fake: 0.961,
# loss_perturb: 8.486, loss_adv: 2.350,
#
# accuracy in training set after perturbation: 2.137264
#
# 150.64390635490417 seconds
# epoch 18:
# loss_D: 0.018, loss_G_fake: 0.960,
# loss_perturb: 9.141, loss_adv: 3.098,
#
# accuracy in training set after perturbation: 2.759571
#
# 159.4013090133667 seconds
# epoch 19:
# loss_D: 0.013, loss_G_fake: 0.965,
# loss_perturb: 7.976, loss_adv: 1.941,
#
# accuracy in training set after perturbation: 1.759800
#
# 168.24329447746277 seconds
# epoch 20:
# loss_D: 0.018, loss_G_fake: 0.957,
# loss_perturb: 7.964, loss_adv: 1.846,
#
# accuracy in training set after perturbation: 1.683287
#
# 177.12465023994446 seconds
# epoch 21:
# loss_D: 0.011, loss_G_fake: 0.971,
# loss_perturb: 7.846, loss_adv: 1.953,
#
# accuracy in training set after perturbation: 1.754699
#
# 185.88885879516602 seconds
# epoch 22:
# loss_D: 0.014, loss_G_fake: 0.961,
# loss_perturb: 7.844, loss_adv: 1.605,
#
# accuracy in training set after perturbation: 1.494555
#
# 194.62340474128723 seconds
# epoch 23:
# loss_D: 0.009, loss_G_fake: 0.961,
# loss_perturb: 7.590, loss_adv: 1.958,
#
# accuracy in training set after perturbation: 1.777653
#
# 203.31937909126282 seconds
# epoch 24:
# loss_D: 0.006, loss_G_fake: 0.966,
# loss_perturb: 8.087, loss_adv: 1.759,
#
# accuracy in training set after perturbation: 1.614425
#
# 212.03895139694214 seconds
# epoch 25:
# loss_D: 0.002, loss_G_fake: 0.976,
# loss_perturb: 7.919, loss_adv: 1.792,
#
# accuracy in training set after perturbation: 1.713892
#
# 220.7296380996704 seconds
# epoch 26:
# loss_D: 0.002, loss_G_fake: 0.981,
# loss_perturb: 7.019, loss_adv: 1.230,
#
# accuracy in training set after perturbation: 1.193604
#
# 229.40525269508362 seconds
# epoch 27:
# loss_D: 0.001, loss_G_fake: 0.984,
# loss_perturb: 7.429, loss_adv: 1.150,
#
# accuracy in training set after perturbation: 1.117090
#
# 238.1070249080658 seconds
# epoch 28:
# loss_D: 0.004, loss_G_fake: 0.979,
# loss_perturb: 7.380, loss_adv: 1.292,
#
# accuracy in training set after perturbation: 1.242062
#
# 246.829594373703 seconds
# epoch 29:
# loss_D: 0.003, loss_G_fake: 0.977,
# loss_perturb: 6.260, loss_adv: 0.932,
#
# accuracy in training set after perturbation: 0.895203
#
# 255.63597011566162 seconds
# epoch 30:
# loss_D: 0.001, loss_G_fake: 0.986,
# loss_perturb: 5.697, loss_adv: 0.864,
#
# accuracy in training set after perturbation: 0.816139
#
# 264.36220622062683 seconds
# epoch 31:
# loss_D: 0.003, loss_G_fake: 0.980,
# loss_perturb: 7.232, loss_adv: 1.200,
#
# accuracy in training set after perturbation: 1.160448
#
# 273.0600607395172 seconds
# epoch 32:
# loss_D: 0.001, loss_G_fake: 0.984,
# loss_perturb: 5.970, loss_adv: 0.840,
#
# accuracy in training set after perturbation: 0.798286
#
# 281.72932744026184 seconds
# epoch 33:
# loss_D: 0.001, loss_G_fake: 0.986,
# loss_perturb: 5.999, loss_adv: 0.742,
#
# accuracy in training set after perturbation: 0.716672
#
# 290.40550208091736 seconds
# epoch 34:
# loss_D: 0.001, loss_G_fake: 0.986,
# loss_perturb: 6.199, loss_adv: 0.780,
#
# accuracy in training set after perturbation: 0.757479
#
# 299.084415435791 seconds
# epoch 35:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 7.437, loss_adv: 1.132,
#
# accuracy in training set after perturbation: 1.122191
#
# 307.73016595840454 seconds
# epoch 36:
# loss_D: 0.002, loss_G_fake: 0.988,
# loss_perturb: 6.143, loss_adv: 0.834,
#
# accuracy in training set after perturbation: 0.780433
#
# 316.3579511642456 seconds
# epoch 37:
# loss_D: 0.003, loss_G_fake: 0.980,
# loss_perturb: 5.720, loss_adv: 0.695,
#
# accuracy in training set after perturbation: 0.683517
#
# 325.04884123802185 seconds
# epoch 38:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 5.721, loss_adv: 0.773,
#
# accuracy in training set after perturbation: 0.760030
#
# 333.778085231781 seconds
# epoch 39:
# loss_D: 0.004, loss_G_fake: 0.980,
# loss_perturb: 6.849, loss_adv: 1.137,
#
# accuracy in training set after perturbation: 1.071183
#
# 342.4915704727173 seconds
# epoch 40:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 6.038, loss_adv: 0.668,
#
# accuracy in training set after perturbation: 0.655462
#
# 351.14547538757324 seconds
# epoch 41:
# loss_D: 0.008, loss_G_fake: 0.977,
# loss_perturb: 5.555, loss_adv: 0.709,
#
# accuracy in training set after perturbation: 0.701370
#
# 359.75992250442505 seconds
# epoch 42:
# loss_D: 0.001, loss_G_fake: 0.987,
# loss_perturb: 5.746, loss_adv: 0.681,
#
# accuracy in training set after perturbation: 0.683517
#
# 368.4025285243988 seconds
# epoch 43:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 6.766, loss_adv: 1.041,
#
# accuracy in training set after perturbation: 1.030376
#
# 377.32387375831604 seconds
# epoch 44:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 6.350, loss_adv: 0.845,
#
# accuracy in training set after perturbation: 0.818690
#
# 386.1095004081726 seconds
# epoch 45:
# loss_D: 0.002, loss_G_fake: 0.988,
# loss_perturb: 5.610, loss_adv: 0.644,
#
# accuracy in training set after perturbation: 0.635058
#
# 394.7697513103485 seconds
# epoch 46:
# loss_D: 0.001, loss_G_fake: 0.991,
# loss_perturb: 5.637, loss_adv: 0.548,
#
# accuracy in training set after perturbation: 0.527940
#
# 403.4104268550873 seconds
# epoch 47:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 5.716, loss_adv: 0.645,
#
# accuracy in training set after perturbation: 0.627407
#
# 412.0952715873718 seconds
# epoch 48:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 4.817, loss_adv: 0.586,
#
# accuracy in training set after perturbation: 0.568747
#
# 420.88765478134155 seconds
# epoch 49:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 4.606, loss_adv: 0.443,
#
# accuracy in training set after perturbation: 0.436124
#
# 429.5373520851135 seconds
# epoch 50:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.927, loss_adv: 0.406,
#
# accuracy in training set after perturbation: 0.397868
#
# 438.13969588279724 seconds
# epoch 51:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.726, loss_adv: 0.350,
#
# accuracy in training set after perturbation: 0.323905
#
# 446.8182764053345 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.592, loss_adv: 0.337,
#
# accuracy in training set after perturbation: 0.313703
#
# 455.45923113822937 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.527, loss_adv: 0.329,
#
# accuracy in training set after perturbation: 0.311153
#
# 464.10319542884827 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.444, loss_adv: 0.323,
#
# accuracy in training set after perturbation: 0.288199
#
# 472.8652822971344 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.329, loss_adv: 0.315,
#
# accuracy in training set after perturbation: 0.295850
#
# 481.5023715496063 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.265, loss_adv: 0.313,
#
# accuracy in training set after perturbation: 0.290750
#
# 490.1740608215332 seconds
# epoch 57:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.221, loss_adv: 0.310,
#
# accuracy in training set after perturbation: 0.283098
#
# 498.9398102760315 seconds
# epoch 58:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.115, loss_adv: 0.294,
#
# accuracy in training set after perturbation: 0.267796
#
# 507.62539744377136 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.115, loss_adv: 0.295,
#
# accuracy in training set after perturbation: 0.280548
#
# 516.2692048549652 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.097, loss_adv: 0.297,
#
# accuracy in training set after perturbation: 0.283098
#
# 524.9566640853882 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 3.109, loss_adv: 0.290,
#
# accuracy in training set after perturbation: 0.275447
#
# 533.6131200790405 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 3.067, loss_adv: 0.294,
#
# accuracy in training set after perturbation: 0.277997
#
# 542.2764689922333 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.033, loss_adv: 0.277,
#
# accuracy in training set after perturbation: 0.255043
#
# 550.8889193534851 seconds
# epoch 64:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.016, loss_adv: 0.285,
#
# accuracy in training set after perturbation: 0.260144
#
# 559.5064005851746 seconds
# epoch 65:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.030, loss_adv: 0.278,
#
# accuracy in training set after perturbation: 0.265245
#
# 568.11048412323 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.010, loss_adv: 0.275,
#
# accuracy in training set after perturbation: 0.252493
#
# 576.8064212799072 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 2.978, loss_adv: 0.269,
#
# accuracy in training set after perturbation: 0.260144
#
# 585.473123550415 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.947, loss_adv: 0.270,
#
# accuracy in training set after perturbation: 0.257594
#
# 594.1257193088531 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 2.912, loss_adv: 0.257,
#
# accuracy in training set after perturbation: 0.237190
#
# 602.7477142810822 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 3.019, loss_adv: 0.253,
#
# accuracy in training set after perturbation: 0.232090
#
# 611.4117913246155 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.855, loss_adv: 0.256,
#
# accuracy in training set after perturbation: 0.247392
#
# 620.0527274608612 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 2.865, loss_adv: 0.257,
#
# accuracy in training set after perturbation: 0.255043
#
# 628.6929020881653 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.925, loss_adv: 0.253,
#
# accuracy in training set after perturbation: 0.242291
#
# 637.3396544456482 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.876, loss_adv: 0.237,
#
# accuracy in training set after perturbation: 0.221888
#
# 646.0161008834839 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.849, loss_adv: 0.240,
#
# accuracy in training set after perturbation: 0.234640
#
# 654.7313406467438 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.846, loss_adv: 0.234,
#
# accuracy in training set after perturbation: 0.211686
#
# 663.4418396949768 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.775, loss_adv: 0.242,
#
# accuracy in training set after perturbation: 0.221888
#
# 672.0605759620667 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.795, loss_adv: 0.242,
#
# accuracy in training set after perturbation: 0.221888
#
# 680.7015182971954 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.822, loss_adv: 0.234,
#
# accuracy in training set after perturbation: 0.226989
#
# 689.609281539917 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.709, loss_adv: 0.236,
#
# accuracy in training set after perturbation: 0.221888
#
# 698.2889378070831 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.688, loss_adv: 0.225,
#
# accuracy in training set after perturbation: 0.201484
#
# 706.897922039032 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.663, loss_adv: 0.224,
#
# accuracy in training set after perturbation: 0.201484
#
# 715.535896062851 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.643, loss_adv: 0.222,
#
# accuracy in training set after perturbation: 0.201484
#
# 724.1718785762787 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.632, loss_adv: 0.222,
#
# accuracy in training set after perturbation: 0.193833
#
# 732.8010203838348 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.618, loss_adv: 0.223,
#
# accuracy in training set after perturbation: 0.204035
#
# 741.5620920658112 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.598, loss_adv: 0.222,
#
# accuracy in training set after perturbation: 0.196383
#
# 750.1887214183807 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.585, loss_adv: 0.220,
#
# accuracy in training set after perturbation: 0.211686
#
# 758.7982831001282 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.575, loss_adv: 0.221,
#
# accuracy in training set after perturbation: 0.211686
#
# 767.4313995838165 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.575, loss_adv: 0.221,
#
# accuracy in training set after perturbation: 0.198934
#
# 776.1632680892944 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.563, loss_adv: 0.220,
#
# accuracy in training set after perturbation: 0.201484
#
# 784.7876708507538 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.556, loss_adv: 0.221,
#
# accuracy in training set after perturbation: 0.206585
#
# 793.4083802700043 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.547, loss_adv: 0.219,
#
# accuracy in training set after perturbation: 0.201484
#
# 802.0326917171478 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.532, loss_adv: 0.219,
#
# accuracy in training set after perturbation: 0.211686
#
# 810.657559633255 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.541, loss_adv: 0.220,
#
# accuracy in training set after perturbation: 0.209136
#
# 819.3683152198792 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.532, loss_adv: 0.218,
#
# accuracy in training set after perturbation: 0.201484
#
# 827.9855649471283 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.532, loss_adv: 0.220,
#
# accuracy in training set after perturbation: 0.209136
#
# 836.6113331317902 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.528, loss_adv: 0.219,
#
# accuracy in training set after perturbation: 0.198934
#
# 845.2074060440063 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.516, loss_adv: 0.219,
#
# accuracy in training set after perturbation: 0.204035
#
# 853.8215506076813 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.522, loss_adv: 0.218,
#
# accuracy in training set after perturbation: 0.198934
#
# 862.434629201889 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.998,
# loss_perturb: 2.513, loss_adv: 0.217,
#
# accuracy in training set after perturbation: 0.206585
#
# 871.0669794082642 seconds
# accuracy in test set on all perturbed images: 4.228029
#
# misclassifications on previously correctly classified images: 96.096595
