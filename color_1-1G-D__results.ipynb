# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_1-1G-D__results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.03, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1130.945801
#
# Train accuracy so far: 49.231044
#
# loss in epoch 1: 351.420074
#
# Train accuracy so far: 83.376266
#
# loss in epoch 2: 216.973434
#
# Train accuracy so far: 89.971690
#
# loss in epoch 3: 150.079224
#
# Train accuracy so far: 93.118927
#
# loss in epoch 4: 110.570129
#
# Train accuracy so far: 95.052156
#
# loss in epoch 5: 83.844406
#
# Train accuracy so far: 96.284016
#
# loss in epoch 6: 66.961159
#
# Train accuracy so far: 97.005789
#
# loss in epoch 7: 55.298065
#
# Train accuracy so far: 97.480170
#
# loss in epoch 8: 46.474003
#
# Train accuracy so far: 97.870387
#
# loss in epoch 9: 40.211346
#
# Train accuracy so far: 98.245301
#
# loss in epoch 10: 30.582113
#
# Train accuracy so far: 98.594710
#
# loss in epoch 11: 30.492558
#
# Train accuracy so far: 98.564105
#
# loss in epoch 12: 26.486862
#
# Train accuracy so far: 98.686526
#
# loss in epoch 13: 21.067282
#
# Train accuracy so far: 98.939019
#
# loss in epoch 14: 22.991495
#
# Train accuracy so far: 98.900763
#
# loss in epoch 15: 17.665693
#
# Train accuracy so far: 99.112449
#
# loss in epoch 16: 20.148735
#
# Train accuracy so far: 99.007881
#
# loss in epoch 17: 15.143624
#
# Train accuracy so far: 99.262924
#
# loss in epoch 18: 14.905992
#
# Train accuracy so far: 99.209365
#
# loss in epoch 19: 12.837030
#
# Train accuracy so far: 99.367492
#
# accuracy in testing set: 90.395883

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.03
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.03
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.03
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.395883
#
# epoch 1:
# loss_D: 0.405, loss_G_fake: 0.324,
# loss_perturb: 16.064, loss_adv: 91.390,
#
# accuracy in training set after perturbation: 74.541559
#
# 8.52922797203064 seconds
# epoch 2:
# loss_D: 0.181, loss_G_fake: 0.573,
# loss_perturb: 11.057, loss_adv: 76.380,
#
# accuracy in training set after perturbation: 62.559616
#
# 16.971193313598633 seconds
# epoch 3:
# loss_D: 0.100, loss_G_fake: 0.721,
# loss_perturb: 9.507, loss_adv: 70.761,
#
# accuracy in training set after perturbation: 57.912724
#
# 25.497647523880005 seconds
# epoch 4:
# loss_D: 0.095, loss_G_fake: 0.751,
# loss_perturb: 8.300, loss_adv: 65.912,
#
# accuracy in training set after perturbation: 54.020761
#
# 34.011008977890015 seconds
# epoch 5:
# loss_D: 0.079, loss_G_fake: 0.786,
# loss_perturb: 8.222, loss_adv: 63.451,
#
# accuracy in training set after perturbation: 52.072228
#
# 42.578468799591064 seconds
# epoch 6:
# loss_D: 0.059, loss_G_fake: 0.835,
# loss_perturb: 7.676, loss_adv: 60.798,
#
# accuracy in training set after perturbation: 49.985973
#
# 51.15578055381775 seconds
# epoch 7:
# loss_D: 0.060, loss_G_fake: 0.844,
# loss_perturb: 7.386, loss_adv: 57.367,
#
# accuracy in training set after perturbation: 47.157540
#
# 59.69723963737488 seconds
# epoch 8:
# loss_D: 0.053, loss_G_fake: 0.869,
# loss_perturb: 7.746, loss_adv: 56.802,
#
# accuracy in training set after perturbation: 46.889745
#
# 68.21093821525574 seconds
# epoch 9:
# loss_D: 0.057, loss_G_fake: 0.862,
# loss_perturb: 7.172, loss_adv: 53.453,
#
# accuracy in training set after perturbation: 44.076615
#
# 76.7429850101471 seconds
# epoch 10:
# loss_D: 0.051, loss_G_fake: 0.880,
# loss_perturb: 7.289, loss_adv: 51.855,
#
# accuracy in training set after perturbation: 42.913617
#
# 85.22207975387573 seconds
# epoch 11:
# loss_D: 0.047, loss_G_fake: 0.889,
# loss_perturb: 7.162, loss_adv: 49.986,
#
# accuracy in training set after perturbation: 41.411411
#
# 93.75139379501343 seconds
# epoch 12:
# loss_D: 0.049, loss_G_fake: 0.887,
# loss_perturb: 7.143, loss_adv: 48.314,
#
# accuracy in training set after perturbation: 40.034176
#
# 102.2706253528595 seconds
# epoch 13:
# loss_D: 0.050, loss_G_fake: 0.888,
# loss_perturb: 6.979, loss_adv: 47.517,
#
# accuracy in training set after perturbation: 39.399118
#
# 110.77732133865356 seconds
# epoch 14:
# loss_D: 0.053, loss_G_fake: 0.887,
# loss_perturb: 7.418, loss_adv: 46.840,
#
# accuracy in training set after perturbation: 38.843123
#
# 119.31658458709717 seconds
# epoch 15:
# loss_D: 0.048, loss_G_fake: 0.898,
# loss_perturb: 7.140, loss_adv: 45.870,
#
# accuracy in training set after perturbation: 38.016782
#
# 127.85143852233887 seconds
# epoch 16:
# loss_D: 0.047, loss_G_fake: 0.904,
# loss_perturb: 6.593, loss_adv: 44.050,
#
# accuracy in training set after perturbation: 36.501824
#
# 136.3984031677246 seconds
# epoch 17:
# loss_D: 0.052, loss_G_fake: 0.890,
# loss_perturb: 6.631, loss_adv: 43.420,
#
# accuracy in training set after perturbation: 36.096304
#
# 144.86544013023376 seconds
# epoch 18:
# loss_D: 0.049, loss_G_fake: 0.897,
# loss_perturb: 6.615, loss_adv: 42.820,
#
# accuracy in training set after perturbation: 35.642327
#
# 153.38663411140442 seconds
# epoch 19:
# loss_D: 0.052, loss_G_fake: 0.895,
# loss_perturb: 6.598, loss_adv: 42.154,
#
# accuracy in training set after perturbation: 35.134790
#
# 161.89541888237 seconds
# epoch 20:
# loss_D: 0.046, loss_G_fake: 0.911,
# loss_perturb: 6.799, loss_adv: 42.268,
#
# accuracy in training set after perturbation: 35.257211
#
# 170.54160952568054 seconds
# epoch 21:
# loss_D: 0.044, loss_G_fake: 0.912,
# loss_perturb: 6.827, loss_adv: 40.907,
#
# accuracy in training set after perturbation: 34.091663
#
# 179.1070055961609 seconds
# epoch 22:
# loss_D: 0.045, loss_G_fake: 0.907,
# loss_perturb: 6.809, loss_adv: 40.187,
#
# accuracy in training set after perturbation: 33.479558
#
# 187.57294034957886 seconds
# epoch 23:
# loss_D: 0.049, loss_G_fake: 0.899,
# loss_perturb: 6.705, loss_adv: 40.077,
#
# accuracy in training set after perturbation: 33.418348
#
# 196.03707027435303 seconds
# epoch 24:
# loss_D: 0.041, loss_G_fake: 0.921,
# loss_perturb: 6.642, loss_adv: 39.109,
#
# accuracy in training set after perturbation: 32.602209
#
# 204.57779502868652 seconds
# epoch 25:
# loss_D: 0.048, loss_G_fake: 0.909,
# loss_perturb: 6.450, loss_adv: 38.507,
#
# accuracy in training set after perturbation: 32.036012
#
# 213.0868320465088 seconds
# epoch 26:
# loss_D: 0.037, loss_G_fake: 0.931,
# loss_perturb: 6.847, loss_adv: 39.116,
#
# accuracy in training set after perturbation: 32.742483
#
# 221.57714414596558 seconds
# epoch 27:
# loss_D: 0.035, loss_G_fake: 0.931,
# loss_perturb: 6.755, loss_adv: 38.247,
#
# accuracy in training set after perturbation: 31.946747
#
# 230.07511234283447 seconds
# epoch 28:
# loss_D: 0.036, loss_G_fake: 0.927,
# loss_perturb: 6.584, loss_adv: 38.221,
#
# accuracy in training set after perturbation: 31.982453
#
# 238.57275009155273 seconds
# epoch 29:
# loss_D: 0.036, loss_G_fake: 0.931,
# loss_perturb: 6.273, loss_adv: 37.069,
#
# accuracy in training set after perturbation: 30.793950
#
# 247.0817356109619 seconds
# epoch 30:
# loss_D: 0.030, loss_G_fake: 0.933,
# loss_perturb: 6.294, loss_adv: 36.788,
#
# accuracy in training set after perturbation: 30.612869
#
# 255.58919954299927 seconds
# epoch 31:
# loss_D: 0.034, loss_G_fake: 0.931,
# loss_perturb: 6.109, loss_adv: 36.684,
#
# accuracy in training set after perturbation: 30.521054
#
# 264.0572009086609 seconds
# epoch 32:
# loss_D: 0.044, loss_G_fake: 0.915,
# loss_perturb: 5.905, loss_adv: 35.885,
#
# accuracy in training set after perturbation: 29.801831
#
# 272.5310175418854 seconds
# epoch 33:
# loss_D: 0.033, loss_G_fake: 0.934,
# loss_perturb: 6.031, loss_adv: 35.948,
#
# accuracy in training set after perturbation: 29.942105
#
# 281.0425765514374 seconds
# epoch 34:
# loss_D: 0.029, loss_G_fake: 0.935,
# loss_perturb: 6.308, loss_adv: 36.172,
#
# accuracy in training set after perturbation: 30.245607
#
# 289.59526562690735 seconds
# epoch 35:
# loss_D: 0.035, loss_G_fake: 0.933,
# loss_perturb: 6.018, loss_adv: 35.356,
#
# accuracy in training set after perturbation: 29.378459
#
# 298.10303950309753 seconds
# epoch 36:
# loss_D: 0.043, loss_G_fake: 0.912,
# loss_perturb: 6.175, loss_adv: 35.954,
#
# accuracy in training set after perturbation: 30.041572
#
# 306.59103536605835 seconds
# epoch 37:
# loss_D: 0.035, loss_G_fake: 0.928,
# loss_perturb: 6.175, loss_adv: 35.751,
#
# accuracy in training set after perturbation: 29.865592
#
# 315.09515142440796 seconds
# epoch 38:
# loss_D: 0.035, loss_G_fake: 0.931,
# loss_perturb: 6.339, loss_adv: 35.151,
#
# accuracy in training set after perturbation: 29.281543
#
# 323.6295120716095 seconds
# epoch 39:
# loss_D: 0.042, loss_G_fake: 0.921,
# loss_perturb: 6.360, loss_adv: 35.164,
#
# accuracy in training set after perturbation: 29.345303
#
# 332.1114068031311 seconds
# epoch 40:
# loss_D: 0.031, loss_G_fake: 0.938,
# loss_perturb: 6.130, loss_adv: 34.596,
#
# accuracy in training set after perturbation: 28.802061
#
# 340.59278655052185 seconds
# epoch 41:
# loss_D: 0.033, loss_G_fake: 0.934,
# loss_perturb: 5.995, loss_adv: 34.766,
#
# accuracy in training set after perturbation: 29.008646
#
# 349.07821702957153 seconds
# epoch 42:
# loss_D: 0.034, loss_G_fake: 0.933,
# loss_perturb: 6.163, loss_adv: 34.281,
#
# accuracy in training set after perturbation: 28.557219
#
# 357.5540335178375 seconds
# epoch 43:
# loss_D: 0.029, loss_G_fake: 0.941,
# loss_perturb: 5.974, loss_adv: 34.165,
#
# accuracy in training set after perturbation: 28.434798
#
# 366.1061210632324 seconds
# epoch 44:
# loss_D: 0.025, loss_G_fake: 0.948,
# loss_perturb: 5.861, loss_adv: 33.802,
#
# accuracy in training set after perturbation: 28.141498
#
# 374.5983214378357 seconds
# epoch 45:
# loss_D: 0.030, loss_G_fake: 0.943,
# loss_perturb: 5.682, loss_adv: 33.384,
#
# accuracy in training set after perturbation: 27.730878
#
# 383.1156198978424 seconds
# epoch 46:
# loss_D: 0.029, loss_G_fake: 0.946,
# loss_perturb: 6.231, loss_adv: 33.507,
#
# accuracy in training set after perturbation: 27.858400
#
# 391.6123638153076 seconds
# epoch 47:
# loss_D: 0.028, loss_G_fake: 0.941,
# loss_perturb: 5.820, loss_adv: 33.022,
#
# accuracy in training set after perturbation: 27.292203
#
# 400.2030117511749 seconds
# epoch 48:
# loss_D: 0.035, loss_G_fake: 0.933,
# loss_perturb: 6.042, loss_adv: 33.736,
#
# accuracy in training set after perturbation: 28.146599
#
# 408.68851494789124 seconds
# epoch 49:
# loss_D: 0.028, loss_G_fake: 0.946,
# loss_perturb: 6.125, loss_adv: 33.478,
#
# accuracy in training set after perturbation: 27.965518
#
# 417.168794631958 seconds
# epoch 50:
# loss_D: 0.015, loss_G_fake: 0.964,
# loss_perturb: 5.736, loss_adv: 32.999,
#
# accuracy in training set after perturbation: 27.289653
#
# 425.6606161594391 seconds
# epoch 51:
# loss_D: 0.014, loss_G_fake: 0.961,
# loss_perturb: 5.339, loss_adv: 32.030,
#
# accuracy in training set after perturbation: 26.119003
#
# 434.1283895969391 seconds
# epoch 52:
# loss_D: 0.013, loss_G_fake: 0.963,
# loss_perturb: 5.007, loss_adv: 31.758,
#
# accuracy in training set after perturbation: 25.759392
#
# 442.6446840763092 seconds
# epoch 53:
# loss_D: 0.012, loss_G_fake: 0.965,
# loss_perturb: 4.805, loss_adv: 31.623,
#
# accuracy in training set after perturbation: 25.693081
#
# 451.20931792259216 seconds
# epoch 54:
# loss_D: 0.011, loss_G_fake: 0.965,
# loss_perturb: 4.602, loss_adv: 31.467,
#
# accuracy in training set after perturbation: 25.489046
#
# 459.7190885543823 seconds
# epoch 55:
# loss_D: 0.012, loss_G_fake: 0.964,
# loss_perturb: 4.445, loss_adv: 31.322,
#
# accuracy in training set after perturbation: 25.364075
#
# 468.2240056991577 seconds
# epoch 56:
# loss_D: 0.010, loss_G_fake: 0.968,
# loss_perturb: 4.321, loss_adv: 31.220,
#
# accuracy in training set after perturbation: 25.269708
#
# 476.84992122650146 seconds
# epoch 57:
# loss_D: 0.011, loss_G_fake: 0.968,
# loss_perturb: 4.182, loss_adv: 31.118,
#
# accuracy in training set after perturbation: 25.126884
#
# 485.5154321193695 seconds
# epoch 58:
# loss_D: 0.011, loss_G_fake: 0.969,
# loss_perturb: 4.111, loss_adv: 31.034,
#
# accuracy in training set after perturbation: 25.063123
#
# 494.0349736213684 seconds
# epoch 59:
# loss_D: 0.010, loss_G_fake: 0.969,
# loss_perturb: 4.062, loss_adv: 30.976,
#
# accuracy in training set after perturbation: 25.063123
#
# 502.5356035232544 seconds
# epoch 60:
# loss_D: 0.010, loss_G_fake: 0.967,
# loss_perturb: 4.016, loss_adv: 30.905,
#
# accuracy in training set after perturbation: 25.029968
#
# 511.02073526382446 seconds
# epoch 61:
# loss_D: 0.011, loss_G_fake: 0.965,
# loss_perturb: 3.975, loss_adv: 30.829,
#
# accuracy in training set after perturbation: 24.945803
#
# 519.5421006679535 seconds
# epoch 62:
# loss_D: 0.010, loss_G_fake: 0.968,
# loss_perturb: 3.920, loss_adv: 30.768,
#
# accuracy in training set after perturbation: 24.833584
#
# 528.1004030704498 seconds
# epoch 63:
# loss_D: 0.010, loss_G_fake: 0.968,
# loss_perturb: 3.879, loss_adv: 30.694,
#
# accuracy in training set after perturbation: 24.787676
#
# 536.6113266944885 seconds
# epoch 64:
# loss_D: 0.010, loss_G_fake: 0.968,
# loss_perturb: 3.854, loss_adv: 30.634,
#
# accuracy in training set after perturbation: 24.764722
#
# 545.1156630516052 seconds
# epoch 65:
# loss_D: 0.010, loss_G_fake: 0.969,
# loss_perturb: 3.903, loss_adv: 30.628,
#
# accuracy in training set after perturbation: 24.961106
#
# 553.616854429245 seconds
# epoch 66:
# loss_D: 0.009, loss_G_fake: 0.969,
# loss_perturb: 3.926, loss_adv: 30.511,
#
# accuracy in training set after perturbation: 24.642302
#
# 562.1215860843658 seconds
# epoch 67:
# loss_D: 0.010, loss_G_fake: 0.968,
# loss_perturb: 3.819, loss_adv: 30.433,
#
# accuracy in training set after perturbation: 24.524982
#
# 570.6380288600922 seconds
# epoch 68:
# loss_D: 0.009, loss_G_fake: 0.969,
# loss_perturb: 3.772, loss_adv: 30.391,
#
# accuracy in training set after perturbation: 24.547935
#
# 579.166188955307 seconds
# epoch 69:
# loss_D: 0.009, loss_G_fake: 0.967,
# loss_perturb: 3.803, loss_adv: 30.372,
#
# accuracy in training set after perturbation: 24.606595
#
# 587.6703591346741 seconds
# epoch 70:
# loss_D: 0.009, loss_G_fake: 0.968,
# loss_perturb: 3.770, loss_adv: 30.290,
#
# accuracy in training set after perturbation: 24.379607
#
# 596.1626007556915 seconds
# epoch 71:
# loss_D: 0.010, loss_G_fake: 0.968,
# loss_perturb: 3.719, loss_adv: 30.251,
#
# accuracy in training set after perturbation: 24.387258
#
# 604.699456691742 seconds
# epoch 72:
# loss_D: 0.009, loss_G_fake: 0.968,
# loss_perturb: 3.707, loss_adv: 30.223,
#
# accuracy in training set after perturbation: 24.440817
#
# 613.2483987808228 seconds
# epoch 73:
# loss_D: 0.009, loss_G_fake: 0.967,
# loss_perturb: 3.747, loss_adv: 30.205,
#
# accuracy in training set after perturbation: 24.471422
#
# 621.7508919239044 seconds
# epoch 74:
# loss_D: 0.010, loss_G_fake: 0.967,
# loss_perturb: 3.711, loss_adv: 30.149,
#
# accuracy in training set after perturbation: 24.326048
#
# 630.2500896453857 seconds
# epoch 75:
# loss_D: 0.009, loss_G_fake: 0.968,
# loss_perturb: 3.689, loss_adv: 30.099,
#
# accuracy in training set after perturbation: 24.272488
#
# 638.7492594718933 seconds
# epoch 76:
# loss_D: 0.009, loss_G_fake: 0.968,
# loss_perturb: 3.669, loss_adv: 30.071,
#
# accuracy in training set after perturbation: 24.292892
#
# 647.2504374980927 seconds
# epoch 77:
# loss_D: 0.010, loss_G_fake: 0.967,
# loss_perturb: 3.647, loss_adv: 30.040,
#
# accuracy in training set after perturbation: 24.203627
#
# 655.7542767524719 seconds
# epoch 78:
# loss_D: 0.009, loss_G_fake: 0.968,
# loss_perturb: 3.667, loss_adv: 30.011,
#
# accuracy in training set after perturbation: 24.236782
#
# 664.2531869411469 seconds
# epoch 79:
# loss_D: 0.009, loss_G_fake: 0.969,
# loss_perturb: 3.648, loss_adv: 29.964,
#
# accuracy in training set after perturbation: 24.160269
#
# 672.7667739391327 seconds
# epoch 80:
# loss_D: 0.008, loss_G_fake: 0.968,
# loss_perturb: 3.613, loss_adv: 29.888,
#
# accuracy in training set after perturbation: 23.925629
#
# 681.2916991710663 seconds
# epoch 81:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.579, loss_adv: 29.862,
#
# accuracy in training set after perturbation: 23.790456
#
# 689.8431606292725 seconds
# epoch 82:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.542, loss_adv: 29.856,
#
# accuracy in training set after perturbation: 23.818511
#
# 698.356695652008 seconds
# epoch 83:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.510, loss_adv: 29.850,
#
# accuracy in training set after perturbation: 23.790456
#
# 706.947182893753 seconds
# epoch 84:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.481, loss_adv: 29.845,
#
# accuracy in training set after perturbation: 23.818511
#
# 715.4355232715607 seconds
# epoch 85:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.459, loss_adv: 29.840,
#
# accuracy in training set after perturbation: 23.805759
#
# 723.9403173923492 seconds
# epoch 86:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.437, loss_adv: 29.835,
#
# accuracy in training set after perturbation: 23.826162
#
# 732.442093372345 seconds
# epoch 87:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.421, loss_adv: 29.828,
#
# accuracy in training set after perturbation: 23.846566
#
# 740.9357166290283 seconds
# epoch 88:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.407, loss_adv: 29.823,
#
# accuracy in training set after perturbation: 23.821061
#
# 749.435809135437 seconds
# epoch 89:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.398, loss_adv: 29.815,
#
# accuracy in training set after perturbation: 23.818511
#
# 757.9755749702454 seconds
# epoch 90:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.385, loss_adv: 29.810,
#
# accuracy in training set after perturbation: 23.844015
#
# 766.5236604213715 seconds
# epoch 91:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.377, loss_adv: 29.803,
#
# accuracy in training set after perturbation: 23.790456
#
# 775.0742554664612 seconds
# epoch 92:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.363, loss_adv: 29.797,
#
# accuracy in training set after perturbation: 23.823612
#
# 783.6188843250275 seconds
# epoch 93:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.358, loss_adv: 29.791,
#
# accuracy in training set after perturbation: 23.818511
#
# 792.3196811676025 seconds
# epoch 94:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.348, loss_adv: 29.786,
#
# accuracy in training set after perturbation: 23.844015
#
# 800.8433787822723 seconds
# epoch 95:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.344, loss_adv: 29.779,
#
# accuracy in training set after perturbation: 23.790456
#
# 809.3369448184967 seconds
# epoch 96:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.336, loss_adv: 29.774,
#
# accuracy in training set after perturbation: 23.833814
#
# 817.8333201408386 seconds
# epoch 97:
# loss_D: 0.008, loss_G_fake: 0.970,
# loss_perturb: 3.332, loss_adv: 29.768,
#
# accuracy in training set after perturbation: 23.815961
#
# 826.3401296138763 seconds
# epoch 98:
# loss_D: 0.008, loss_G_fake: 0.970,
# loss_perturb: 3.323, loss_adv: 29.762,
#
# accuracy in training set after perturbation: 23.810860
#
# 834.8225877285004 seconds
# epoch 99:
# loss_D: 0.008, loss_G_fake: 0.969,
# loss_perturb: 3.317, loss_adv: 29.757,
#
# accuracy in training set after perturbation: 23.826162
#
# 843.36177110672 seconds
# epoch 100:
# loss_D: 0.008, loss_G_fake: 0.970,
# loss_perturb: 3.317, loss_adv: 29.751,
#
# accuracy in training set after perturbation: 23.808309
#
# 851.910740852356 seconds
# accuracy in test set on all perturbed images: 33.262074
#
# misclassifications on previously correctly classified images: 67.474268
