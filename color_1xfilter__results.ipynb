# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_1xfilter__results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.03, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1225.206055
#
# Train accuracy so far: 41.482823
#
# loss in epoch 1: 334.397461
#
# Train accuracy so far: 84.013874
#
# loss in epoch 2: 162.469284
#
# Train accuracy so far: 92.764416
#
# loss in epoch 3: 103.400063
#
# Train accuracy so far: 95.546941
#
# loss in epoch 4: 74.065338
#
# Train accuracy so far: 96.944579
#
# loss in epoch 5: 55.048695
#
# Train accuracy so far: 97.719911
#
# loss in epoch 6: 48.800976
#
# Train accuracy so far: 97.880589
#
# loss in epoch 7: 37.256519
#
# Train accuracy so far: 98.390676
#
# loss in epoch 8: 32.316429
#
# Train accuracy so far: 98.620215
#
# loss in epoch 9: 26.370127
#
# Train accuracy so far: 98.829350
#
# loss in epoch 10: 25.195860
#
# Train accuracy so far: 98.895662
#
# loss in epoch 11: 23.576263
#
# Train accuracy so far: 98.933918
#
# loss in epoch 12: 18.174234
#
# Train accuracy so far: 99.150705
#
# loss in epoch 13: 16.483107
#
# Train accuracy so far: 99.234870
#
# loss in epoch 14: 17.204882
#
# Train accuracy so far: 99.178760
#
# loss in epoch 15: 12.248221
#
# Train accuracy so far: 99.390446
#
# loss in epoch 16: 10.045057
#
# Train accuracy so far: 99.520518
#
# loss in epoch 17: 16.489794
#
# Train accuracy so far: 99.247622
#
# loss in epoch 18: 11.815685
#
# Train accuracy so far: 99.446556
#
# loss in epoch 19: 11.962004
#
# Train accuracy so far: 99.428703
#
# accuracy in testing set: 90.950119

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.03
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.03
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.03
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.950119
#
# epoch 1:
# loss_D: 0.430, loss_G_fake: 0.309,
# loss_perturb: 16.939, loss_adv: 85.206,
#
# accuracy in training set after perturbation: 69.535056
#
# 8.476487636566162 seconds
# epoch 2:
# loss_D: 0.241, loss_G_fake: 0.492,
# loss_perturb: 13.108, loss_adv: 70.377,
#
# accuracy in training set after perturbation: 58.075952
#
# 16.839866876602173 seconds
# epoch 3:
# loss_D: 0.128, loss_G_fake: 0.633,
# loss_perturb: 10.319, loss_adv: 61.347,
#
# accuracy in training set after perturbation: 50.496060
#
# 25.19886565208435 seconds
# epoch 4:
# loss_D: 0.088, loss_G_fake: 0.707,
# loss_perturb: 9.332, loss_adv: 55.279,
#
# accuracy in training set after perturbation: 45.548216
#
# 33.60170912742615 seconds
# epoch 5:
# loss_D: 0.057, loss_G_fake: 0.769,
# loss_perturb: 9.689, loss_adv: 52.213,
#
# accuracy in training set after perturbation: 43.107450
#
# 42.057393312454224 seconds
# epoch 6:
# loss_D: 0.041, loss_G_fake: 0.805,
# loss_perturb: 8.501, loss_adv: 48.371,
#
# accuracy in training set after perturbation: 39.944911
#
# 50.47625374794006 seconds
# epoch 7:
# loss_D: 0.033, loss_G_fake: 0.835,
# loss_perturb: 8.368, loss_adv: 46.260,
#
# accuracy in training set after perturbation: 38.287128
#
# 58.95863175392151 seconds
# epoch 8:
# loss_D: 0.025, loss_G_fake: 0.855,
# loss_perturb: 8.041, loss_adv: 44.536,
#
# accuracy in training set after perturbation: 36.807876
#
# 67.43162989616394 seconds
# epoch 9:
# loss_D: 0.020, loss_G_fake: 0.873,
# loss_perturb: 7.549, loss_adv: 42.985,
#
# accuracy in training set after perturbation: 35.331174
#
# 76.00123476982117 seconds
# epoch 10:
# loss_D: 0.017, loss_G_fake: 0.883,
# loss_perturb: 6.891, loss_adv: 41.503,
#
# accuracy in training set after perturbation: 34.191130
#
# 84.67883801460266 seconds
# epoch 11:
# loss_D: 0.014, loss_G_fake: 0.898,
# loss_perturb: 7.080, loss_adv: 40.163,
#
# accuracy in training set after perturbation: 33.114846
#
# 93.13378620147705 seconds
# epoch 12:
# loss_D: 0.015, loss_G_fake: 0.901,
# loss_perturb: 7.205, loss_adv: 39.235,
#
# accuracy in training set after perturbation: 32.449183
#
# 101.5960373878479 seconds
# epoch 13:
# loss_D: 0.011, loss_G_fake: 0.915,
# loss_perturb: 7.107, loss_adv: 38.589,
#
# accuracy in training set after perturbation: 31.913591
#
# 110.08558511734009 seconds
# epoch 14:
# loss_D: 0.012, loss_G_fake: 0.911,
# loss_perturb: 6.684, loss_adv: 37.299,
#
# accuracy in training set after perturbation: 30.783749
#
# 118.57960200309753 seconds
# epoch 15:
# loss_D: 0.006, loss_G_fake: 0.931,
# loss_perturb: 6.549, loss_adv: 36.529,
#
# accuracy in training set after perturbation: 30.212451
#
# 127.12154197692871 seconds
# epoch 16:
# loss_D: 0.005, loss_G_fake: 0.940,
# loss_perturb: 6.510, loss_adv: 36.161,
#
# accuracy in training set after perturbation: 29.832436
#
# 135.64660167694092 seconds
# epoch 17:
# loss_D: 0.006, loss_G_fake: 0.941,
# loss_perturb: 6.661, loss_adv: 35.151,
#
# accuracy in training set after perturbation: 29.074957
#
# 144.09782481193542 seconds
# epoch 18:
# loss_D: 0.016, loss_G_fake: 0.917,
# loss_perturb: 7.006, loss_adv: 34.772,
#
# accuracy in training set after perturbation: 28.768905
#
# 152.58653044700623 seconds
# epoch 19:
# loss_D: 0.005, loss_G_fake: 0.942,
# loss_perturb: 6.351, loss_adv: 34.413,
#
# accuracy in training set after perturbation: 28.439899
#
# 161.10596442222595 seconds
# epoch 20:
# loss_D: 0.006, loss_G_fake: 0.943,
# loss_perturb: 6.604, loss_adv: 34.226,
#
# accuracy in training set after perturbation: 28.353184
#
# 169.61134433746338 seconds
# epoch 21:
# loss_D: 0.002, loss_G_fake: 0.958,
# loss_perturb: 6.288, loss_adv: 33.456,
#
# accuracy in training set after perturbation: 27.730878
#
# 178.08365440368652 seconds
# epoch 22:
# loss_D: 0.006, loss_G_fake: 0.946,
# loss_perturb: 6.272, loss_adv: 33.151,
#
# accuracy in training set after perturbation: 27.401872
#
# 186.5662763118744 seconds
# epoch 23:
# loss_D: 0.008, loss_G_fake: 0.944,
# loss_perturb: 6.430, loss_adv: 32.787,
#
# accuracy in training set after perturbation: 27.131526
#
# 195.1118311882019 seconds
# epoch 24:
# loss_D: 0.003, loss_G_fake: 0.957,
# loss_perturb: 6.170, loss_adv: 32.562,
#
# accuracy in training set after perturbation: 27.049912
#
# 203.68185186386108 seconds
# epoch 25:
# loss_D: 0.002, loss_G_fake: 0.967,
# loss_perturb: 6.123, loss_adv: 31.854,
#
# accuracy in training set after perturbation: 26.305185
#
# 212.23338890075684 seconds
# epoch 26:
# loss_D: 0.001, loss_G_fake: 0.972,
# loss_perturb: 6.149, loss_adv: 31.905,
#
# accuracy in training set after perturbation: 26.437808
#
# 220.77258396148682 seconds
# epoch 27:
# loss_D: 0.007, loss_G_fake: 0.954,
# loss_perturb: 6.160, loss_adv: 31.316,
#
# accuracy in training set after perturbation: 25.835905
#
# 229.31629538536072 seconds
# epoch 28:
# loss_D: 0.010, loss_G_fake: 0.942,
# loss_perturb: 6.339, loss_adv: 31.254,
#
# accuracy in training set after perturbation: 25.907317
#
# 237.79872035980225 seconds
# epoch 29:
# loss_D: 0.002, loss_G_fake: 0.963,
# loss_perturb: 6.229, loss_adv: 31.064,
#
# accuracy in training set after perturbation: 25.795098
#
# 246.34721755981445 seconds
# epoch 30:
# loss_D: 0.002, loss_G_fake: 0.967,
# loss_perturb: 6.056, loss_adv: 31.172,
#
# accuracy in training set after perturbation: 25.784896
#
# 254.89310503005981 seconds
# epoch 31:
# loss_D: 0.002, loss_G_fake: 0.970,
# loss_perturb: 6.151, loss_adv: 30.766,
#
# accuracy in training set after perturbation: 25.527302
#
# 263.44122672080994 seconds
# epoch 32:
# loss_D: 0.001, loss_G_fake: 0.978,
# loss_perturb: 6.099, loss_adv: 30.224,
#
# accuracy in training set after perturbation: 24.966207
#
# 271.9678747653961 seconds
# epoch 33:
# loss_D: 0.010, loss_G_fake: 0.950,
# loss_perturb: 5.825, loss_adv: 30.268,
#
# accuracy in training set after perturbation: 25.116682
#
# 280.55526328086853 seconds
# epoch 34:
# loss_D: 0.001, loss_G_fake: 0.973,
# loss_perturb: 6.031, loss_adv: 30.096,
#
# accuracy in training set after perturbation: 24.866740
#
# 289.1482095718384 seconds
# epoch 35:
# loss_D: 0.001, loss_G_fake: 0.978,
# loss_perturb: 6.032, loss_adv: 29.689,
#
# accuracy in training set after perturbation: 24.502028
#
# 297.6754033565521 seconds
# epoch 36:
# loss_D: 0.000, loss_G_fake: 0.981,
# loss_perturb: 5.790, loss_adv: 29.662,
#
# accuracy in training set after perturbation: 24.532633
#
# 306.19734597206116 seconds
# epoch 37:
# loss_D: 0.001, loss_G_fake: 0.982,
# loss_perturb: 5.528, loss_adv: 29.266,
#
# accuracy in training set after perturbation: 24.122013
#
# 314.75424337387085 seconds
# epoch 38:
# loss_D: 0.011, loss_G_fake: 0.950,
# loss_perturb: 5.533, loss_adv: 29.144,
#
# accuracy in training set after perturbation: 24.055701
#
# 323.2992377281189 seconds
# epoch 39:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 5.627, loss_adv: 29.115,
#
# accuracy in training set after perturbation: 24.093958
#
# 331.80990529060364 seconds
# epoch 40:
# loss_D: 0.001, loss_G_fake: 0.978,
# loss_perturb: 6.103, loss_adv: 28.983,
#
# accuracy in training set after perturbation: 24.035298
#
# 340.36053681373596 seconds
# epoch 41:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 5.818, loss_adv: 28.669,
#
# accuracy in training set after perturbation: 23.591522
#
# 348.9260153770447 seconds
# epoch 42:
# loss_D: 0.000, loss_G_fake: 0.982,
# loss_perturb: 5.779, loss_adv: 28.741,
#
# accuracy in training set after perturbation: 23.808309
#
# 357.4701247215271 seconds
# epoch 43:
# loss_D: 0.011, loss_G_fake: 0.960,
# loss_perturb: 5.905, loss_adv: 28.832,
#
# accuracy in training set after perturbation: 23.963886
#
# 366.1693181991577 seconds
# epoch 44:
# loss_D: 0.002, loss_G_fake: 0.968,
# loss_perturb: 5.520, loss_adv: 28.215,
#
# accuracy in training set after perturbation: 23.211508
#
# 374.76028776168823 seconds
# epoch 45:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 5.296, loss_adv: 28.162,
#
# accuracy in training set after perturbation: 23.203856
#
# 383.30742597579956 seconds
# epoch 46:
# loss_D: 0.001, loss_G_fake: 0.975,
# loss_perturb: 5.514, loss_adv: 28.036,
#
# accuracy in training set after perturbation: 23.203856
#
# 392.10078597068787 seconds
# epoch 47:
# loss_D: 0.000, loss_G_fake: 0.984,
# loss_perturb: 5.606, loss_adv: 27.980,
#
# accuracy in training set after perturbation: 23.152848
#
# 400.7363727092743 seconds
# epoch 48:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 5.399, loss_adv: 27.841,
#
# accuracy in training set after perturbation: 22.961565
#
# 409.3134546279907 seconds
# epoch 49:
# loss_D: 0.005, loss_G_fake: 0.973,
# loss_perturb: 5.516, loss_adv: 27.579,
#
# accuracy in training set after perturbation: 22.691219
#
# 417.8569874763489 seconds
# epoch 50:
# loss_D: 0.001, loss_G_fake: 0.975,
# loss_perturb: 5.186, loss_adv: 27.082,
#
# accuracy in training set after perturbation: 22.107169
#
# 426.4029824733734 seconds
# epoch 51:
# loss_D: 0.000, loss_G_fake: 0.982,
# loss_perturb: 4.839, loss_adv: 26.673,
#
# accuracy in training set after perturbation: 21.538422
#
# 434.9662778377533 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.984,
# loss_perturb: 4.492, loss_adv: 26.553,
#
# accuracy in training set after perturbation: 21.344589
#
# 443.57589864730835 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 4.227, loss_adv: 26.458,
#
# accuracy in training set after perturbation: 21.301232
#
# 452.1694793701172 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 4.065, loss_adv: 26.368,
#
# accuracy in training set after perturbation: 21.206866
#
# 460.73831248283386 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.938, loss_adv: 26.292,
#
# accuracy in training set after perturbation: 21.145655
#
# 469.32185792922974 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 3.844, loss_adv: 26.227,
#
# accuracy in training set after perturbation: 21.094647
#
# 477.907235622406 seconds
# epoch 57:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.774, loss_adv: 26.161,
#
# accuracy in training set after perturbation: 21.115050
#
# 486.43273520469666 seconds
# epoch 58:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.729, loss_adv: 26.080,
#
# accuracy in training set after perturbation: 20.997730
#
# 495.02332973480225 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.708, loss_adv: 26.019,
#
# accuracy in training set after perturbation: 20.995180
#
# 503.5987322330475 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.675, loss_adv: 25.936,
#
# accuracy in training set after perturbation: 20.888061
#
# 512.1863031387329 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.676, loss_adv: 25.879,
#
# accuracy in training set after perturbation: 20.877860
#
# 520.773063659668 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.634, loss_adv: 25.814,
#
# accuracy in training set after perturbation: 20.821750
#
# 529.3936049938202 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.630, loss_adv: 25.758,
#
# accuracy in training set after perturbation: 20.755439
#
# 537.9604198932648 seconds
# epoch 64:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.576, loss_adv: 25.704,
#
# accuracy in training set after perturbation: 20.724834
#
# 546.5059883594513 seconds
# epoch 65:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.581, loss_adv: 25.663,
#
# accuracy in training set after perturbation: 20.681476
#
# 555.0995848178864 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.547, loss_adv: 25.617,
#
# accuracy in training set after perturbation: 20.655972
#
# 563.6715550422668 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.515, loss_adv: 25.560,
#
# accuracy in training set after perturbation: 20.553954
#
# 572.2417275905609 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.509, loss_adv: 25.535,
#
# accuracy in training set after perturbation: 20.599862
#
# 580.7910406589508 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.545, loss_adv: 25.489,
#
# accuracy in training set after perturbation: 20.564156
#
# 589.3663332462311 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.502, loss_adv: 25.439,
#
# accuracy in training set after perturbation: 20.487643
#
# 597.9409971237183 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.471, loss_adv: 25.392,
#
# accuracy in training set after perturbation: 20.421332
#
# 606.5454301834106 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.457, loss_adv: 25.353,
#
# accuracy in training set after perturbation: 20.398378
#
# 615.126825094223 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.478, loss_adv: 25.336,
#
# accuracy in training set after perturbation: 20.474891
#
# 623.7148625850677 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.447, loss_adv: 25.298,
#
# accuracy in training set after perturbation: 20.367773
#
# 632.2770237922668 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.497, loss_adv: 25.289,
#
# accuracy in training set after perturbation: 20.454487
#
# 640.857097864151 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.508, loss_adv: 25.244,
#
# accuracy in training set after perturbation: 20.355021
#
# 649.4417369365692 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.436, loss_adv: 25.209,
#
# accuracy in training set after perturbation: 20.247902
#
# 658.0199384689331 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.412, loss_adv: 25.185,
#
# accuracy in training set after perturbation: 20.291260
#
# 666.6160576343536 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.422, loss_adv: 25.150,
#
# accuracy in training set after perturbation: 20.263205
#
# 675.2975833415985 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.363, loss_adv: 25.084,
#
# accuracy in training set after perturbation: 20.094876
#
# 683.867356300354 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 3.332, loss_adv: 25.066,
#
# accuracy in training set after perturbation: 20.000510
#
# 692.4954149723053 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.302, loss_adv: 25.057,
#
# accuracy in training set after perturbation: 19.977556
#
# 701.295646905899 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.273, loss_adv: 25.052,
#
# accuracy in training set after perturbation: 19.995409
#
# 709.9582898616791 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.256, loss_adv: 25.043,
#
# accuracy in training set after perturbation: 20.005611
#
# 718.5170476436615 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.238, loss_adv: 25.036,
#
# accuracy in training set after perturbation: 19.997960
#
# 727.0576128959656 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.224, loss_adv: 25.029,
#
# accuracy in training set after perturbation: 20.008161
#
# 735.6180160045624 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.211, loss_adv: 25.023,
#
# accuracy in training set after perturbation: 19.980107
#
# 744.1639673709869 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.201, loss_adv: 25.017,
#
# accuracy in training set after perturbation: 19.977556
#
# 752.7650015354156 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.192, loss_adv: 25.011,
#
# accuracy in training set after perturbation: 19.997960
#
# 761.3668038845062 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.180, loss_adv: 25.005,
#
# accuracy in training set after perturbation: 19.954602
#
# 770.0104961395264 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.171, loss_adv: 25.000,
#
# accuracy in training set after perturbation: 19.972455
#
# 778.582528591156 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.165, loss_adv: 24.995,
#
# accuracy in training set after perturbation: 20.003061
#
# 787.1187105178833 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.156, loss_adv: 24.989,
#
# accuracy in training set after perturbation: 19.977556
#
# 795.7038598060608 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.148, loss_adv: 24.985,
#
# accuracy in training set after perturbation: 19.982657
#
# 804.295211315155 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.142, loss_adv: 24.980,
#
# accuracy in training set after perturbation: 19.957153
#
# 812.8522419929504 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.136, loss_adv: 24.975,
#
# accuracy in training set after perturbation: 19.969905
#
# 821.4511559009552 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.131, loss_adv: 24.970,
#
# accuracy in training set after perturbation: 19.980107
#
# 829.9949464797974 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.129, loss_adv: 24.963,
#
# accuracy in training set after perturbation: 19.980107
#
# 838.5491824150085 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.125, loss_adv: 24.956,
#
# accuracy in training set after perturbation: 19.967354
#
# 847.1646213531494 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.120, loss_adv: 24.951,
#
# accuracy in training set after perturbation: 19.946951
#
# 855.7642469406128 seconds
# accuracy in test set on all perturbed images: 28.709422
#
# misclassifications on previously correctly classified images: 71.512272
