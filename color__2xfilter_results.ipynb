# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color__2xfilter_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.03, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 16, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(64),
                       ResnetBlock(64),
                       ResnetBlock(64),
                       ResnetBlock(64),]

        decoder_lis = [
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(16, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1225.206055
#
# Train accuracy so far: 41.482823
#
# loss in epoch 1: 334.397461
#
# Train accuracy so far: 84.013874
#
# loss in epoch 2: 162.469284
#
# Train accuracy so far: 92.764416
#
# loss in epoch 3: 103.400063
#
# Train accuracy so far: 95.546941
#
# loss in epoch 4: 74.065338
#
# Train accuracy so far: 96.944579
#
# loss in epoch 5: 55.048695
#
# Train accuracy so far: 97.719911
#
# loss in epoch 6: 48.800976
#
# Train accuracy so far: 97.880589
#
# loss in epoch 7: 37.256519
#
# Train accuracy so far: 98.390676
#
# loss in epoch 8: 32.316429
#
# Train accuracy so far: 98.620215
#
# loss in epoch 9: 26.370127
#
# Train accuracy so far: 98.829350
#
# loss in epoch 10: 25.195860
#
# Train accuracy so far: 98.895662
#
# loss in epoch 11: 23.576263
#
# Train accuracy so far: 98.933918
#
# loss in epoch 12: 18.174234
#
# Train accuracy so far: 99.150705
#
# loss in epoch 13: 16.483107
#
# Train accuracy so far: 99.234870
#
# loss in epoch 14: 17.204882
#
# Train accuracy so far: 99.178760
#
# loss in epoch 15: 12.248221
#
# Train accuracy so far: 99.390446
#
# loss in epoch 16: 10.045057
#
# Train accuracy so far: 99.520518
#
# loss in epoch 17: 16.489794
#
# Train accuracy so far: 99.247622
#
# loss in epoch 18: 11.815685
#
# Train accuracy so far: 99.446556
#
# loss in epoch 19: 11.962004
#
# Train accuracy so far: 99.428703
#
# accuracy in testing set: 90.950119

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.03
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.03
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.03
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 90.950119
#
# epoch 1:
# loss_D: 0.423, loss_G_fake: 0.314,
# loss_perturb: 25.145, loss_adv: 86.462,
#
# accuracy in training set after perturbation: 70.435359
#
# 10.567398309707642 seconds
# epoch 2:
# loss_D: 0.232, loss_G_fake: 0.515,
# loss_perturb: 25.625, loss_adv: 77.638,
#
# accuracy in training set after perturbation: 63.544084
#
# 21.1461660861969 seconds
# epoch 3:
# loss_D: 0.139, loss_G_fake: 0.642,
# loss_perturb: 22.851, loss_adv: 72.020,
#
# accuracy in training set after perturbation: 58.881889
#
# 31.66832733154297 seconds
# epoch 4:
# loss_D: 0.142, loss_G_fake: 0.647,
# loss_perturb: 22.155, loss_adv: 67.604,
#
# accuracy in training set after perturbation: 55.324033
#
# 42.07811641693115 seconds
# epoch 5:
# loss_D: 0.103, loss_G_fake: 0.703,
# loss_perturb: 20.479, loss_adv: 66.329,
#
# accuracy in training set after perturbation: 54.423729
#
# 52.4829580783844 seconds
# epoch 6:
# loss_D: 0.093, loss_G_fake: 0.723,
# loss_perturb: 16.609, loss_adv: 62.027,
#
# accuracy in training set after perturbation: 50.899028
#
# 62.89861869812012 seconds
# epoch 7:
# loss_D: 0.067, loss_G_fake: 0.763,
# loss_perturb: 14.120, loss_adv: 58.116,
#
# accuracy in training set after perturbation: 47.695682
#
# 73.22205543518066 seconds
# epoch 8:
# loss_D: 0.076, loss_G_fake: 0.760,
# loss_perturb: 13.651, loss_adv: 55.775,
#
# accuracy in training set after perturbation: 45.877222
#
# 83.57485246658325 seconds
# epoch 9:
# loss_D: 0.053, loss_G_fake: 0.799,
# loss_perturb: 13.108, loss_adv: 53.657,
#
# accuracy in training set after perturbation: 44.178632
#
# 94.0049889087677 seconds
# epoch 10:
# loss_D: 0.044, loss_G_fake: 0.817,
# loss_perturb: 11.639, loss_adv: 50.479,
#
# accuracy in training set after perturbation: 41.656252
#
# 104.41609787940979 seconds
# epoch 11:
# loss_D: 0.027, loss_G_fake: 0.858,
# loss_perturb: 11.007, loss_adv: 50.589,
#
# accuracy in training set after perturbation: 41.697059
#
# 114.84791970252991 seconds
# epoch 12:
# loss_D: 0.054, loss_G_fake: 0.813,
# loss_perturb: 10.741, loss_adv: 46.133,
#
# accuracy in training set after perturbation: 38.042286
#
# 125.25638961791992 seconds
# epoch 13:
# loss_D: 0.036, loss_G_fake: 0.848,
# loss_perturb: 9.953, loss_adv: 44.067,
#
# accuracy in training set after perturbation: 36.369201
#
# 135.71858310699463 seconds
# epoch 14:
# loss_D: 0.027, loss_G_fake: 0.867,
# loss_perturb: 9.016, loss_adv: 42.753,
#
# accuracy in training set after perturbation: 35.193450
#
# 146.13526558876038 seconds
# epoch 15:
# loss_D: 0.040, loss_G_fake: 0.848,
# loss_perturb: 9.170, loss_adv: 41.594,
#
# accuracy in training set after perturbation: 34.244689
#
# 156.53662037849426 seconds
# epoch 16:
# loss_D: 0.020, loss_G_fake: 0.888,
# loss_perturb: 8.740, loss_adv: 39.999,
#
# accuracy in training set after perturbation: 33.033232
#
# 166.9035837650299 seconds
# epoch 17:
# loss_D: 0.027, loss_G_fake: 0.884,
# loss_perturb: 8.617, loss_adv: 38.421,
#
# accuracy in training set after perturbation: 31.729960
#
# 177.2878966331482 seconds
# epoch 18:
# loss_D: 0.020, loss_G_fake: 0.898,
# loss_perturb: 8.208, loss_adv: 37.321,
#
# accuracy in training set after perturbation: 30.865363
#
# 187.6895353794098 seconds
# epoch 19:
# loss_D: 0.014, loss_G_fake: 0.910,
# loss_perturb: 8.546, loss_adv: 36.979,
#
# accuracy in training set after perturbation: 30.653676
#
# 198.11352062225342 seconds
# epoch 20:
# loss_D: 0.020, loss_G_fake: 0.905,
# loss_perturb: 8.095, loss_adv: 35.241,
#
# accuracy in training set after perturbation: 29.120865
#
# 208.46977829933167 seconds
# epoch 21:
# loss_D: 0.018, loss_G_fake: 0.909,
# loss_perturb: 8.657, loss_adv: 35.862,
#
# accuracy in training set after perturbation: 29.766125
#
# 218.91763067245483 seconds
# epoch 22:
# loss_D: 0.009, loss_G_fake: 0.933,
# loss_perturb: 8.033, loss_adv: 33.901,
#
# accuracy in training set after perturbation: 28.054783
#
# 229.2443492412567 seconds
# epoch 23:
# loss_D: 0.010, loss_G_fake: 0.930,
# loss_perturb: 7.545, loss_adv: 33.290,
#
# accuracy in training set after perturbation: 27.547247
#
# 239.58830976486206 seconds
# epoch 24:
# loss_D: 0.015, loss_G_fake: 0.918,
# loss_perturb: 7.562, loss_adv: 32.859,
#
# accuracy in training set after perturbation: 27.174883
#
# 250.02013754844666 seconds
# epoch 25:
# loss_D: 0.010, loss_G_fake: 0.933,
# loss_perturb: 7.311, loss_adv: 32.181,
#
# accuracy in training set after perturbation: 26.639292
#
# 260.4619257450104 seconds
# epoch 26:
# loss_D: 0.005, loss_G_fake: 0.949,
# loss_perturb: 7.166, loss_adv: 32.082,
#
# accuracy in training set after perturbation: 26.514321
#
# 270.8258361816406 seconds
# epoch 27:
# loss_D: 0.024, loss_G_fake: 0.916,
# loss_perturb: 7.249, loss_adv: 31.409,
#
# accuracy in training set after perturbation: 25.981280
#
# 281.21819710731506 seconds
# epoch 28:
# loss_D: 0.007, loss_G_fake: 0.943,
# loss_perturb: 7.323, loss_adv: 30.901,
#
# accuracy in training set after perturbation: 25.514550
#
# 291.6153166294098 seconds
# epoch 29:
# loss_D: 0.004, loss_G_fake: 0.957,
# loss_perturb: 6.834, loss_adv: 30.089,
#
# accuracy in training set after perturbation: 24.820832
#
# 302.0597767829895 seconds
# epoch 30:
# loss_D: 0.011, loss_G_fake: 0.936,
# loss_perturb: 6.513, loss_adv: 29.805,
#
# accuracy in training set after perturbation: 24.558137
#
# 312.4711923599243 seconds
# epoch 31:
# loss_D: 0.003, loss_G_fake: 0.959,
# loss_perturb: 7.376, loss_adv: 29.844,
#
# accuracy in training set after perturbation: 24.741768
#
# 322.8934931755066 seconds
# epoch 32:
# loss_D: 0.032, loss_G_fake: 0.913,
# loss_perturb: 6.785, loss_adv: 29.221,
#
# accuracy in training set after perturbation: 24.050601
#
# 333.3522005081177 seconds
# epoch 33:
# loss_D: 0.002, loss_G_fake: 0.965,
# loss_perturb: 6.937, loss_adv: 29.250,
#
# accuracy in training set after perturbation: 24.178122
#
# 343.7296071052551 seconds
# epoch 34:
# loss_D: 0.014, loss_G_fake: 0.939,
# loss_perturb: 6.731, loss_adv: 28.965,
#
# accuracy in training set after perturbation: 23.986840
#
# 354.144766330719 seconds
# epoch 35:
# loss_D: 0.005, loss_G_fake: 0.958,
# loss_perturb: 6.557, loss_adv: 28.568,
#
# accuracy in training set after perturbation: 23.634880
#
# 364.5139775276184 seconds
# epoch 36:
# loss_D: 0.001, loss_G_fake: 0.971,
# loss_perturb: 6.803, loss_adv: 28.496,
#
# accuracy in training set after perturbation: 23.588972
#
# 374.92805528640747 seconds
# epoch 37:
# loss_D: 0.001, loss_G_fake: 0.976,
# loss_perturb: 6.360, loss_adv: 28.383,
#
# accuracy in training set after perturbation: 23.420643
#
# 385.34305810928345 seconds
# epoch 38:
# loss_D: 0.017, loss_G_fake: 0.939,
# loss_perturb: 6.405, loss_adv: 28.381,
#
# accuracy in training set after perturbation: 23.525211
#
# 395.75680589675903 seconds
# epoch 39:
# loss_D: 0.015, loss_G_fake: 0.936,
# loss_perturb: 6.346, loss_adv: 27.945,
#
# accuracy in training set after perturbation: 23.112041
#
# 406.10758423805237 seconds
# epoch 40:
# loss_D: 0.008, loss_G_fake: 0.952,
# loss_perturb: 6.350, loss_adv: 27.701,
#
# accuracy in training set after perturbation: 22.831493
#
# 416.47278356552124 seconds
# epoch 41:
# loss_D: 0.003, loss_G_fake: 0.967,
# loss_perturb: 6.125, loss_adv: 27.312,
#
# accuracy in training set after perturbation: 22.454028
#
# 426.85073375701904 seconds
# epoch 42:
# loss_D: 0.003, loss_G_fake: 0.969,
# loss_perturb: 6.284, loss_adv: 27.180,
#
# accuracy in training set after perturbation: 22.428524
#
# 437.18796277046204 seconds
# epoch 43:
# loss_D: 0.011, loss_G_fake: 0.948,
# loss_perturb: 6.473, loss_adv: 27.635,
#
# accuracy in training set after perturbation: 22.964115
#
# 447.52787232398987 seconds
# epoch 44:
# loss_D: 0.001, loss_G_fake: 0.974,
# loss_perturb: 6.088, loss_adv: 26.828,
#
# accuracy in training set after perturbation: 22.117371
#
# 457.95488023757935 seconds
# epoch 45:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 5.832, loss_adv: 26.470,
#
# accuracy in training set after perturbation: 21.747558
#
# 468.3037922382355 seconds
# epoch 46:
# loss_D: 0.001, loss_G_fake: 0.981,
# loss_perturb: 6.050, loss_adv: 26.624,
#
# accuracy in training set after perturbation: 21.984748
#
# 478.6557071208954 seconds
# epoch 47:
# loss_D: 0.016, loss_G_fake: 0.944,
# loss_perturb: 6.115, loss_adv: 26.547,
#
# accuracy in training set after perturbation: 21.898034
#
# 489.04700756073 seconds
# epoch 48:
# loss_D: 0.001, loss_G_fake: 0.974,
# loss_perturb: 6.162, loss_adv: 26.422,
#
# accuracy in training set after perturbation: 21.811319
#
# 499.43286061286926 seconds
# epoch 49:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 6.046, loss_adv: 25.983,
#
# accuracy in training set after perturbation: 21.382846
#
# 509.8195569515228 seconds
# epoch 50:
# loss_D: 0.000, loss_G_fake: 0.984,
# loss_perturb: 5.305, loss_adv: 25.213,
#
# accuracy in training set after perturbation: 20.416231
#
# 520.1826226711273 seconds
# epoch 51:
# loss_D: 0.001, loss_G_fake: 0.983,
# loss_perturb: 4.798, loss_adv: 24.902,
#
# accuracy in training set after perturbation: 20.077023
#
# 530.5645596981049 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.985,
# loss_perturb: 4.397, loss_adv: 24.747,
#
# accuracy in training set after perturbation: 19.885741
#
# 540.9731521606445 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 4.145, loss_adv: 24.630,
#
# accuracy in training set after perturbation: 19.791374
#
# 551.3361527919769 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 3.936, loss_adv: 24.542,
#
# accuracy in training set after perturbation: 19.709761
#
# 561.7596361637115 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 3.767, loss_adv: 24.456,
#
# accuracy in training set after perturbation: 19.623046
#
# 572.1903975009918 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.663, loss_adv: 24.402,
#
# accuracy in training set after perturbation: 19.579688
#
# 582.5309216976166 seconds
# epoch 57:
# loss_D: 0.001, loss_G_fake: 0.983,
# loss_perturb: 3.560, loss_adv: 24.334,
#
# accuracy in training set after perturbation: 19.533781
#
# 592.8701956272125 seconds
# epoch 58:
# loss_D: 0.000, loss_G_fake: 0.986,
# loss_perturb: 3.497, loss_adv: 24.286,
#
# accuracy in training set after perturbation: 19.510827
#
# 603.2381956577301 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.468, loss_adv: 24.221,
#
# accuracy in training set after perturbation: 19.454717
#
# 613.6207988262177 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.987,
# loss_perturb: 3.402, loss_adv: 24.153,
#
# accuracy in training set after perturbation: 19.368002
#
# 624.0205562114716 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 3.323, loss_adv: 24.090,
#
# accuracy in training set after perturbation: 19.309342
#
# 634.3820803165436 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 3.273, loss_adv: 24.038,
#
# accuracy in training set after perturbation: 19.245581
#
# 644.7444734573364 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 3.300, loss_adv: 24.036,
#
# accuracy in training set after perturbation: 19.322094
#
# 655.1071918010712 seconds
# epoch 64:
# loss_D: 0.001, loss_G_fake: 0.986,
# loss_perturb: 3.310, loss_adv: 23.964,
#
# accuracy in training set after perturbation: 19.235380
#
# 665.4375081062317 seconds
# epoch 65:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.271, loss_adv: 23.922,
#
# accuracy in training set after perturbation: 19.163967
#
# 675.7598447799683 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.226, loss_adv: 23.865,
#
# accuracy in training set after perturbation: 19.135913
#
# 686.112044095993 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.227, loss_adv: 23.816,
#
# accuracy in training set after perturbation: 19.112959
#
# 696.4969961643219 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.188, loss_adv: 23.791,
#
# accuracy in training set after perturbation: 19.112959
#
# 706.8640604019165 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.231, loss_adv: 23.748,
#
# accuracy in training set after perturbation: 19.087454
#
# 717.1957223415375 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.194, loss_adv: 23.687,
#
# accuracy in training set after perturbation: 19.000740
#
# 727.547417640686 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.162, loss_adv: 23.654,
#
# accuracy in training set after perturbation: 18.970134
#
# 737.9038438796997 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.121, loss_adv: 23.608,
#
# accuracy in training set after perturbation: 18.921676
#
# 748.2692866325378 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.152, loss_adv: 23.574,
#
# accuracy in training set after perturbation: 18.916575
#
# 758.601797580719 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.116, loss_adv: 23.528,
#
# accuracy in training set after perturbation: 18.845163
#
# 768.9613111019135 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.132, loss_adv: 23.500,
#
# accuracy in training set after perturbation: 18.878319
#
# 779.3607006072998 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 3.158, loss_adv: 23.478,
#
# accuracy in training set after perturbation: 18.873218
#
# 789.7029869556427 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.167, loss_adv: 23.450,
#
# accuracy in training set after perturbation: 18.891071
#
# 800.0291912555695 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 3.150, loss_adv: 23.410,
#
# accuracy in training set after perturbation: 18.773751
#
# 810.4356622695923 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 3.087, loss_adv: 23.359,
#
# accuracy in training set after perturbation: 18.715091
#
# 820.7675676345825 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.091, loss_adv: 23.289,
#
# accuracy in training set after perturbation: 18.582468
#
# 831.1277792453766 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.045, loss_adv: 23.272,
#
# accuracy in training set after perturbation: 18.513607
#
# 841.4739623069763 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 3.006, loss_adv: 23.264,
#
# accuracy in training set after perturbation: 18.505955
#
# 851.8126049041748 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.975, loss_adv: 23.256,
#
# accuracy in training set after perturbation: 18.523808
#
# 862.1867043972015 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.952, loss_adv: 23.249,
#
# accuracy in training set after perturbation: 18.513607
#
# 872.6321828365326 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 2.925, loss_adv: 23.242,
#
# accuracy in training set after perturbation: 18.498304
#
# 883.0730292797089 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.908, loss_adv: 23.235,
#
# accuracy in training set after perturbation: 18.508506
#
# 893.4109230041504 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.891, loss_adv: 23.230,
#
# accuracy in training set after perturbation: 18.511056
#
# 903.7494926452637 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.869, loss_adv: 23.223,
#
# accuracy in training set after perturbation: 18.495754
#
# 914.1123864650726 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.856, loss_adv: 23.218,
#
# accuracy in training set after perturbation: 18.495754
#
# 924.4361257553101 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.844, loss_adv: 23.212,
#
# accuracy in training set after perturbation: 18.495754
#
# 934.8246166706085 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.833, loss_adv: 23.206,
#
# accuracy in training set after perturbation: 18.498304
#
# 945.2025759220123 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.823, loss_adv: 23.203,
#
# accuracy in training set after perturbation: 18.526359
#
# 955.5646433830261 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.816, loss_adv: 23.196,
#
# accuracy in training set after perturbation: 18.485552
#
# 965.8726811408997 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.806, loss_adv: 23.191,
#
# accuracy in training set after perturbation: 18.490653
#
# 976.2038109302521 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.796, loss_adv: 23.186,
#
# accuracy in training set after perturbation: 18.465148
#
# 986.5483872890472 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.794, loss_adv: 23.181,
#
# accuracy in training set after perturbation: 18.516157
#
# 996.878306388855 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.790, loss_adv: 23.175,
#
# accuracy in training set after perturbation: 18.495754
#
# 1007.2308015823364 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.784, loss_adv: 23.169,
#
# accuracy in training set after perturbation: 18.475350
#
# 1017.5843183994293 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.775, loss_adv: 23.164,
#
# accuracy in training set after perturbation: 18.475350
#
# 1027.9212651252747 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 2.771, loss_adv: 23.158,
#
# accuracy in training set after perturbation: 18.493203
#
# 1038.2730464935303 seconds
# accuracy in test set on all perturbed images: 27.996833
#
# misclassifications on previously correctly classified images: 72.296120
