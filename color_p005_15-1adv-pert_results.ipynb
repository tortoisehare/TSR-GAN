# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p005_15-1adv-pert_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.005, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 15:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.005
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 15
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.005
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.005
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<20:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.500, loss_G_fake: 0.252,
# loss_perturb: 12.624, loss_adv: 125.744,
#
# accuracy in training set after perturbation: 99.479711
#
# 8.951274871826172 seconds
# epoch 2:
# loss_D: 0.476, loss_G_fake: 0.266,
# loss_perturb: 13.480, loss_adv: 122.710,
#
# accuracy in training set after perturbation: 97.923946
#
# 17.707295417785645 seconds
# epoch 3:
# loss_D: 0.481, loss_G_fake: 0.270,
# loss_perturb: 10.657, loss_adv: 121.392,
#
# accuracy in training set after perturbation: 97.153715
#
# 26.428661108016968 seconds
# epoch 4:
# loss_D: 0.492, loss_G_fake: 0.258,
# loss_perturb: 8.115, loss_adv: 120.025,
#
# accuracy in training set after perturbation: 96.317172
#
# 35.27467155456543 seconds
# epoch 5:
# loss_D: 0.460, loss_G_fake: 0.285,
# loss_perturb: 8.254, loss_adv: 118.797,
#
# accuracy in training set after perturbation: 95.467877
#
# 43.97269058227539 seconds
# epoch 6:
# loss_D: 0.414, loss_G_fake: 0.325,
# loss_perturb: 7.954, loss_adv: 117.888,
#
# accuracy in training set after perturbation: 94.837920
#
# 52.93859672546387 seconds
# epoch 7:
# loss_D: 0.380, loss_G_fake: 0.364,
# loss_perturb: 7.412, loss_adv: 116.701,
#
# accuracy in training set after perturbation: 93.991175
#
# 62.03803205490112 seconds
# epoch 8:
# loss_D: 0.369, loss_G_fake: 0.383,
# loss_perturb: 7.308, loss_adv: 116.174,
#
# accuracy in training set after perturbation: 93.669821
#
# 71.08608961105347 seconds
# epoch 9:
# loss_D: 0.396, loss_G_fake: 0.380,
# loss_perturb: 7.627, loss_adv: 115.512,
#
# accuracy in training set after perturbation: 93.106175
#
# 80.04561758041382 seconds
# epoch 10:
# loss_D: 0.378, loss_G_fake: 0.382,
# loss_perturb: 7.364, loss_adv: 114.977,
#
# accuracy in training set after perturbation: 92.736362
#
# 89.00274014472961 seconds
# epoch 11:
# loss_D: 0.363, loss_G_fake: 0.420,
# loss_perturb: 7.203, loss_adv: 114.333,
#
# accuracy in training set after perturbation: 92.254329
#
# 97.97036123275757 seconds
# epoch 12:
# loss_D: 0.352, loss_G_fake: 0.422,
# loss_perturb: 6.823, loss_adv: 114.032,
#
# accuracy in training set after perturbation: 92.111505
#
# 106.95766019821167 seconds
# epoch 13:
# loss_D: 0.353, loss_G_fake: 0.420,
# loss_perturb: 6.717, loss_adv: 113.601,
#
# accuracy in training set after perturbation: 91.800352
#
# 116.03907012939453 seconds
# epoch 14:
# loss_D: 0.343, loss_G_fake: 0.441,
# loss_perturb: 6.705, loss_adv: 113.164,
#
# accuracy in training set after perturbation: 91.415236
#
# 124.90338683128357 seconds
# epoch 15:
# loss_D: 0.360, loss_G_fake: 0.432,
# loss_perturb: 6.522, loss_adv: 112.822,
#
# accuracy in training set after perturbation: 91.246908
#
# 133.7238426208496 seconds
# epoch 16:
# loss_D: 0.317, loss_G_fake: 0.461,
# loss_perturb: 6.249, loss_adv: 112.375,
#
# accuracy in training set after perturbation: 90.874544
#
# 142.5616979598999 seconds
# epoch 17:
# loss_D: 0.341, loss_G_fake: 0.465,
# loss_perturb: 6.469, loss_adv: 112.503,
#
# accuracy in training set after perturbation: 91.037772
#
# 151.3315155506134 seconds
# epoch 18:
# loss_D: 0.321, loss_G_fake: 0.472,
# loss_perturb: 6.215, loss_adv: 111.848,
#
# accuracy in training set after perturbation: 90.479227
#
# 160.10666131973267 seconds
# epoch 19:
# loss_D: 0.361, loss_G_fake: 0.435,
# loss_perturb: 6.423, loss_adv: 111.656,
#
# accuracy in training set after perturbation: 90.402714
#
# 168.74742150306702 seconds
# epoch 20:
# loss_D: 0.336, loss_G_fake: 0.471,
# loss_perturb: 6.278, loss_adv: 111.257,
#
# accuracy in training set after perturbation: 90.078808
#
# 177.42800426483154 seconds
# epoch 21:
# loss_D: 0.363, loss_G_fake: 0.435,
# loss_perturb: 6.051, loss_adv: 111.103,
#
# accuracy in training set after perturbation: 89.951287
#
# 186.10434937477112 seconds
# epoch 22:
# loss_D: 0.360, loss_G_fake: 0.482,
# loss_perturb: 6.356, loss_adv: 111.184,
#
# accuracy in training set after perturbation: 90.076258
#
# 194.80072045326233 seconds
# epoch 23:
# loss_D: 0.430, loss_G_fake: 0.400,
# loss_perturb: 6.123, loss_adv: 110.585,
#
# accuracy in training set after perturbation: 89.545768
#
# 203.52436351776123 seconds
# epoch 24:
# loss_D: 0.364, loss_G_fake: 0.431,
# loss_perturb: 6.145, loss_adv: 110.407,
#
# accuracy in training set after perturbation: 89.425897
#
# 212.16926383972168 seconds
# epoch 25:
# loss_D: 0.347, loss_G_fake: 0.456,
# loss_perturb: 5.661, loss_adv: 109.886,
#
# accuracy in training set after perturbation: 89.073937
#
# 220.78281426429749 seconds
# epoch 26:
# loss_D: 0.351, loss_G_fake: 0.459,
# loss_perturb: 5.556, loss_adv: 109.661,
#
# accuracy in training set after perturbation: 88.846948
#
# 229.47536945343018 seconds
# epoch 27:
# loss_D: 0.340, loss_G_fake: 0.451,
# loss_perturb: 5.631, loss_adv: 109.666,
#
# accuracy in training set after perturbation: 88.905608
#
# 238.17972230911255 seconds
# epoch 28:
# loss_D: 0.374, loss_G_fake: 0.449,
# loss_perturb: 5.688, loss_adv: 109.496,
#
# accuracy in training set after perturbation: 88.767885
#
# 247.15477561950684 seconds
# epoch 29:
# loss_D: 0.343, loss_G_fake: 0.470,
# loss_perturb: 5.766, loss_adv: 109.755,
#
# accuracy in training set after perturbation: 89.010176
#
# 256.170202255249 seconds
# epoch 30:
# loss_D: 0.346, loss_G_fake: 0.468,
# loss_perturb: 6.066, loss_adv: 109.448,
#
# accuracy in training set after perturbation: 88.918361
#
# 265.01371717453003 seconds
# epoch 31:
# loss_D: 0.349, loss_G_fake: 0.453,
# loss_perturb: 5.782, loss_adv: 108.898,
#
# accuracy in training set after perturbation: 88.362366
#
# 274.0362231731415 seconds
# epoch 32:
# loss_D: 0.611, loss_G_fake: 0.339,
# loss_perturb: 5.598, loss_adv: 108.667,
#
# accuracy in training set after perturbation: 88.178734
#
# 283.2382469177246 seconds
# epoch 33:
# loss_D: 0.460, loss_G_fake: 0.370,
# loss_perturb: 5.552, loss_adv: 108.512,
#
# accuracy in training set after perturbation: 88.120074
#
# 292.19490909576416 seconds
# epoch 34:
# loss_D: 0.465, loss_G_fake: 0.352,
# loss_perturb: 5.585, loss_adv: 108.386,
#
# accuracy in training set after perturbation: 88.000204
#
# 301.21788597106934 seconds
# epoch 35:
# loss_D: 0.455, loss_G_fake: 0.350,
# loss_perturb: 5.312, loss_adv: 108.050,
#
# accuracy in training set after perturbation: 87.658446
#
# 310.17441964149475 seconds
# epoch 36:
# loss_D: 0.424, loss_G_fake: 0.369,
# loss_perturb: 5.549, loss_adv: 108.006,
#
# accuracy in training set after perturbation: 87.691601
#
# 319.03597021102905 seconds
# epoch 37:
# loss_D: 0.414, loss_G_fake: 0.379,
# loss_perturb: 5.639, loss_adv: 108.197,
#
# accuracy in training set after perturbation: 87.877783
#
# 327.6649053096771 seconds
# epoch 38:
# loss_D: 0.427, loss_G_fake: 0.370,
# loss_perturb: 5.402, loss_adv: 107.693,
#
# accuracy in training set after perturbation: 87.408503
#
# 336.31927514076233 seconds
# epoch 39:
# loss_D: 0.412, loss_G_fake: 0.378,
# loss_perturb: 5.193, loss_adv: 107.660,
#
# accuracy in training set after perturbation: 87.454411
#
# 344.95020365715027 seconds
# epoch 40:
# loss_D: 0.411, loss_G_fake: 0.427,
# loss_perturb: 5.153, loss_adv: 107.582,
#
# accuracy in training set after perturbation: 87.393201
#
# 353.69422483444214 seconds
# epoch 41:
# loss_D: 0.557, loss_G_fake: 0.251,
# loss_perturb: 5.463, loss_adv: 107.398,
#
# accuracy in training set after perturbation: 87.283532
#
# 362.4574887752533 seconds
# epoch 42:
# loss_D: 0.496, loss_G_fake: 0.280,
# loss_perturb: 5.559, loss_adv: 107.505,
#
# accuracy in training set after perturbation: 87.434007
#
# 371.24479818344116 seconds
# epoch 43:
# loss_D: 0.503, loss_G_fake: 0.262,
# loss_perturb: 5.395, loss_adv: 107.265,
#
# accuracy in training set after perturbation: 87.163661
#
# 379.9961426258087 seconds
# epoch 44:
# loss_D: 0.481, loss_G_fake: 0.287,
# loss_perturb: 5.215, loss_adv: 107.065,
#
# accuracy in training set after perturbation: 86.967278
#
# 388.7776174545288 seconds
# epoch 45:
# loss_D: 0.460, loss_G_fake: 0.331,
# loss_perturb: 4.950, loss_adv: 106.771,
#
# accuracy in training set after perturbation: 86.699482
#
# 397.47778367996216 seconds
# epoch 46:
# loss_D: 0.430, loss_G_fake: 0.356,
# loss_perturb: 4.892, loss_adv: 106.736,
#
# accuracy in training set after perturbation: 86.747941
#
# 406.07669472694397 seconds
# epoch 47:
# loss_D: 0.421, loss_G_fake: 0.369,
# loss_perturb: 4.959, loss_adv: 106.579,
#
# accuracy in training set after perturbation: 86.658675
#
# 414.6925013065338 seconds
# epoch 48:
# loss_D: 0.461, loss_G_fake: 0.300,
# loss_perturb: 4.939, loss_adv: 106.537,
#
# accuracy in training set after perturbation: 86.628070
#
# 423.3632972240448 seconds
# epoch 49:
# loss_D: 0.466, loss_G_fake: 0.307,
# loss_perturb: 4.849, loss_adv: 106.416,
#
# accuracy in training set after perturbation: 86.508200
#
# 431.9547555446625 seconds
# epoch 50:
# loss_D: 0.357, loss_G_fake: 0.403,
# loss_perturb: 4.623, loss_adv: 105.857,
#
# accuracy in training set after perturbation: 85.870591
#
# 440.679514169693 seconds
# epoch 51:
# loss_D: 0.311, loss_G_fake: 0.443,
# loss_perturb: 4.363, loss_adv: 105.537,
#
# accuracy in training set after perturbation: 85.375807
#
# 449.3113033771515 seconds
# epoch 52:
# loss_D: 0.300, loss_G_fake: 0.459,
# loss_perturb: 4.159, loss_adv: 105.387,
#
# accuracy in training set after perturbation: 85.179423
#
# 457.9870300292969 seconds
# epoch 53:
# loss_D: 0.289, loss_G_fake: 0.472,
# loss_perturb: 3.994, loss_adv: 105.279,
#
# accuracy in training set after perturbation: 85.077406
#
# 466.58876156806946 seconds
# epoch 54:
# loss_D: 0.279, loss_G_fake: 0.485,
# loss_perturb: 3.847, loss_adv: 105.194,
#
# accuracy in training set after perturbation: 85.082507
#
# 475.2303833961487 seconds
# epoch 55:
# loss_D: 0.274, loss_G_fake: 0.496,
# loss_perturb: 3.731, loss_adv: 105.106,
#
# accuracy in training set after perturbation: 84.914178
#
# 483.83290243148804 seconds
# epoch 56:
# loss_D: 0.266, loss_G_fake: 0.506,
# loss_perturb: 3.620, loss_adv: 105.032,
#
# accuracy in training set after perturbation: 84.898875
#
# 492.44551634788513 seconds
# epoch 57:
# loss_D: 0.265, loss_G_fake: 0.511,
# loss_perturb: 3.524, loss_adv: 104.974,
#
# accuracy in training set after perturbation: 84.873371
#
# 501.02121114730835 seconds
# epoch 58:
# loss_D: 0.264, loss_G_fake: 0.514,
# loss_perturb: 3.427, loss_adv: 104.910,
#
# accuracy in training set after perturbation: 84.812160
#
# 509.626256942749 seconds
# epoch 59:
# loss_D: 0.262, loss_G_fake: 0.518,
# loss_perturb: 3.353, loss_adv: 104.859,
#
# accuracy in training set after perturbation: 84.830014
#
# 518.3142478466034 seconds
# epoch 60:
# loss_D: 0.256, loss_G_fake: 0.526,
# loss_perturb: 3.278, loss_adv: 104.810,
#
# accuracy in training set after perturbation: 84.794307
#
# 526.9686458110809 seconds
# epoch 61:
# loss_D: 0.253, loss_G_fake: 0.532,
# loss_perturb: 3.210, loss_adv: 104.761,
#
# accuracy in training set after perturbation: 84.771354
#
# 535.5439691543579 seconds
# epoch 62:
# loss_D: 0.250, loss_G_fake: 0.534,
# loss_perturb: 3.158, loss_adv: 104.707,
#
# accuracy in training set after perturbation: 84.692290
#
# 544.153566122055 seconds
# epoch 63:
# loss_D: 0.256, loss_G_fake: 0.532,
# loss_perturb: 3.106, loss_adv: 104.664,
#
# accuracy in training set after perturbation: 84.725446
#
# 552.7246017456055 seconds
# epoch 64:
# loss_D: 0.251, loss_G_fake: 0.538,
# loss_perturb: 3.065, loss_adv: 104.629,
#
# accuracy in training set after perturbation: 84.656584
#
# 561.3325593471527 seconds
# epoch 65:
# loss_D: 0.248, loss_G_fake: 0.540,
# loss_perturb: 3.037, loss_adv: 104.590,
#
# accuracy in training set after perturbation: 84.689740
#
# 569.9143431186676 seconds
# epoch 66:
# loss_D: 0.246, loss_G_fake: 0.550,
# loss_perturb: 2.996, loss_adv: 104.546,
#
# accuracy in training set after perturbation: 84.582621
#
# 578.5622563362122 seconds
# epoch 67:
# loss_D: 0.249, loss_G_fake: 0.544,
# loss_perturb: 2.964, loss_adv: 104.507,
#
# accuracy in training set after perturbation: 84.620878
#
# 587.4049999713898 seconds
# epoch 68:
# loss_D: 0.248, loss_G_fake: 0.547,
# loss_perturb: 2.938, loss_adv: 104.462,
#
# accuracy in training set after perturbation: 84.531613
#
# 596.1312913894653 seconds
# epoch 69:
# loss_D: 0.241, loss_G_fake: 0.555,
# loss_perturb: 2.917, loss_adv: 104.428,
#
# accuracy in training set after perturbation: 84.554567
#
# 604.7811806201935 seconds
# epoch 70:
# loss_D: 0.241, loss_G_fake: 0.557,
# loss_perturb: 2.899, loss_adv: 104.400,
#
# accuracy in training set after perturbation: 84.534163
#
# 613.381129026413 seconds
# epoch 71:
# loss_D: 0.246, loss_G_fake: 0.552,
# loss_perturb: 2.879, loss_adv: 104.367,
#
# accuracy in training set after perturbation: 84.511209
#
# 621.9484360218048 seconds
# epoch 72:
# loss_D: 0.242, loss_G_fake: 0.558,
# loss_perturb: 2.857, loss_adv: 104.328,
#
# accuracy in training set after perturbation: 84.490806
#
# 630.5366363525391 seconds
# epoch 73:
# loss_D: 0.239, loss_G_fake: 0.562,
# loss_perturb: 2.846, loss_adv: 104.291,
#
# accuracy in training set after perturbation: 84.411742
#
# 639.1481907367706 seconds
# epoch 74:
# loss_D: 0.242, loss_G_fake: 0.560,
# loss_perturb: 2.840, loss_adv: 104.272,
#
# accuracy in training set after perturbation: 84.485705
#
# 647.7267258167267 seconds
# epoch 75:
# loss_D: 0.239, loss_G_fake: 0.562,
# loss_perturb: 2.830, loss_adv: 104.238,
#
# accuracy in training set after perturbation: 84.437247
#
# 656.2796835899353 seconds
# epoch 76:
# loss_D: 0.239, loss_G_fake: 0.565,
# loss_perturb: 2.808, loss_adv: 104.202,
#
# accuracy in training set after perturbation: 84.424494
#
# 664.8865969181061 seconds
# epoch 77:
# loss_D: 0.243, loss_G_fake: 0.560,
# loss_perturb: 2.800, loss_adv: 104.168,
#
# accuracy in training set after perturbation: 84.332679
#
# 673.4754917621613 seconds
# epoch 78:
# loss_D: 0.241, loss_G_fake: 0.566,
# loss_perturb: 2.783, loss_adv: 104.136,
#
# accuracy in training set after perturbation: 84.363284
#
# 682.1350886821747 seconds
# epoch 79:
# loss_D: 0.244, loss_G_fake: 0.557,
# loss_perturb: 2.772, loss_adv: 104.105,
#
# accuracy in training set after perturbation: 84.274019
#
# 690.702733039856 seconds
# epoch 80:
# loss_D: 0.234, loss_G_fake: 0.560,
# loss_perturb: 2.760, loss_adv: 104.043,
#
# accuracy in training set after perturbation: 84.194955
#
# 699.2975330352783 seconds
# epoch 81:
# loss_D: 0.225, loss_G_fake: 0.582,
# loss_perturb: 2.747, loss_adv: 104.019,
#
# accuracy in training set after perturbation: 84.103140
#
# 707.8527886867523 seconds
# epoch 82:
# loss_D: 0.223, loss_G_fake: 0.584,
# loss_perturb: 2.738, loss_adv: 104.006,
#
# accuracy in training set after perturbation: 84.067433
#
# 716.4433681964874 seconds
# epoch 83:
# loss_D: 0.222, loss_G_fake: 0.585,
# loss_perturb: 2.730, loss_adv: 103.995,
#
# accuracy in training set after perturbation: 84.021526
#
# 725.0207307338715 seconds
# epoch 84:
# loss_D: 0.221, loss_G_fake: 0.585,
# loss_perturb: 2.723, loss_adv: 103.986,
#
# accuracy in training set after perturbation: 84.024076
#
# 733.6244554519653 seconds
# epoch 85:
# loss_D: 0.221, loss_G_fake: 0.585,
# loss_perturb: 2.716, loss_adv: 103.978,
#
# accuracy in training set after perturbation: 84.011324
#
# 742.191700220108 seconds
# epoch 86:
# loss_D: 0.220, loss_G_fake: 0.586,
# loss_perturb: 2.710, loss_adv: 103.970,
#
# accuracy in training set after perturbation: 84.016425
#
# 750.7561137676239 seconds
# epoch 87:
# loss_D: 0.220, loss_G_fake: 0.585,
# loss_perturb: 2.704, loss_adv: 103.963,
#
# accuracy in training set after perturbation: 84.001122
#
# 759.4012730121613 seconds
# epoch 88:
# loss_D: 0.220, loss_G_fake: 0.585,
# loss_perturb: 2.699, loss_adv: 103.956,
#
# accuracy in training set after perturbation: 84.041929
#
# 768.0038769245148 seconds
# epoch 89:
# loss_D: 0.220, loss_G_fake: 0.586,
# loss_perturb: 2.695, loss_adv: 103.949,
#
# accuracy in training set after perturbation: 84.024076
#
# 776.5753057003021 seconds
# epoch 90:
# loss_D: 0.219, loss_G_fake: 0.586,
# loss_perturb: 2.689, loss_adv: 103.943,
#
# accuracy in training set after perturbation: 84.001122
#
# 785.1516902446747 seconds
# epoch 91:
# loss_D: 0.219, loss_G_fake: 0.586,
# loss_perturb: 2.685, loss_adv: 103.937,
#
# accuracy in training set after perturbation: 83.980719
#
# 793.7142653465271 seconds
# epoch 92:
# loss_D: 0.218, loss_G_fake: 0.587,
# loss_perturb: 2.680, loss_adv: 103.931,
#
# accuracy in training set after perturbation: 84.011324
#
# 802.2949266433716 seconds
# epoch 93:
# loss_D: 0.218, loss_G_fake: 0.587,
# loss_perturb: 2.676, loss_adv: 103.926,
#
# accuracy in training set after perturbation: 83.993471
#
# 810.881753206253 seconds
# epoch 94:
# loss_D: 0.218, loss_G_fake: 0.588,
# loss_perturb: 2.671, loss_adv: 103.920,
#
# accuracy in training set after perturbation: 83.988370
#
# 819.5210793018341 seconds
# epoch 95:
# loss_D: 0.218, loss_G_fake: 0.587,
# loss_perturb: 2.667, loss_adv: 103.916,
#
# accuracy in training set after perturbation: 84.003673
#
# 828.0931136608124 seconds
# epoch 96:
# loss_D: 0.217, loss_G_fake: 0.588,
# loss_perturb: 2.664, loss_adv: 103.911,
#
# accuracy in training set after perturbation: 84.041929
#
# 836.7446064949036 seconds
# epoch 97:
# loss_D: 0.217, loss_G_fake: 0.588,
# loss_perturb: 2.660, loss_adv: 103.906,
#
# accuracy in training set after perturbation: 84.016425
#
# 845.3991787433624 seconds
# epoch 98:
# loss_D: 0.217, loss_G_fake: 0.588,
# loss_perturb: 2.656, loss_adv: 103.901,
#
# accuracy in training set after perturbation: 83.965416
#
# 854.0057280063629 seconds
# epoch 99:
# loss_D: 0.216, loss_G_fake: 0.589,
# loss_perturb: 2.652, loss_adv: 103.896,
#
# accuracy in training set after perturbation: 83.973067
#
# 862.5775406360626 seconds
# epoch 100:
# loss_D: 0.216, loss_G_fake: 0.589,
# loss_perturb: 2.649, loss_adv: 103.892,
#
# accuracy in training set after perturbation: 84.021526
#
# 871.161731004715 seconds
# accuracy in test set on all perturbed images: 82.121932
#
# misclassifications on previously correctly classified images: 18.408551
