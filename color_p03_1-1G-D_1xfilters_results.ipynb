# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p03_1-1G-D_1xfilters_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.03, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.03
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.03
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.03
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.416, loss_G_fake: 0.319,
# loss_perturb: 16.816, loss_adv: 84.236,
#
# accuracy in training set after perturbation: 68.797980
#
# 8.851135730743408 seconds
# epoch 2:
# loss_D: 0.168, loss_G_fake: 0.585,
# loss_perturb: 13.774, loss_adv: 69.094,
#
# accuracy in training set after perturbation: 56.675763
#
# 17.669610738754272 seconds
# epoch 3:
# loss_D: 0.093, loss_G_fake: 0.701,
# loss_perturb: 12.337, loss_adv: 61.153,
#
# accuracy in training set after perturbation: 50.121146
#
# 26.510430097579956 seconds
# epoch 4:
# loss_D: 0.056, loss_G_fake: 0.778,
# loss_perturb: 10.689, loss_adv: 55.911,
#
# accuracy in training set after perturbation: 46.002193
#
# 35.381319761276245 seconds
# epoch 5:
# loss_D: 0.034, loss_G_fake: 0.828,
# loss_perturb: 9.799, loss_adv: 52.450,
#
# accuracy in training set after perturbation: 43.191614
#
# 44.22203540802002 seconds
# epoch 6:
# loss_D: 0.040, loss_G_fake: 0.831,
# loss_perturb: 8.891, loss_adv: 49.231,
#
# accuracy in training set after perturbation: 40.577418
#
# 52.9566867351532 seconds
# epoch 7:
# loss_D: 0.021, loss_G_fake: 0.874,
# loss_perturb: 8.096, loss_adv: 46.994,
#
# accuracy in training set after perturbation: 38.728353
#
# 61.67070960998535 seconds
# epoch 8:
# loss_D: 0.014, loss_G_fake: 0.899,
# loss_perturb: 7.834, loss_adv: 45.190,
#
# accuracy in training set after perturbation: 37.246551
#
# 70.35669040679932 seconds
# epoch 9:
# loss_D: 0.012, loss_G_fake: 0.909,
# loss_perturb: 7.930, loss_adv: 44.252,
#
# accuracy in training set after perturbation: 36.665051
#
# 79.03720712661743 seconds
# epoch 10:
# loss_D: 0.010, loss_G_fake: 0.918,
# loss_perturb: 7.505, loss_adv: 42.554,
#
# accuracy in training set after perturbation: 35.083782
#
# 87.70418119430542 seconds
# epoch 11:
# loss_D: 0.012, loss_G_fake: 0.917,
# loss_perturb: 7.266, loss_adv: 41.641,
#
# accuracy in training set after perturbation: 34.351807
#
# 96.42851638793945 seconds
# epoch 12:
# loss_D: 0.007, loss_G_fake: 0.933,
# loss_perturb: 7.119, loss_adv: 40.522,
#
# accuracy in training set after perturbation: 33.482109
#
# 105.17966055870056 seconds
# epoch 13:
# loss_D: 0.016, loss_G_fake: 0.914,
# loss_perturb: 7.250, loss_adv: 40.048,
#
# accuracy in training set after perturbation: 33.267872
#
# 113.91828680038452 seconds
# epoch 14:
# loss_D: 0.004, loss_G_fake: 0.951,
# loss_perturb: 7.305, loss_adv: 38.760,
#
# accuracy in training set after perturbation: 32.120176
#
# 122.7055332660675 seconds
# epoch 15:
# loss_D: 0.003, loss_G_fake: 0.959,
# loss_perturb: 6.945, loss_adv: 38.068,
#
# accuracy in training set after perturbation: 31.515723
#
# 131.4063000679016 seconds
# epoch 16:
# loss_D: 0.007, loss_G_fake: 0.949,
# loss_perturb: 6.708, loss_adv: 37.426,
#
# accuracy in training set after perturbation: 31.033691
#
# 140.10903191566467 seconds
# epoch 17:
# loss_D: 0.007, loss_G_fake: 0.943,
# loss_perturb: 6.707, loss_adv: 36.818,
#
# accuracy in training set after perturbation: 30.559310
#
# 149.04357266426086 seconds
# epoch 18:
# loss_D: 0.007, loss_G_fake: 0.948,
# loss_perturb: 6.418, loss_adv: 36.329,
#
# accuracy in training set after perturbation: 30.082379
#
# 157.7100486755371 seconds
# epoch 19:
# loss_D: 0.002, loss_G_fake: 0.966,
# loss_perturb: 6.461, loss_adv: 35.624,
#
# accuracy in training set after perturbation: 29.513632
#
# 166.3609700202942 seconds
# epoch 20:
# loss_D: 0.001, loss_G_fake: 0.974,
# loss_perturb: 6.468, loss_adv: 35.359,
#
# accuracy in training set after perturbation: 29.327450
#
# 174.99557280540466 seconds
# epoch 21:
# loss_D: 0.005, loss_G_fake: 0.958,
# loss_perturb: 6.136, loss_adv: 35.052,
#
# accuracy in training set after perturbation: 29.006096
#
# 183.65256261825562 seconds
# epoch 22:
# loss_D: 0.006, loss_G_fake: 0.954,
# loss_perturb: 6.214, loss_adv: 34.687,
#
# accuracy in training set after perturbation: 28.753602
#
# 192.3183355331421 seconds
# epoch 23:
# loss_D: 0.001, loss_G_fake: 0.977,
# loss_perturb: 6.701, loss_adv: 34.465,
#
# accuracy in training set after perturbation: 28.628631
#
# 201.049813747406 seconds
# epoch 24:
# loss_D: 0.010, loss_G_fake: 0.947,
# loss_perturb: 6.576, loss_adv: 33.930,
#
# accuracy in training set after perturbation: 28.154250
#
# 209.70286107063293 seconds
# epoch 25:
# loss_D: 0.001, loss_G_fake: 0.976,
# loss_perturb: 6.262, loss_adv: 33.675,
#
# accuracy in training set after perturbation: 27.919610
#
# 218.32064628601074 seconds
# epoch 26:
# loss_D: 0.001, loss_G_fake: 0.981,
# loss_perturb: 6.249, loss_adv: 33.241,
#
# accuracy in training set after perturbation: 27.636512
#
# 226.97744822502136 seconds
# epoch 27:
# loss_D: 0.001, loss_G_fake: 0.981,
# loss_perturb: 6.585, loss_adv: 32.842,
#
# accuracy in training set after perturbation: 27.330460
#
# 235.61467576026917 seconds
# epoch 28:
# loss_D: 0.001, loss_G_fake: 0.984,
# loss_perturb: 6.532, loss_adv: 32.949,
#
# accuracy in training set after perturbation: 27.562549
#
# 244.25015139579773 seconds
# epoch 29:
# loss_D: 0.008, loss_G_fake: 0.957,
# loss_perturb: 6.198, loss_adv: 32.154,
#
# accuracy in training set after perturbation: 26.756612
#
# 252.84939813613892 seconds
# epoch 30:
# loss_D: 0.001, loss_G_fake: 0.979,
# loss_perturb: 5.899, loss_adv: 31.677,
#
# accuracy in training set after perturbation: 26.226122
#
# 261.47908449172974 seconds
# epoch 31:
# loss_D: 0.001, loss_G_fake: 0.981,
# loss_perturb: 6.393, loss_adv: 31.830,
#
# accuracy in training set after perturbation: 26.532174
#
# 270.23500967025757 seconds
# epoch 32:
# loss_D: 0.001, loss_G_fake: 0.984,
# loss_perturb: 6.288, loss_adv: 31.723,
#
# accuracy in training set after perturbation: 26.417404
#
# 278.90276074409485 seconds
# epoch 33:
# loss_D: 0.007, loss_G_fake: 0.963,
# loss_perturb: 5.955, loss_adv: 31.329,
#
# accuracy in training set after perturbation: 26.057793
#
# 287.6386420726776 seconds
# epoch 34:
# loss_D: 0.001, loss_G_fake: 0.976,
# loss_perturb: 6.049, loss_adv: 31.133,
#
# accuracy in training set after perturbation: 25.943023
#
# 296.2722566127777 seconds
# epoch 35:
# loss_D: 0.004, loss_G_fake: 0.976,
# loss_perturb: 6.001, loss_adv: 30.913,
#
# accuracy in training set after perturbation: 25.657375
#
# 304.9109513759613 seconds
# epoch 36:
# loss_D: 0.001, loss_G_fake: 0.981,
# loss_perturb: 5.796, loss_adv: 30.733,
#
# accuracy in training set after perturbation: 25.489046
#
# 313.55316710472107 seconds
# epoch 37:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 6.346, loss_adv: 30.642,
#
# accuracy in training set after perturbation: 25.522202
#
# 322.18541073799133 seconds
# epoch 38:
# loss_D: 0.004, loss_G_fake: 0.981,
# loss_perturb: 6.229, loss_adv: 30.541,
#
# accuracy in training set after perturbation: 25.422735
#
# 330.80104327201843 seconds
# epoch 39:
# loss_D: 0.001, loss_G_fake: 0.975,
# loss_perturb: 6.279, loss_adv: 30.362,
#
# accuracy in training set after perturbation: 25.236553
#
# 339.42460012435913 seconds
# epoch 40:
# loss_D: 0.001, loss_G_fake: 0.983,
# loss_perturb: 6.021, loss_adv: 30.042,
#
# accuracy in training set after perturbation: 24.910097
#
# 348.02838826179504 seconds
# epoch 41:
# loss_D: 0.000, loss_G_fake: 0.988,
# loss_perturb: 5.613, loss_adv: 29.940,
#
# accuracy in training set after perturbation: 24.823382
#
# 356.69647121429443 seconds
# epoch 42:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 5.937, loss_adv: 29.834,
#
# accuracy in training set after perturbation: 24.729016
#
# 365.4060089588165 seconds
# epoch 43:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 5.622, loss_adv: 29.539,
#
# accuracy in training set after perturbation: 24.377056
#
# 374.0442888736725 seconds
# epoch 44:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 5.871, loss_adv: 29.736,
#
# accuracy in training set after perturbation: 24.698411
#
# 382.6592583656311 seconds
# epoch 45:
# loss_D: 0.014, loss_G_fake: 0.961,
# loss_perturb: 5.380, loss_adv: 29.324,
#
# accuracy in training set after perturbation: 24.226581
#
# 391.22013449668884 seconds
# epoch 46:
# loss_D: 0.001, loss_G_fake: 0.983,
# loss_perturb: 5.730, loss_adv: 29.312,
#
# accuracy in training set after perturbation: 24.259736
#
# 399.82143211364746 seconds
# epoch 47:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 5.510, loss_adv: 29.227,
#
# accuracy in training set after perturbation: 24.208728
#
# 408.43581557273865 seconds
# epoch 48:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 5.679, loss_adv: 29.234,
#
# accuracy in training set after perturbation: 24.257186
#
# 417.0329613685608 seconds
# epoch 49:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 5.773, loss_adv: 29.056,
#
# accuracy in training set after perturbation: 24.050601
#
# 425.6675510406494 seconds
# epoch 50:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 5.764, loss_adv: 28.338,
#
# accuracy in training set after perturbation: 23.020225
#
# 434.28449153900146 seconds
# epoch 51:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.929, loss_adv: 28.066,
#
# accuracy in training set after perturbation: 22.617256
#
# 442.99844574928284 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.408, loss_adv: 27.964,
#
# accuracy in training set after perturbation: 22.520340
#
# 451.6737241744995 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.088, loss_adv: 27.883,
#
# accuracy in training set after perturbation: 22.456579
#
# 460.5623712539673 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 3.900, loss_adv: 27.823,
#
# accuracy in training set after perturbation: 22.454028
#
# 469.1863431930542 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.805, loss_adv: 27.753,
#
# accuracy in training set after perturbation: 22.364763
#
# 477.7744700908661 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.697, loss_adv: 27.677,
#
# accuracy in training set after perturbation: 22.308654
#
# 486.3955135345459 seconds
# epoch 57:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.626, loss_adv: 27.613,
#
# accuracy in training set after perturbation: 22.242342
#
# 495.04060769081116 seconds
# epoch 58:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.561, loss_adv: 27.559,
#
# accuracy in training set after perturbation: 22.181132
#
# 503.6790072917938 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.529, loss_adv: 27.504,
#
# accuracy in training set after perturbation: 22.188783
#
# 512.2878880500793 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.499, loss_adv: 27.453,
#
# accuracy in training set after perturbation: 22.130123
#
# 520.9944784641266 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.472, loss_adv: 27.402,
#
# accuracy in training set after perturbation: 22.048509
#
# 529.6615123748779 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.476, loss_adv: 27.356,
#
# accuracy in training set after perturbation: 22.043408
#
# 538.2318921089172 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.455, loss_adv: 27.318,
#
# accuracy in training set after perturbation: 22.035757
#
# 546.8345382213593 seconds
# epoch 64:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.504, loss_adv: 27.276,
#
# accuracy in training set after perturbation: 21.992400
#
# 555.4147453308105 seconds
# epoch 65:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.484, loss_adv: 27.229,
#
# accuracy in training set after perturbation: 21.923538
#
# 564.0237646102905 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.432, loss_adv: 27.191,
#
# accuracy in training set after perturbation: 21.903134
#
# 572.7101647853851 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.406, loss_adv: 27.145,
#
# accuracy in training set after perturbation: 21.806218
#
# 581.3268139362335 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.370, loss_adv: 27.123,
#
# accuracy in training set after perturbation: 21.877630
#
# 589.9397974014282 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.367, loss_adv: 27.082,
#
# accuracy in training set after perturbation: 21.801117
#
# 598.6382150650024 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.381, loss_adv: 27.046,
#
# accuracy in training set after perturbation: 21.801117
#
# 607.3070778846741 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.360, loss_adv: 27.014,
#
# accuracy in training set after perturbation: 21.755209
#
# 615.8829057216644 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.384, loss_adv: 26.996,
#
# accuracy in training set after perturbation: 21.755209
#
# 624.5320627689362 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.368, loss_adv: 26.947,
#
# accuracy in training set after perturbation: 21.709301
#
# 633.122447013855 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.392, loss_adv: 26.923,
#
# accuracy in training set after perturbation: 21.716953
#
# 641.6981282234192 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.342, loss_adv: 26.871,
#
# accuracy in training set after perturbation: 21.607284
#
# 650.2775988578796 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.289, loss_adv: 26.853,
#
# accuracy in training set after perturbation: 21.604734
#
# 658.8682582378387 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.335, loss_adv: 26.835,
#
# accuracy in training set after perturbation: 21.676146
#
# 667.4754450321198 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.340, loss_adv: 26.793,
#
# accuracy in training set after perturbation: 21.563927
#
# 676.0833575725555 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.325, loss_adv: 26.775,
#
# accuracy in training set after perturbation: 21.581780
#
# 684.8033421039581 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.331, loss_adv: 26.700,
#
# accuracy in training set after perturbation: 21.436405
#
# 693.4120767116547 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.296, loss_adv: 26.684,
#
# accuracy in training set after perturbation: 21.336938
#
# 701.9772822856903 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.262, loss_adv: 26.677,
#
# accuracy in training set after perturbation: 21.329287
#
# 710.5557911396027 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.233, loss_adv: 26.671,
#
# accuracy in training set after perturbation: 21.324186
#
# 719.1491043567657 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.208, loss_adv: 26.666,
#
# accuracy in training set after perturbation: 21.319085
#
# 727.7438356876373 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.190, loss_adv: 26.661,
#
# accuracy in training set after perturbation: 21.344589
#
# 736.3460319042206 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.175, loss_adv: 26.654,
#
# accuracy in training set after perturbation: 21.339488
#
# 744.9347908496857 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.164, loss_adv: 26.648,
#
# accuracy in training set after perturbation: 21.334388
#
# 753.5256955623627 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.152, loss_adv: 26.643,
#
# accuracy in training set after perturbation: 21.334388
#
# 762.243940114975 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.142, loss_adv: 26.637,
#
# accuracy in training set after perturbation: 21.319085
#
# 771.0816516876221 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.135, loss_adv: 26.632,
#
# accuracy in training set after perturbation: 21.336938
#
# 779.665590763092 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.128, loss_adv: 26.627,
#
# accuracy in training set after perturbation: 21.334388
#
# 788.2061049938202 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.121, loss_adv: 26.621,
#
# accuracy in training set after perturbation: 21.336938
#
# 796.7714540958405 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.114, loss_adv: 26.616,
#
# accuracy in training set after perturbation: 21.344589
#
# 805.3507754802704 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.113, loss_adv: 26.609,
#
# accuracy in training set after perturbation: 21.329287
#
# 813.9559366703033 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.107, loss_adv: 26.604,
#
# accuracy in training set after perturbation: 21.298681
#
# 822.4960391521454 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.099, loss_adv: 26.599,
#
# accuracy in training set after perturbation: 21.313984
#
# 831.1050488948822 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.096, loss_adv: 26.594,
#
# accuracy in training set after perturbation: 21.342039
#
# 839.7691841125488 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.094, loss_adv: 26.588,
#
# accuracy in training set after perturbation: 21.331837
#
# 848.3999176025391 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.092, loss_adv: 26.584,
#
# accuracy in training set after perturbation: 21.288480
#
# 856.9480304718018 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.997,
# loss_perturb: 3.088, loss_adv: 26.579,
#
# accuracy in training set after perturbation: 21.316534
#
# 865.5394985675812 seconds
# accuracy in test set on all perturbed images: 31.821061
#
# misclassifications on previously correctly classified images: 68.828187
