# %% [markdown]
# <a href="https://colab.research.google.com/github/tortoisehare/TSR-GAN/blob/master/color_p05_1-1G-D_1xfilters_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COLOR!
#
# pert 0.05, 1:1 G:D, 1x filters, 100 epochs, 90% classifier, adv_lambda:pert_lambda 5:1

# %% [markdown]
# Foundation of PyTorch code provided by github: mathcbc
#
# https://github.com/mathcbc/advGAN_pytorch/blob/master/main.py
#
# Changes made:
#
# target model is LeNet 5
#
# generator given optimizations to allow it to train more than discriminator
#
# parameters like filters/strides changed in GAN
#
# traffic sign dataset loading and preprocessing added
#
# input_sizes for layers work with traffic sign images (32x32)
#
# training accuracy visualization added
#
# testing accuracy plus misclassification percentage
#
# misclassified images visualization
#
# restoration model testing added
#
# bugs fixed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#torch.multiprocessing.set_start_method("spawn") 

import torch.optim
print(torch.__version__)
#from torch import np

import matplotlib
matplotlib.use('Agg')       
get_ipython().magic('matplotlib inline')
from matplotlib import pyplot    
from matplotlib.pyplot import subplot     
from sklearn.metrics import accuracy_score


# Target Model definition - LeNet 5
class target_net(nn.Module):
    def __init__(self):
        super(target_net, self).__init__()

        # LAYER 1: Convolution, Input 3x32x32, Output 6x28x28
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 6x28x28, Output 6x14x14
        self.max_pool_1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        # Dropout
        self.drop1 = torch.nn.Dropout(0.6)
       
        # LAYER 2: Convolution, Input 6x14x14, Output 16x10x10
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True)
        # Max-pooling, Input 16x10x10, Output 16x5x5
        self.max_pool_2 = torch.nn.MaxPool2d(kernel_size=2, stride=2) 
        # Dropout
        self.drop2 = torch.nn.Dropout(0.6)
        
        # LAYER 3: FC, Input 400, Output 120
        self.fc1 = torch.nn.Linear(16*5*5, 120)   # convert matrix with 16*5*5 (= 400) features to a matrix of 120 features (columns)
        self.drop3 = torch.nn.Dropout(0.8)
        
        # LAYER 4: FC, Input 120, Output 84
        self.fc2 = torch.nn.Linear(120, 84)       # convert matrix with 120 features to a matrix of 84 features (columns)
        self.drop4 = torch.nn.Dropout(0.8)
        
        # LAYER 5: FC Input 84, Output 43
        self.fc3 = torch.nn.Linear(84, 43)        # convert matrix with 84 features to a matrix of 43 features (columns)
        


    def forward(self, x):
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv1(x))  
        # max-pooling with 2x2 grid 
        x = self.max_pool_1(x) 
        # convolve, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.conv2(x))
        # max-pooling with 2x2 grid
        x = self.max_pool_2(x)
        # first flatten 'max_pool_2_out' to contain 16*5*5 columns
        # read through https://stackoverflow.com/a/42482819/7551231
        
        x = x.view(-1, 16*5*5)
        # FC-1, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc1(x))
        # FC-2, then perform ReLU non-linearity
        x = torch.nn.functional.relu(self.fc2(x))
        # FC-3
        x = self.fc3(x)
        
        return x


class Discriminator(nn.Module):
    def __init__(self, image_nc):
        super(Discriminator, self).__init__()
        # Traffic Sign Dataset: 3*32x32
        model = [
            nn.Conv2d(image_nc, 8, kernel_size=4, stride=2, padding=0, bias=True),
            nn.LeakyReLU(0.2),
            # 8*16*16
            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            # 16*5*5
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=0, bias=True),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32, 1, 1),
            nn.Sigmoid()
            # 32*1*1
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        output = self.model(x).squeeze()
        return output


class Generator(nn.Module):
    def __init__(self,
                 gen_input_nc,
                 image_nc,
                 ):
        super(Generator, self).__init__()

        encoder_lis = [
            # Traffic Sign Dataset:3*32x32
            nn.Conv2d(gen_input_nc, 8, kernel_size=3, stride=1, padding=0, bias=True),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # 8*26*26
            nn.Conv2d(8, 16, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # 16*12*12
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=0, bias=True),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            # 32*5*5
        ]

        bottle_neck_lis = [ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),
                       ResnetBlock(32),]

        decoder_lis = [
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            # state size. 16 x 11 x 11
            nn.ConvTranspose2d(16, 8, kernel_size=3, stride=2, padding=0, bias=False),
            nn.InstanceNorm2d(8),
            nn.ReLU(),
            # state size. 8 x 23 x 23
            nn.ConvTranspose2d(8, image_nc, kernel_size=6, stride=1, padding=0, bias=False),
            nn.Tanh()
            # state size. image_nc x 32 x 32
        ]

        self.encoder = nn.Sequential(*encoder_lis)
        self.bottle_neck = nn.Sequential(*bottle_neck_lis)
        self.decoder = nn.Sequential(*decoder_lis)

    def forward(self, x):
        x = self.encoder(x)
        x = self.bottle_neck(x)
        x = self.decoder(x)
        return x


# Define a resnet block
# modified from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
class ResnetBlock(nn.Module):
    def __init__(self, dim, padding_type='reflect', norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=False):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out
# Out:
# 1.1.0

# %%
#If you want to show the traffic sign name
import csv

sign_names = []
with open('signnames.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        sign_names.append(row[1])
    sign_names.reverse()
    sign_names.pop()
    sign_names.reverse()

# %%
#Data loading and preprocessing

import pickle
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import numpy as np
from torch.utils.data import TensorDataset

import keras
from keras.utils import to_categorical

training_file = 'train.p'
testing_file = 'test.p'
validation_file = 'valid.p'

with open(training_file, mode='rb') as f:
    tstrain = pickle.load(f)
with open(testing_file, mode='rb') as f:
    tstest = pickle.load(f)
with open(validation_file, mode='rb') as f:
    tsvalid = pickle.load(f)

X_train, Y_train = tstrain['features'], tstrain['labels']
X_valid, Y_valid = tsvalid['features'], tsvalid['labels']
X_test, Y_test = tstest['features'], tstest['labels']

#shuffle training set
X_train, Y_train = shuffle(X_train, Y_train, random_state=33)
X_test, Y_test = shuffle(X_test, Y_test, random_state=33)
X_valid, Y_valid = shuffle(X_valid, Y_valid, random_state=33)

#grayscale images
grayscale = [0.299,0.587,0.144]

#X_test = np.dot(X_test, grayscale)
#X_train = np.dot(X_train, grayscale)
#X_valid = np.dot(X_valid, grayscale)


#normalize
X_train = np.array(X_train)/255
X_test = np.array(X_test)/255
X_valid = np.array(X_valid)/255

X_train = np.concatenate((X_train,X_valid), axis=0)
Y_train = np.concatenate((Y_train,Y_valid), axis=0)

#expand dimensions to fit 4D input array
#X_train = np.expand_dims(X_train,-1)
#X_test = np.expand_dims(X_test,-1)
#X_valid = np.expand_dims(X_valid,-1)

X_train = np.transpose(X_train, (0,3,1,2))
X_test = np.transpose(X_test, (0,3,1,2))
#X_valid = np.transpose(X_valid, (0,3,1,2))

assert(len(X_train)==len(Y_train))
n_train = len(X_train)
assert(len(X_test)==len(Y_test))
n_test = len(X_test)

#Y_train = Y_train.reshape(Y_train.shape[0],1)
#Y_test = Y_test.reshape(Y_test.shape[0],1)
#Y_valid = Y_valid.reshape(Y_valid.shape[0],1)
Y_train = to_categorical(Y_train, num_classes=43)
Y_test = to_categorical(Y_test, num_classes=43)
#Y_valid = to_categorical(Y_valid, num_classes=43)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
#print(X_valid.shape)
#print(Y_valid.shape)

train_x = torch.stack([torch.Tensor(i) for i in X_train])
train_y = torch.stack([torch.LongTensor(i) for i in Y_train])

test_x = torch.stack([torch.Tensor(i) for i in X_test])
test_y = torch.stack([torch.LongTensor(i) for i in Y_test])

#valid_x = torch.stack([torch.Tensor(i) for i in X_valid])
#valid_y = torch.stack([torch.LongTensor(i) for i in Y_valid])

train_dataset = TensorDataset(train_x,train_y)
test_dataset = TensorDataset(test_x,test_y)
#valid_dataset = TensorDataset(valid_x,valid_y)
# Out:
# Using TensorFlow backend.
# (39209, 3, 32, 32)
# (39209, 43)
# (12630, 3, 32, 32)
# (12630, 43)

# %%
#import torch
#import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
#import torch.nn.functional as F


if __name__ == "__main__":
    use_cuda = True
    image_nc = 3 #number of channels
    batch_size = 64

    # Define what device we are using
    print("CUDA Available: ", torch.cuda.is_available())
    device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

    
    #Training set

    train_dataloader = DataLoader(train_dataset, 
                                  batch_size=batch_size, shuffle=False, num_workers=1)


    # training the target model
    target_model = target_net().to(device)
    target_model.train()
    opt_model = torch.optim.Adam(target_model.parameters(), lr=0.001)
    epochs = 20
    
    for epoch in range(epochs):
        loss_epoch = 0
        num_acc_correct = 0
        if epoch == 20:
            opt_model = torch.optim.Adam(target_model.parameters(), lr=0.0001)
        for i, data in enumerate(train_dataloader, 0):
            train_imgs, train_labels = data
            train_imgs, train_labels = train_imgs.to(device), train_labels.to(device)
            logits_model = target_model(train_imgs)
            loss_model = F.cross_entropy(logits_model, torch.max(train_labels,1)[1])
            loss_epoch += loss_model
            
            #stuff for accuracy
            train_label = torch.argmax(train_labels,1)
            pred_train = torch.argmax(logits_model,1)
            num_acc_correct += torch.sum(pred_train==train_label,0)
            
            opt_model.zero_grad()
            loss_model.backward()
            opt_model.step()
        
        print('loss in epoch %d: %f\n' % (epoch, loss_epoch.item()))
        print('Train accuracy so far: %f\n'%(100*num_acc_correct.item()/len(train_dataset)))

    # save model
    targeted_model_file_name = './target_model.pth'
    torch.save(target_model.state_dict(), targeted_model_file_name)
    target_model.eval()

    # TESTING
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=1)
    
    num_correct = 0
    for i, data in enumerate(test_dataloader, 0):
        test_img, test_label = data
        test_img, test_label = test_img.to(device), test_label.to(device)
        test_label = torch.argmax(test_label,1)
        pred_lab = torch.argmax(target_model(test_img), 1)
        num_correct += torch.sum(pred_lab==test_label,0)

    print('accuracy in testing set: %f\n'%(100*num_correct.item()/len(test_dataset)))
# Out:
# CUDA Available:  True
# loss in epoch 0: 1222.426636
#
# Train accuracy so far: 42.538703
#
# loss in epoch 1: 424.738953
#
# Train accuracy so far: 78.739575
#
# loss in epoch 2: 224.582108
#
# Train accuracy so far: 89.346834
#
# loss in epoch 3: 142.685028
#
# Train accuracy so far: 93.498942
#
# loss in epoch 4: 101.307083
#
# Train accuracy so far: 95.495932
#
# loss in epoch 5: 74.509689
#
# Train accuracy so far: 96.638527
#
# loss in epoch 6: 55.734894
#
# Train accuracy so far: 97.510776
#
# loss in epoch 7: 45.904202
#
# Train accuracy so far: 97.926496
#
# loss in epoch 8: 39.567333
#
# Train accuracy so far: 98.204494
#
# loss in epoch 9: 31.910498
#
# Train accuracy so far: 98.528399
#
# loss in epoch 10: 27.309244
#
# Train accuracy so far: 98.760489
#
# loss in epoch 11: 23.973104
#
# Train accuracy so far: 98.839552
#
# loss in epoch 12: 21.792894
#
# Train accuracy so far: 98.908414
#
# loss in epoch 13: 17.433025
#
# Train accuracy so far: 99.135403
#
# loss in epoch 14: 17.744680
#
# Train accuracy so far: 99.140503
#
# loss in epoch 15: 15.539872
#
# Train accuracy so far: 99.201714
#
# loss in epoch 16: 12.003419
#
# Train accuracy so far: 99.469510
#
# loss in epoch 17: 10.891714
#
# Train accuracy so far: 99.472060
#
# loss in epoch 18: 15.106422
#
# Train accuracy so far: 99.227218
#
# loss in epoch 19: 15.437040
#
# Train accuracy so far: 99.242521
#
# accuracy in testing set: 91.163895

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import torchvision
import os
import time



# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


class AdvGAN_Attack:
    def __init__(self,
                 device,
                 model,
                 model_num_labels,
                 image_nc,
                 box_min,
                 box_max):
        output_nc = image_nc
        self.device = device
        self.model_num_labels = model_num_labels
        self.model = model
        self.input_nc = image_nc
        self.output_nc = output_nc
        self.box_min = box_min
        self.box_max = box_max

        self.gen_input_nc = image_nc
        self.netG = Generator(self.gen_input_nc, image_nc).to(device)
        self.netDisc = Discriminator(image_nc).to(device)

        # initialize all weights
        self.netG.apply(weights_init)
        self.netDisc.apply(weights_init)

        # initialize optimizers
        self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                            lr=0.001)
        self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                            lr=0.001)

    def train_batch(self, x, labels):
        # optimize D
        for i in range(1):
            perturbation = self.netG(x)
            pert = 0.05
            
            # add a clipping trick
            adv_images = torch.clamp(perturbation, -pert, pert) + x
            adv_images = torch.clamp(adv_images, self.box_min, self.box_max)

            self.optimizer_D.zero_grad()
            pred_real = self.netDisc(x)
            loss_D_real = F.mse_loss(pred_real, torch.ones_like(pred_real, device=self.device))
            loss_D_real.backward()

            pred_fake = self.netDisc(adv_images.detach())
            loss_D_fake = F.mse_loss(pred_fake, torch.zeros_like(pred_fake, device=self.device))
            loss_D_fake.backward()
            loss_D_GAN = loss_D_fake + loss_D_real
            self.optimizer_D.step()

        # optimize G
        for i in range(1):
            self.optimizer_G.zero_grad()

            # cal G's loss in GAN
            pred_fake = self.netDisc(adv_images)
            loss_G_fake = F.mse_loss(pred_fake, torch.ones_like(pred_fake, device=self.device))
            loss_G_fake.backward(retain_graph=True)

            # calculate perturbation norm
            C = 0.1
            loss_perturb = torch.mean(torch.norm(perturbation.view(perturbation.shape[0], -1), 2, dim=1))
            # loss_perturb = torch.max(loss_perturb - C, torch.zeros(1, device=self.device))
            
            
            # cal adv loss
            logits_model = self.model(adv_images)
            probs_model = F.softmax(logits_model, dim=1)
            #print("logits model")
            #print(logits_model.shape)
            onehot_labels = labels.type(torch.cuda.FloatTensor)   #torch.eye(self.model_num_labels, device=self.device)[labels]
            #print(onehot_labels.shape)
            #print("one hot labels")
            #print(onehot_labels)
            #print(probs_model.shape)
            #print('probs_model')
            #print(probs_model)

            # C&W loss function
            
            real = torch.sum(onehot_labels * probs_model, dim=1)
            other, _ = torch.max((1 - onehot_labels) * probs_model - onehot_labels * 10000, dim=1)
            zeros = torch.zeros_like(other)
            loss_adv = torch.max(real - other, zeros)
            loss_adv = torch.sum(loss_adv)

            # maximize cross_entropy loss
            # loss_adv = -F.mse_loss(logits_model, onehot_labels)
            # loss_adv = - F.cross_entropy(logits_model, labels)

            adv_lambda = 5
            pert_lambda = 1
            loss_G = adv_lambda * loss_adv + pert_lambda * loss_perturb
            loss_G.backward(retain_graph=True)
            self.optimizer_G.step()

        return loss_D_GAN.item(), loss_G_fake.item(), loss_perturb.item(), loss_adv.item()

    def train(self, train_dataloader, epochs):
        t0 = time.time()
        for epoch in range(1, epochs+1):

            if epoch == 50:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.0001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.0001)
            if epoch == 80:
                self.optimizer_G = torch.optim.Adam(self.netG.parameters(),
                                                    lr=0.00001)
                self.optimizer_D = torch.optim.Adam(self.netDisc.parameters(),
                                                    lr=0.00001)
            loss_D_sum = 0
            loss_G_fake_sum = 0
            loss_perturb_sum = 0
            loss_adv_sum = 0
            
            
            #For accuracy calculation
            num_correct = 0
             
            
            for i, data in enumerate(train_dataloader, start=0):
                images, labels = data
                images, labels = images.to(self.device), labels.to(self.device)
                
                perturbation = self.netG(images)
                pert = 0.05
                # add a clipping trick
                adv_images = torch.clamp(perturbation, -pert, pert) + images
                adv_images = torch.clamp(adv_images, self.box_min, self.box_max)
                

                #print('labels shape')
                #print(labels.shape)
                #print('images shape')
                #print(images.shape)
                
                loss_D_batch, loss_G_fake_batch, loss_perturb_batch, loss_adv_batch = \
                    self.train_batch(images, labels)
                loss_D_sum += loss_D_batch
                loss_G_fake_sum += loss_G_fake_batch
                loss_perturb_sum += loss_perturb_batch
                loss_adv_sum += loss_adv_batch
                
                #calculate accuracy
                train_label = torch.argmax(labels,1)
                pred_label = torch.argmax(targeted_model(adv_images), 1)
                num_correct += torch.sum(pred_label==train_label,0)
                

            # print statistics
            num_batch = len(train_dataloader)
            print("epoch %d:\nloss_D: %.3f, loss_G_fake: %.3f,\
             \nloss_perturb: %.3f, loss_adv: %.3f, \n" %
                  (epoch, loss_D_sum/num_batch, loss_G_fake_sum/num_batch,
                   loss_perturb_sum/num_batch, loss_adv_sum/num_batch))
            print('accuracy in training set after perturbation: %f\n'%(100*num_correct.item()/len(train_dataset)))
            
            print('{} seconds'.format(time.time() - t0))
            #plt.imshow(images[10].cpu().permute(1, 2, 0))
            #plt.imshow(adv_images[10].cpu().permute(1, 2, 0))
           

            # save generator
            if epoch%20==0:
                netG_file_name = models_path + 'netG_epoch_' + str(epoch) + '.pth'
                torch.save(self.netG.state_dict(), netG_file_name)


    def test(self, test_dataloader):
        num_correct_test = 0
        num_correct_all = 0
        
        miss = [] #defaultdict(list)
        
        for i, data in enumerate(test_dataloader, 0):
            test_img, test_label = data
            test_img, test_label = test_img.to(device), test_label.to(device)
            #test_img.requires_grad=True
            
            perturbation = self.netG(test_img)
            pert = 0.05
            # add a clipping trick
            adv_images_test = torch.clamp(perturbation, -pert, pert) + test_img
            adv_images_test = torch.clamp(adv_images_test, self.box_min, self.box_max)
            pred_label = targeted_model(adv_images_test)
            pred_lab_test = torch.argmax(pred_label,1)
            
            #first see if the model will just get it wrong on the real image
            output = targeted_model(test_img)
            init_pred = torch.argmax(output,1)
            test_label = torch.argmax(test_label,1)
            
            num_correct_all += torch.sum(pred_lab_test==test_label,0)
            
            
            for j in range(len(init_pred)):
            #if so, move on without adding perturbations
                if (init_pred[j] != test_label[j]):
                    continue
                    
                else:
                    num_correct_test += torch.sum(pred_lab_test[j]==test_label[j],0)
            
                    if pred_lab_test[j] != test_label[j]:
                        if len(miss)<10:
                            adv_ex = adv_images_test[j].squeeze().detach().cpu().numpy()
                            adv_ex = np.transpose(adv_ex, (1,2,0))
                            real_im = test_img[j].squeeze().detach().cpu().numpy()
                            real_im = np.transpose(real_im, (1,2,0))
                            miss.append((sign_names[test_label[j]], real_im, sign_names[pred_lab_test[j]], adv_ex))
        
        print('accuracy in test set on all perturbed images: %f\n'%(100*num_correct_all.item()/len(test_dataset)))
        
        print('misclassifications on previously correctly classified images: %f\n'%(100-(100*num_correct_test.item()/len(test_dataset))))
        
        #print 10 misclassified images
        #ctr=0
        for i in range(len(miss)):
            real,r_image,fake,f_image = miss[i]
            f, axarr = plt.subplots(1,2)
            axarr[0].imshow(r_image)
            axarr[0].set_title('Actual: %s'%(real))
            axarr[1].imshow(f_image)
            axarr[1].set_title('Classified as: %s'%(fake))
            f.tight_layout()
            #plt.title("{} -> {}".format(real,fake))
            #plt.imshow(image,cmap='gray')

            plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

#import torch
import torchvision
import torchvision.datasets
#import torchvision.transforms as transforms
#from torch.utils.data import DataLoader

use_cuda=True
image_nc=3
epochs = 100

batch_size = 128
BOX_MIN = 0
BOX_MAX = 1

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

pretrained_model = "./target_model.pth"
targeted_model = target_net().to(device)
targeted_model.load_state_dict(torch.load(pretrained_model))
targeted_model.eval()

#test to make sure restoring model worked
num_correct2 = 0
for i, data in enumerate(test_dataloader, 0):
    test_img2, test_label2 = data
    test_img2, test_label2 = test_img2.to(device), test_label2.to(device)
    test_label2 = torch.argmax(test_label2,1)
    pred_lab2 = torch.argmax(targeted_model(test_img2), 1)
    num_correct2 += torch.sum(pred_lab2==test_label2,0)

print('accuracy in testing set: %f\n'%(100*num_correct2.item()/len(test_dataset)))


model_num_labels = 43

models_path = "./models/"
if not os.path.exists(models_path):
    os.makedirs(models_path)
            
# train dataset and dataloader declaration
dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=1)
advGAN = AdvGAN_Attack(device,
                          targeted_model,
                          model_num_labels,
                          image_nc,
                          BOX_MIN,
                          BOX_MAX)

advGAN.train(dataloader, epochs)

advGAN.test(test_dataloader)

#ideas for optimizing:
#improve target classifier - stop it from overfitting

#Stephanie is doing:
#color
#p 0.005, 0.01, 0.03, 0.05, 0.1

#Koosha is doing:
#G:D ratio
#filters in G
# Out:
# CUDA Available:  True
# accuracy in testing set: 91.163895
#
# epoch 1:
# loss_D: 0.324, loss_G_fake: 0.391,
# loss_perturb: 16.812, loss_adv: 58.448,
#
# accuracy in training set after perturbation: 48.187916
#
# 8.922510862350464 seconds
# epoch 2:
# loss_D: 0.126, loss_G_fake: 0.654,
# loss_perturb: 12.280, loss_adv: 44.359,
#
# accuracy in training set after perturbation: 36.733913
#
# 17.736196041107178 seconds
# epoch 3:
# loss_D: 0.101, loss_G_fake: 0.736,
# loss_perturb: 11.877, loss_adv: 41.132,
#
# accuracy in training set after perturbation: 34.147772
#
# 26.5648295879364 seconds
# epoch 4:
# loss_D: 0.077, loss_G_fake: 0.796,
# loss_perturb: 11.762, loss_adv: 37.048,
#
# accuracy in training set after perturbation: 30.903619
#
# 35.40025067329407 seconds
# epoch 5:
# loss_D: 0.087, loss_G_fake: 0.801,
# loss_perturb: 10.838, loss_adv: 31.707,
#
# accuracy in training set after perturbation: 26.514321
#
# 44.136078119277954 seconds
# epoch 6:
# loss_D: 0.084, loss_G_fake: 0.818,
# loss_perturb: 10.445, loss_adv: 30.944,
#
# accuracy in training set after perturbation: 25.807850
#
# 52.821129322052 seconds
# epoch 7:
# loss_D: 0.074, loss_G_fake: 0.838,
# loss_perturb: 10.292, loss_adv: 28.841,
#
# accuracy in training set after perturbation: 24.065903
#
# 61.55365180969238 seconds
# epoch 8:
# loss_D: 0.088, loss_G_fake: 0.815,
# loss_perturb: 10.206, loss_adv: 27.278,
#
# accuracy in training set after perturbation: 22.813640
#
# 70.3072783946991 seconds
# epoch 9:
# loss_D: 0.070, loss_G_fake: 0.855,
# loss_perturb: 9.644, loss_adv: 24.844,
#
# accuracy in training set after perturbation: 20.780943
#
# 79.04169034957886 seconds
# epoch 10:
# loss_D: 0.071, loss_G_fake: 0.865,
# loss_perturb: 9.491, loss_adv: 25.026,
#
# accuracy in training set after perturbation: 20.890612
#
# 87.78868913650513 seconds
# epoch 11:
# loss_D: 0.066, loss_G_fake: 0.866,
# loss_perturb: 9.446, loss_adv: 23.476,
#
# accuracy in training set after perturbation: 19.620495
#
# 96.43515920639038 seconds
# epoch 12:
# loss_D: 0.064, loss_G_fake: 0.873,
# loss_perturb: 8.984, loss_adv: 23.863,
#
# accuracy in training set after perturbation: 20.005611
#
# 105.06566166877747 seconds
# epoch 13:
# loss_D: 0.059, loss_G_fake: 0.887,
# loss_perturb: 8.336, loss_adv: 22.056,
#
# accuracy in training set after perturbation: 18.429442
#
# 113.702397108078 seconds
# epoch 14:
# loss_D: 0.058, loss_G_fake: 0.890,
# loss_perturb: 8.345, loss_adv: 22.027,
#
# accuracy in training set after perturbation: 18.465148
#
# 122.33164525032043 seconds
# epoch 15:
# loss_D: 0.059, loss_G_fake: 0.890,
# loss_perturb: 8.498, loss_adv: 21.321,
#
# accuracy in training set after perturbation: 17.802035
#
# 130.95457863807678 seconds
# epoch 16:
# loss_D: 0.055, loss_G_fake: 0.898,
# loss_perturb: 7.956, loss_adv: 19.696,
#
# accuracy in training set after perturbation: 16.373792
#
# 139.55735778808594 seconds
# epoch 17:
# loss_D: 0.060, loss_G_fake: 0.885,
# loss_perturb: 7.614, loss_adv: 19.282,
#
# accuracy in training set after perturbation: 16.111097
#
# 148.189373254776 seconds
# epoch 18:
# loss_D: 0.049, loss_G_fake: 0.902,
# loss_perturb: 8.838, loss_adv: 20.142,
#
# accuracy in training set after perturbation: 16.937438
#
# 156.98945021629333 seconds
# epoch 19:
# loss_D: 0.045, loss_G_fake: 0.903,
# loss_perturb: 8.413, loss_adv: 20.184,
#
# accuracy in training set after perturbation: 16.939988
#
# 165.80015754699707 seconds
# epoch 20:
# loss_D: 0.040, loss_G_fake: 0.915,
# loss_perturb: 7.725, loss_adv: 19.385,
#
# accuracy in training set after perturbation: 16.210564
#
# 174.47939705848694 seconds
# epoch 21:
# loss_D: 0.039, loss_G_fake: 0.915,
# loss_perturb: 7.663, loss_adv: 18.532,
#
# accuracy in training set after perturbation: 15.483690
#
# 183.21805500984192 seconds
# epoch 22:
# loss_D: 0.039, loss_G_fake: 0.914,
# loss_perturb: 7.903, loss_adv: 18.979,
#
# accuracy in training set after perturbation: 15.937667
#
# 191.89973521232605 seconds
# epoch 23:
# loss_D: 0.038, loss_G_fake: 0.926,
# loss_perturb: 7.661, loss_adv: 18.070,
#
# accuracy in training set after perturbation: 15.190390
#
# 200.52855682373047 seconds
# epoch 24:
# loss_D: 0.033, loss_G_fake: 0.935,
# loss_perturb: 7.858, loss_adv: 18.031,
#
# accuracy in training set after perturbation: 15.108776
#
# 209.13398241996765 seconds
# epoch 25:
# loss_D: 0.042, loss_G_fake: 0.912,
# loss_perturb: 7.509, loss_adv: 17.544,
#
# accuracy in training set after perturbation: 14.767018
#
# 217.7667591571808 seconds
# epoch 26:
# loss_D: 0.042, loss_G_fake: 0.908,
# loss_perturb: 7.808, loss_adv: 17.310,
#
# accuracy in training set after perturbation: 14.550231
#
# 226.37869954109192 seconds
# epoch 27:
# loss_D: 0.035, loss_G_fake: 0.931,
# loss_perturb: 7.465, loss_adv: 16.532,
#
# accuracy in training set after perturbation: 13.897319
#
# 235.02363395690918 seconds
# epoch 28:
# loss_D: 0.029, loss_G_fake: 0.942,
# loss_perturb: 7.736, loss_adv: 16.510,
#
# accuracy in training set after perturbation: 13.943227
#
# 243.7479853630066 seconds
# epoch 29:
# loss_D: 0.017, loss_G_fake: 0.947,
# loss_perturb: 8.140, loss_adv: 17.198,
#
# accuracy in training set after perturbation: 14.532378
#
# 252.41158652305603 seconds
# epoch 30:
# loss_D: 0.020, loss_G_fake: 0.948,
# loss_perturb: 7.342, loss_adv: 15.733,
#
# accuracy in training set after perturbation: 13.195950
#
# 261.06951785087585 seconds
# epoch 31:
# loss_D: 0.014, loss_G_fake: 0.957,
# loss_perturb: 7.332, loss_adv: 15.679,
#
# accuracy in training set after perturbation: 13.190849
#
# 269.6881625652313 seconds
# epoch 32:
# loss_D: 0.020, loss_G_fake: 0.947,
# loss_perturb: 6.932, loss_adv: 14.804,
#
# accuracy in training set after perturbation: 12.418067
#
# 278.31700134277344 seconds
# epoch 33:
# loss_D: 0.014, loss_G_fake: 0.957,
# loss_perturb: 7.134, loss_adv: 14.785,
#
# accuracy in training set after perturbation: 12.471626
#
# 287.03638887405396 seconds
# epoch 34:
# loss_D: 0.020, loss_G_fake: 0.952,
# loss_perturb: 7.556, loss_adv: 15.163,
#
# accuracy in training set after perturbation: 12.754725
#
# 295.9328911304474 seconds
# epoch 35:
# loss_D: 0.016, loss_G_fake: 0.952,
# loss_perturb: 7.132, loss_adv: 14.287,
#
# accuracy in training set after perturbation: 11.984493
#
# 304.5594687461853 seconds
# epoch 36:
# loss_D: 0.027, loss_G_fake: 0.942,
# loss_perturb: 7.062, loss_adv: 14.584,
#
# accuracy in training set after perturbation: 12.316050
#
# 313.15239691734314 seconds
# epoch 37:
# loss_D: 0.017, loss_G_fake: 0.958,
# loss_perturb: 7.454, loss_adv: 15.218,
#
# accuracy in training set after perturbation: 12.933255
#
# 321.8349013328552 seconds
# epoch 38:
# loss_D: 0.023, loss_G_fake: 0.950,
# loss_perturb: 7.765, loss_adv: 15.079,
#
# accuracy in training set after perturbation: 12.813385
#
# 330.52366828918457 seconds
# epoch 39:
# loss_D: 0.013, loss_G_fake: 0.964,
# loss_perturb: 7.442, loss_adv: 14.516,
#
# accuracy in training set after perturbation: 12.344105
#
# 339.1519863605499 seconds
# epoch 40:
# loss_D: 0.019, loss_G_fake: 0.951,
# loss_perturb: 7.835, loss_adv: 16.218,
#
# accuracy in training set after perturbation: 13.869265
#
# 347.8149378299713 seconds
# epoch 41:
# loss_D: 0.011, loss_G_fake: 0.958,
# loss_perturb: 7.620, loss_adv: 14.502,
#
# accuracy in training set after perturbation: 12.333903
#
# 356.5520429611206 seconds
# epoch 42:
# loss_D: 0.007, loss_G_fake: 0.967,
# loss_perturb: 7.283, loss_adv: 13.385,
#
# accuracy in training set after perturbation: 11.382591
#
# 365.24677062034607 seconds
# epoch 43:
# loss_D: 0.010, loss_G_fake: 0.962,
# loss_perturb: 6.974, loss_adv: 12.752,
#
# accuracy in training set after perturbation: 10.775587
#
# 373.9043412208557 seconds
# epoch 44:
# loss_D: 0.009, loss_G_fake: 0.969,
# loss_perturb: 7.351, loss_adv: 14.691,
#
# accuracy in training set after perturbation: 12.520085
#
# 382.5400664806366 seconds
# epoch 45:
# loss_D: 0.012, loss_G_fake: 0.968,
# loss_perturb: 7.291, loss_adv: 14.058,
#
# accuracy in training set after perturbation: 11.964090
#
# 391.16591334342957 seconds
# epoch 46:
# loss_D: 0.005, loss_G_fake: 0.972,
# loss_perturb: 6.695, loss_adv: 13.140,
#
# accuracy in training set after perturbation: 11.173455
#
# 399.7900438308716 seconds
# epoch 47:
# loss_D: 0.002, loss_G_fake: 0.982,
# loss_perturb: 6.665, loss_adv: 12.755,
#
# accuracy in training set after perturbation: 10.808743
#
# 408.5057294368744 seconds
# epoch 48:
# loss_D: 0.002, loss_G_fake: 0.982,
# loss_perturb: 7.094, loss_adv: 12.755,
#
# accuracy in training set after perturbation: 10.829146
#
# 417.13518047332764 seconds
# epoch 49:
# loss_D: 0.001, loss_G_fake: 0.984,
# loss_perturb: 6.747, loss_adv: 12.483,
#
# accuracy in training set after perturbation: 10.625112
#
# 425.72278690338135 seconds
# epoch 50:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 6.428, loss_adv: 11.571,
#
# accuracy in training set after perturbation: 9.691652
#
# 434.29756927490234 seconds
# epoch 51:
# loss_D: 0.000, loss_G_fake: 0.989,
# loss_perturb: 5.921, loss_adv: 11.205,
#
# accuracy in training set after perturbation: 9.311638
#
# 442.8784453868866 seconds
# epoch 52:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 5.656, loss_adv: 11.022,
#
# accuracy in training set after perturbation: 9.171364
#
# 451.4459865093231 seconds
# epoch 53:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 5.328, loss_adv: 10.938,
#
# accuracy in training set after perturbation: 9.033640
#
# 460.1043632030487 seconds
# epoch 54:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 5.116, loss_adv: 10.881,
#
# accuracy in training set after perturbation: 8.990283
#
# 468.71377420425415 seconds
# epoch 55:
# loss_D: 0.000, loss_G_fake: 0.990,
# loss_perturb: 4.969, loss_adv: 10.781,
#
# accuracy in training set after perturbation: 8.878064
#
# 477.3017601966858 seconds
# epoch 56:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 4.837, loss_adv: 10.756,
#
# accuracy in training set after perturbation: 8.850009
#
# 485.9919180870056 seconds
# epoch 57:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 4.701, loss_adv: 10.684,
#
# accuracy in training set after perturbation: 8.796450
#
# 494.5954821109772 seconds
# epoch 58:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 4.636, loss_adv: 10.651,
#
# accuracy in training set after perturbation: 8.791349
#
# 503.20125436782837 seconds
# epoch 59:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 4.621, loss_adv: 10.577,
#
# accuracy in training set after perturbation: 8.681680
#
# 511.78784227371216 seconds
# epoch 60:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 4.478, loss_adv: 10.526,
#
# accuracy in training set after perturbation: 8.607718
#
# 520.3488636016846 seconds
# epoch 61:
# loss_D: 0.000, loss_G_fake: 0.991,
# loss_perturb: 4.418, loss_adv: 10.461,
#
# accuracy in training set after perturbation: 8.574562
#
# 528.9375233650208 seconds
# epoch 62:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.422, loss_adv: 10.462,
#
# accuracy in training set after perturbation: 8.630672
#
# 537.5438652038574 seconds
# epoch 63:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.362, loss_adv: 10.385,
#
# accuracy in training set after perturbation: 8.485297
#
# 546.1356523036957 seconds
# epoch 64:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.261, loss_adv: 10.356,
#
# accuracy in training set after perturbation: 8.441939
#
# 554.687658071518 seconds
# epoch 65:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.231, loss_adv: 10.328,
#
# accuracy in training set after perturbation: 8.480196
#
# 563.3370411396027 seconds
# epoch 66:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.203, loss_adv: 10.328,
#
# accuracy in training set after perturbation: 8.434288
#
# 571.9698262214661 seconds
# epoch 67:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.246, loss_adv: 10.331,
#
# accuracy in training set after perturbation: 8.549058
#
# 580.5912194252014 seconds
# epoch 68:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.236, loss_adv: 10.311,
#
# accuracy in training set after perturbation: 8.459792
#
# 589.229730129242 seconds
# epoch 69:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 4.166, loss_adv: 10.219,
#
# accuracy in training set after perturbation: 8.299115
#
# 598.2762529850006 seconds
# epoch 70:
# loss_D: 0.000, loss_G_fake: 0.993,
# loss_perturb: 4.070, loss_adv: 10.197,
#
# accuracy in training set after perturbation: 8.299115
#
# 607.3128292560577 seconds
# epoch 71:
# loss_D: 0.000, loss_G_fake: 0.992,
# loss_perturb: 4.050, loss_adv: 10.200,
#
# accuracy in training set after perturbation: 8.314418
#
# 616.1319513320923 seconds
# epoch 72:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 4.056, loss_adv: 10.192,
#
# accuracy in training set after perturbation: 8.357775
#
# 624.8888018131256 seconds
# epoch 73:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 4.023, loss_adv: 10.137,
#
# accuracy in training set after perturbation: 8.227703
#
# 633.5796272754669 seconds
# epoch 74:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.999, loss_adv: 10.110,
#
# accuracy in training set after perturbation: 8.237905
#
# 642.300793170929 seconds
# epoch 75:
# loss_D: 0.000, loss_G_fake: 0.994,
# loss_perturb: 3.962, loss_adv: 10.064,
#
# accuracy in training set after perturbation: 8.176694
#
# 651.051923751831 seconds
# epoch 76:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.932, loss_adv: 10.062,
#
# accuracy in training set after perturbation: 8.194547
#
# 659.688803434372 seconds
# epoch 77:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.908, loss_adv: 10.009,
#
# accuracy in training set after perturbation: 8.146089
#
# 668.3619556427002 seconds
# epoch 78:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.950, loss_adv: 9.983,
#
# accuracy in training set after perturbation: 8.153740
#
# 676.9694013595581 seconds
# epoch 79:
# loss_D: 0.000, loss_G_fake: 0.995,
# loss_perturb: 3.893, loss_adv: 9.980,
#
# accuracy in training set after perturbation: 8.163942
#
# 685.5732798576355 seconds
# epoch 80:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.921, loss_adv: 9.921,
#
# accuracy in training set after perturbation: 8.018567
#
# 694.2201771736145 seconds
# epoch 81:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.878, loss_adv: 9.898,
#
# accuracy in training set after perturbation: 7.962458
#
# 702.8928818702698 seconds
# epoch 82:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.837, loss_adv: 9.892,
#
# accuracy in training set after perturbation: 7.959907
#
# 711.5667707920074 seconds
# epoch 83:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.802, loss_adv: 9.885,
#
# accuracy in training set after perturbation: 7.957357
#
# 720.277774810791 seconds
# epoch 84:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.771, loss_adv: 9.876,
#
# accuracy in training set after perturbation: 7.949705
#
# 729.061247587204 seconds
# epoch 85:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.744, loss_adv: 9.870,
#
# accuracy in training set after perturbation: 7.942054
#
# 737.6608002185822 seconds
# epoch 86:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.720, loss_adv: 9.870,
#
# accuracy in training set after perturbation: 7.947155
#
# 746.2445337772369 seconds
# epoch 87:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.695, loss_adv: 9.862,
#
# accuracy in training set after perturbation: 7.944605
#
# 754.8806045055389 seconds
# epoch 88:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.677, loss_adv: 9.856,
#
# accuracy in training set after perturbation: 7.942054
#
# 763.5507378578186 seconds
# epoch 89:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.661, loss_adv: 9.848,
#
# accuracy in training set after perturbation: 7.934403
#
# 772.2709484100342 seconds
# epoch 90:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.645, loss_adv: 9.844,
#
# accuracy in training set after perturbation: 7.949705
#
# 780.9253964424133 seconds
# epoch 91:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.631, loss_adv: 9.839,
#
# accuracy in training set after perturbation: 7.929302
#
# 789.5135583877563 seconds
# epoch 92:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.618, loss_adv: 9.833,
#
# accuracy in training set after perturbation: 7.954806
#
# 798.1133105754852 seconds
# epoch 93:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.604, loss_adv: 9.829,
#
# accuracy in training set after perturbation: 7.929302
#
# 806.8524572849274 seconds
# epoch 94:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.602, loss_adv: 9.844,
#
# accuracy in training set after perturbation: 7.939504
#
# 815.5106797218323 seconds
# epoch 95:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.591, loss_adv: 9.831,
#
# accuracy in training set after perturbation: 7.934403
#
# 824.1171128749847 seconds
# epoch 96:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.578, loss_adv: 9.824,
#
# accuracy in training set after perturbation: 7.913999
#
# 832.7239890098572 seconds
# epoch 97:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.569, loss_adv: 9.822,
#
# accuracy in training set after perturbation: 7.924201
#
# 841.4020586013794 seconds
# epoch 98:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.561, loss_adv: 9.819,
#
# accuracy in training set after perturbation: 7.919100
#
# 849.9931781291962 seconds
# epoch 99:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.553, loss_adv: 9.816,
#
# accuracy in training set after perturbation: 7.893596
#
# 858.6029100418091 seconds
# epoch 100:
# loss_D: 0.000, loss_G_fake: 0.996,
# loss_perturb: 3.548, loss_adv: 9.828,
#
# accuracy in training set after perturbation: 7.934403
#
# 867.2392766475677 seconds
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# (32, 32, 3)
# accuracy in test set on all perturbed images: 15.494854
#
# misclassifications on previously correctly classified images: 84.766429
